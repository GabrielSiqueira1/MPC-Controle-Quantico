# %%
# Bilbiotecas para auxílio na programação matemática
import math, sys 
import numpy as np
import sympy as sp

from scipy import sparse # Produção das diagonais das matrizes
from scipy.sparse import diags 

# Plotagem 2D e 3D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm


from os import path # Suficiente para manipulação de arquivos
    
# Para solução exata
from scipy.special import hermite
from math import factorial

# %matplotlib inline
count = 0

# Para otimização dos sistemas
from scipy import optimize

import random

# %%
def somar(A, B):
    C = []
    nLinhasA, nLinhasB = len(A), len(B)
    nColA, nColB = len(A[0]), len(B[0])
    
    for i in range (nLinhasA):
        linha = [0]*nColA
        C.append(linha)
        for j in range(nColA):
            C[i][j] = A[i][j] + B[i][j]

    return C

def sub(A, B):
    C = []
    nLinhasA, nLinhasB = len(A), len(B)
    nColA, nColB = len(A[0]), len(B[0])
    
    for i in range (nLinhasA):
        linha = [0]*nColA
        C.append(linha)
        for j in range(nColA):
            C[i][j] = A[i][j] - B[i][j]

    return C

def dpsidt(t,psi, H):
    A = np.zeros((2,2), dtype=np.complex_)
    A = np.dot(complex(0,1),H)
    #print("A = ",A)
    #print("psi = ",psi)
    return (-1*np.matmul(A,psi))

def rungeKutta(psi0, h, H, t = 2, t0 = 0, p = 0):
    
    n = (int)((t-t0))
    S = np.zeros((2,int(t)), dtype=np.complex_)
    r = 0
    
    for i in range(1 + p, n + 1 + p):
        
        S[0][r] = psi0[0][0]
        S[1][r] = psi0[1][0]
        
        k1 = dpsidt(t0, psi0, H)
        k2 = dpsidt(t0 + 0.5 * h, somar(psi0, np.dot((0.5*h), k1)), H)
        k3 = dpsidt(t0 + 0.5 * h, somar(psi0, np.dot((0.5*h), k2)), H)
        k4 = dpsidt(t0 + h, somar(psi0, np.dot(h, k3)), H)
        
        A = somar(np.dot(2,k3), k4)
        B = somar(np.dot(2,k2), k1)
        C = somar(A, B)
 
        psi0 = somar(psi0,np.dot((h / 6.0),(C)))
    
        t0 = t0 + h
        
        r = r + 1
        
    return S

def fo(x, D, H, i, psi0):
    
    H1 = np.zeros((2,2), dtype=np.complex_)
    #H2 = np.zeros((2,2), dtype=np.complex_)
    
    H1 = [[0, x[0]], [x[0], 0]]
    #H2 = [[0, x[1]], [x[1], 0]]
    
    M = np.zeros((2,1),dtype=np.complex_)
    N = np.zeros((2,1),dtype=np.complex_)
    O = np.zeros((2,1),dtype=np.complex_)
    P = np.zeros((2,1),dtype=np.complex_)
    
    Result1 = np.zeros((2,1),dtype=np.complex_)
    Result2 = np.zeros((2,1),dtype=np.complex_)
    Result3 = np.zeros((2,1),dtype=np.complex_)
    Result4 = np.zeros((2,1),dtype=np.complex_)
    
    M = psi0
    
    Result2 = rungeKutta(M, h, somar(H,H1), t = 2, t0 = 0, p = 0)
    N = [[Result2[0][1]],[Result2[1][1]]]
    
    H1 = [[0, x[1]], [x[1], 0]]
    Result3 = rungeKutta(M, h, somar(H,H1), t = 2, t0 = 0, p = 0)
    O = [[Result3[0][1]],[Result3[1][1]]]
    
    
    Z = np.zeros((2,1),dtype=np.complex_)
    Y = np.zeros((2,1),dtype=np.complex_)
    W = np.zeros((2,1),dtype=np.complex_)
    X = np.zeros((2,1),dtype=np.complex_)
    
    Z[0][0] = D[0][0]*np.exp(-1*complex(0,1)*(1/2*np.pi)*i/100)
    Z[1][0] = D[1][0]*np.exp(-1*complex(0,1)*(3/2*np.pi)*i/100)
    
    Y[0][0] = D[0][0]*np.exp(-1*complex(0,1)*(1/2*np.pi)*(i+1)/100)
    Y[1][0] = D[1][0]*np.exp(-1*complex(0,1)*(3/2*np.pi)*(i+1)/100)
    
    W[0][0] = D[0][0]*np.exp(-1*complex(0,1)*(1/2*np.pi)*(i+2)/100)
    W[1][0] = D[1][0]*np.exp(-1*complex(0,1)*(3/2*np.pi)*(i+2)/100)

    return (np.linalg.norm(Z-M)**2+np.linalg.norm(Y-N)**2+np.linalg.norm(W-O)**2)

def foS(x, alpha, d, D, H, i, psi0):
    
    z = x + np.dot(alpha,d)
    
    H1 = np.zeros((2,2), dtype=np.complex_)
    #H2 = np.zeros((2,2), dtype=np.complex_)
    
    H1 = [[0, z[0]], [z[0], 0]]
    #H2 = [[0, z[1]], [z[1], 0]]
    
    M = np.zeros((2,1),dtype=np.complex_)
    N = np.zeros((2,1),dtype=np.complex_)
    O = np.zeros((2,1),dtype=np.complex_)
    
    Result1 = np.zeros((2,1),dtype=np.complex_)
    Result2 = np.zeros((2,1),dtype=np.complex_)
    Result3 = np.zeros((2,1),dtype=np.complex_)
    
    M = psi0
    
    Result2 = rungeKutta(M, h, somar(H,H1), t = 2, t0 = 0, p = 0)
    N = [[Result2[0][1]],[Result2[1][1]]]
    
    H1 = [[0, z[1]], [z[1], 0]]
    Result3 = rungeKutta(M, h, somar(H,H1), t = 2, t0 = 0, p = 0)
    O = [[Result3[0][1]],[Result3[1][1]]]
    
    
    Z = np.zeros((2,1),dtype=np.complex_)
    Y = np.zeros((2,1),dtype=np.complex_)
    W = np.zeros((2,1),dtype=np.complex_)
    
    Z[0][0] = D[0][0]*np.exp(-1*complex(0,1)*(1/2*np.pi)*i/100)
    Z[1][0] = D[1][0]*np.exp(-1*complex(0,1)*(3/2*np.pi)*i/100)
    
    Y[0][0] = D[0][0]*np.exp(-1*complex(0,1)*(1/2*np.pi)*(i+1)/100)
    Y[1][0] = D[1][0]*np.exp(-1*complex(0,1)*(3/2*np.pi)*(i+1)/100)
    
    W[0][0] = D[0][0]*np.exp(-1*complex(0,1)*(1/2*np.pi)*(i+2)/100)
    W[1][0] = D[1][0]*np.exp(-1*complex(0,1)*(3/2*np.pi)*(i+2)/100)

    return (np.linalg.norm(Z-M)**2+np.linalg.norm(Y-N)**2+np.linalg.norm(W-O)**2)

# %%
def SecaoAurea(d, x, D, H, i, psi0):
    eps = 0.00001
    r1=[]
    r1.append(x[0][0])
    r1.append(x[1][0])
    
    r2=[]
    r2.append(d[0][0])
    r2.append(d[1][0])
    a = 0
    b = 1
    xa = b - 0.618*(b-a)
    xb = a + 0.618*(b-a)
    fxa = foS(r1, xa, r2, D, H, i, psi0)
    fxb = foS(r1, xb, r2, D, H, i, psi0)
    
    while(b - a > eps):
        if(fxa < fxb):
            b = xb
            xb = xa
            xa = b - 0.618*(b - a)
            fxb = fxa
            fxa = foS(r1, xa, r2, D, H, i, psi0)
        else:
            a = xa
            xa = xb
            xb = a + 0.618*(b - a)
            fxa = fxb
            fxb = foS(r1, xb, r2, D, H, i, psi0)
            
    xp = (a+b)/2
    return xp

#Avaliação do gradiente
def gradiente(x, D, H, i, psi0):
    h = 0.0001
    gradiente = np.zeros((len(x), 1))
    
    t = []
    t.append(x[0][0])
    t.append(x[1][0])
    
    for i in range(len(x)):
        xh = t.copy()
        xh[i] = xh[i] + h
        dx = (fo(xh, D, H, i, psi0)-fo(t, D, H, i, psi0))/h
        gradiente[i][0] = dx
    return gradiente

# %%
def MetodoGrad(x, D, H, i, psi0):
    
    n = len(x)
    L = np.identity(n)
    
    grad = gradiente(x, D, H, i, psi0)
    gamma = 0.5
    
    eps = 0.00001
    errox = eps + 1
    xant = x.copy()
    
    k = 0
    kmax = 100
    normagrad = eps + 1
    
    CP = ''
    
    while(CP == ''):
        
        xant = x.copy()
        gradant = grad.copy()
        
        d = -1*(np.matmul(L, grad))
        alpha = SecaoAurea(d, x, D, H, i, psi0)
        
        x = x + alpha * d
        grad = gradiente(x, D, H, i, psi0)
        
        v = x - xant
        r = grad - gradant
        
        A = np.matmul(np.matmul(H,r),r.T)
        
        Cdfp = np.matmul(v,v.T)/np.matmul(v.T,r) - (np.matmul(A,L))/np.matmul(np.matmul(r.T, H),r)
        Cbfgs = ((np.matmul(r.T, v) + np.matmul(np.matmul(r.T,L),r))/(np.matmul(r.T,v)))*((np.matmul(v,v.T))/(np.matmul(v.T, r)))-((np.matmul(np.matmul(v,r.T),L)+(np.matmul(np.matmul(L,r),v.T)))/(np.matmul(r.T,v)))
        
        C = gamma * Cdfp + (1-gamma) * Cbfgs
        
        L = L + C;
        
        xant = x.copy()
        
        normagrad = np.linalg.norm(d)
        if(normagrad <= eps):
            CP = CP + 'Norma Gradiente'
        if(k >= kmax):
            CP = 'Numero de iteracoes'
            
        k += 1
        
    xOtimo = x
    return k, xOtimo, CP

# %%
a = random.uniform(-5., 5.)
x = np.array([[a],[a]]) #Ponto fora da bacia de atração

i = 0

psi0 = [[complex(0.80,0)],[complex(0.60,0)]]
h = 0.01

E = np.zeros((2,2))
I = np.zeros((2,2))
R = np.zeros((2,2), dtype=np.complex_)
H = E.astype(complex)

A = (1/2*np.pi)
B = (3/2*np.pi)

I = [[1, 0], [0, 1]]
H = [[A, 0], [0, B]]
R = H

Resp = np.zeros((2,1000), dtype=np.complex_)

D = np.zeros((2,1), dtype=np.complex_)
D = [[complex(1/np.sqrt(2),0)],[complex(1/np.sqrt(2),0)]]

while i < 1000:
    
    print("iteracao: ", i+1)
    
    Resp[0][i] = psi0[0][0]
    Resp[1][i] = psi0[1][0]
    
    resultado = MetodoGrad(x, D, H, i, psi0)
    
    x = []
    u = np.zeros((2,2))
    a = random.uniform(-5., 5.)
    x = np.array([[a],[a]]) #Ponto fora da bacia de atração
    
    a = resultado[1][0]
    
    u = [[0, a[0]],[a[0], 0]]
        
    i = i + 1
    H = somar(H, u)
    
    psi_t = np.zeros((2,2), dtype=np.complex_)
    
    psi_t = rungeKutta(psi0, h, H, t = 2, t0 = 0, p = 0)
    
    psi0[0][0] = psi_t[0][1]
    psi0[1][0] = psi_t[1][1]
    
    H = [[A, 0], [0, B]]
    
    print(psi0)
# Out:
# iteracao:  1
# [[(0.7997954152255395-0.015607658587660115j)], [(0.5991987421837778-0.03231968527733388j)]]
# iteracao:  2
# [[(0.7998899889904233-0.02264072211105439j)], [(0.5973619449342213-0.05312353381204557j)]]
# iteracao:  3
# [[(0.798238432327429-0.04433658186058276j)], [(0.5933931673969005-0.09345705537955348j)]]
# iteracao:  4
# [[(0.7983538897178625-0.05192509985569833j)], [(0.5888923645980317-0.11463260144694257j)]]
# iteracao:  5
# [[(0.7974072773469828-0.06460153414816029j)], [(0.5828198723126405-0.1424404149820937j)]]
# iteracao:  6
# [[(0.7992632817878124-0.06588161095387053j)], [(0.5770938410060453-0.15427416485076814j)]]
# iteracao:  7
# [[(0.7896949176813648-0.10373030975605399j)], [(0.5645857611684758-0.21648296639665127j)]]
# iteracao:  8
# [[(0.7964452663668061-0.09443510177515792j)], [(0.5583202138391011-0.21221565599177392j)]]
# iteracao:  9
# [[(0.7955216082665376-0.10534544684686664j)], [(0.5480451976441888-0.23599611331570608j)]]
# iteracao:  10
# [[(0.7895643098953785-0.1265659461136995j)], [(0.5341383873693616-0.27434547793339303j)]]
# iteracao:  11
# [[(0.7859526983579913-0.14168593645552136j)], [(0.5198268538289209-0.3032877999633025j)]]
# iteracao:  12
# [[(0.7888289932445153-0.14551893852493597j)], [(0.507655293882714-0.3144187601377926j)]]
# iteracao:  13
# [[(0.7946352215406152-0.14511136191500942j)], [(0.4964723357430448-0.31782506717541587j)]]
# iteracao:  14
# [[(0.7912076634400671-0.15910085278329744j)], [(0.48041345592644014-0.343336947335849j)]]
# iteracao:  15
# [[(0.7861775289764925-0.17466981510841204j)], [(0.46245632882695-0.3708766486820985j)]]
# iteracao:  16
# [[(0.7669327404718301-0.2052569173968647j)], [(0.4359491051387988-0.42383032104745777j)]]
# iteracao:  17
# [[(0.7604488400472392-0.2203106512411931j)], [(0.4138401994755727-0.44935182393398126j)]]
# iteracao:  18
# [[(0.7769814222672561-0.21395326878028675j)], [(0.40282435254455407-0.43388524145105967j)]]
# iteracao:  19
# [[(0.7854410515041278-0.21540668766699272j)], [(0.3883086830242021-0.4311596846494189j)]]
# iteracao:  20
# [[(0.7997025301561377-0.21194773765471414j)], [(0.3772178831630359-0.41624593891124684j)]]
# iteracao:  21
# [[(0.7994541985885801-0.22175294433564474j)], [(0.35895420122083294-0.42761020884144696j)]]
# iteracao:  22
# [[(0.8154512617242985-0.21792746630776086j)], [(0.34953778782342215-0.40665733364690443j)]]
# iteracao:  23
# [[(0.8229882997819993-0.22146016596163284j)], [(0.3364947701994035-0.4005208057354782j)]]
# iteracao:  24
# [[(0.8086761285921895-0.24252802954154273j)], [(0.31085258580304703-0.43657042525049106j)]]
# iteracao:  25
# [[(0.798522239822713-0.2592811419029628j)], [(0.2862113496142615-0.4617559718308127j)]]
# iteracao:  26
# [[(0.7971671202732531-0.2701531695889896j)], [(0.2658468366655326-0.46996521033615785j)]]
# iteracao:  27
# [[(0.7959136490661265-0.2810052449032564j)], [(0.24532434396878805-0.47683694693950796j)]]
# iteracao:  28
# [[(0.7953746636706489-0.2915605052769964j)], [(0.22510831835736222-0.48135003196400933j)]]
# iteracao:  29
# [[(0.8043138477379833-0.2978982737374058j)], [(0.2111326512750174-0.4687844370377017j)]]
# iteracao:  30
# [[(0.7980715213420349-0.3110968358858448j)], [(0.18782201417754488-0.4806490283616049j)]]
# iteracao:  31
# [[(0.7716313418257723-0.33065337721580523j)], [(0.15048917506340653-0.5221172421796633j)]]
# iteracao:  32
# [[(0.7403285165199053-0.3487318122352534j)], [(0.10863944676117959-0.5643556222653214j)]]
# iteracao:  33
# [[(0.7582217722166713-0.3561224694673832j)], [(0.09765975710742339-0.5373444790983539j)]]
# iteracao:  34
# [[(0.7567544330325273-0.3673423833244931j)], [(0.0752197106593086-0.5354664163956013j)]]
# iteracao:  35
# [[(0.7629952570065837-0.37774695009972864j)], [(0.05884239757157179-0.5212322304699021j)]]
# iteracao:  36
# [[(0.7708353832008219-0.3883913497407521j)], [(0.04507106304644136-0.5029250013020854j)]]
# iteracao:  37
# [[(0.7801639872015378-0.3993250716675708j)], [(0.03432729278543282-0.48031787720525826j)]]
# iteracao:  38
# [[(0.7757031769669951-0.4114503097881121j)], [(0.013348020464242914-0.47834615094029287j)]]
# iteracao:  39
# [[(0.7572446905767727-0.42341426422472767j)], [(-0.01982437647024324-0.49689819796047296j)]]
# iteracao:  40
# [[(0.7271157057068839-0.4331811541821247j)], [(-0.06354425719470384-0.5287900802907892j)]]
# iteracao:  41
# [[(0.7196151450380013-0.4444561949471069j)], [(-0.08890791586483748-0.5260305121535737j)]]
# iteracao:  42
# [[(0.7139924544517952-0.45599500518824526j)], [(-0.11229385796793322-0.5193008791309697j)]]
# iteracao:  43
# [[(0.7073299500485637-0.46730009481496054j)], [(-0.13608564132638618-0.512635976797969j)]]
# iteracao:  44
# [[(0.6971770796405246-0.47753273458333445j)], [(-0.16269587956830117-0.5093492329155083j)]]
# iteracao:  45
# [[(0.6642582671549362-0.4791471261579591j)], [(-0.21058247914557388-0.5336984038859625j)]]
# iteracao:  46
# [[(0.5440786279149992-0.4370008823665986j)], [(-0.32667920495395686-0.6374074067889878j)]]
# iteracao:  47
# [[(0.5388488811699357-0.4464330622965395j)], [(-0.3551078246971664-0.6198682655479545j)]]
# iteracao:  48
# [[(0.5335658865352116-0.4559463327535605j)], [(-0.38254302584782696-0.6008993670456477j)]]
# iteracao:  49
# [[(0.5284207611052022-0.4656897842248568j)], [(-0.40874780789681764-0.5803693506109979j)]]
# iteracao:  50
# [[(0.540712346582992-0.48867600857362065j)], [(-0.41837636011348484-0.542020264329812j)]]
# iteracao:  51
# [[(0.5180547620426933-0.4848031523375914j)], [(-0.45734019983174545-0.5361193308478377j)]]
# iteracao:  52
# [[(0.5136335637686754-0.4958405528209321j)], [(-0.47893963599147976-0.5108212619115199j)]]
# iteracao:  53
# [[(0.5105455282790418-0.5086029355935413j)], [(-0.49750416952983145-0.4828610015856091j)]]
# iteracao:  54
# [[(0.5113625416980029-0.5262953912577158j)], [(-0.509541462313097-0.4493193053367012j)]]
# iteracao:  55
# [[(0.5223569600410446-0.5576811253760766j)], [(-0.5047473457649216-0.4017012716872046j)]]
# iteracao:  56
# /tmp/ipykernel_27971/1208971206.py:35: RuntimeWarning: divide by zero encountered in divide
#   Cdfp = np.matmul(v,v.T)/np.matmul(v.T,r) - (np.matmul(A,L))/np.matmul(np.matmul(r.T, H),r)
# /tmp/ipykernel_27971/1208971206.py:35: RuntimeWarning: invalid value encountered in divide
#   Cdfp = np.matmul(v,v.T)/np.matmul(v.T,r) - (np.matmul(A,L))/np.matmul(np.matmul(r.T, H),r)
# /tmp/ipykernel_27971/1208971206.py:36: RuntimeWarning: invalid value encountered in divide
#   Cbfgs = ((np.matmul(r.T, v) + np.matmul(np.matmul(r.T,L),r))/(np.matmul(r.T,v)))*((np.matmul(v,v.T))/(np.matmul(v.T, r)))-((np.matmul(np.matmul(v,r.T),L)+(np.matmul(np.matmul(L,r),v.T)))/(np.matmul(r.T,v)))
# /tmp/ipykernel_27971/1208971206.py:36: RuntimeWarning: divide by zero encountered in divide
#   Cbfgs = ((np.matmul(r.T, v) + np.matmul(np.matmul(r.T,L),r))/(np.matmul(r.T,v)))*((np.matmul(v,v.T))/(np.matmul(v.T, r)))-((np.matmul(np.matmul(v,r.T),L)+(np.matmul(np.matmul(L,r),v.T)))/(np.matmul(r.T,v)))
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  57
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  58
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  59
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  60
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  61
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  62
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  63
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  64
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  65
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  66
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  67
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  68
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  69
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  70
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  71
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  72
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  73
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  74
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  75
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  76
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  77
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  78
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  79
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  80
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  81
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  82
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  83
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  84
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  85
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  86
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  87
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  88
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  89
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  90
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  91
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  92
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  93
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  94
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  95
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  96
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  97
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  98
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  99
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  100
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  101
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  102
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  103
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  104
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  105
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  106
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  107
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  108
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  109
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  110
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  111
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  112
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  113
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  114
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  115
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  116
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  117
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  118
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  119
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  120
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  121
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  122
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  123
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  124
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  125
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  126
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  127
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  128
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  129
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  130
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  131
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  132
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  133
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  134
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  135
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  136
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  137
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  138
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  139
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  140
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  141
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  142
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  143
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  144
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  145
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  146
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  147
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  148
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  149
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  150
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  151
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  152
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  153
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  154
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  155
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  156
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  157
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  158
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  159
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  160
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  161
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  162
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  163
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  164
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  165
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  166
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  167
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  168
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  169
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  170
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  171
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  172
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  173
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  174
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  175
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  176
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  177
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  178
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  179
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  180
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  181
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  182
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  183
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  184
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  185
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  186
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  187
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  188
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  189
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  190
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  191
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  192
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  193
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  194
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  195
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  196
# [[(nan+nanj)], [(nan+nanj)]]
# iteracao:  197
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [5], line 33
#      30 Resp[0][i] = psi0[0][0]
#      31 Resp[1][i] = psi0[1][0]
# ---> 33 resultado = MetodoGrad(x, D, H, i, psi0)
#      35 x = []
#      36 u = np.zeros((2,2))
#
# Cell In [4], line 25, in MetodoGrad(x, D, H, i, psi0)
#      22 gradant = grad.copy()
#      24 d = -1*(np.matmul(L, grad))
# ---> 25 alpha = SecaoAurea(d, x, D, H, i, psi0)
#      27 x = x + alpha * d
#      28 grad = gradiente(x, D, H, i, psi0)
#
# Cell In [3], line 29, in SecaoAurea(d, x, D, H, i, psi0)
#      27         xb = a + 0.618*(b - a)
#      28         fxa = fxb
# ---> 29         fxb = foS(r1, xb, r2, D, H, i, psi0)
#      31 xp = (a+b)/2
#      32 return xp
#
# Cell In [2], line 130, in foS(x, alpha, d, D, H, i, psi0)
#     127 N = [[Result2[0][1]],[Result2[1][1]]]
#     129 H1 = [[0, z[1]], [z[1], 0]]
# --> 130 Result3 = rungeKutta(M, h, somar(H,H1), t = 2, t0 = 0, p = 0)
#     131 O = [[Result3[0][1]],[Result3[1][1]]]
#     134 Z = np.zeros((2,1),dtype=np.complex_)
#
# Cell In [2], line 47, in rungeKutta(psi0, h, H, t, t0, p)
#      45 k1 = dpsidt(t0, psi0, H)
#      46 k2 = dpsidt(t0 + 0.5 * h, somar(psi0, np.dot((0.5*h), k1)), H)
# ---> 47 k3 = dpsidt(t0 + 0.5 * h, somar(psi0, np.dot((0.5*h), k2)), H)
#      48 k4 = dpsidt(t0 + h, somar(psi0, np.dot(h, k3)), H)
#      50 A = somar(np.dot(2,k3), k4)
#
# Cell In [2], line 10, in somar(A, B)
#       8     C.append(linha)
#       9     for j in range(nColA):
# ---> 10         C[i][j] = A[i][j] + B[i][j]
#      12 return C
#
# KeyboardInterrupt:

# %%
len(Resp[0])

# %%
ts = np.linspace(0, 10, 1000)

x = [ele.real for ele in Resp[0]] 
y = [ele.imag for ele in Resp[0]] 

plt.ylabel('Real') 
plt.xlabel('Tempo') 
plt.plot(ts, x, color='r', marker='*', linewidth=1, markersize=1)

p = []

for i in range(0, 1000):
    p.append(1/np.sqrt(2)*np.exp(-1*complex(0,1)*(1/2*np.pi)*i/100))

plt.plot(ts, p, color='b', marker='o',  linewidth=1, markersize=1)
plt.savefig('rk_000.png', format='png')
plt.show()

# %%
ts = np.linspace(0, 10, 1000)

x = [ele.real for ele in Resp[1]] 
y = [ele.imag for ele in Resp[1]] 

plt.ylabel('Real') 
plt.xlabel('Tempo') 
plt.plot(ts, x, color='r', marker='*', linewidth=1, markersize=1)

p = []

for i in range(0, 1000):
    p.append(1/np.sqrt(2)*np.exp(-3*complex(0,1)*(1/2*np.pi)*i/100))

plt.plot(ts, p, color='b', marker='o',  linewidth=1, markersize=1)
plt.savefig('rk_111.png', format='png')
plt.show()
