# %% [markdown]
# # <center>Algoritmo Genético<center>

# %% [markdown]
# Nome: Fernando Veizaga, Gabriel Siqueira

# %%
from random import randint,uniform,random
from tqdm import tqdm
import numpy as np

# %%
# x = [0, 10]
LIMITE_INFERIOR = 0
LIMITE_SUPERIOR = 10
SIZE_POP = 100 # Tamanho da população
QTD_VAR = 2 # Quantidade de variáveis 
QTD_GERACOES = 100 # Número de loops 
TAXA_CRUZAMENTO = 0.70
TAXA_MUTACAO = 0.01
QTD_TROCA = 2 # Número de trocas na mutação

# %%
def funcao_objetivo(x):
    return (np.sqrt(x[0])*np.sin(x[0]))*(np.sqrt(x[1])*np.sin(x[1]))

# %%
def somar(fit):
    sfit = np.zeros(SIZE_POP)
    sfit[0] = fit[0]
    for i in range(1, SIZE_POP):
        for j in range(0, i+1):
            sfit[i] += fit[j]
    
    return sfit

# %%
# populacao[individuo, pos] => individuo_1 -> x0 e x1, individuo_2 -> x0 e x1
def geraca_populacao():
    populacao = np.zeros((SIZE_POP,QTD_VAR))
    for individuo in range(SIZE_POP):
        for pos in range(QTD_VAR):
            populacao[individuo,pos] = uniform(LIMITE_INFERIOR, LIMITE_SUPERIOR)
    return populacao

# %%
def calcula_fo(pop):
    valor_fo = np.zeros(SIZE_POP) # Valor da função objetivo para cada individuo
    for individuo in range(SIZE_POP):
        valor_fo[individuo] = funcao_objetivo(pop[individuo,:]) # x0 e x1 de um individuo
    return valor_fo

# %%
def fitness(valor_fo):
    return valor_fo # Fitness é a própria função objetivo

# %%
def selecao(valor_fitness, soma_fitness):
    valor = uniform(0, soma_fitness[SIZE_POP-1])
    
    for i in range(0, SIZE_POP):
        if soma_fitness[i] >= valor:
            return i

# %%
def cruzamento(pai1,pai2):
    x = random()
    filho1 = x*pai1+(1-x)*pai2
    filho2 = (1-x)*pai1+x*pai2
    return filho1,filho2

# %%
def mutacao(individuo):
    
    if random() < TAXA_MUTACAO:
        individuo[0] = uniform(LIMITE_INFERIOR, LIMITE_SUPERIOR)
    
    if random() < TAXA_MUTACAO:
        individuo[1] = uniform(LIMITE_INFERIOR, LIMITE_SUPERIOR)
    
    return individuo

# %%
import matplotlib.pyplot as plt

# %%
def main_ga():
    pop = geraca_populacao()
    fo = calcula_fo(pop)
    fit = fitness(fo)
    sfit = somar(fit)
    aux_pior = 0
    melhor_fo = np.zeros(QTD_GERACOES)
    pior_fo = np.zeros(QTD_GERACOES)
    med_fo = np.zeros(QTD_GERACOES)
    melhor_ind_geracao = np.zeros((QTD_GERACOES, QTD_VAR))
    for geracao in range(QTD_GERACOES):
        new_pop = np.empty((0, QTD_VAR))
        for i in range(round((SIZE_POP) / 2)):
            pai1 = selecao(fit, sfit)
            pai2 = selecao(fit, sfit)
            if random() < TAXA_CRUZAMENTO:
                filho1, filho2 = cruzamento(pop[pai1, :], pop[pai2, :]) 
                filho1 = mutacao(filho1)
                filho2 = mutacao(filho2)  
                new_pop = np.vstack([new_pop, filho1, filho2])     
            else:
                pais = np.vstack([mutacao(pop[pai1, :]), mutacao(pop[pai2, :])])
                new_pop = np.vstack([new_pop, pais])
        pop = new_pop    
        fo = calcula_fo(pop)
        fit = fitness(fo)
        sfit = somar(fit)
        max_fo = max(fo)
        if aux_pior == 0:
            min_fo = max(fo)
            aux_pior = 1
            for l in range(len(fo)):
                if fo[l] == max_fo:
                    pior = l
        else:
            min_fo = fo[pior]
            
        media_fo = (max_fo+min_fo)/2
            
        melhor_fo[geracao] = max_fo
        pior_fo[geracao] = min_fo
        med_fo[geracao] = media_fo
        pos_max_fo = np.where(fo == max_fo)

    
    plt.plot(melhor_fo)
    plt.plot(pior_fo)
    plt.plot(med_fo)
    plt.xlim(0, QTD_GERACOES)
    plt.ylabel('Gerações')
    plt.ylabel('')
    plt.title('Evolução da função objetivo - GA')
    plt.grid(True)
    plt.show()
    

    return pop[pos_max_fo,:][0,0]

# %%
minimo = main_ga()

# %%
minimo
# Out:
# array([7.62707536, 7.95194816])
