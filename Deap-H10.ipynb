# %% [markdown]
# ## Algoritmo Genético
#
# No jupyter anterior utilizamos o algoritmo Gradiente Decrescente para otimizar a função objetivo, afim de comparações, dessa vez utilizaremos um algoritmo genético.

# %%
from random import randint, uniform, random
from tqdm import tqdm
import numpy as np

# %%
# Manipulação das matrizes

def somar(A, B):
    C = []
    nLinhasA, nLinhasB = len(A), len(B)
    nColA, nColB = len(A[0]), len(B[0])
    
    for i in range (nLinhasA):
        linha = [0]*nColA
        C.append(linha)
        for j in range(nColA):
            C[i][j] = A[i][j] + B[i][j]

    return C

def sub(A, B):
    C = []
    nLinhasA, nLinhasB = len(A), len(B)
    nColA, nColB = len(A[0]), len(B[0])
    
    for i in range (nLinhasA):
        linha = [0]*nColA
        C.append(linha)
        for j in range(nColA):
            C[i][j] = A[i][j] - B[i][j]

    return C


#################################################################

## d (psi) / dt = -i * H * |psi>
def dpsidt(t, psi, H): # A derivada da onda em relação ao tempo não tem dependência temporal
    A = np.zeros((2,2), dtype=np.complex_)
    A = np.dot(complex(0,1),H) # i * H
    return -1*np.matmul(A,psi) # - i * H * |psi>

# Runge-Kutta de quarta ordem

def rungeKutta(onda, fatorRungeKutta, hamiltoniano, tempoFinal = 2, tempoInicial = 0):
    
    resultado = np.zeros((2,2), dtype=np.complex_)
    indice = 0

    for i in range(0, 2):
        
        resultado[0][indice] = onda[0][0]
        resultado[1][indice] = onda[1][0]
        
        k1 = dpsidt(tempoInicial, onda, hamiltoniano)
        k2 = dpsidt(tempoInicial + 0.5 * fatorRungeKutta, somar(onda, np.dot((0.5*fatorRungeKutta), k1)), hamiltoniano)
        k3 = dpsidt(tempoInicial + 0.5 * fatorRungeKutta, somar(onda, np.dot((0.5*fatorRungeKutta), k2)), hamiltoniano)
        k4 = dpsidt(tempoInicial + fatorRungeKutta, somar(onda, np.dot(fatorRungeKutta, k3)), hamiltoniano)
        
        ## y(i+1) = y(i) + h/6*(k1+2*k2+2*k3+k4)
        
        A = somar(np.dot(2,k3), k4)
        B = somar(np.dot(2,k2), k1)
        C = somar(A, B)
 
        onda = somar(onda,np.dot((fatorRungeKutta / 6.0),(C)))
    
        tempoInicial += fatorRungeKutta
        
        indice += 1
        
    runge = np.zeros((2,1), dtype=np.complex_)
    runge[0][0] = resultado[0][indice-1]
    runge[1][0] = resultado[1][indice-1]
    return runge

def funcaoObjetivo(x, iteracao, ondaDestino, hamiltoniano, onda, horizonteAnalisavel, fatorRungeKutta, tempoAnalise):
    
    avanco = np.zeros((2,1),dtype=np.complex_)
    
    y = 0
    
    horizonte = (horizonteAnalisavel+iteracao)/100
    
    tempo = iteracao/100
    
    tempoInicialAnalise = 0.00
    tempoFinalAnalise = 0.02
    
    controles = np.zeros((2,2), dtype=np.complex_)
    controles = [[0, x[0]], [x[0], 0]]
    
    matrizOrigem = np.zeros((2,1),dtype=np.complex_)
    matrizOrigem = [[onda[0][0]], [onda[1][0]]] 

    matrizDestino = np.zeros((2,1),dtype=np.complex_)
    
    ## Função-Objetivo (Return) = somatorio ||(Matriz_Origem - Matriz_Destino)||^2
    
    ## Avanço temporal
    
    matrizDestino[0][0] = ondaDestino[0][0]*np.exp(-1*complex(0,1)*(1/2*np.pi)*tempo)
    matrizDestino[1][0] = ondaDestino[1][0]*np.exp(-1*complex(0,1)*(3/2*np.pi)*tempo)

    y += (np.linalg.norm(matrizOrigem-matrizDestino))**2

    avanco = rungeKutta(matrizOrigem, fatorRungeKutta, somar(hamiltoniano, controles), tempoFinal = tempoFinalAnalise, tempoInicial = tempoInicialAnalise)

    matrizOrigem = avanco

    tempoInicialAnalise += 0.01
    tempoFinalAnalise += 0.01
    
    for indice in range((iteracao+1), (horizonteAnalisavel+iteracao)):
        tempo = indice/100
        
        matrizDestino[0][0] = ondaDestino[0][0]*np.exp(-1*complex(0,1)*(1/2*np.pi)*tempo)
        matrizDestino[1][0] = ondaDestino[1][0]*np.exp(-1*complex(0,1)*(3/2*np.pi)*tempo)
        
        y += (np.linalg.norm(matrizOrigem-matrizDestino))**2
        
        controles = [[0, x[int(tempoInicialAnalise*100)]], [x[int(tempoInicialAnalise*100)], 0]]

        avanco = rungeKutta(matrizOrigem, fatorRungeKutta, somar(hamiltoniano, controles), tempoFinal = tempoFinalAnalise, tempoInicial = tempoInicialAnalise)

        matrizOrigem = avanco

        tempoInicialAnalise += 0.01
        tempoFinalAnalise += 0.01
    
    return y

# %%
import matplotlib.pyplot as plt

# %%
import random
import numpy as np
from deap import algorithms, base, creator, tools

hamiltoniano = np.zeros((2,2), dtype=np.complex_) # Hamiltoniano
A = (1/2*np.pi)
B = (3/2*np.pi)
hamiltoniano = [[A, 0], [0, B]]
fatorRungeKutta = 0.01

iteracao = 0
fatorRungeKutta = 0.01
tempoAnalise = 2000
horizonte = 10

ondaOrigem = [[complex(1.0,0.0)],[complex(0.0,0.0)]]
ondaDestino = [[complex(1/np.sqrt(2),0)],[complex(1/np.sqrt(2),0)]]


def evaluate(individual, iteracao, ondaDestino, hamiltoniano, ondaOrigem, horizonteAnalisavel, fatorRungeKutta, tempoAnalise):
    teste = funcaoObjetivo(individual, iteracao, ondaDestino, hamiltoniano, ondaOrigem, horizonteAnalisavel, fatorRungeKutta, tempoAnalise)
    return teste.item(),

while iteracao < tempoAnalise:
    # Criando o objeto Fitness
    creator.create("FitnessMin", base.Fitness, weights=(-1.0,))

    # Criando o objeto Individual
    creator.create("Individual", list, fitness=creator.FitnessMin)

    # Criando o Toolbox
    toolbox = base.Toolbox()

    # Registrando o gerador de números aleatórios
    toolbox.register("attr_float", random.uniform, -5.0, 5.0)

    # Registrando o inicializador de indivíduos
    toolbox.register("individual", tools.initCycle, creator.Individual,
                     (toolbox.attr_float, toolbox.attr_float, toolbox.attr_float,
                     toolbox.attr_float, toolbox.attr_float, toolbox.attr_float,
                     toolbox.attr_float, toolbox.attr_float, toolbox.attr_float,
                     toolbox.attr_float), n=1)

    # Registrando a população
    toolbox.register("population", tools.initRepeat, list, toolbox.individual)

    # Registrando a função objetivo
    toolbox.register("evaluate", evaluate, iteracao=iteracao, ondaDestino=ondaDestino , hamiltoniano=hamiltoniano , ondaOrigem=ondaOrigem , horizonteAnalisavel=horizonte, fatorRungeKutta=fatorRungeKutta, tempoAnalise=tempoAnalise)

    # Registrando os operadores genéticos
    toolbox.register("mate", tools.cxBlend, alpha=0.5)
    toolbox.register("mutate", tools.mutGaussian, mu=0.0, sigma=0.2, indpb=0.1)
    toolbox.register("select", tools.selTournament, tournsize=3)

    # Criando a população inicial
    pop = toolbox.population(n=10)

    # Avaliando a população inicial
    fitnesses = list(map(toolbox.evaluate, pop))
    for ind, fit in zip(pop, fitnesses):
        ind.fitness.values = fit

    # Executando o algoritmo genético
    for g in range(10):
        # Selecionando os indivíduos para cruzamento
        selected = toolbox.select(pop, len(pop))
        # Clonando os indivíduos selecionados
        offspring = [toolbox.clone(ind) for ind in selected]
        # Realizando o cruzamento e a mutação
        for child1, child2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < 0.5:
                toolbox.mate(child1, child2)
            toolbox.mutate(child1)
            toolbox.mutate(child2)
            del child1.fitness.values, child2.fitness.values
        # Avaliando os novos indivíduos gerados
        invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
        fitnesses = list(map(toolbox.evaluate, invalid_ind))
        for ind, fit in zip(invalid_ind, fitnesses):
            ind.fitness.values = fit
        # Substituindo a população antiga pela nova
        pop[:] = offspring

    # Exibindo o melhor indivíduo encontrado
    best_ind = tools.selBest(pop, 1)[0]
    print("Melhor solução encontrada: f(X) = %.2f" % (best_ind.fitness.values[0]))
    
    controle = np.zeros((2,1), dtype=np.complex_)
    controle = [[0, sum(best_ind.fitness.values)],[sum(best_ind.fitness.values),0]]
    hamiltoniano = somar(hamiltoniano, controle)

    ondaAvancada = np.zeros((2,2), dtype=np.complex_)
    ondaAvancada = rungeKutta(ondaOrigem, fatorRungeKutta, hamiltoniano, tempoFinal = 0.02, tempoInicial = 0)

    ondaOrigem[0][0] = ondaAvancada[0][0]
    ondaOrigem[1][0] = ondaAvancada[1][0]

    A = (1/2*np.pi)
    B = (3/2*np.pi)
    hamiltoniano = [[A, 0], [0, B]]
    
    iteracao += 1
# Out:
# Melhor solução encontrada: f(X) = 5.76
# C:\Users\Gabriel\anaconda3\lib\site-packages\deap\creator.py:138: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# C:\Users\Gabriel\anaconda3\lib\site-packages\deap\creator.py:138: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# Melhor solução encontrada: f(X) = 5.78
# Melhor solução encontrada: f(X) = 5.85
# Melhor solução encontrada: f(X) = 5.86
# Melhor solução encontrada: f(X) = 5.96
# Melhor solução encontrada: f(X) = 6.06
# Melhor solução encontrada: f(X) = 6.15
# Melhor solução encontrada: f(X) = 6.27
# Melhor solução encontrada: f(X) = 6.41
# Melhor solução encontrada: f(X) = 6.56
# Melhor solução encontrada: f(X) = 6.81
# Melhor solução encontrada: f(X) = 7.10
# Melhor solução encontrada: f(X) = 7.21
# Melhor solução encontrada: f(X) = 7.69
# Melhor solução encontrada: f(X) = 7.99
# Melhor solução encontrada: f(X) = 8.70
# Melhor solução encontrada: f(X) = 8.77
# Melhor solução encontrada: f(X) = 9.82
# Melhor solução encontrada: f(X) = 10.08
# Melhor solução encontrada: f(X) = 10.87
# Melhor solução encontrada: f(X) = 11.24
# Melhor solução encontrada: f(X) = 13.47
# Melhor solução encontrada: f(X) = 14.58
# Melhor solução encontrada: f(X) = 15.98
# Melhor solução encontrada: f(X) = 18.03
# Melhor solução encontrada: f(X) = 20.45
# Melhor solução encontrada: f(X) = 22.07
# Melhor solução encontrada: f(X) = 24.69
# Melhor solução encontrada: f(X) = 27.18
# Melhor solução encontrada: f(X) = 29.72
# Melhor solução encontrada: f(X) = 31.84
# Melhor solução encontrada: f(X) = 33.16
# Melhor solução encontrada: f(X) = 32.32
# Melhor solução encontrada: f(X) = 29.63
# Melhor solução encontrada: f(X) = 26.91
# Melhor solução encontrada: f(X) = 23.05
# Melhor solução encontrada: f(X) = 20.70
# Melhor solução encontrada: f(X) = 16.76
# Melhor solução encontrada: f(X) = 16.17
# Melhor solução encontrada: f(X) = 13.27
# Melhor solução encontrada: f(X) = 12.79
# Melhor solução encontrada: f(X) = 10.69
# Melhor solução encontrada: f(X) = 9.81
# Melhor solução encontrada: f(X) = 9.10
# Melhor solução encontrada: f(X) = 8.66
# Melhor solução encontrada: f(X) = 7.02
# Melhor solução encontrada: f(X) = 6.36
# Melhor solução encontrada: f(X) = 6.16
# Melhor solução encontrada: f(X) = 5.61
# Melhor solução encontrada: f(X) = 4.59
# Melhor solução encontrada: f(X) = 4.66
# Melhor solução encontrada: f(X) = 4.63
# Melhor solução encontrada: f(X) = 4.15
# Melhor solução encontrada: f(X) = 4.34
# Melhor solução encontrada: f(X) = 4.16
# Melhor solução encontrada: f(X) = 3.63
# Melhor solução encontrada: f(X) = 3.42
# Melhor solução encontrada: f(X) = 3.17
# Melhor solução encontrada: f(X) = 2.96
# Melhor solução encontrada: f(X) = 2.86
# Melhor solução encontrada: f(X) = 2.81
# Melhor solução encontrada: f(X) = 2.64
# Melhor solução encontrada: f(X) = 2.78
# Melhor solução encontrada: f(X) = 2.50
# Melhor solução encontrada: f(X) = 2.41
# Melhor solução encontrada: f(X) = 2.72
# Melhor solução encontrada: f(X) = 2.29
# Melhor solução encontrada: f(X) = 2.19
# Melhor solução encontrada: f(X) = 2.15
# Melhor solução encontrada: f(X) = 2.08
# Melhor solução encontrada: f(X) = 2.04
# Melhor solução encontrada: f(X) = 1.99
# Melhor solução encontrada: f(X) = 1.96
# Melhor solução encontrada: f(X) = 1.96
# Melhor solução encontrada: f(X) = 1.91
# Melhor solução encontrada: f(X) = 1.84
# Melhor solução encontrada: f(X) = 1.81
# Melhor solução encontrada: f(X) = 1.79
# Melhor solução encontrada: f(X) = 1.76
# Melhor solução encontrada: f(X) = 1.73
# Melhor solução encontrada: f(X) = 1.71
# Melhor solução encontrada: f(X) = 1.69
# Melhor solução encontrada: f(X) = 1.67
# Melhor solução encontrada: f(X) = 1.64
# Melhor solução encontrada: f(X) = 1.63
# Melhor solução encontrada: f(X) = 1.61
# Melhor solução encontrada: f(X) = 1.60
# Melhor solução encontrada: f(X) = 1.59
# Melhor solução encontrada: f(X) = 1.58
# Melhor solução encontrada: f(X) = 1.57
# Melhor solução encontrada: f(X) = 1.56
# Melhor solução encontrada: f(X) = 1.55
# Melhor solução encontrada: f(X) = 1.55
# Melhor solução encontrada: f(X) = 1.55
# Melhor solução encontrada: f(X) = 1.55
# Melhor solução encontrada: f(X) = 1.55
# Melhor solução encontrada: f(X) = 1.54
# Melhor solução encontrada: f(X) = 1.55
# Melhor solução encontrada: f(X) = 1.55
# Melhor solução encontrada: f(X) = 1.55
# Melhor solução encontrada: f(X) = 1.56
# Melhor solução encontrada: f(X) = 1.56
# Melhor solução encontrada: f(X) = 1.58
# Melhor solução encontrada: f(X) = 1.59
# Melhor solução encontrada: f(X) = 1.59
# Melhor solução encontrada: f(X) = 1.63
# Melhor solução encontrada: f(X) = 1.63
# Melhor solução encontrada: f(X) = 1.64
# Melhor solução encontrada: f(X) = 1.67
# Melhor solução encontrada: f(X) = 1.69
# Melhor solução encontrada: f(X) = 1.69
# Melhor solução encontrada: f(X) = 1.71
# Melhor solução encontrada: f(X) = 1.82
# Melhor solução encontrada: f(X) = 1.78
# Melhor solução encontrada: f(X) = 1.83
# Melhor solução encontrada: f(X) = 1.84
# Melhor solução encontrada: f(X) = 1.88
# Melhor solução encontrada: f(X) = 1.89
# Melhor solução encontrada: f(X) = 2.10
# Melhor solução encontrada: f(X) = 2.09
# Melhor solução encontrada: f(X) = 2.11
# Melhor solução encontrada: f(X) = 2.07
# Melhor solução encontrada: f(X) = 2.41
# Melhor solução encontrada: f(X) = 2.44
# Melhor solução encontrada: f(X) = 2.48
# Melhor solução encontrada: f(X) = 2.50
# Melhor solução encontrada: f(X) = 2.74
# Melhor solução encontrada: f(X) = 2.61
# Melhor solução encontrada: f(X) = 2.93
# Melhor solução encontrada: f(X) = 3.20
# Melhor solução encontrada: f(X) = 3.93
# Melhor solução encontrada: f(X) = 3.60
# Melhor solução encontrada: f(X) = 4.13
# Melhor solução encontrada: f(X) = 4.23
# Melhor solução encontrada: f(X) = 4.50
# Melhor solução encontrada: f(X) = 4.55
# Melhor solução encontrada: f(X) = 6.13
# Melhor solução encontrada: f(X) = 5.80
# Melhor solução encontrada: f(X) = 5.92
# Melhor solução encontrada: f(X) = 6.62
# Melhor solução encontrada: f(X) = 7.96
# Melhor solução encontrada: f(X) = 8.65
# Melhor solução encontrada: f(X) = 10.28
# Melhor solução encontrada: f(X) = 11.94
# Melhor solução encontrada: f(X) = 13.97
# Melhor solução encontrada: f(X) = 17.08
# Melhor solução encontrada: f(X) = 19.38
# Melhor solução encontrada: f(X) = 23.32
# Melhor solução encontrada: f(X) = 25.94
# Melhor solução encontrada: f(X) = 30.59
# Melhor solução encontrada: f(X) = 33.70
# Melhor solução encontrada: f(X) = 36.31
# Melhor solução encontrada: f(X) = 37.37
# Melhor solução encontrada: f(X) = 34.61
# Melhor solução encontrada: f(X) = 29.81
# Melhor solução encontrada: f(X) = 25.72
# Melhor solução encontrada: f(X) = 19.97
# Melhor solução encontrada: f(X) = 17.70
# Melhor solução encontrada: f(X) = 14.60
# Melhor solução encontrada: f(X) = 13.03
# Melhor solução encontrada: f(X) = 10.53
# Melhor solução encontrada: f(X) = 8.54
# Melhor solução encontrada: f(X) = 6.22
# Melhor solução encontrada: f(X) = 5.42
# Melhor solução encontrada: f(X) = 5.84
# Melhor solução encontrada: f(X) = 5.45
# Melhor solução encontrada: f(X) = 5.18
# Melhor solução encontrada: f(X) = 4.68
# Melhor solução encontrada: f(X) = 3.81
# Melhor solução encontrada: f(X) = 3.42
# Melhor solução encontrada: f(X) = 3.32
# Melhor solução encontrada: f(X) = 2.95
# Melhor solução encontrada: f(X) = 3.08
# Melhor solução encontrada: f(X) = 2.43
# Melhor solução encontrada: f(X) = 2.85
# Melhor solução encontrada: f(X) = 2.29
# Melhor solução encontrada: f(X) = 2.22
# Melhor solução encontrada: f(X) = 2.23
# Melhor solução encontrada: f(X) = 1.85
# Melhor solução encontrada: f(X) = 1.94
# Melhor solução encontrada: f(X) = 1.72
# Melhor solução encontrada: f(X) = 1.67
# Melhor solução encontrada: f(X) = 2.00
# Melhor solução encontrada: f(X) = 1.82
# Melhor solução encontrada: f(X) = 1.51
# Melhor solução encontrada: f(X) = 1.58
# Melhor solução encontrada: f(X) = 1.52
# Melhor solução encontrada: f(X) = 1.46
# Melhor solução encontrada: f(X) = 1.42
# Melhor solução encontrada: f(X) = 1.39
# Melhor solução encontrada: f(X) = 1.34
# Melhor solução encontrada: f(X) = 1.33
# Melhor solução encontrada: f(X) = 1.32
# Melhor solução encontrada: f(X) = 1.27
# Melhor solução encontrada: f(X) = 1.29
# Melhor solução encontrada: f(X) = 1.26
# Melhor solução encontrada: f(X) = 1.31
# Melhor solução encontrada: f(X) = 1.22
# Melhor solução encontrada: f(X) = 1.22
# Melhor solução encontrada: f(X) = 1.20
# Melhor solução encontrada: f(X) = 1.18
# Melhor solução encontrada: f(X) = 1.18
# Melhor solução encontrada: f(X) = 1.16
# Melhor solução encontrada: f(X) = 1.16
# Melhor solução encontrada: f(X) = 1.15
# Melhor solução encontrada: f(X) = 1.14
# Melhor solução encontrada: f(X) = 1.14
# Melhor solução encontrada: f(X) = 1.13
# Melhor solução encontrada: f(X) = 1.12
# Melhor solução encontrada: f(X) = 1.12
# Melhor solução encontrada: f(X) = 1.11
# Melhor solução encontrada: f(X) = 1.11
# Melhor solução encontrada: f(X) = 1.11
# Melhor solução encontrada: f(X) = 1.11
# Melhor solução encontrada: f(X) = 1.10
# Melhor solução encontrada: f(X) = 1.10
# Melhor solução encontrada: f(X) = 1.11
# Melhor solução encontrada: f(X) = 1.10
# Melhor solução encontrada: f(X) = 1.11
# Melhor solução encontrada: f(X) = 1.11
# Melhor solução encontrada: f(X) = 1.11
# Melhor solução encontrada: f(X) = 1.12
# Melhor solução encontrada: f(X) = 1.13
# Melhor solução encontrada: f(X) = 1.12
# Melhor solução encontrada: f(X) = 1.13
# Melhor solução encontrada: f(X) = 1.13
# Melhor solução encontrada: f(X) = 1.15
# Melhor solução encontrada: f(X) = 1.15
# Melhor solução encontrada: f(X) = 1.16
# Melhor solução encontrada: f(X) = 1.18
# Melhor solução encontrada: f(X) = 1.18
# Melhor solução encontrada: f(X) = 1.20
# Melhor solução encontrada: f(X) = 1.22
# Melhor solução encontrada: f(X) = 1.22
# Melhor solução encontrada: f(X) = 1.24
# Melhor solução encontrada: f(X) = 1.27
# Melhor solução encontrada: f(X) = 1.29
# Melhor solução encontrada: f(X) = 1.29
# Melhor solução encontrada: f(X) = 1.33
# Melhor solução encontrada: f(X) = 1.35
# Melhor solução encontrada: f(X) = 1.39
# Melhor solução encontrada: f(X) = 1.40
# Melhor solução encontrada: f(X) = 1.41
# Melhor solução encontrada: f(X) = 1.45
# Melhor solução encontrada: f(X) = 1.54
# Melhor solução encontrada: f(X) = 1.53
# Melhor solução encontrada: f(X) = 1.56
# Melhor solução encontrada: f(X) = 1.60
# Melhor solução encontrada: f(X) = 1.65
# Melhor solução encontrada: f(X) = 1.68
# Melhor solução encontrada: f(X) = 1.75
# Melhor solução encontrada: f(X) = 1.84
# Melhor solução encontrada: f(X) = 1.85
# Melhor solução encontrada: f(X) = 1.91
# Melhor solução encontrada: f(X) = 1.95
# Melhor solução encontrada: f(X) = 2.01
# Melhor solução encontrada: f(X) = 2.09
# Melhor solução encontrada: f(X) = 2.14
# Melhor solução encontrada: f(X) = 2.23
# Melhor solução encontrada: f(X) = 2.30
# Melhor solução encontrada: f(X) = 2.39
# Melhor solução encontrada: f(X) = 2.50
# Melhor solução encontrada: f(X) = 2.57
# Melhor solução encontrada: f(X) = 2.78
# Melhor solução encontrada: f(X) = 2.92
# Melhor solução encontrada: f(X) = 2.88
# Melhor solução encontrada: f(X) = 3.08
# Melhor solução encontrada: f(X) = 3.30
# Melhor solução encontrada: f(X) = 3.40
# Melhor solução encontrada: f(X) = 3.55
# Melhor solução encontrada: f(X) = 3.66
# Melhor solução encontrada: f(X) = 4.30
# Melhor solução encontrada: f(X) = 4.20
# Melhor solução encontrada: f(X) = 4.75
# Melhor solução encontrada: f(X) = 4.93
# Melhor solução encontrada: f(X) = 5.09
# Melhor solução encontrada: f(X) = 5.33
# Melhor solução encontrada: f(X) = 5.91
# Melhor solução encontrada: f(X) = 6.61
# Melhor solução encontrada: f(X) = 6.93
# Melhor solução encontrada: f(X) = 7.33
# Melhor solução encontrada: f(X) = 8.42
# Melhor solução encontrada: f(X) = 8.83
# Melhor solução encontrada: f(X) = 9.99
# Melhor solução encontrada: f(X) = 10.77
# Melhor solução encontrada: f(X) = 12.36
# Melhor solução encontrada: f(X) = 13.61
# Melhor solução encontrada: f(X) = 15.58
# Melhor solução encontrada: f(X) = 17.51
# Melhor solução encontrada: f(X) = 19.36
# Melhor solução encontrada: f(X) = 21.92
# Melhor solução encontrada: f(X) = 25.38
# Melhor solução encontrada: f(X) = 27.38
# Melhor solução encontrada: f(X) = 30.67
# Melhor solução encontrada: f(X) = 32.26
# Melhor solução encontrada: f(X) = 33.18
# Melhor solução encontrada: f(X) = 31.96
# Melhor solução encontrada: f(X) = 30.11
# Melhor solução encontrada: f(X) = 26.17
# Melhor solução encontrada: f(X) = 23.67
# Melhor solução encontrada: f(X) = 20.91
# Melhor solução encontrada: f(X) = 18.19
# Melhor solução encontrada: f(X) = 15.90
# Melhor solução encontrada: f(X) = 14.30
# Melhor solução encontrada: f(X) = 13.13
# Melhor solução encontrada: f(X) = 11.69
# Melhor solução encontrada: f(X) = 10.70
# Melhor solução encontrada: f(X) = 9.23
# Melhor solução encontrada: f(X) = 8.86
# Melhor solução encontrada: f(X) = 8.53
# Melhor solução encontrada: f(X) = 8.14
# Melhor solução encontrada: f(X) = 7.52
# Melhor solução encontrada: f(X) = 7.18
# Melhor solução encontrada: f(X) = 7.11
# Melhor solução encontrada: f(X) = 6.62
# Melhor solução encontrada: f(X) = 6.39
# Melhor solução encontrada: f(X) = 6.30
# Melhor solução encontrada: f(X) = 6.10
# Melhor solução encontrada: f(X) = 5.97
# Melhor solução encontrada: f(X) = 5.98
# Melhor solução encontrada: f(X) = 5.83
# Melhor solução encontrada: f(X) = 5.91
# Melhor solução encontrada: f(X) = 5.75
# Melhor solução encontrada: f(X) = 5.77
# Melhor solução encontrada: f(X) = 5.75
# Melhor solução encontrada: f(X) = 5.77
# Melhor solução encontrada: f(X) = 5.77
# Melhor solução encontrada: f(X) = 5.80
# Melhor solução encontrada: f(X) = 5.88
# Melhor solução encontrada: f(X) = 5.95
# Melhor solução encontrada: f(X) = 6.05
# Melhor solução encontrada: f(X) = 6.12
# Melhor solução encontrada: f(X) = 6.34
# Melhor solução encontrada: f(X) = 6.36
# Melhor solução encontrada: f(X) = 6.59
# Melhor solução encontrada: f(X) = 6.82
# Melhor solução encontrada: f(X) = 7.09
# Melhor solução encontrada: f(X) = 7.22
# Melhor solução encontrada: f(X) = 7.51
# Melhor solução encontrada: f(X) = 8.09
# Melhor solução encontrada: f(X) = 8.38
# Melhor solução encontrada: f(X) = 8.73
# Melhor solução encontrada: f(X) = 9.52
# Melhor solução encontrada: f(X) = 10.16
# Melhor solução encontrada: f(X) = 10.91
# Melhor solução encontrada: f(X) = 12.36
# Melhor solução encontrada: f(X) = 12.71
# Melhor solução encontrada: f(X) = 14.03
# Melhor solução encontrada: f(X) = 15.32
# Melhor solução encontrada: f(X) = 18.15
# Melhor solução encontrada: f(X) = 19.34
# Melhor solução encontrada: f(X) = 22.79
# Melhor solução encontrada: f(X) = 24.09
# Melhor solução encontrada: f(X) = 27.62
# Melhor solução encontrada: f(X) = 29.49
# Melhor solução encontrada: f(X) = 32.21
# Melhor solução encontrada: f(X) = 33.14
# Melhor solução encontrada: f(X) = 32.40
# Melhor solução encontrada: f(X) = 30.20
# Melhor solução encontrada: f(X) = 26.70
# Melhor solução encontrada: f(X) = 23.22
# Melhor solução encontrada: f(X) = 20.77
# Melhor solução encontrada: f(X) = 18.59
# Melhor solução encontrada: f(X) = 15.66
# Melhor solução encontrada: f(X) = 13.05
# Melhor solução encontrada: f(X) = 11.96
# Melhor solução encontrada: f(X) = 10.60
# Melhor solução encontrada: f(X) = 9.38
# Melhor solução encontrada: f(X) = 8.65
# Melhor solução encontrada: f(X) = 6.79
# Melhor solução encontrada: f(X) = 6.91
# Melhor solução encontrada: f(X) = 7.27
# Melhor solução encontrada: f(X) = 6.14
# Melhor solução encontrada: f(X) = 5.50
# Melhor solução encontrada: f(X) = 5.29
# Melhor solução encontrada: f(X) = 5.09
# Melhor solução encontrada: f(X) = 4.61
# Melhor solução encontrada: f(X) = 4.51
# Melhor solução encontrada: f(X) = 4.32
# Melhor solução encontrada: f(X) = 3.75
# Melhor solução encontrada: f(X) = 3.76
# Melhor solução encontrada: f(X) = 3.49
# Melhor solução encontrada: f(X) = 3.25
# Melhor solução encontrada: f(X) = 3.17
# Melhor solução encontrada: f(X) = 2.82
# Melhor solução encontrada: f(X) = 2.89
# Melhor solução encontrada: f(X) = 2.98
# Melhor solução encontrada: f(X) = 2.68
# Melhor solução encontrada: f(X) = 2.65
# Melhor solução encontrada: f(X) = 2.46
# Melhor solução encontrada: f(X) = 2.31
# Melhor solução encontrada: f(X) = 2.27
# Melhor solução encontrada: f(X) = 2.23
# Melhor solução encontrada: f(X) = 2.14
# Melhor solução encontrada: f(X) = 2.12
# Melhor solução encontrada: f(X) = 2.04
# Melhor solução encontrada: f(X) = 1.97
# Melhor solução encontrada: f(X) = 2.11
# Melhor solução encontrada: f(X) = 1.89
# Melhor solução encontrada: f(X) = 1.90
# Melhor solução encontrada: f(X) = 1.85
# Melhor solução encontrada: f(X) = 1.79
# Melhor solução encontrada: f(X) = 1.76
# Melhor solução encontrada: f(X) = 1.73
# Melhor solução encontrada: f(X) = 1.70
# Melhor solução encontrada: f(X) = 1.70
# Melhor solução encontrada: f(X) = 1.66
# Melhor solução encontrada: f(X) = 1.63
# Melhor solução encontrada: f(X) = 1.61
# Melhor solução encontrada: f(X) = 1.59
# Melhor solução encontrada: f(X) = 1.58
# Melhor solução encontrada: f(X) = 1.56
# Melhor solução encontrada: f(X) = 1.55
# Melhor solução encontrada: f(X) = 1.54
# Melhor solução encontrada: f(X) = 1.53
# Melhor solução encontrada: f(X) = 1.52
# Melhor solução encontrada: f(X) = 1.51
# Melhor solução encontrada: f(X) = 1.51
# Melhor solução encontrada: f(X) = 1.50
# Melhor solução encontrada: f(X) = 1.49
# Melhor solução encontrada: f(X) = 1.50
# Melhor solução encontrada: f(X) = 1.50
# Melhor solução encontrada: f(X) = 1.49
# Melhor solução encontrada: f(X) = 1.49
# Melhor solução encontrada: f(X) = 1.50
# Melhor solução encontrada: f(X) = 1.50
# Melhor solução encontrada: f(X) = 1.50
# Melhor solução encontrada: f(X) = 1.51
# Melhor solução encontrada: f(X) = 1.53
# Melhor solução encontrada: f(X) = 1.54
# Melhor solução encontrada: f(X) = 1.53
# Melhor solução encontrada: f(X) = 1.55
# Melhor solução encontrada: f(X) = 1.57
# Melhor solução encontrada: f(X) = 1.57
# Melhor solução encontrada: f(X) = 1.60
# Melhor solução encontrada: f(X) = 1.62
# Melhor solução encontrada: f(X) = 1.64
# Melhor solução encontrada: f(X) = 1.65
# Melhor solução encontrada: f(X) = 1.72
# Melhor solução encontrada: f(X) = 1.71
# Melhor solução encontrada: f(X) = 1.70
# Melhor solução encontrada: f(X) = 1.76
# Melhor solução encontrada: f(X) = 1.80
# Melhor solução encontrada: f(X) = 1.85
# Melhor solução encontrada: f(X) = 1.85
# Melhor solução encontrada: f(X) = 1.91
# Melhor solução encontrada: f(X) = 2.07
# Melhor solução encontrada: f(X) = 2.04
# Melhor solução encontrada: f(X) = 2.40
# Melhor solução encontrada: f(X) = 2.21
# Melhor solução encontrada: f(X) = 2.17
# Melhor solução encontrada: f(X) = 2.33
# Melhor solução encontrada: f(X) = 2.30
# Melhor solução encontrada: f(X) = 2.61
# Melhor solução encontrada: f(X) = 2.60
# Melhor solução encontrada: f(X) = 2.80
# Melhor solução encontrada: f(X) = 3.40
# Melhor solução encontrada: f(X) = 3.25
# Melhor solução encontrada: f(X) = 3.99
# Melhor solução encontrada: f(X) = 3.77
# Melhor solução encontrada: f(X) = 4.24
# Melhor solução encontrada: f(X) = 4.33
# Melhor solução encontrada: f(X) = 4.44
# Melhor solução encontrada: f(X) = 4.83
# Melhor solução encontrada: f(X) = 5.41
# Melhor solução encontrada: f(X) = 5.66
# Melhor solução encontrada: f(X) = 7.11
# Melhor solução encontrada: f(X) = 7.87
# Melhor solução encontrada: f(X) = 9.20
# Melhor solução encontrada: f(X) = 9.31
# Melhor solução encontrada: f(X) = 10.55
# Melhor solução encontrada: f(X) = 13.69
# Melhor solução encontrada: f(X) = 16.29
# Melhor solução encontrada: f(X) = 17.99
# Melhor solução encontrada: f(X) = 20.47
# Melhor solução encontrada: f(X) = 23.89
# Melhor solução encontrada: f(X) = 28.36
# Melhor solução encontrada: f(X) = 32.43
# Melhor solução encontrada: f(X) = 35.05
# Melhor solução encontrada: f(X) = 37.57
# Melhor solução encontrada: f(X) = 34.96
# Melhor solução encontrada: f(X) = 32.91
# Melhor solução encontrada: f(X) = 26.51
# Melhor solução encontrada: f(X) = 23.16
# Melhor solução encontrada: f(X) = 18.44
# Melhor solução encontrada: f(X) = 15.04
# Melhor solução encontrada: f(X) = 13.60
# Melhor solução encontrada: f(X) = 10.35
# Melhor solução encontrada: f(X) = 9.23
# Melhor solução encontrada: f(X) = 8.89
# Melhor solução encontrada: f(X) = 7.48
# Melhor solução encontrada: f(X) = 6.72
# Melhor solução encontrada: f(X) = 5.83
# Melhor solução encontrada: f(X) = 5.67
# Melhor solução encontrada: f(X) = 4.20
# Melhor solução encontrada: f(X) = 4.08
# Melhor solução encontrada: f(X) = 3.92
# Melhor solução encontrada: f(X) = 3.47
# Melhor solução encontrada: f(X) = 3.49
# Melhor solução encontrada: f(X) = 2.67
# Melhor solução encontrada: f(X) = 2.93
# Melhor solução encontrada: f(X) = 2.59
# Melhor solução encontrada: f(X) = 2.58
# Melhor solução encontrada: f(X) = 2.28
# Melhor solução encontrada: f(X) = 2.39
# Melhor solução encontrada: f(X) = 2.09
# Melhor solução encontrada: f(X) = 1.97
# Melhor solução encontrada: f(X) = 1.86
# Melhor solução encontrada: f(X) = 1.86
# Melhor solução encontrada: f(X) = 1.93
# Melhor solução encontrada: f(X) = 1.71
# Melhor solução encontrada: f(X) = 1.86
# Melhor solução encontrada: f(X) = 1.69
# Melhor solução encontrada: f(X) = 1.64
# Melhor solução encontrada: f(X) = 1.59
# Melhor solução encontrada: f(X) = 1.48
# Melhor solução encontrada: f(X) = 1.44
# Melhor solução encontrada: f(X) = 1.41
# Melhor solução encontrada: f(X) = 1.35
# Melhor solução encontrada: f(X) = 1.34
# Melhor solução encontrada: f(X) = 1.33
# Melhor solução encontrada: f(X) = 1.39
# Melhor solução encontrada: f(X) = 1.29
# Melhor solução encontrada: f(X) = 1.27
# Melhor solução encontrada: f(X) = 1.27
# Melhor solução encontrada: f(X) = 1.26
# Melhor solução encontrada: f(X) = 1.23
# Melhor solução encontrada: f(X) = 1.22
# Melhor solução encontrada: f(X) = 1.22
# Melhor solução encontrada: f(X) = 1.21
# Melhor solução encontrada: f(X) = 1.21
# Melhor solução encontrada: f(X) = 1.19
# Melhor solução encontrada: f(X) = 1.18
# Melhor solução encontrada: f(X) = 1.18
# Melhor solução encontrada: f(X) = 1.17
# Melhor solução encontrada: f(X) = 1.16
# Melhor solução encontrada: f(X) = 1.16
# Melhor solução encontrada: f(X) = 1.15
# Melhor solução encontrada: f(X) = 1.15
# Melhor solução encontrada: f(X) = 1.15
# Melhor solução encontrada: f(X) = 1.14
# Melhor solução encontrada: f(X) = 1.15
# Melhor solução encontrada: f(X) = 1.14
# Melhor solução encontrada: f(X) = 1.14
# Melhor solução encontrada: f(X) = 1.15
# Melhor solução encontrada: f(X) = 1.15
# Melhor solução encontrada: f(X) = 1.15
# Melhor solução encontrada: f(X) = 1.15
# Melhor solução encontrada: f(X) = 1.16
# Melhor solução encontrada: f(X) = 1.17
# Melhor solução encontrada: f(X) = 1.17
# Melhor solução encontrada: f(X) = 1.17
# Melhor solução encontrada: f(X) = 1.19
# Melhor solução encontrada: f(X) = 1.20
# Melhor solução encontrada: f(X) = 1.19
# Melhor solução encontrada: f(X) = 1.21
# Melhor solução encontrada: f(X) = 1.23
# Melhor solução encontrada: f(X) = 1.24
# Melhor solução encontrada: f(X) = 1.25
# Melhor solução encontrada: f(X) = 1.26
# Melhor solução encontrada: f(X) = 1.29
# Melhor solução encontrada: f(X) = 1.29
# Melhor solução encontrada: f(X) = 1.33
# Melhor solução encontrada: f(X) = 1.34
# Melhor solução encontrada: f(X) = 1.38
# Melhor solução encontrada: f(X) = 1.38
# Melhor solução encontrada: f(X) = 1.40
# Melhor solução encontrada: f(X) = 1.44
# Melhor solução encontrada: f(X) = 1.46
# Melhor solução encontrada: f(X) = 1.48
# Melhor solução encontrada: f(X) = 1.51
# Melhor solução encontrada: f(X) = 1.55
# Melhor solução encontrada: f(X) = 1.60
# Melhor solução encontrada: f(X) = 1.64
# Melhor solução encontrada: f(X) = 1.68
# Melhor solução encontrada: f(X) = 1.71
# Melhor solução encontrada: f(X) = 1.79
# Melhor solução encontrada: f(X) = 1.77
# Melhor solução encontrada: f(X) = 1.88
# Melhor solução encontrada: f(X) = 1.91
# Melhor solução encontrada: f(X) = 1.95
# Melhor solução encontrada: f(X) = 2.10
# Melhor solução encontrada: f(X) = 2.13
# Melhor solução encontrada: f(X) = 2.17
# Melhor solução encontrada: f(X) = 2.19
# Melhor solução encontrada: f(X) = 2.27
# Melhor solução encontrada: f(X) = 2.44
# Melhor solução encontrada: f(X) = 2.56
# Melhor solução encontrada: f(X) = 2.55
# Melhor solução encontrada: f(X) = 2.66
# Melhor solução encontrada: f(X) = 2.74
# Melhor solução encontrada: f(X) = 2.88
# Melhor solução encontrada: f(X) = 3.21
# Melhor solução encontrada: f(X) = 3.26
# Melhor solução encontrada: f(X) = 3.36
# Melhor solução encontrada: f(X) = 3.50
# Melhor solução encontrada: f(X) = 3.64
# Melhor solução encontrada: f(X) = 3.84
# Melhor solução encontrada: f(X) = 4.14
# Melhor solução encontrada: f(X) = 4.35
# Melhor solução encontrada: f(X) = 4.58
# Melhor solução encontrada: f(X) = 4.89
# Melhor solução encontrada: f(X) = 5.06
# Melhor solução encontrada: f(X) = 6.01
# Melhor solução encontrada: f(X) = 6.21
# Melhor solução encontrada: f(X) = 6.76
# Melhor solução encontrada: f(X) = 6.55
# Melhor solução encontrada: f(X) = 7.73
# Melhor solução encontrada: f(X) = 7.96
# Melhor solução encontrada: f(X) = 9.41
# Melhor solução encontrada: f(X) = 10.07
# Melhor solução encontrada: f(X) = 11.39
# Melhor solução encontrada: f(X) = 12.74
# Melhor solução encontrada: f(X) = 15.02
# Melhor solução encontrada: f(X) = 16.44
# Melhor solução encontrada: f(X) = 18.60
# Melhor solução encontrada: f(X) = 21.37
# Melhor solução encontrada: f(X) = 22.35
# Melhor solução encontrada: f(X) = 25.06
# Melhor solução encontrada: f(X) = 28.89
# Melhor solução encontrada: f(X) = 31.25
# Melhor solução encontrada: f(X) = 32.76
# Melhor solução encontrada: f(X) = 33.40
# Melhor solução encontrada: f(X) = 31.73
# Melhor solução encontrada: f(X) = 28.43
# Melhor solução encontrada: f(X) = 25.98
# Melhor solução encontrada: f(X) = 22.79
# Melhor solução encontrada: f(X) = 19.75
# Melhor solução encontrada: f(X) = 17.63
# Melhor solução encontrada: f(X) = 14.95
# Melhor solução encontrada: f(X) = 14.00
# Melhor solução encontrada: f(X) = 11.73
# Melhor solução encontrada: f(X) = 11.10
# Melhor solução encontrada: f(X) = 10.45
# Melhor solução encontrada: f(X) = 8.68
# Melhor solução encontrada: f(X) = 8.83
# Melhor solução encontrada: f(X) = 8.02
# Melhor solução encontrada: f(X) = 7.78
# Melhor solução encontrada: f(X) = 7.39
# Melhor solução encontrada: f(X) = 6.68
# Melhor solução encontrada: f(X) = 6.34
# Melhor solução encontrada: f(X) = 6.44
# Melhor solução encontrada: f(X) = 6.21
# Melhor solução encontrada: f(X) = 5.86
# Melhor solução encontrada: f(X) = 5.67
# Melhor solução encontrada: f(X) = 5.58
# Melhor solução encontrada: f(X) = 5.55
# Melhor solução encontrada: f(X) = 5.52
# Melhor solução encontrada: f(X) = 5.41
# Melhor solução encontrada: f(X) = 5.37
# Melhor solução encontrada: f(X) = 5.34
# Melhor solução encontrada: f(X) = 5.34
# Melhor solução encontrada: f(X) = 5.30
# Melhor solução encontrada: f(X) = 5.34
# Melhor solução encontrada: f(X) = 5.36
# Melhor solução encontrada: f(X) = 5.41
# Melhor solução encontrada: f(X) = 5.39
# Melhor solução encontrada: f(X) = 5.49
# Melhor solução encontrada: f(X) = 5.59
# Melhor solução encontrada: f(X) = 5.69
# Melhor solução encontrada: f(X) = 5.81
# Melhor solução encontrada: f(X) = 5.95
# Melhor solução encontrada: f(X) = 6.16
# Melhor solução encontrada: f(X) = 6.27
# Melhor solução encontrada: f(X) = 6.48
# Melhor solução encontrada: f(X) = 6.76
# Melhor solução encontrada: f(X) = 6.93
# Melhor solução encontrada: f(X) = 7.21
# Melhor solução encontrada: f(X) = 7.46
# Melhor solução encontrada: f(X) = 8.03
# Melhor solução encontrada: f(X) = 8.28
# Melhor solução encontrada: f(X) = 9.31
# Melhor solução encontrada: f(X) = 10.33
# Melhor solução encontrada: f(X) = 11.04
# Melhor solução encontrada: f(X) = 11.42
# Melhor solução encontrada: f(X) = 12.70
# Melhor solução encontrada: f(X) = 14.96
# Melhor solução encontrada: f(X) = 16.01
# Melhor solução encontrada: f(X) = 18.07
# Melhor solução encontrada: f(X) = 19.42
# Melhor solução encontrada: f(X) = 22.46
# Melhor solução encontrada: f(X) = 25.53
# Melhor solução encontrada: f(X) = 27.76
# Melhor solução encontrada: f(X) = 29.35
# Melhor solução encontrada: f(X) = 31.51
# Melhor solução encontrada: f(X) = 33.48
# Melhor solução encontrada: f(X) = 32.73
# Melhor solução encontrada: f(X) = 29.36
# Melhor solução encontrada: f(X) = 27.56
# Melhor solução encontrada: f(X) = 22.92
# Melhor solução encontrada: f(X) = 21.01
# Melhor solução encontrada: f(X) = 16.82
# Melhor solução encontrada: f(X) = 15.50
# Melhor solução encontrada: f(X) = 14.11
# Melhor solução encontrada: f(X) = 10.81
# Melhor solução encontrada: f(X) = 9.55
# Melhor solução encontrada: f(X) = 8.28
# Melhor solução encontrada: f(X) = 8.50
# Melhor solução encontrada: f(X) = 7.37
# Melhor solução encontrada: f(X) = 6.81
# Melhor solução encontrada: f(X) = 6.54
# Melhor solução encontrada: f(X) = 5.45
# Melhor solução encontrada: f(X) = 5.61
# Melhor solução encontrada: f(X) = 5.22
# Melhor solução encontrada: f(X) = 4.34
# Melhor solução encontrada: f(X) = 4.20
# Melhor solução encontrada: f(X) = 3.81
# Melhor solução encontrada: f(X) = 3.57
# Melhor solução encontrada: f(X) = 3.74
# Melhor solução encontrada: f(X) = 3.40
# Melhor solução encontrada: f(X) = 2.85
# Melhor solução encontrada: f(X) = 2.94
# Melhor solução encontrada: f(X) = 2.65
# Melhor solução encontrada: f(X) = 2.76
# Melhor solução encontrada: f(X) = 2.62
# Melhor solução encontrada: f(X) = 2.49
# Melhor solução encontrada: f(X) = 2.34
# Melhor solução encontrada: f(X) = 2.34
# Melhor solução encontrada: f(X) = 2.15
# Melhor solução encontrada: f(X) = 1.96
# Melhor solução encontrada: f(X) = 1.94
# Melhor solução encontrada: f(X) = 1.86
# Melhor solução encontrada: f(X) = 1.73
# Melhor solução encontrada: f(X) = 1.73
# Melhor solução encontrada: f(X) = 1.67
# Melhor solução encontrada: f(X) = 1.61
# Melhor solução encontrada: f(X) = 1.53
# Melhor solução encontrada: f(X) = 1.48
# Melhor solução encontrada: f(X) = 1.43
# Melhor solução encontrada: f(X) = 1.40
# Melhor solução encontrada: f(X) = 1.35
# Melhor solução encontrada: f(X) = 1.40
# Melhor solução encontrada: f(X) = 1.27
# Melhor solução encontrada: f(X) = 1.28
# Melhor solução encontrada: f(X) = 1.13
# Melhor solução encontrada: f(X) = 1.10
# Melhor solução encontrada: f(X) = 1.08
# Melhor solução encontrada: f(X) = 1.05
# Melhor solução encontrada: f(X) = 1.02
# Melhor solução encontrada: f(X) = 1.00
# Melhor solução encontrada: f(X) = 0.96
# Melhor solução encontrada: f(X) = 0.95
# Melhor solução encontrada: f(X) = 0.92
# Melhor solução encontrada: f(X) = 0.88
# Melhor solução encontrada: f(X) = 0.87
# Melhor solução encontrada: f(X) = 0.85
# Melhor solução encontrada: f(X) = 0.89
# Melhor solução encontrada: f(X) = 0.77
# Melhor solução encontrada: f(X) = 0.74
# Melhor solução encontrada: f(X) = 0.71
# Melhor solução encontrada: f(X) = 0.70
# Melhor solução encontrada: f(X) = 0.69
# Melhor solução encontrada: f(X) = 0.66
# Melhor solução encontrada: f(X) = 0.70
# Melhor solução encontrada: f(X) = 0.65
# Melhor solução encontrada: f(X) = 0.62
# Melhor solução encontrada: f(X) = 0.60
# Melhor solução encontrada: f(X) = 0.61
# Melhor solução encontrada: f(X) = 0.58
# Melhor solução encontrada: f(X) = 0.56
# Melhor solução encontrada: f(X) = 0.61
# Melhor solução encontrada: f(X) = 0.60
# Melhor solução encontrada: f(X) = 0.52
# Melhor solução encontrada: f(X) = 0.52
# Melhor solução encontrada: f(X) = 0.52
# Melhor solução encontrada: f(X) = 0.51
# Melhor solução encontrada: f(X) = 0.50
# Melhor solução encontrada: f(X) = 0.49
# Melhor solução encontrada: f(X) = 0.48
# Melhor solução encontrada: f(X) = 0.51
# Melhor solução encontrada: f(X) = 0.53
# Melhor solução encontrada: f(X) = 0.47
# Melhor solução encontrada: f(X) = 0.48
# Melhor solução encontrada: f(X) = 0.47
# Melhor solução encontrada: f(X) = 0.47
# Melhor solução encontrada: f(X) = 0.46
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.46
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.43
# Melhor solução encontrada: f(X) = 0.46
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.46
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.46
# Melhor solução encontrada: f(X) = 0.46
# Melhor solução encontrada: f(X) = 0.46
# Melhor solução encontrada: f(X) = 0.47
# Melhor solução encontrada: f(X) = 0.46
# Melhor solução encontrada: f(X) = 0.47
# Melhor solução encontrada: f(X) = 0.47
# Melhor solução encontrada: f(X) = 0.48
# Melhor solução encontrada: f(X) = 0.51
# Melhor solução encontrada: f(X) = 0.51
# Melhor solução encontrada: f(X) = 0.49
# Melhor solução encontrada: f(X) = 0.49
# Melhor solução encontrada: f(X) = 0.56
# Melhor solução encontrada: f(X) = 0.51
# Melhor solução encontrada: f(X) = 0.56
# Melhor solução encontrada: f(X) = 0.55
# Melhor solução encontrada: f(X) = 0.57
# Melhor solução encontrada: f(X) = 0.64
# Melhor solução encontrada: f(X) = 0.60
# Melhor solução encontrada: f(X) = 0.70
# Melhor solução encontrada: f(X) = 0.72
# Melhor solução encontrada: f(X) = 0.63
# Melhor solução encontrada: f(X) = 0.67
# Melhor solução encontrada: f(X) = 0.79
# Melhor solução encontrada: f(X) = 0.71
# Melhor solução encontrada: f(X) = 0.87
# Melhor solução encontrada: f(X) = 0.76
# Melhor solução encontrada: f(X) = 0.88
# Melhor solução encontrada: f(X) = 0.90
# Melhor solução encontrada: f(X) = 0.91
# Melhor solução encontrada: f(X) = 0.88
# Melhor solução encontrada: f(X) = 0.90
# Melhor solução encontrada: f(X) = 0.96
# Melhor solução encontrada: f(X) = 1.13
# Melhor solução encontrada: f(X) = 1.14
# Melhor solução encontrada: f(X) = 1.09
# Melhor solução encontrada: f(X) = 1.21
# Melhor solução encontrada: f(X) = 1.37
# Melhor solução encontrada: f(X) = 1.40
# Melhor solução encontrada: f(X) = 1.25
# Melhor solução encontrada: f(X) = 1.48
# Melhor solução encontrada: f(X) = 1.37
# Melhor solução encontrada: f(X) = 1.58
# Melhor solução encontrada: f(X) = 1.53
# Melhor solução encontrada: f(X) = 1.83
# Melhor solução encontrada: f(X) = 1.73
# Melhor solução encontrada: f(X) = 1.72
# Melhor solução encontrada: f(X) = 2.30
# Melhor solução encontrada: f(X) = 2.12
# Melhor solução encontrada: f(X) = 2.31
# Melhor solução encontrada: f(X) = 2.40
# Melhor solução encontrada: f(X) = 2.48
# Melhor solução encontrada: f(X) = 2.74
# Melhor solução encontrada: f(X) = 2.92
# Melhor solução encontrada: f(X) = 3.34
# Melhor solução encontrada: f(X) = 3.37
# Melhor solução encontrada: f(X) = 3.73
# Melhor solução encontrada: f(X) = 3.74
# Melhor solução encontrada: f(X) = 3.60
# Melhor solução encontrada: f(X) = 4.90
# Melhor solução encontrada: f(X) = 4.70
# Melhor solução encontrada: f(X) = 4.65
# Melhor solução encontrada: f(X) = 6.19
# Melhor solução encontrada: f(X) = 7.04
# Melhor solução encontrada: f(X) = 7.79
# Melhor solução encontrada: f(X) = 8.65
# Melhor solução encontrada: f(X) = 9.74
# Melhor solução encontrada: f(X) = 10.35
# Melhor solução encontrada: f(X) = 11.76
# Melhor solução encontrada: f(X) = 13.90
# Melhor solução encontrada: f(X) = 16.65
# Melhor solução encontrada: f(X) = 18.59
# Melhor solução encontrada: f(X) = 22.17
# Melhor solução encontrada: f(X) = 24.56
# Melhor solução encontrada: f(X) = 29.31
# Melhor solução encontrada: f(X) = 31.59
# Melhor solução encontrada: f(X) = 35.39
# Melhor solução encontrada: f(X) = 36.45
# Melhor solução encontrada: f(X) = 34.37
# Melhor solução encontrada: f(X) = 29.42
# Melhor solução encontrada: f(X) = 27.29
# Melhor solução encontrada: f(X) = 23.37
# Melhor solução encontrada: f(X) = 18.10
# Melhor solução encontrada: f(X) = 15.84
# Melhor solução encontrada: f(X) = 13.73
# Melhor solução encontrada: f(X) = 11.48
# Melhor solução encontrada: f(X) = 9.84
# Melhor solução encontrada: f(X) = 8.79
# Melhor solução encontrada: f(X) = 8.07
# Melhor solução encontrada: f(X) = 6.98
# Melhor solução encontrada: f(X) = 6.35
# Melhor solução encontrada: f(X) = 6.27
# Melhor solução encontrada: f(X) = 5.37
# Melhor solução encontrada: f(X) = 4.92
# Melhor solução encontrada: f(X) = 4.84
# Melhor solução encontrada: f(X) = 4.44
# Melhor solução encontrada: f(X) = 4.30
# Melhor solução encontrada: f(X) = 4.25
# Melhor solução encontrada: f(X) = 3.62
# Melhor solução encontrada: f(X) = 3.66
# Melhor solução encontrada: f(X) = 3.47
# Melhor solução encontrada: f(X) = 3.39
# Melhor solução encontrada: f(X) = 3.20
# Melhor solução encontrada: f(X) = 3.18
# Melhor solução encontrada: f(X) = 3.09
# Melhor solução encontrada: f(X) = 2.98
# Melhor solução encontrada: f(X) = 2.95
# Melhor solução encontrada: f(X) = 2.95
# Melhor solução encontrada: f(X) = 2.84
# Melhor solução encontrada: f(X) = 2.83
# Melhor solução encontrada: f(X) = 2.77
# Melhor solução encontrada: f(X) = 2.84
# Melhor solução encontrada: f(X) = 2.70
# Melhor solução encontrada: f(X) = 2.68
# Melhor solução encontrada: f(X) = 2.66
# Melhor solução encontrada: f(X) = 2.64
# Melhor solução encontrada: f(X) = 2.63
# Melhor solução encontrada: f(X) = 2.61
# Melhor solução encontrada: f(X) = 2.60
# Melhor solução encontrada: f(X) = 2.59
# Melhor solução encontrada: f(X) = 2.59
# Melhor solução encontrada: f(X) = 2.60
# Melhor solução encontrada: f(X) = 2.60
# Melhor solução encontrada: f(X) = 2.60
# Melhor solução encontrada: f(X) = 2.61
# Melhor solução encontrada: f(X) = 2.64
# Melhor solução encontrada: f(X) = 2.64
# Melhor solução encontrada: f(X) = 2.66
# Melhor solução encontrada: f(X) = 2.69
# Melhor solução encontrada: f(X) = 2.72
# Melhor solução encontrada: f(X) = 2.78
# Melhor solução encontrada: f(X) = 2.79
# Melhor solução encontrada: f(X) = 2.84
# Melhor solução encontrada: f(X) = 2.86
# Melhor solução encontrada: f(X) = 2.92
# Melhor solução encontrada: f(X) = 2.99
# Melhor solução encontrada: f(X) = 3.04
# Melhor solução encontrada: f(X) = 3.10
# Melhor solução encontrada: f(X) = 3.16
# Melhor solução encontrada: f(X) = 3.24
# Melhor solução encontrada: f(X) = 3.28
# Melhor solução encontrada: f(X) = 3.37
# Melhor solução encontrada: f(X) = 3.49
# Melhor solução encontrada: f(X) = 3.56
# Melhor solução encontrada: f(X) = 3.75
# Melhor solução encontrada: f(X) = 3.84
# Melhor solução encontrada: f(X) = 3.95
# Melhor solução encontrada: f(X) = 3.99
# Melhor solução encontrada: f(X) = 4.45
# Melhor solução encontrada: f(X) = 4.45
# Melhor solução encontrada: f(X) = 4.65
# Melhor solução encontrada: f(X) = 4.91
# Melhor solução encontrada: f(X) = 5.35
# Melhor solução encontrada: f(X) = 5.20
# Melhor solução encontrada: f(X) = 5.79
# Melhor solução encontrada: f(X) = 6.11
# Melhor solução encontrada: f(X) = 6.25
# Melhor solução encontrada: f(X) = 6.91
# Melhor solução encontrada: f(X) = 7.64
# Melhor solução encontrada: f(X) = 7.99
# Melhor solução encontrada: f(X) = 9.14
# Melhor solução encontrada: f(X) = 10.49
# Melhor solução encontrada: f(X) = 10.87
# Melhor solução encontrada: f(X) = 12.32
# Melhor solução encontrada: f(X) = 13.61
# Melhor solução encontrada: f(X) = 14.97
# Melhor solução encontrada: f(X) = 16.72
# Melhor solução encontrada: f(X) = 19.44
# Melhor solução encontrada: f(X) = 21.80
# Melhor solução encontrada: f(X) = 24.49
# Melhor solução encontrada: f(X) = 25.99
# Melhor solução encontrada: f(X) = 30.13
# Melhor solução encontrada: f(X) = 32.37
# Melhor solução encontrada: f(X) = 33.88
# Melhor solução encontrada: f(X) = 32.90
# Melhor solução encontrada: f(X) = 30.46
# Melhor solução encontrada: f(X) = 27.63
# Melhor solução encontrada: f(X) = 23.64
# Melhor solução encontrada: f(X) = 20.56
# Melhor solução encontrada: f(X) = 19.36
# Melhor solução encontrada: f(X) = 16.35
# Melhor solução encontrada: f(X) = 13.80
# Melhor solução encontrada: f(X) = 12.77
# Melhor solução encontrada: f(X) = 10.62
# Melhor solução encontrada: f(X) = 9.13
# Melhor solução encontrada: f(X) = 9.31
# Melhor solução encontrada: f(X) = 7.90
# Melhor solução encontrada: f(X) = 7.02
# Melhor solução encontrada: f(X) = 7.22
# Melhor solução encontrada: f(X) = 6.32
# Melhor solução encontrada: f(X) = 5.86
# Melhor solução encontrada: f(X) = 5.48
# Melhor solução encontrada: f(X) = 5.36
# Melhor solução encontrada: f(X) = 4.76
# Melhor solução encontrada: f(X) = 4.80
# Melhor solução encontrada: f(X) = 4.35
# Melhor solução encontrada: f(X) = 4.08
# Melhor solução encontrada: f(X) = 4.40
# Melhor solução encontrada: f(X) = 3.97
# Melhor solução encontrada: f(X) = 3.83
# Melhor solução encontrada: f(X) = 3.77
# Melhor solução encontrada: f(X) = 3.59
# Melhor solução encontrada: f(X) = 3.49
# Melhor solução encontrada: f(X) = 3.34
# Melhor solução encontrada: f(X) = 3.29
# Melhor solução encontrada: f(X) = 3.26
# Melhor solução encontrada: f(X) = 3.16
# Melhor solução encontrada: f(X) = 3.11
# Melhor solução encontrada: f(X) = 3.08
# Melhor solução encontrada: f(X) = 3.03
# Melhor solução encontrada: f(X) = 3.00
# Melhor solução encontrada: f(X) = 2.98
# Melhor solução encontrada: f(X) = 2.95
# Melhor solução encontrada: f(X) = 2.92
# Melhor solução encontrada: f(X) = 2.88
# Melhor solução encontrada: f(X) = 2.87
# Melhor solução encontrada: f(X) = 2.86
# Melhor solução encontrada: f(X) = 2.84
# Melhor solução encontrada: f(X) = 2.83
# Melhor solução encontrada: f(X) = 2.84
# Melhor solução encontrada: f(X) = 2.85
# Melhor solução encontrada: f(X) = 2.83
# Melhor solução encontrada: f(X) = 2.85
# Melhor solução encontrada: f(X) = 2.86
# Melhor solução encontrada: f(X) = 2.88
# Melhor solução encontrada: f(X) = 2.91
# Melhor solução encontrada: f(X) = 2.93
# Melhor solução encontrada: f(X) = 2.96
# Melhor solução encontrada: f(X) = 2.98
# Melhor solução encontrada: f(X) = 3.04
# Melhor solução encontrada: f(X) = 3.08
# Melhor solução encontrada: f(X) = 3.12
# Melhor solução encontrada: f(X) = 3.16
# Melhor solução encontrada: f(X) = 3.24
# Melhor solução encontrada: f(X) = 3.29
# Melhor solução encontrada: f(X) = 3.43
# Melhor solução encontrada: f(X) = 3.45
# Melhor solução encontrada: f(X) = 3.55
# Melhor solução encontrada: f(X) = 3.61
# Melhor solução encontrada: f(X) = 3.84
# Melhor solução encontrada: f(X) = 4.05
# Melhor solução encontrada: f(X) = 4.13
# Melhor solução encontrada: f(X) = 4.39
# Melhor solução encontrada: f(X) = 4.61
# Melhor solução encontrada: f(X) = 4.91
# Melhor solução encontrada: f(X) = 5.28
# Melhor solução encontrada: f(X) = 5.09
# Melhor solução encontrada: f(X) = 5.68
# Melhor solução encontrada: f(X) = 6.24
# Melhor solução encontrada: f(X) = 6.65
# Melhor solução encontrada: f(X) = 6.72
# Melhor solução encontrada: f(X) = 8.05
# Melhor solução encontrada: f(X) = 9.17
# Melhor solução encontrada: f(X) = 9.32
# Melhor solução encontrada: f(X) = 11.55
# Melhor solução encontrada: f(X) = 12.28
# Melhor solução encontrada: f(X) = 13.31
# Melhor solução encontrada: f(X) = 16.16
# Melhor solução encontrada: f(X) = 18.88
# Melhor solução encontrada: f(X) = 21.40
# Melhor solução encontrada: f(X) = 25.10
# Melhor solução encontrada: f(X) = 28.36
# Melhor solução encontrada: f(X) = 31.15
# Melhor solução encontrada: f(X) = 34.45
# Melhor solução encontrada: f(X) = 36.26
# Melhor solução encontrada: f(X) = 34.72
# Melhor solução encontrada: f(X) = 32.02
# Melhor solução encontrada: f(X) = 27.60
# Melhor solução encontrada: f(X) = 22.61
# Melhor solução encontrada: f(X) = 20.63
# Melhor solução encontrada: f(X) = 16.40
# Melhor solução encontrada: f(X) = 13.98
# Melhor solução encontrada: f(X) = 10.53
# Melhor solução encontrada: f(X) = 8.97
# Melhor solução encontrada: f(X) = 7.35
# Melhor solução encontrada: f(X) = 7.63
# Melhor solução encontrada: f(X) = 6.82
# Melhor solução encontrada: f(X) = 6.35
# Melhor solução encontrada: f(X) = 5.91
# Melhor solução encontrada: f(X) = 5.42
# Melhor solução encontrada: f(X) = 4.89
# Melhor solução encontrada: f(X) = 4.34
# Melhor solução encontrada: f(X) = 4.17
# Melhor solução encontrada: f(X) = 3.37
# Melhor solução encontrada: f(X) = 3.02
# Melhor solução encontrada: f(X) = 2.59
# Melhor solução encontrada: f(X) = 2.50
# Melhor solução encontrada: f(X) = 2.56
# Melhor solução encontrada: f(X) = 2.53
# Melhor solução encontrada: f(X) = 2.23
# Melhor solução encontrada: f(X) = 2.31
# Melhor solução encontrada: f(X) = 1.78
# Melhor solução encontrada: f(X) = 1.79
# Melhor solução encontrada: f(X) = 2.08
# Melhor solução encontrada: f(X) = 1.60
# Melhor solução encontrada: f(X) = 1.55
# Melhor solução encontrada: f(X) = 1.41
# Melhor solução encontrada: f(X) = 1.42
# Melhor solução encontrada: f(X) = 1.64
# Melhor solução encontrada: f(X) = 1.14
# Melhor solução encontrada: f(X) = 1.28
# Melhor solução encontrada: f(X) = 1.24
# Melhor solução encontrada: f(X) = 0.93
# Melhor solução encontrada: f(X) = 1.06
# Melhor solução encontrada: f(X) = 0.84
# Melhor solução encontrada: f(X) = 0.83
# Melhor solução encontrada: f(X) = 0.91
# Melhor solução encontrada: f(X) = 1.11
# Melhor solução encontrada: f(X) = 0.81
# Melhor solução encontrada: f(X) = 0.80
# Melhor solução encontrada: f(X) = 0.94
# Melhor solução encontrada: f(X) = 0.69
# Melhor solução encontrada: f(X) = 0.73
# Melhor solução encontrada: f(X) = 0.57
# Melhor solução encontrada: f(X) = 0.63
# Melhor solução encontrada: f(X) = 0.57
# Melhor solução encontrada: f(X) = 0.61
# Melhor solução encontrada: f(X) = 0.65
# Melhor solução encontrada: f(X) = 0.52
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.49
# Melhor solução encontrada: f(X) = 0.46
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.48
# Melhor solução encontrada: f(X) = 0.49
# Melhor solução encontrada: f(X) = 0.42
# Melhor solução encontrada: f(X) = 0.40
# Melhor solução encontrada: f(X) = 0.38
# Melhor solução encontrada: f(X) = 0.46
# Melhor solução encontrada: f(X) = 0.39
# Melhor solução encontrada: f(X) = 0.36
# Melhor solução encontrada: f(X) = 0.53
# Melhor solução encontrada: f(X) = 0.32
# Melhor solução encontrada: f(X) = 0.40
# Melhor solução encontrada: f(X) = 0.39
# Melhor solução encontrada: f(X) = 0.34
# Melhor solução encontrada: f(X) = 0.41
# Melhor solução encontrada: f(X) = 0.37
# Melhor solução encontrada: f(X) = 0.33
# Melhor solução encontrada: f(X) = 0.35
# Melhor solução encontrada: f(X) = 0.35
# Melhor solução encontrada: f(X) = 0.35
# Melhor solução encontrada: f(X) = 0.37
# Melhor solução encontrada: f(X) = 0.35
# Melhor solução encontrada: f(X) = 0.37
# Melhor solução encontrada: f(X) = 0.35
# Melhor solução encontrada: f(X) = 0.36
# Melhor solução encontrada: f(X) = 0.37
# Melhor solução encontrada: f(X) = 0.37
# Melhor solução encontrada: f(X) = 0.37
# Melhor solução encontrada: f(X) = 0.38
# Melhor solução encontrada: f(X) = 0.36
# Melhor solução encontrada: f(X) = 0.38
# Melhor solução encontrada: f(X) = 0.38
# Melhor solução encontrada: f(X) = 0.38
# Melhor solução encontrada: f(X) = 0.39
# Melhor solução encontrada: f(X) = 0.38
# Melhor solução encontrada: f(X) = 0.40
# Melhor solução encontrada: f(X) = 0.40
# Melhor solução encontrada: f(X) = 0.39
# Melhor solução encontrada: f(X) = 0.39
# Melhor solução encontrada: f(X) = 0.40
# Melhor solução encontrada: f(X) = 0.40
# Melhor solução encontrada: f(X) = 0.40
# Melhor solução encontrada: f(X) = 0.40
# Melhor solução encontrada: f(X) = 0.40
# Melhor solução encontrada: f(X) = 0.40
# Melhor solução encontrada: f(X) = 0.40
# Melhor solução encontrada: f(X) = 0.40
# Melhor solução encontrada: f(X) = 0.40
# Melhor solução encontrada: f(X) = 0.40
# Melhor solução encontrada: f(X) = 0.40
# Melhor solução encontrada: f(X) = 0.40
# Melhor solução encontrada: f(X) = 0.40
# Melhor solução encontrada: f(X) = 0.39
# Melhor solução encontrada: f(X) = 0.39
# Melhor solução encontrada: f(X) = 0.39
# Melhor solução encontrada: f(X) = 0.39
# Melhor solução encontrada: f(X) = 0.38
# Melhor solução encontrada: f(X) = 0.38
# Melhor solução encontrada: f(X) = 0.38
# Melhor solução encontrada: f(X) = 0.38
# Melhor solução encontrada: f(X) = 0.37
# Melhor solução encontrada: f(X) = 0.37
# Melhor solução encontrada: f(X) = 0.37
# Melhor solução encontrada: f(X) = 0.37
# Melhor solução encontrada: f(X) = 0.37
# Melhor solução encontrada: f(X) = 0.39
# ...
# Melhor solução encontrada: f(X) = 10.99
# Melhor solução encontrada: f(X) = 12.53
# Melhor solução encontrada: f(X) = 14.73
# Melhor solução encontrada: f(X) = 15.86
# Melhor solução encontrada: f(X) = 18.75
# Melhor solução encontrada: f(X) = 20.36
# Melhor solução encontrada: f(X) = 24.63
# Melhor solução encontrada: f(X) = 27.29
# Melhor solução encontrada: f(X) = 29.45
# Melhor solução encontrada: f(X) = 31.74
# Melhor solução encontrada: f(X) = 32.93
# Melhor solução encontrada: f(X) = 32.46
# Melhor solução encontrada: f(X) = 30.55
# Melhor solução encontrada: f(X) = 27.74
# Melhor solução encontrada: f(X) = 24.48
# Melhor solução encontrada: f(X) = 22.22
# Melhor solução encontrada: f(X) = 18.24
# Melhor solução encontrada: f(X) = 16.99
# Melhor solução encontrada: f(X) = 14.94
# Melhor solução encontrada: f(X) = 13.97
# Melhor solução encontrada: f(X) = 12.23
# Melhor solução encontrada: f(X) = 11.61
# Melhor solução encontrada: f(X) = 10.54
# Melhor solução encontrada: f(X) = 10.22
# Melhor solução encontrada: f(X) = 9.45
# Melhor solução encontrada: f(X) = 9.11
# Melhor solução encontrada: f(X) = 8.73
# Melhor solução encontrada: f(X) = 8.38
# Melhor solução encontrada: f(X) = 8.14
# Melhor solução encontrada: f(X) = 7.99
# Melhor solução encontrada: f(X) = 7.86
# Melhor solução encontrada: f(X) = 7.86
# Melhor solução encontrada: f(X) = 7.77
# Melhor solução encontrada: f(X) = 7.79
# Melhor solução encontrada: f(X) = 7.83
# Melhor solução encontrada: f(X) = 7.87
# Melhor solução encontrada: f(X) = 7.96
# Melhor solução encontrada: f(X) = 8.04
# Melhor solução encontrada: f(X) = 8.23
# Melhor solução encontrada: f(X) = 8.48
# Melhor solução encontrada: f(X) = 8.60
# Melhor solução encontrada: f(X) = 8.87
# Melhor solução encontrada: f(X) = 9.25
# Melhor solução encontrada: f(X) = 9.41
# Melhor solução encontrada: f(X) = 9.96
# Melhor solução encontrada: f(X) = 10.20
# Melhor solução encontrada: f(X) = 10.75
# Melhor solução encontrada: f(X) = 11.66
# Melhor solução encontrada: f(X) = 12.04
# Melhor solução encontrada: f(X) = 12.50
# Melhor solução encontrada: f(X) = 13.45
# Melhor solução encontrada: f(X) = 14.98
# Melhor solução encontrada: f(X) = 15.85
# Melhor solução encontrada: f(X) = 17.32
# Melhor solução encontrada: f(X) = 18.48
# Melhor solução encontrada: f(X) = 19.84
# Melhor solução encontrada: f(X) = 21.69
# Melhor solução encontrada: f(X) = 23.66
# Melhor solução encontrada: f(X) = 25.29
# Melhor solução encontrada: f(X) = 27.58
# Melhor solução encontrada: f(X) = 28.84
# Melhor solução encontrada: f(X) = 29.69
# Melhor solução encontrada: f(X) = 30.03
# Melhor solução encontrada: f(X) = 29.28
# Melhor solução encontrada: f(X) = 27.50
# Melhor solução encontrada: f(X) = 25.12
# Melhor solução encontrada: f(X) = 22.20
# Melhor solução encontrada: f(X) = 20.01
# Melhor solução encontrada: f(X) = 19.30
# Melhor solução encontrada: f(X) = 17.10
# Melhor solução encontrada: f(X) = 14.98
# Melhor solução encontrada: f(X) = 14.02
# Melhor solução encontrada: f(X) = 12.24
# Melhor solução encontrada: f(X) = 11.57
# Melhor solução encontrada: f(X) = 10.89
# Melhor solução encontrada: f(X) = 9.74
# Melhor solução encontrada: f(X) = 9.60
# Melhor solução encontrada: f(X) = 8.70
# Melhor solução encontrada: f(X) = 8.12
# Melhor solução encontrada: f(X) = 7.58
# Melhor solução encontrada: f(X) = 7.24
# Melhor solução encontrada: f(X) = 7.04
# Melhor solução encontrada: f(X) = 6.89
# Melhor solução encontrada: f(X) = 6.64
# Melhor solução encontrada: f(X) = 6.35
# Melhor solução encontrada: f(X) = 6.18
# Melhor solução encontrada: f(X) = 6.18
# Melhor solução encontrada: f(X) = 6.02
# Melhor solução encontrada: f(X) = 5.97
# Melhor solução encontrada: f(X) = 5.95
# Melhor solução encontrada: f(X) = 5.91
# Melhor solução encontrada: f(X) = 5.91
# Melhor solução encontrada: f(X) = 5.91
# Melhor solução encontrada: f(X) = 5.93
# Melhor solução encontrada: f(X) = 6.00
# Melhor solução encontrada: f(X) = 6.04
# Melhor solução encontrada: f(X) = 6.16
# Melhor solução encontrada: f(X) = 6.23
# Melhor solução encontrada: f(X) = 6.31
# Melhor solução encontrada: f(X) = 6.51
# Melhor solução encontrada: f(X) = 6.60
# Melhor solução encontrada: f(X) = 7.09
# Melhor solução encontrada: f(X) = 7.19
# Melhor solução encontrada: f(X) = 7.67
# Melhor solução encontrada: f(X) = 7.65
# Melhor solução encontrada: f(X) = 8.23
# Melhor solução encontrada: f(X) = 8.95
# Melhor solução encontrada: f(X) = 10.20
# Melhor solução encontrada: f(X) = 10.77
# Melhor solução encontrada: f(X) = 11.50
# Melhor solução encontrada: f(X) = 13.33
# Melhor solução encontrada: f(X) = 14.58
# Melhor solução encontrada: f(X) = 16.96
# Melhor solução encontrada: f(X) = 18.89
# Melhor solução encontrada: f(X) = 21.10
# Melhor solução encontrada: f(X) = 24.37
# Melhor solução encontrada: f(X) = 29.22
# Melhor solução encontrada: f(X) = 31.92
# Melhor solução encontrada: f(X) = 34.65
# Melhor solução encontrada: f(X) = 35.74
# Melhor solução encontrada: f(X) = 34.42
# Melhor solução encontrada: f(X) = 29.67
# Melhor solução encontrada: f(X) = 26.89
# Melhor solução encontrada: f(X) = 22.14
# Melhor solução encontrada: f(X) = 19.45
# Melhor solução encontrada: f(X) = 15.42
# Melhor solução encontrada: f(X) = 13.56
# Melhor solução encontrada: f(X) = 12.20
# Melhor solução encontrada: f(X) = 9.49
# Melhor solução encontrada: f(X) = 8.36
# Melhor solução encontrada: f(X) = 7.25
# Melhor solução encontrada: f(X) = 6.81
# Melhor solução encontrada: f(X) = 5.29
# Melhor solução encontrada: f(X) = 5.08
# Melhor solução encontrada: f(X) = 5.33
# Melhor solução encontrada: f(X) = 4.31
# Melhor solução encontrada: f(X) = 4.02
# Melhor solução encontrada: f(X) = 3.09
# Melhor solução encontrada: f(X) = 3.02
# Melhor solução encontrada: f(X) = 2.96
# Melhor solução encontrada: f(X) = 2.27
# Melhor solução encontrada: f(X) = 2.17
# Melhor solução encontrada: f(X) = 2.16
# Melhor solução encontrada: f(X) = 1.89
# Melhor solução encontrada: f(X) = 1.59
# Melhor solução encontrada: f(X) = 1.80
# Melhor solução encontrada: f(X) = 1.69
# Melhor solução encontrada: f(X) = 1.53
# Melhor solução encontrada: f(X) = 1.50
# Melhor solução encontrada: f(X) = 1.15
# Melhor solução encontrada: f(X) = 1.33
# Melhor solução encontrada: f(X) = 1.22
# Melhor solução encontrada: f(X) = 1.02
# Melhor solução encontrada: f(X) = 1.02
# Melhor solução encontrada: f(X) = 0.69
# Melhor solução encontrada: f(X) = 0.81
# Melhor solução encontrada: f(X) = 0.88
# Melhor solução encontrada: f(X) = 0.73
# Melhor solução encontrada: f(X) = 0.63
# Melhor solução encontrada: f(X) = 0.70
# Melhor solução encontrada: f(X) = 0.71
# Melhor solução encontrada: f(X) = 0.82
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.35
# Melhor solução encontrada: f(X) = 0.36
# Melhor solução encontrada: f(X) = 0.41
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.37
# Melhor solução encontrada: f(X) = 0.43
# Melhor solução encontrada: f(X) = 0.35
# Melhor solução encontrada: f(X) = 0.39
# Melhor solução encontrada: f(X) = 0.57
# Melhor solução encontrada: f(X) = 0.31
# Melhor solução encontrada: f(X) = 0.25
# Melhor solução encontrada: f(X) = 0.31
# Melhor solução encontrada: f(X) = 0.31
# Melhor solução encontrada: f(X) = 0.51
# Melhor solução encontrada: f(X) = 0.39
# Melhor solução encontrada: f(X) = 0.55
# Melhor solução encontrada: f(X) = 0.36
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.34
# Melhor solução encontrada: f(X) = 0.37
# Melhor solução encontrada: f(X) = 0.36
# Melhor solução encontrada: f(X) = 0.36
# Melhor solução encontrada: f(X) = 0.38
# Melhor solução encontrada: f(X) = 0.42
# Melhor solução encontrada: f(X) = 0.41
# Melhor solução encontrada: f(X) = 0.39
# Melhor solução encontrada: f(X) = 0.41
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.48
# Melhor solução encontrada: f(X) = 0.47
# Melhor solução encontrada: f(X) = 0.48
# Melhor solução encontrada: f(X) = 0.49
# Melhor solução encontrada: f(X) = 0.49
# Melhor solução encontrada: f(X) = 0.51
# Melhor solução encontrada: f(X) = 0.53
# Melhor solução encontrada: f(X) = 0.51
# Melhor solução encontrada: f(X) = 0.51
# Melhor solução encontrada: f(X) = 0.51
# Melhor solução encontrada: f(X) = 0.51
# Melhor solução encontrada: f(X) = 0.52
# Melhor solução encontrada: f(X) = 0.52
# Melhor solução encontrada: f(X) = 0.51
# Melhor solução encontrada: f(X) = 0.51
# Melhor solução encontrada: f(X) = 0.50
# Melhor solução encontrada: f(X) = 0.50
# Melhor solução encontrada: f(X) = 0.49
# Melhor solução encontrada: f(X) = 0.49
# Melhor solução encontrada: f(X) = 0.47
# Melhor solução encontrada: f(X) = 0.46
# Melhor solução encontrada: f(X) = 0.45
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.43
# Melhor solução encontrada: f(X) = 0.41
# Melhor solução encontrada: f(X) = 0.41
# Melhor solução encontrada: f(X) = 0.40
# Melhor solução encontrada: f(X) = 0.41
# Melhor solução encontrada: f(X) = 0.37
# Melhor solução encontrada: f(X) = 0.37
# Melhor solução encontrada: f(X) = 0.39
# Melhor solução encontrada: f(X) = 0.36
# Melhor solução encontrada: f(X) = 0.33
# Melhor solução encontrada: f(X) = 0.33
# Melhor solução encontrada: f(X) = 0.32
# Melhor solução encontrada: f(X) = 0.29
# Melhor solução encontrada: f(X) = 0.31
# Melhor solução encontrada: f(X) = 0.39
# Melhor solução encontrada: f(X) = 0.59
# Melhor solução encontrada: f(X) = 0.31
# Melhor solução encontrada: f(X) = 0.42
# Melhor solução encontrada: f(X) = 0.27
# Melhor solução encontrada: f(X) = 0.35
# Melhor solução encontrada: f(X) = 0.36
# Melhor solução encontrada: f(X) = 0.29
# Melhor solução encontrada: f(X) = 0.24
# Melhor solução encontrada: f(X) = 0.24
# Melhor solução encontrada: f(X) = 0.39
# Melhor solução encontrada: f(X) = 0.35
# Melhor solução encontrada: f(X) = 0.43
# Melhor solução encontrada: f(X) = 0.24
# Melhor solução encontrada: f(X) = 0.46
# Melhor solução encontrada: f(X) = 0.48
# Melhor solução encontrada: f(X) = 0.53
# Melhor solução encontrada: f(X) = 0.52
# Melhor solução encontrada: f(X) = 0.76
# Melhor solução encontrada: f(X) = 0.75
# Melhor solução encontrada: f(X) = 0.59
# Melhor solução encontrada: f(X) = 0.44
# Melhor solução encontrada: f(X) = 0.39
# Melhor solução encontrada: f(X) = 0.66
# Melhor solução encontrada: f(X) = 0.83
# Melhor solução encontrada: f(X) = 1.01
# Melhor solução encontrada: f(X) = 0.68
# Melhor solução encontrada: f(X) = 0.84
# Melhor solução encontrada: f(X) = 0.84
# Melhor solução encontrada: f(X) = 0.99
# Melhor solução encontrada: f(X) = 1.30
# Melhor solução encontrada: f(X) = 1.05
# Melhor solução encontrada: f(X) = 1.29
# Melhor solução encontrada: f(X) = 1.31
# Melhor solução encontrada: f(X) = 1.19
# Melhor solução encontrada: f(X) = 1.71
# Melhor solução encontrada: f(X) = 1.39
# Melhor solução encontrada: f(X) = 1.92
# Melhor solução encontrada: f(X) = 1.98
# Melhor solução encontrada: f(X) = 1.95
# Melhor solução encontrada: f(X) = 2.20
# Melhor solução encontrada: f(X) = 2.24
# Melhor solução encontrada: f(X) = 2.85
# Melhor solução encontrada: f(X) = 2.96
# Melhor solução encontrada: f(X) = 2.76
# Melhor solução encontrada: f(X) = 3.34
# Melhor solução encontrada: f(X) = 2.88
# Melhor solução encontrada: f(X) = 4.23
# Melhor solução encontrada: f(X) = 4.01
# Melhor solução encontrada: f(X) = 4.61
# Melhor solução encontrada: f(X) = 4.86
# Melhor solução encontrada: f(X) = 5.22
# Melhor solução encontrada: f(X) = 6.03
# Melhor solução encontrada: f(X) = 6.75
# Melhor solução encontrada: f(X) = 7.29
# Melhor solução encontrada: f(X) = 8.10
# Melhor solução encontrada: f(X) = 9.33
# Melhor solução encontrada: f(X) = 11.00
# Melhor solução encontrada: f(X) = 12.10
# Melhor solução encontrada: f(X) = 13.24
# Melhor solução encontrada: f(X) = 16.11
# Melhor solução encontrada: f(X) = 18.87
# Melhor solução encontrada: f(X) = 21.23
# Melhor solução encontrada: f(X) = 24.89
# Melhor solução encontrada: f(X) = 27.95
# Melhor solução encontrada: f(X) = 31.64
# Melhor solução encontrada: f(X) = 33.30
# Melhor solução encontrada: f(X) = 34.68
# Melhor solução encontrada: f(X) = 33.47
# Melhor solução encontrada: f(X) = 31.24
# Melhor solução encontrada: f(X) = 27.66
# Melhor solução encontrada: f(X) = 24.14
# Melhor solução encontrada: f(X) = 20.81
# Melhor solução encontrada: f(X) = 17.82
# Melhor solução encontrada: f(X) = 14.00
# Melhor solução encontrada: f(X) = 13.55
# Melhor solução encontrada: f(X) = 11.75
# Melhor solução encontrada: f(X) = 10.77
# Melhor solução encontrada: f(X) = 9.39
# Melhor solução encontrada: f(X) = 9.32
# Melhor solução encontrada: f(X) = 7.76
# Melhor solução encontrada: f(X) = 7.43
# Melhor solução encontrada: f(X) = 7.11
# Melhor solução encontrada: f(X) = 7.12
# Melhor solução encontrada: f(X) = 6.52
# Melhor solução encontrada: f(X) = 6.54
# Melhor solução encontrada: f(X) = 6.36
# Melhor solução encontrada: f(X) = 6.03
# Melhor solução encontrada: f(X) = 6.03
# Melhor solução encontrada: f(X) = 5.84
# Melhor solução encontrada: f(X) = 5.81
# Melhor solução encontrada: f(X) = 5.78
# Melhor solução encontrada: f(X) = 5.75
# Melhor solução encontrada: f(X) = 5.75
# Melhor solução encontrada: f(X) = 5.78
# Melhor solução encontrada: f(X) = 5.82
# Melhor solução encontrada: f(X) = 5.83
# Melhor solução encontrada: f(X) = 5.93
# Melhor solução encontrada: f(X) = 6.03
# Melhor solução encontrada: f(X) = 6.04
# Melhor solução encontrada: f(X) = 6.21
# Melhor solução encontrada: f(X) = 6.40
# Melhor solução encontrada: f(X) = 6.56
# Melhor solução encontrada: f(X) = 6.75
# Melhor solução encontrada: f(X) = 7.01
# Melhor solução encontrada: f(X) = 7.16
# Melhor solução encontrada: f(X) = 7.47
# Melhor solução encontrada: f(X) = 7.85
# Melhor solução encontrada: f(X) = 8.39
# Melhor solução encontrada: f(X) = 8.75
# Melhor solução encontrada: f(X) = 9.28
# Melhor solução encontrada: f(X) = 9.61
# Melhor solução encontrada: f(X) = 10.59
# Melhor solução encontrada: f(X) = 10.95
# Melhor solução encontrada: f(X) = 12.02
# Melhor solução encontrada: f(X) = 12.80
# Melhor solução encontrada: f(X) = 14.47
# Melhor solução encontrada: f(X) = 14.98
# Melhor solução encontrada: f(X) = 17.34
# Melhor solução encontrada: f(X) = 18.89
# Melhor solução encontrada: f(X) = 20.01
# Melhor solução encontrada: f(X) = 23.03
# Melhor solução encontrada: f(X) = 24.73
# Melhor solução encontrada: f(X) = 26.70
# Melhor solução encontrada: f(X) = 28.65
# Melhor solução encontrada: f(X) = 30.02
# Melhor solução encontrada: f(X) = 30.74
# Melhor solução encontrada: f(X) = 30.09
# Melhor solução encontrada: f(X) = 28.56
# Melhor solução encontrada: f(X) = 26.56
# Melhor solução encontrada: f(X) = 23.12
# Melhor solução encontrada: f(X) = 21.98
# Melhor solução encontrada: f(X) = 19.67
# Melhor solução encontrada: f(X) = 16.84
# Melhor solução encontrada: f(X) = 16.20
# Melhor solução encontrada: f(X) = 13.64
# Melhor solução encontrada: f(X) = 12.76
# Melhor solução encontrada: f(X) = 11.85
# Melhor solução encontrada: f(X) = 11.28
# Melhor solução encontrada: f(X) = 10.25
# Melhor solução encontrada: f(X) = 9.29
# Melhor solução encontrada: f(X) = 9.15
# Melhor solução encontrada: f(X) = 8.30
# Melhor solução encontrada: f(X) = 7.82
# Melhor solução encontrada: f(X) = 7.90
# Melhor solução encontrada: f(X) = 7.54
# Melhor solução encontrada: f(X) = 7.04
# Melhor solução encontrada: f(X) = 6.97
# Melhor solução encontrada: f(X) = 6.75
# Melhor solução encontrada: f(X) = 6.44
# Melhor solução encontrada: f(X) = 6.38
# Melhor solução encontrada: f(X) = 6.20
# Melhor solução encontrada: f(X) = 6.19
# Melhor solução encontrada: f(X) = 6.16
# Melhor solução encontrada: f(X) = 6.09
# Melhor solução encontrada: f(X) = 6.09
# Melhor solução encontrada: f(X) = 6.10
# Melhor solução encontrada: f(X) = 6.11
# Melhor solução encontrada: f(X) = 6.17
# Melhor solução encontrada: f(X) = 6.21
# Melhor solução encontrada: f(X) = 6.27
# Melhor solução encontrada: f(X) = 6.40
# Melhor solução encontrada: f(X) = 6.50
# Melhor solução encontrada: f(X) = 6.63
# Melhor solução encontrada: f(X) = 6.77
# Melhor solução encontrada: f(X) = 6.96
# Melhor solução encontrada: f(X) = 7.24
# Melhor solução encontrada: f(X) = 7.30
# Melhor solução encontrada: f(X) = 7.77
# Melhor solução encontrada: f(X) = 8.14
# Melhor solução encontrada: f(X) = 9.10
# Melhor solução encontrada: f(X) = 9.17
# Melhor solução encontrada: f(X) = 10.29
# Melhor solução encontrada: f(X) = 11.11
# Melhor solução encontrada: f(X) = 12.84
# Melhor solução encontrada: f(X) = 13.20
# Melhor solução encontrada: f(X) = 15.77
