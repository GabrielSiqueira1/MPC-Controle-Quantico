# %%
# Bilbiotecas para auxílio na programação matemática
import math, sys 
import numpy as np
import sympy as sp

from scipy import sparse # Produção das diagonais das matrizes
from scipy.sparse import diags 

# Plotagem 2D e 3D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm


from os import path # Suficiente para manipulação de arquivos
    
# Para solução exata
from scipy.special import hermite
from math import factorial

# %matplotlib inline
count = 0

# Para otimização dos sistemas
from scipy import optimize

import time

tempoInicial = time.time()

# %%
def N(n):
    return 1*1./np.sqrt(np.sqrt(np.pi)*2**n*factorial(n))

def psix(n, x):
    Hn=hermite(n)
    Px = N(n)*Hn(x)*np.exp(-0.5*x**2)
    return Px

def psixt(n, x, t):
    Hn=hermite(n)
    a = complex(0,1)
    Pxt = N(n)*Hn(x)*np.exp(-0.5*x**2)*np.exp(-a*(n+1/2)*t*np.pi)
    return Pxt

# %%
def CrankNicolson(M, O = 0, L = 1, T = 0.5):
    N = 500 #São os pontos no intervalo de tempo
    
    #Pensando no poço quadrado infinito, temos essas duas limitações, onde L varia
    x0, xL = O, L

    P = 3.141111111111111111111111111
    #Discretização espacial
    dx = (xL - x0)/(P*M-1) 

    #Discretização temporal
    t0, tF = 0, T
    dt = (tF - t0)/(P*N-1)

    #Retorno dos números em um intervalo
    xs = np.linspace(x0, xL, M)
    ts = np.linspace(t0, tF, N)

    #Suponha um oscilador harmônico simples
    hbar = 1
    m = 1
    w = np.pi
    V = 1/2*m*w**2*xs**2

    #A partir da demonstração
    a = hbar/(4*m*dx**2) 
    b = 1j*hbar/dt - 2*a - 1/2*V
    c = 1j*hbar/dt + 2*a + 1/2*V

    #Obtenção da matriz
    ##Diagonais principais
    diagPrincipalA = b*np.ones((1,M)) #Cria uma matriz de 1's
    diagPrincipalB = c*np.ones((1,M))

    ##Diagonais secundárias, tem um tamanho a menos
    diagSecundariaA = a*np.ones((1,M-1))
    diagSecundariaB = (-a)*np.ones((1,M-1))

    diagonaisA = [diagPrincipalA, diagSecundariaA, diagSecundariaA]
    matrizA = sparse.diags(diagonaisA, [0, -1, 1], shape=(M,M)).toarray()
    
    diagonaisB = [diagPrincipalB, diagSecundariaB, diagSecundariaB]         
    matrizB = sparse.diags(diagonaisB, [0, -1, 1], shape=(M,M)).toarray()
    
    #Obtenção da matriz psi (Ela acumulará para o psi futuro)
    ps = np.zeros((M, N))
    psi_c = np.zeros((M, N))

    #Condição inicial
    ps[:,0] = 0.80 * psix(0, xs) + 0.60 * psix(1, xs) #A primeira coluna da matriz terá a equação inicial, em todas as posições
    psi_c = ps.astype(complex)
    #For para o acúmulo de resultados
    for k in range(1,N):
        b = np.matmul(matrizB, np.array(psi_c[0:M, k-1])) #Multiplicação de arrays já que houve uma conversão anterior
        psi_c[0:M, k] = np.linalg.solve(matrizA, b) #Matlab: x = A\b
        #plt.plot(xs, np.absolute(psi_c[0:M, k])**2)
    return psi_c

# %%
def multMatrizes(M, us, O = -5, L = 5, T = 10):
    N = 500 #São os pontos no intervalo de tempo
    
    #Pensando no poço quadrado infinito, temos essas duas limitações, onde L varia
    x0, xL = O, L

    P = 3.141111111111111111111111111
    #Discretização espacial
    dx = (xL - x0)/(P*M-1) 

    #Discretização temporal
    t0, tF = 0, T
    dt = (tF - t0)/(P*N-1)

    #Retorno dos números em um intervalo
    xs = np.linspace(x0, xL, M)
    ts = np.linspace(t0, tF, N)
    
    #Suponha um oscilador harmônico simples
    hbar = 1
    m = 1
    w = np.pi
    #V = us #V(x,u(t))
    V = 1/2*m*w**2*xs**2+us

    #A partir da demonstração
    a = hbar/(4*m*dx**2) 
    b = 1j*hbar/dt - 2*a - 1/2*V
    c = 1j*hbar/dt + 2*a + 1/2*V

    #Obtenção da matriz
    ##Diagonais principais
    diagPrincipalA = b*np.ones((1,M)) #Cria uma matriz de 1's
    diagPrincipalB = c*np.ones((1,M))

    ##Diagonais secundárias, tem um tamanho a menos
    diagSecundariaA = a*np.ones((1,M-1))
    diagSecundariaB = (-a)*np.ones((1,M-1))

    diagonaisA = [diagPrincipalA, diagSecundariaA, diagSecundariaA]
    matrizA = sparse.diags(diagonaisA, [0, -1, 1], shape=(M,M)).toarray()
    
    diagonaisB = [diagPrincipalB, diagSecundariaB, diagSecundariaB]         
    matrizB = sparse.diags(diagonaisB, [0, -1, 1], shape=(M,M)).toarray()

    return np.matmul(np.linalg.inv(matrizA), matrizB)

# %%
# Gradiente e função objetivo

def ExactSolution(M, T = 5, L = 5):
    N = 100

    xs = np.linspace(-5, L, M)
    
    psiExato = np.zeros((M, M)).astype(complex)
    r=0
    for i in np.arange(-5, 5, 0.02):
        for j in np.arange(0, 10, 0.02):
            psiExato[r][int(j*50)] = 1/np.sqrt(2)*psixt(0,i,j)+1/np.sqrt(2)*psixt(1,i,j)
        r+=1
    return psiExato

def Objetivo(x, y, psi, psiExato):
    A = np.zeros((500,500))
    B = np.zeros((500,500))
    A = multMatrizes(M = 500, us = x[0])
    B = multMatrizes(M = 500, us = x[1])
    return ((np.linalg.norm(np.array(psiExato[0:500, y])-np.array(psi)))**2+
            (np.linalg.norm(np.array(psiExato[0:500, y+1])-np.array(np.matmul(A,psi))))**2+
            (np.linalg.norm(np.array(psiExato[0:500, y+2])-np.array(np.matmul(np.matmul(B,A),psi))))**2)

# %%
import random

psi = np.zeros((500,500))
psi_f = np.zeros((500,500))
psi_g = psi_f.astype(complex)
psi = CrankNicolson(M = 500, O = -5, L = 5, T = 10)
psiExato = ExactSolution(M = 500)

# %%
xs = np.linspace(-5,5,500)
plt.plot(xs, np.absolute(psi[0:500,0:500])**2)
# Out:
# [<matplotlib.lines.Line2D at 0x2e897865310>,
#  <matplotlib.lines.Line2D at 0x2e897865370>,
#  <matplotlib.lines.Line2D at 0x2e8978653a0>,
#  <matplotlib.lines.Line2D at 0x2e897865490>,
#  <matplotlib.lines.Line2D at 0x2e897865580>,
#  <matplotlib.lines.Line2D at 0x2e897865670>,
#  <matplotlib.lines.Line2D at 0x2e897865760>,
#  <matplotlib.lines.Line2D at 0x2e897865850>,
#  <matplotlib.lines.Line2D at 0x2e897865940>,
#  <matplotlib.lines.Line2D at 0x2e897865a30>,
#  <matplotlib.lines.Line2D at 0x2e897865b20>,
#  <matplotlib.lines.Line2D at 0x2e897865340>,
#  <matplotlib.lines.Line2D at 0x2e897865c10>,
#  <matplotlib.lines.Line2D at 0x2e897865dc0>,
#  <matplotlib.lines.Line2D at 0x2e897865eb0>,
#  <matplotlib.lines.Line2D at 0x2e897865fa0>,
#  <matplotlib.lines.Line2D at 0x2e8978710d0>,
#  <matplotlib.lines.Line2D at 0x2e8978711c0>,
#  <matplotlib.lines.Line2D at 0x2e8978712b0>,
#  <matplotlib.lines.Line2D at 0x2e8978713a0>,
#  <matplotlib.lines.Line2D at 0x2e897871490>,
#  <matplotlib.lines.Line2D at 0x2e897871580>,
#  <matplotlib.lines.Line2D at 0x2e897871670>,
#  <matplotlib.lines.Line2D at 0x2e897871760>,
#  <matplotlib.lines.Line2D at 0x2e897871850>,
#  <matplotlib.lines.Line2D at 0x2e897871940>,
#  <matplotlib.lines.Line2D at 0x2e897871a30>,
#  <matplotlib.lines.Line2D at 0x2e897871b20>,
#  <matplotlib.lines.Line2D at 0x2e897871c10>,
#  <matplotlib.lines.Line2D at 0x2e897871d00>,
#  <matplotlib.lines.Line2D at 0x2e897871df0>,
#  <matplotlib.lines.Line2D at 0x2e897871ee0>,
#  <matplotlib.lines.Line2D at 0x2e897871fd0>,
#  <matplotlib.lines.Line2D at 0x2e89787b100>,
#  <matplotlib.lines.Line2D at 0x2e89787b1f0>,
#  <matplotlib.lines.Line2D at 0x2e89787b2e0>,
#  <matplotlib.lines.Line2D at 0x2e89787b3d0>,
#  <matplotlib.lines.Line2D at 0x2e89787b4c0>,
#  <matplotlib.lines.Line2D at 0x2e89787b5b0>,
#  <matplotlib.lines.Line2D at 0x2e89787b6a0>,
#  <matplotlib.lines.Line2D at 0x2e89787b790>,
#  <matplotlib.lines.Line2D at 0x2e89787b880>,
#  <matplotlib.lines.Line2D at 0x2e89787b970>,
#  <matplotlib.lines.Line2D at 0x2e89787ba60>,
#  <matplotlib.lines.Line2D at 0x2e89787bb50>,
#  <matplotlib.lines.Line2D at 0x2e89787bc40>,
#  <matplotlib.lines.Line2D at 0x2e89787bd30>,
#  <matplotlib.lines.Line2D at 0x2e89787be20>,
#  <matplotlib.lines.Line2D at 0x2e89787bf10>,
#  <matplotlib.lines.Line2D at 0x2e897883040>,
#  <matplotlib.lines.Line2D at 0x2e897883130>,
#  <matplotlib.lines.Line2D at 0x2e897883220>,
#  <matplotlib.lines.Line2D at 0x2e897883310>,
#  <matplotlib.lines.Line2D at 0x2e897883400>,
#  <matplotlib.lines.Line2D at 0x2e8978834f0>,
#  <matplotlib.lines.Line2D at 0x2e8978835e0>,
#  <matplotlib.lines.Line2D at 0x2e8978836d0>,
#  <matplotlib.lines.Line2D at 0x2e8978837c0>,
#  <matplotlib.lines.Line2D at 0x2e8978838b0>,
#  <matplotlib.lines.Line2D at 0x2e8978839a0>,
#  <matplotlib.lines.Line2D at 0x2e897883a90>,
#  <matplotlib.lines.Line2D at 0x2e897883b80>,
#  <matplotlib.lines.Line2D at 0x2e897883c70>,
#  <matplotlib.lines.Line2D at 0x2e897883d60>,
#  <matplotlib.lines.Line2D at 0x2e897883e50>,
#  <matplotlib.lines.Line2D at 0x2e897883f40>,
#  <matplotlib.lines.Line2D at 0x2e89788b070>,
#  <matplotlib.lines.Line2D at 0x2e89788b160>,
#  <matplotlib.lines.Line2D at 0x2e89788b250>,
#  <matplotlib.lines.Line2D at 0x2e89788b340>,
#  <matplotlib.lines.Line2D at 0x2e89788b430>,
#  <matplotlib.lines.Line2D at 0x2e89788b520>,
#  <matplotlib.lines.Line2D at 0x2e89788b610>,
#  <matplotlib.lines.Line2D at 0x2e89788b700>,
#  <matplotlib.lines.Line2D at 0x2e89788b7f0>,
#  <matplotlib.lines.Line2D at 0x2e89788b8e0>,
#  <matplotlib.lines.Line2D at 0x2e89788b9d0>,
#  <matplotlib.lines.Line2D at 0x2e89788bac0>,
#  <matplotlib.lines.Line2D at 0x2e89788bbb0>,
#  <matplotlib.lines.Line2D at 0x2e89788bca0>,
#  <matplotlib.lines.Line2D at 0x2e89788bd90>,
#  <matplotlib.lines.Line2D at 0x2e89788be80>,
#  <matplotlib.lines.Line2D at 0x2e89788bf70>,
#  <matplotlib.lines.Line2D at 0x2e8978930a0>,
#  <matplotlib.lines.Line2D at 0x2e897893190>,
#  <matplotlib.lines.Line2D at 0x2e897893280>,
#  <matplotlib.lines.Line2D at 0x2e897893370>,
#  <matplotlib.lines.Line2D at 0x2e897893460>,
#  <matplotlib.lines.Line2D at 0x2e897893550>,
#  <matplotlib.lines.Line2D at 0x2e897893640>,
#  <matplotlib.lines.Line2D at 0x2e897893730>,
#  <matplotlib.lines.Line2D at 0x2e897893820>,
#  <matplotlib.lines.Line2D at 0x2e897893910>,
#  <matplotlib.lines.Line2D at 0x2e897893a00>,
#  <matplotlib.lines.Line2D at 0x2e897893af0>,
#  <matplotlib.lines.Line2D at 0x2e897893be0>,
#  <matplotlib.lines.Line2D at 0x2e897893cd0>,
#  <matplotlib.lines.Line2D at 0x2e897893dc0>,
#  <matplotlib.lines.Line2D at 0x2e897893eb0>,
#  <matplotlib.lines.Line2D at 0x2e897893fa0>,
#  <matplotlib.lines.Line2D at 0x2e89789a0d0>,
#  <matplotlib.lines.Line2D at 0x2e89789a1c0>,
#  <matplotlib.lines.Line2D at 0x2e89789a2b0>,
#  <matplotlib.lines.Line2D at 0x2e89789a3a0>,
#  <matplotlib.lines.Line2D at 0x2e89789a490>,
#  <matplotlib.lines.Line2D at 0x2e89789a580>,
#  <matplotlib.lines.Line2D at 0x2e89789a670>,
#  <matplotlib.lines.Line2D at 0x2e89789a760>,
#  <matplotlib.lines.Line2D at 0x2e89789a850>,
#  <matplotlib.lines.Line2D at 0x2e89789a940>,
#  <matplotlib.lines.Line2D at 0x2e89789aa30>,
#  <matplotlib.lines.Line2D at 0x2e89789ab20>,
#  <matplotlib.lines.Line2D at 0x2e89789ac10>,
#  <matplotlib.lines.Line2D at 0x2e89789ad00>,
#  <matplotlib.lines.Line2D at 0x2e89789adf0>,
#  <matplotlib.lines.Line2D at 0x2e89789aee0>,
#  <matplotlib.lines.Line2D at 0x2e89789afd0>,
#  <matplotlib.lines.Line2D at 0x2e8978a2100>,
#  <matplotlib.lines.Line2D at 0x2e8978a21f0>,
#  <matplotlib.lines.Line2D at 0x2e8978a22e0>,
#  <matplotlib.lines.Line2D at 0x2e8978a23d0>,
#  <matplotlib.lines.Line2D at 0x2e8978a24c0>,
#  <matplotlib.lines.Line2D at 0x2e8978a25b0>,
#  <matplotlib.lines.Line2D at 0x2e8978a26a0>,
#  <matplotlib.lines.Line2D at 0x2e8978a2790>,
#  <matplotlib.lines.Line2D at 0x2e8978a2880>,
#  <matplotlib.lines.Line2D at 0x2e8978a2970>,
#  <matplotlib.lines.Line2D at 0x2e8978a2a60>,
#  <matplotlib.lines.Line2D at 0x2e8978a2b50>,
#  <matplotlib.lines.Line2D at 0x2e8978a2c40>,
#  <matplotlib.lines.Line2D at 0x2e8978a2d30>,
#  <matplotlib.lines.Line2D at 0x2e8978a2e20>,
#  <matplotlib.lines.Line2D at 0x2e8978a2f10>,
#  <matplotlib.lines.Line2D at 0x2e8978a9040>,
#  <matplotlib.lines.Line2D at 0x2e8978a9130>,
#  <matplotlib.lines.Line2D at 0x2e8978a9220>,
#  <matplotlib.lines.Line2D at 0x2e8978a9310>,
#  <matplotlib.lines.Line2D at 0x2e8978a9400>,
#  <matplotlib.lines.Line2D at 0x2e8978a94f0>,
#  <matplotlib.lines.Line2D at 0x2e8978a95e0>,
#  <matplotlib.lines.Line2D at 0x2e8978a96d0>,
#  <matplotlib.lines.Line2D at 0x2e8978a97c0>,
#  <matplotlib.lines.Line2D at 0x2e8978a98b0>,
#  <matplotlib.lines.Line2D at 0x2e8978a99a0>,
#  <matplotlib.lines.Line2D at 0x2e8978a9a90>,
#  <matplotlib.lines.Line2D at 0x2e8978a9b80>,
#  <matplotlib.lines.Line2D at 0x2e8978a9c70>,
#  <matplotlib.lines.Line2D at 0x2e8978a9d60>,
#  <matplotlib.lines.Line2D at 0x2e8978a9e50>,
#  <matplotlib.lines.Line2D at 0x2e8978a9f40>,
#  <matplotlib.lines.Line2D at 0x2e8978b2070>,
#  <matplotlib.lines.Line2D at 0x2e8978b2160>,
#  <matplotlib.lines.Line2D at 0x2e8978b2250>,
#  <matplotlib.lines.Line2D at 0x2e8978b2340>,
#  <matplotlib.lines.Line2D at 0x2e8978b2430>,
#  <matplotlib.lines.Line2D at 0x2e8978b2520>,
#  <matplotlib.lines.Line2D at 0x2e8978b2610>,
#  <matplotlib.lines.Line2D at 0x2e8978b2700>,
#  <matplotlib.lines.Line2D at 0x2e8978b27f0>,
#  <matplotlib.lines.Line2D at 0x2e8978b28e0>,
#  <matplotlib.lines.Line2D at 0x2e8978b29d0>,
#  <matplotlib.lines.Line2D at 0x2e8978b2ac0>,
#  <matplotlib.lines.Line2D at 0x2e8978b2bb0>,
#  <matplotlib.lines.Line2D at 0x2e8978b2ca0>,
#  <matplotlib.lines.Line2D at 0x2e8978b2d90>,
#  <matplotlib.lines.Line2D at 0x2e8978b2e80>,
#  <matplotlib.lines.Line2D at 0x2e8978b2f70>,
#  <matplotlib.lines.Line2D at 0x2e8978b70a0>,
#  <matplotlib.lines.Line2D at 0x2e8978b7190>,
#  <matplotlib.lines.Line2D at 0x2e8978b7280>,
#  <matplotlib.lines.Line2D at 0x2e8978b7370>,
#  <matplotlib.lines.Line2D at 0x2e8978b7460>,
#  <matplotlib.lines.Line2D at 0x2e8978b7550>,
#  <matplotlib.lines.Line2D at 0x2e8978b7640>,
#  <matplotlib.lines.Line2D at 0x2e8978b7730>,
#  <matplotlib.lines.Line2D at 0x2e8978b7820>,
#  <matplotlib.lines.Line2D at 0x2e8978b7910>,
#  <matplotlib.lines.Line2D at 0x2e8978b7a00>,
#  <matplotlib.lines.Line2D at 0x2e8978b7af0>,
#  <matplotlib.lines.Line2D at 0x2e8978b7be0>,
#  <matplotlib.lines.Line2D at 0x2e8978b7cd0>,
#  <matplotlib.lines.Line2D at 0x2e8978b7dc0>,
#  <matplotlib.lines.Line2D at 0x2e8978b7eb0>,
#  <matplotlib.lines.Line2D at 0x2e8978b7fa0>,
#  <matplotlib.lines.Line2D at 0x2e8978c00d0>,
#  <matplotlib.lines.Line2D at 0x2e8978c01c0>,
#  <matplotlib.lines.Line2D at 0x2e8978c02b0>,
#  <matplotlib.lines.Line2D at 0x2e8978c03a0>,
#  <matplotlib.lines.Line2D at 0x2e8978c0490>,
#  <matplotlib.lines.Line2D at 0x2e8978c0580>,
#  <matplotlib.lines.Line2D at 0x2e8978c0670>,
#  <matplotlib.lines.Line2D at 0x2e8978c0760>,
#  <matplotlib.lines.Line2D at 0x2e8978c0850>,
#  <matplotlib.lines.Line2D at 0x2e8978c0940>,
#  <matplotlib.lines.Line2D at 0x2e8978c0a30>,
#  <matplotlib.lines.Line2D at 0x2e8978c0b20>,
#  <matplotlib.lines.Line2D at 0x2e8978c0c10>,
#  <matplotlib.lines.Line2D at 0x2e8978c0d00>,
#  <matplotlib.lines.Line2D at 0x2e8978c0df0>,
#  <matplotlib.lines.Line2D at 0x2e8978c0ee0>,
#  <matplotlib.lines.Line2D at 0x2e8978c0fd0>,
#  <matplotlib.lines.Line2D at 0x2e8978c6100>,
#  <matplotlib.lines.Line2D at 0x2e8978c61f0>,
#  <matplotlib.lines.Line2D at 0x2e8978c62e0>,
#  <matplotlib.lines.Line2D at 0x2e8978c63d0>,
#  <matplotlib.lines.Line2D at 0x2e8978c64c0>,
#  <matplotlib.lines.Line2D at 0x2e8978c65b0>,
#  <matplotlib.lines.Line2D at 0x2e8978c66a0>,
#  <matplotlib.lines.Line2D at 0x2e8978c6790>,
#  <matplotlib.lines.Line2D at 0x2e8978c6880>,
#  <matplotlib.lines.Line2D at 0x2e8978c6970>,
#  <matplotlib.lines.Line2D at 0x2e8978c6a60>,
#  <matplotlib.lines.Line2D at 0x2e8978c6b50>,
#  <matplotlib.lines.Line2D at 0x2e8978c6c40>,
#  <matplotlib.lines.Line2D at 0x2e8978c6d30>,
#  <matplotlib.lines.Line2D at 0x2e8978c6e20>,
#  <matplotlib.lines.Line2D at 0x2e8978c6f10>,
#  <matplotlib.lines.Line2D at 0x2e8978ce040>,
#  <matplotlib.lines.Line2D at 0x2e8978ce130>,
#  <matplotlib.lines.Line2D at 0x2e8978ce220>,
#  <matplotlib.lines.Line2D at 0x2e8978ce310>,
#  <matplotlib.lines.Line2D at 0x2e8978ce400>,
#  <matplotlib.lines.Line2D at 0x2e8978ce4f0>,
#  <matplotlib.lines.Line2D at 0x2e8978ce5e0>,
#  <matplotlib.lines.Line2D at 0x2e8978ce6d0>,
#  <matplotlib.lines.Line2D at 0x2e8978ce7c0>,
#  <matplotlib.lines.Line2D at 0x2e8978ce8b0>,
#  <matplotlib.lines.Line2D at 0x2e8978ce9a0>,
#  <matplotlib.lines.Line2D at 0x2e8978cea90>,
#  <matplotlib.lines.Line2D at 0x2e8978ceb80>,
#  <matplotlib.lines.Line2D at 0x2e8978cec70>,
#  <matplotlib.lines.Line2D at 0x2e8978ced60>,
#  <matplotlib.lines.Line2D at 0x2e8978cee50>,
#  <matplotlib.lines.Line2D at 0x2e8978cef40>,
#  <matplotlib.lines.Line2D at 0x2e8978d6070>,
#  <matplotlib.lines.Line2D at 0x2e8978d6160>,
#  <matplotlib.lines.Line2D at 0x2e8978d6250>,
#  <matplotlib.lines.Line2D at 0x2e8978d6340>,
#  <matplotlib.lines.Line2D at 0x2e8978d6430>,
#  <matplotlib.lines.Line2D at 0x2e8978d6520>,
#  <matplotlib.lines.Line2D at 0x2e8978d6610>,
#  <matplotlib.lines.Line2D at 0x2e8978d6700>,
#  <matplotlib.lines.Line2D at 0x2e8978d67f0>,
#  <matplotlib.lines.Line2D at 0x2e8978d68e0>,
#  <matplotlib.lines.Line2D at 0x2e8978d69d0>,
#  <matplotlib.lines.Line2D at 0x2e8978d6ac0>,
#  <matplotlib.lines.Line2D at 0x2e8978d6bb0>,
#  <matplotlib.lines.Line2D at 0x2e8978d6ca0>,
#  <matplotlib.lines.Line2D at 0x2e8978d6d90>,
#  <matplotlib.lines.Line2D at 0x2e8978d6e80>,
#  <matplotlib.lines.Line2D at 0x2e8978d6f70>,
#  <matplotlib.lines.Line2D at 0x2e8978dd0a0>,
#  <matplotlib.lines.Line2D at 0x2e8978dd190>,
#  <matplotlib.lines.Line2D at 0x2e8978dd280>,
#  <matplotlib.lines.Line2D at 0x2e8978dd370>,
#  <matplotlib.lines.Line2D at 0x2e8978dd460>,
#  <matplotlib.lines.Line2D at 0x2e8978dd550>,
#  <matplotlib.lines.Line2D at 0x2e8978dd640>,
#  <matplotlib.lines.Line2D at 0x2e8978dd730>,
#  <matplotlib.lines.Line2D at 0x2e8978dd820>,
#  <matplotlib.lines.Line2D at 0x2e8978dd910>,
#  <matplotlib.lines.Line2D at 0x2e8978dda00>,
#  <matplotlib.lines.Line2D at 0x2e8978ddaf0>,
#  <matplotlib.lines.Line2D at 0x2e8978ddbe0>,
#  <matplotlib.lines.Line2D at 0x2e8978ddcd0>,
#  <matplotlib.lines.Line2D at 0x2e8978dddc0>,
#  <matplotlib.lines.Line2D at 0x2e8978ddeb0>,
#  <matplotlib.lines.Line2D at 0x2e8978ddfa0>,
#  <matplotlib.lines.Line2D at 0x2e8978e40d0>,
#  <matplotlib.lines.Line2D at 0x2e8978e41c0>,
#  <matplotlib.lines.Line2D at 0x2e8978e42b0>,
#  <matplotlib.lines.Line2D at 0x2e8978e43a0>,
#  <matplotlib.lines.Line2D at 0x2e8978e4490>,
#  <matplotlib.lines.Line2D at 0x2e8978e4580>,
#  <matplotlib.lines.Line2D at 0x2e8978e4670>,
#  <matplotlib.lines.Line2D at 0x2e8978e4760>,
#  <matplotlib.lines.Line2D at 0x2e8978e4850>,
#  <matplotlib.lines.Line2D at 0x2e8978e4940>,
#  <matplotlib.lines.Line2D at 0x2e8978e4a30>,
#  <matplotlib.lines.Line2D at 0x2e8978e4b20>,
#  <matplotlib.lines.Line2D at 0x2e8978e4c10>,
#  <matplotlib.lines.Line2D at 0x2e8978e4d00>,
#  <matplotlib.lines.Line2D at 0x2e8978e4df0>,
#  <matplotlib.lines.Line2D at 0x2e8978e4ee0>,
#  <matplotlib.lines.Line2D at 0x2e8978e4fd0>,
#  <matplotlib.lines.Line2D at 0x2e8978ee100>,
#  <matplotlib.lines.Line2D at 0x2e8978ee1f0>,
#  <matplotlib.lines.Line2D at 0x2e8978ee2e0>,
#  <matplotlib.lines.Line2D at 0x2e8978ee3d0>,
#  <matplotlib.lines.Line2D at 0x2e8978ee4c0>,
#  <matplotlib.lines.Line2D at 0x2e8978ee5b0>,
#  <matplotlib.lines.Line2D at 0x2e8978ee6a0>,
#  <matplotlib.lines.Line2D at 0x2e8978ee790>,
#  <matplotlib.lines.Line2D at 0x2e8978ee880>,
#  <matplotlib.lines.Line2D at 0x2e8978ee970>,
#  <matplotlib.lines.Line2D at 0x2e8978eea60>,
#  <matplotlib.lines.Line2D at 0x2e8978eeb50>,
#  <matplotlib.lines.Line2D at 0x2e8978eec40>,
#  <matplotlib.lines.Line2D at 0x2e8978eed30>,
#  <matplotlib.lines.Line2D at 0x2e8978eee20>,
#  <matplotlib.lines.Line2D at 0x2e8978eef10>,
#  <matplotlib.lines.Line2D at 0x2e8978f5040>,
#  <matplotlib.lines.Line2D at 0x2e8978f5130>,
#  <matplotlib.lines.Line2D at 0x2e8978f5220>,
#  <matplotlib.lines.Line2D at 0x2e8978f5310>,
#  <matplotlib.lines.Line2D at 0x2e8978f5400>,
#  <matplotlib.lines.Line2D at 0x2e8978f54f0>,
#  <matplotlib.lines.Line2D at 0x2e8978f55e0>,
#  <matplotlib.lines.Line2D at 0x2e8978f56d0>,
#  <matplotlib.lines.Line2D at 0x2e8978f57c0>,
#  <matplotlib.lines.Line2D at 0x2e8978f58b0>,
#  <matplotlib.lines.Line2D at 0x2e8978f59a0>,
#  <matplotlib.lines.Line2D at 0x2e8978f5a90>,
#  <matplotlib.lines.Line2D at 0x2e8978f5b80>,
#  <matplotlib.lines.Line2D at 0x2e8978f5c70>,
#  <matplotlib.lines.Line2D at 0x2e8978f5d60>,
#  <matplotlib.lines.Line2D at 0x2e8978f5e50>,
#  <matplotlib.lines.Line2D at 0x2e8978f5f40>,
#  <matplotlib.lines.Line2D at 0x2e8978fc070>,
#  <matplotlib.lines.Line2D at 0x2e8978fc160>,
#  <matplotlib.lines.Line2D at 0x2e8978fc250>,
#  <matplotlib.lines.Line2D at 0x2e8978fc340>,
#  <matplotlib.lines.Line2D at 0x2e8978fc430>,
#  <matplotlib.lines.Line2D at 0x2e8978fc520>,
#  <matplotlib.lines.Line2D at 0x2e8978fc610>,
#  <matplotlib.lines.Line2D at 0x2e8978fc700>,
#  <matplotlib.lines.Line2D at 0x2e8978fc7f0>,
#  <matplotlib.lines.Line2D at 0x2e8978fc8e0>,
#  <matplotlib.lines.Line2D at 0x2e8978fc9d0>,
#  <matplotlib.lines.Line2D at 0x2e8978fcac0>,
#  <matplotlib.lines.Line2D at 0x2e8978fcbb0>,
#  <matplotlib.lines.Line2D at 0x2e8978fcca0>,
#  <matplotlib.lines.Line2D at 0x2e8978fcd90>,
#  <matplotlib.lines.Line2D at 0x2e8978fce80>,
#  <matplotlib.lines.Line2D at 0x2e8978fcf70>,
#  <matplotlib.lines.Line2D at 0x2e8979030a0>,
#  <matplotlib.lines.Line2D at 0x2e897903190>,
#  <matplotlib.lines.Line2D at 0x2e897903280>,
#  <matplotlib.lines.Line2D at 0x2e897903370>,
#  <matplotlib.lines.Line2D at 0x2e897903460>,
#  <matplotlib.lines.Line2D at 0x2e897903550>,
#  <matplotlib.lines.Line2D at 0x2e897903640>,
#  <matplotlib.lines.Line2D at 0x2e897903730>,
#  <matplotlib.lines.Line2D at 0x2e897903820>,
#  <matplotlib.lines.Line2D at 0x2e897903910>,
#  <matplotlib.lines.Line2D at 0x2e897903a00>,
#  <matplotlib.lines.Line2D at 0x2e897903af0>,
#  <matplotlib.lines.Line2D at 0x2e897903be0>,
#  <matplotlib.lines.Line2D at 0x2e897903cd0>,
#  <matplotlib.lines.Line2D at 0x2e897903dc0>,
#  <matplotlib.lines.Line2D at 0x2e897903eb0>,
#  <matplotlib.lines.Line2D at 0x2e897903fa0>,
#  <matplotlib.lines.Line2D at 0x2e89790a0d0>,
#  <matplotlib.lines.Line2D at 0x2e89790a1c0>,
#  <matplotlib.lines.Line2D at 0x2e89790a2b0>,
#  <matplotlib.lines.Line2D at 0x2e89790a3a0>,
#  <matplotlib.lines.Line2D at 0x2e89790a490>,
#  <matplotlib.lines.Line2D at 0x2e89790a580>,
#  <matplotlib.lines.Line2D at 0x2e89790a670>,
#  <matplotlib.lines.Line2D at 0x2e89790a760>,
#  <matplotlib.lines.Line2D at 0x2e89790a850>,
#  <matplotlib.lines.Line2D at 0x2e89790a940>,
#  <matplotlib.lines.Line2D at 0x2e89790aa30>,
#  <matplotlib.lines.Line2D at 0x2e89790ab20>,
#  <matplotlib.lines.Line2D at 0x2e89790ac10>,
#  <matplotlib.lines.Line2D at 0x2e89790ad00>,
#  <matplotlib.lines.Line2D at 0x2e89790adf0>,
#  <matplotlib.lines.Line2D at 0x2e89790aee0>,
#  <matplotlib.lines.Line2D at 0x2e89790afd0>,
#  <matplotlib.lines.Line2D at 0x2e897912100>,
#  <matplotlib.lines.Line2D at 0x2e8979121f0>,
#  <matplotlib.lines.Line2D at 0x2e8979122e0>,
#  <matplotlib.lines.Line2D at 0x2e8979123d0>,
#  <matplotlib.lines.Line2D at 0x2e8979124c0>,
#  <matplotlib.lines.Line2D at 0x2e8979125b0>,
#  <matplotlib.lines.Line2D at 0x2e8979126a0>,
#  <matplotlib.lines.Line2D at 0x2e897912790>,
#  <matplotlib.lines.Line2D at 0x2e897912880>,
#  <matplotlib.lines.Line2D at 0x2e897912970>,
#  <matplotlib.lines.Line2D at 0x2e897912a60>,
#  <matplotlib.lines.Line2D at 0x2e897912b50>,
#  <matplotlib.lines.Line2D at 0x2e897912c40>,
#  <matplotlib.lines.Line2D at 0x2e897912d30>,
#  <matplotlib.lines.Line2D at 0x2e897912e20>,
#  <matplotlib.lines.Line2D at 0x2e897912f10>,
#  <matplotlib.lines.Line2D at 0x2e89791a040>,
#  <matplotlib.lines.Line2D at 0x2e89791a130>,
#  <matplotlib.lines.Line2D at 0x2e89791a220>,
#  <matplotlib.lines.Line2D at 0x2e89791a310>,
#  <matplotlib.lines.Line2D at 0x2e89791a400>,
#  <matplotlib.lines.Line2D at 0x2e89791a4f0>,
#  <matplotlib.lines.Line2D at 0x2e89791a5e0>,
#  <matplotlib.lines.Line2D at 0x2e89791a6d0>,
#  <matplotlib.lines.Line2D at 0x2e89791a7c0>,
#  <matplotlib.lines.Line2D at 0x2e89791a8b0>,
#  <matplotlib.lines.Line2D at 0x2e89791a9a0>,
#  <matplotlib.lines.Line2D at 0x2e89791aa90>,
#  <matplotlib.lines.Line2D at 0x2e89791ab80>,
#  <matplotlib.lines.Line2D at 0x2e89791ac70>,
#  <matplotlib.lines.Line2D at 0x2e89791ad60>,
#  <matplotlib.lines.Line2D at 0x2e89791ae50>,
#  <matplotlib.lines.Line2D at 0x2e89791af40>,
#  <matplotlib.lines.Line2D at 0x2e897923070>,
#  <matplotlib.lines.Line2D at 0x2e897923160>,
#  <matplotlib.lines.Line2D at 0x2e897923250>,
#  <matplotlib.lines.Line2D at 0x2e897923340>,
#  <matplotlib.lines.Line2D at 0x2e897923430>,
#  <matplotlib.lines.Line2D at 0x2e897923520>,
#  <matplotlib.lines.Line2D at 0x2e897923610>,
#  <matplotlib.lines.Line2D at 0x2e897923700>,
#  <matplotlib.lines.Line2D at 0x2e8979237f0>,
#  <matplotlib.lines.Line2D at 0x2e8979238e0>,
#  <matplotlib.lines.Line2D at 0x2e8979239d0>,
#  <matplotlib.lines.Line2D at 0x2e897923ac0>,
#  <matplotlib.lines.Line2D at 0x2e897923bb0>,
#  <matplotlib.lines.Line2D at 0x2e897923ca0>,
#  <matplotlib.lines.Line2D at 0x2e897923d90>,
#  <matplotlib.lines.Line2D at 0x2e897923e80>,
#  <matplotlib.lines.Line2D at 0x2e897923f70>,
#  <matplotlib.lines.Line2D at 0x2e8979290a0>,
#  <matplotlib.lines.Line2D at 0x2e897929190>,
#  <matplotlib.lines.Line2D at 0x2e897929280>,
#  <matplotlib.lines.Line2D at 0x2e897929370>,
#  <matplotlib.lines.Line2D at 0x2e897929460>,
#  <matplotlib.lines.Line2D at 0x2e897929550>,
#  <matplotlib.lines.Line2D at 0x2e897929640>,
#  <matplotlib.lines.Line2D at 0x2e897929730>,
#  <matplotlib.lines.Line2D at 0x2e897929820>,
#  <matplotlib.lines.Line2D at 0x2e897929910>,
#  <matplotlib.lines.Line2D at 0x2e897929a00>,
#  <matplotlib.lines.Line2D at 0x2e897929af0>,
#  <matplotlib.lines.Line2D at 0x2e897929be0>,
#  <matplotlib.lines.Line2D at 0x2e897929cd0>,
#  <matplotlib.lines.Line2D at 0x2e897929dc0>,
#  <matplotlib.lines.Line2D at 0x2e897929eb0>,
#  <matplotlib.lines.Line2D at 0x2e897929fa0>,
#  <matplotlib.lines.Line2D at 0x2e8979320d0>,
#  <matplotlib.lines.Line2D at 0x2e8979321c0>,
#  <matplotlib.lines.Line2D at 0x2e8979322b0>,
#  <matplotlib.lines.Line2D at 0x2e8979323a0>,
#  <matplotlib.lines.Line2D at 0x2e897932490>,
#  <matplotlib.lines.Line2D at 0x2e897932580>,
#  <matplotlib.lines.Line2D at 0x2e897932670>,
#  <matplotlib.lines.Line2D at 0x2e897932760>,
#  <matplotlib.lines.Line2D at 0x2e897932850>,
#  <matplotlib.lines.Line2D at 0x2e897932940>,
#  <matplotlib.lines.Line2D at 0x2e897932a30>,
#  <matplotlib.lines.Line2D at 0x2e897932b20>,
#  <matplotlib.lines.Line2D at 0x2e897932c10>,
#  <matplotlib.lines.Line2D at 0x2e897932d00>,
#  <matplotlib.lines.Line2D at 0x2e897932df0>,
#  <matplotlib.lines.Line2D at 0x2e897932ee0>,
#  <matplotlib.lines.Line2D at 0x2e897932fd0>,
#  <matplotlib.lines.Line2D at 0x2e897939100>,
#  <matplotlib.lines.Line2D at 0x2e8979391f0>,
#  <matplotlib.lines.Line2D at 0x2e8979392e0>,
#  <matplotlib.lines.Line2D at 0x2e8979393d0>,
#  <matplotlib.lines.Line2D at 0x2e8979394c0>,
#  <matplotlib.lines.Line2D at 0x2e8979395b0>,
#  <matplotlib.lines.Line2D at 0x2e8979396a0>,
#  <matplotlib.lines.Line2D at 0x2e897939790>,
#  <matplotlib.lines.Line2D at 0x2e897939880>,
#  <matplotlib.lines.Line2D at 0x2e897939970>,
#  <matplotlib.lines.Line2D at 0x2e897939a60>,
#  <matplotlib.lines.Line2D at 0x2e897939b50>,
#  <matplotlib.lines.Line2D at 0x2e897939c40>,
#  <matplotlib.lines.Line2D at 0x2e897939d30>,
#  <matplotlib.lines.Line2D at 0x2e897939e20>,
#  <matplotlib.lines.Line2D at 0x2e897939f10>,
#  <matplotlib.lines.Line2D at 0x2e897941040>,
#  <matplotlib.lines.Line2D at 0x2e897941130>,
#  <matplotlib.lines.Line2D at 0x2e897941220>,
#  <matplotlib.lines.Line2D at 0x2e897941310>,
#  <matplotlib.lines.Line2D at 0x2e897941400>,
#  <matplotlib.lines.Line2D at 0x2e8979414f0>,
#  <matplotlib.lines.Line2D at 0x2e8979415e0>,
#  <matplotlib.lines.Line2D at 0x2e8979416d0>,
#  <matplotlib.lines.Line2D at 0x2e8979417c0>,
#  <matplotlib.lines.Line2D at 0x2e8979418b0>,
#  <matplotlib.lines.Line2D at 0x2e8979419a0>,
#  <matplotlib.lines.Line2D at 0x2e897941a90>,
#  <matplotlib.lines.Line2D at 0x2e897941b80>,
#  <matplotlib.lines.Line2D at 0x2e897941c70>,
#  <matplotlib.lines.Line2D at 0x2e897941d60>,
#  <matplotlib.lines.Line2D at 0x2e897941e80>,
#  <matplotlib.lines.Line2D at 0x2e897941f70>,
#  <matplotlib.lines.Line2D at 0x2e89794a0a0>,
#  <matplotlib.lines.Line2D at 0x2e89794a190>,
#  <matplotlib.lines.Line2D at 0x2e89794a280>,
#  <matplotlib.lines.Line2D at 0x2e89794a370>,
#  <matplotlib.lines.Line2D at 0x2e89794a460>,
#  <matplotlib.lines.Line2D at 0x2e89794a550>,
#  <matplotlib.lines.Line2D at 0x2e89794a640>,
#  <matplotlib.lines.Line2D at 0x2e89794a730>,
#  <matplotlib.lines.Line2D at 0x2e89794a820>,
#  <matplotlib.lines.Line2D at 0x2e89794a910>,
#  <matplotlib.lines.Line2D at 0x2e89794aa00>,
#  <matplotlib.lines.Line2D at 0x2e89794aaf0>,
#  <matplotlib.lines.Line2D at 0x2e89794abe0>,
#  <matplotlib.lines.Line2D at 0x2e89794acd0>]

# %%
u1 = []
u2 = []
vetor = []
u1.append(random.uniform(-5, 5))
u1.append(random.uniform(-5, 5))
tempo = 0
xs = np.linspace(-5,5,500)
minimo = np.zeros((1, 500)).astype(complex)

while tempo < 498:
    print(u1)
    psi_g[0:500, tempo] = psi[0:500, tempo]
    plt.plot(xs, np.absolute(psi[0:500, tempo])**2)
    u2 = optimize.minimize(Objetivo, u1, args=(tempo, psi, psiExato), method='CG')
    print(f"Iteração: {tempo+1}")
    print(u2)
    print("---------------")
    minimo[0][tempo] = (u2.x[0])
    D = multMatrizes(M = 500, us = u2.x[0])
    psi = np.matmul(D, psi)
    tempo += 1
    u1 = []
    u1.append(u2.x[0])
    u1.append(random.uniform(-5, 5))

tempoFinal = time.time() - tempoInicial
print(tempoFinal)
# Out:
# [-3.417076400611656, 2.9343995338070936]
# Iteração: 1
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 141703.17403303116
#        x: [-1.259e+03  8.018e+00]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 126
#     njev: 42
# ---------------
# [-1259.2832103943617, -2.7314830495241127]
# Iteração: 2
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 127644.96173628364
#        x: [ 8.007e+00  7.858e+00]
#      nit: 17
#      jac: [-1.953e-03  2.930e-03]
#     nfev: 255
#     njev: 81
# ---------------
# [8.007415308472055, 3.241441218176231]
# Iteração: 3
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 127179.13490211853
#        x: [ 7.868e+00  7.742e+00]
#      nit: 6
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 78
#     njev: 26
# ---------------
# [7.867549194171462, -1.4120735655456818]
# Iteração: 4
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 126728.06778873134
#        x: [ 7.734e+00  7.650e+00]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 54
#     njev: 18
# ---------------
# [7.733574144946202, 1.6500779348536243]
# Iteração: 5
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 126292.6438374575
#        x: [ 7.639e+00  7.547e+00]
#      nit: 9
#      jac: [ 4.883e-03  9.766e-04]
#     nfev: 213
#     njev: 67
# ---------------
# [7.638742391406735, -1.2920437532721318]
# Iteração: 6
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 125873.68740344922
#        x: [ 7.437e+00  7.634e+00]
#      nit: 6
#      jac: [-1.172e-02  2.539e-02]
#     nfev: 54
#     njev: 18
# ---------------
# [7.436924518520042, 4.062214868875765]
# Iteração: 7
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 125471.95609126106
#        x: [ 7.564e+00  7.373e+00]
#      nit: 6
#      jac: [ 9.766e-04 -9.766e-04]
#     nfev: 206
#     njev: 65
# ---------------
# [7.563592764707316, 4.4807399067662175]
# Iteração: 8
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 125088.16260575494
#        x: [ 7.369e+00  7.301e+00]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 102
#     njev: 34
# ---------------
# [7.369499139008282, -0.6945064499805422]
# Iteração: 9
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 124722.96991975889
#        x: [ 7.300e+00  7.238e+00]
#      nit: 6
#      jac: [ 9.766e-04 -9.766e-04]
#     nfev: 165
#     njev: 51
# ---------------
# [7.299603149447229, 4.460534215772366]
# Iteração: 10
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 124376.98807497467
#        x: [ 7.235e+00  7.174e+00]
#      nit: 8
#      jac: [ 0.000e+00 -9.766e-04]
#     nfev: 75
#     njev: 25
# ---------------
# [7.2348431637701776, 2.1088546146466856]
# Iteração: 11
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 124050.78376243802
#        x: [ 7.177e+00  7.118e+00]
#      nit: 13
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 120
#     njev: 40
# ---------------
# [7.177011546820059, -4.089635971023588]
# Iteração: 12
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 123744.88031482589
#        x: [ 7.117e+00  7.063e+00]
#      nit: 9
#      jac: [ 9.766e-04  1.953e-03]
#     nfev: 278
#     njev: 89
# ---------------
# [7.116869394687389, 4.593194264918033]
# Iteração: 13
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 123459.75945740574
#        x: [ 7.054e+00  7.039e+00]
#      nit: 5
#      jac: [-2.930e-03  0.000e+00]
#     nfev: 88
#     njev: 26
# ---------------
# [7.053885342789271, -3.420742412536674]
# Iteração: 14
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 123195.8626804913
#        x: [ 7.049e+00  6.976e+00]
#      nit: 13
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 159
#     njev: 53
# ---------------
# [7.04895251741215, 1.697335390380875]
# Iteração: 15
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 122953.59254940195
#        x: [ 6.973e+00  6.959e+00]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 60
#     njev: 20
# ---------------
# [6.973144410849448, -0.23488731019138953]
# Iteração: 16
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 122733.31383184224
#        x: [ 6.954e+00  6.918e+00]
#      nit: 18
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 270
#     njev: 90
# ---------------
# [6.954267396365005, 0.4328520046337614]
# Iteração: 17
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 122535.354292815
#        x: [ 6.917e+00  6.892e+00]
#      nit: 9
#      jac: [-9.766e-04 -2.930e-03]
#     nfev: 225
#     njev: 71
# ---------------
# [6.916787923196039, 1.7251396072759873]
# Iteração: 18
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 122360.00541891673
#        x: [ 6.892e+00  6.868e+00]
#      nit: 6
#      jac: [ 3.906e-03  1.953e-03]
#     nfev: 162
#     njev: 50
# ---------------
# [6.89191706953978, 0.8569810921798782]
# Iteração: 19
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 122207.52312144784
#        x: [ 6.868e+00  6.855e+00]
#      nit: 9
#      jac: [ 9.766e-04  9.766e-04]
#     nfev: 177
#     njev: 56
# ---------------
# [6.867577525017445, -1.1242182920096133]
# Iteração: 20
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 122078.1282314592
#        x: [ 6.857e+00  6.825e+00]
#      nit: 10
#      jac: [-9.766e-04  9.766e-04]
#     nfev: 177
#     njev: 55
# ---------------
# [6.856683393629182, 3.855362344901037]
# Iteração: 21
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 121972.00693211706
#        x: [ 6.827e+00  6.817e+00]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 75
#     njev: 25
# ---------------
# [6.827120221398314, 3.854549925806541]
# Iteração: 22
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 121889.31111386248
#        x: [ 6.825e+00  6.805e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 138
#     njev: 46
# ---------------
# [6.82527688861821, -3.7970208079097514]
# Iteração: 23
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 121830.15866102281
#        x: [ 6.809e+00  6.807e+00]
#      nit: 8
#      jac: [ 3.906e-03  9.766e-04]
#     nfev: 185
#     njev: 58
# ---------------
# [6.809271885963952, -1.8298017213885154]
# Iteração: 24
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 121794.63357711649
#        x: [ 6.795e+00  6.800e+00]
#      nit: 7
#      jac: [ 9.766e-04 -9.766e-04]
#     nfev: 123
#     njev: 37
# ---------------
# [6.795030935743749, -3.50111145326919]
# Iteração: 25
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 121782.7862598403
#        x: [ 6.807e+00  6.799e+00]
#      nit: 6
#      jac: [ 3.906e-03  9.766e-04]
#     nfev: 118
#     njev: 36
# ---------------
# [6.8070244028032, -2.2133343161531362]
# Iteração: 26
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 121794.63349444632
#        x: [ 6.798e+00  6.802e+00]
#      nit: 10
#      jac: [-1.953e-03  0.000e+00]
#     nfev: 99
#     njev: 33
# ---------------
# [6.797660648953191, 0.5584441527471631]
# Iteração: 27
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 121857.73682955027
#        x: [ 6.806e+00  1.860e+01]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 69
#     njev: 23
# ---------------
# [6.805896676449259, -1.4282925220665743]
# Iteração: 28
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 106212.15777122401
#        x: [ 1.860e+01 -1.435e+00]
#      nit: 4
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 60
#     njev: 20
# ---------------
# [18.6016986232595, -3.27264133257665]
# Iteração: 29
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 106294.85356939962
#        x: [ 1.192e+01 -9.996e+00]
#      nit: 5
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 36
#     njev: 12
# ---------------
# [11.916974896057987, -3.0693177641877023]
# Iteração: 30
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 106373.39641094446
#        x: [-1.001e+01  6.841e+00]
#      nit: 6
#      jac: [ 4.883e-03  1.953e-03]
#     nfev: 138
#     njev: 42
# ---------------
# [-10.008633176393175, 4.5935276284089674]
# Iteração: 31
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 122207.52268395227
#        x: [ 6.844e+00  6.869e+00]
#      nit: 10
#      jac: [ 1.953e-03 -9.766e-04]
#     nfev: 87
#     njev: 29
# ---------------
# [6.844441920334931, 1.8802183165898967]
# Iteração: 32
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 122360.0049190614
#        x: [ 6.876e+00  6.886e+00]
#      nit: 10
#      jac: [ 6.836e-03  2.930e-03]
#     nfev: 266
#     njev: 85
# ---------------
# [6.875971868221236, 4.587754118842698]
# Iteração: 33
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 122535.35373178293
#        x: [ 6.882e+00  6.929e+00]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 68
#     njev: 19
# ---------------
# [6.8818228273118915, 0.14815267141025412]
# Iteração: 34
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 122733.31318508246
#        x: [ 6.920e+00  6.949e+00]
#      nit: 11
#      jac: [-1.953e-03 -3.906e-03]
#     nfev: 196
#     njev: 62
# ---------------
# [6.920331853142488, 4.6100353137426655]
# Iteração: 35
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 122953.59180848865
#        x: [ 6.949e+00  6.992e+00]
#      nit: 11
#      jac: [-1.953e-03  0.000e+00]
#     nfev: 174
#     njev: 58
# ---------------
# [6.948858854631037, -0.10997930170399872]
# Iteração: 36
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 123195.8618444066
#        x: [ 6.988e+00  7.027e+00]
#      nit: 8
#      jac: [ 0.000e+00  9.766e-04]
#     nfev: 164
#     njev: 51
# ---------------
# [6.98785790407042, -4.987248372356996]
# Iteração: 37
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 123459.75860095302
#        x: [ 7.031e+00  7.052e+00]
#      nit: 7
#      jac: [-1.953e-03 -4.883e-03]
#     nfev: 68
#     njev: 19
# ---------------
# [7.031242829709422, -3.2401438664530744]
# Iteração: 38
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 123744.87942113016
#        x: [ 7.052e+00  7.129e+00]
#      nit: 8
#      jac: [ 9.766e-04  2.930e-03]
#     nfev: 174
#     njev: 54
# ---------------
# [7.052229752336012, 0.10016698002623947]
# Iteração: 39
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 124050.78281302805
#        x: [ 7.137e+00  7.162e+00]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 51
#     njev: 17
# ---------------
# [7.1368063060216365, 3.6277052526319746]
# Iteração: 40
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 124376.9870382727
#        x: [ 7.167e+00  7.232e+00]
#      nit: 15
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 162
#     njev: 52
# ---------------
# [7.166885426652142, -0.622604876740855]
# Iteração: 41
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 124722.968925961
#        x: [ 7.254e+00  7.291e+00]
#      nit: 6
#      jac: [ 1.172e-02  5.859e-03]
#     nfev: 52
#     njev: 14
# ---------------
# [7.254122855029803, 2.794135345411469]
# Iteração: 42
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 125088.16152296506
#        x: [ 7.277e+00  7.372e+00]
#      nit: 12
#      jac: [ 5.859e-03  1.953e-03]
#     nfev: 186
#     njev: 62
# ---------------
# [7.277340422121546, -1.7856423603387284]
# Iteração: 43
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 125471.9528680507
#        x: [ 7.369e+00  7.453e+00]
#      nit: 9
#      jac: [-4.883e-03  9.766e-04]
#     nfev: 180
#     njev: 56
# ---------------
# [7.369185950888156, -0.5843086122224292]
# Iteração: 44
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 125873.68333458676
#        x: [ 7.443e+00  7.553e+00]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 45
#     njev: 15
# ---------------
# [7.443133288339644, -3.3426468700080605]
# Iteração: 45
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 126292.64252759231
#        x: [ 7.546e+00  7.648e+00]
#      nit: 7
#      jac: [ 1.953e-03  1.953e-03]
#     nfev: 234
#     njev: 74
# ---------------
# [7.545665883559222, -2.4339174152946343]
# Iteração: 46
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 126728.06641261076
#        x: [ 7.642e+00  7.744e+00]
#      nit: 9
#      jac: [ 3.906e-03  1.953e-03]
#     nfev: 203
#     njev: 64
# ---------------
# [7.641814158061663, -3.2530373536821564]
# Iteração: 47
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 127179.1334931136
#        x: [ 7.742e+00  7.875e+00]
#      nit: 9
#      jac: [ 1.953e-03 -9.766e-04]
#     nfev: 105
#     njev: 35
# ---------------
# [7.742354360312114, 2.6000400607263527]
# Iteração: 48
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 127644.96016558906
#        x: [ 7.863e+00  7.991e+00]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 129
#     njev: 43
# ---------------
# [7.86268382368511, -0.29626004369600967]
# Iteração: 49
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 128124.59570689143
#        x: [ 7.989e+00  8.131e+00]
#      nit: 10
#      jac: [-9.766e-04  0.000e+00]
#     nfev: 207
#     njev: 63
# ---------------
# [7.989058389490198, 3.3274669961696706]
# Iteração: 50
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 128617.01605286016
#        x: [ 8.128e+00  8.285e+00]
#      nit: 13
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 180
#     njev: 60
# ---------------
# [8.127945862742859, -0.5200600569251979]
# Iteração: 51
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 129121.11672307194
#        x: [ 8.286e+00  8.455e+00]
#      nit: 11
#      jac: [ 9.766e-04  1.953e-03]
#     nfev: 199
#     njev: 64
# ---------------
# [8.285681969005031, -1.1162492476867403]
# Iteração: 52
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 129635.70451827998
#        x: [ 8.443e+00  8.659e+00]
#      nit: 12
#      jac: [ 4.883e-03  4.883e-03]
#     nfev: 113
#     njev: 34
# ---------------
# [8.442966685948019, 2.9339693278182075]
# Iteração: 53
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 130159.48772694016
#        x: [ 8.637e+00  8.854e+00]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 54
#     njev: 18
# ---------------
# [8.63692379955904, -0.6025704361544051]
# Iteração: 54
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 130691.06504069269
#        x: [ 8.848e+00  9.083e+00]
#      nit: 10
#      jac: [-3.906e-03 -1.953e-03]
#     nfev: 110
#     njev: 33
# ---------------
# [8.848459925365846, 0.5135418595515153]
# Iteração: 55
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 131228.91234925704
#        x: [ 9.071e+00  9.328e+00]
#      nit: 7
#      jac: [ 0.000e+00 -1.953e-03]
#     nfev: 81
#     njev: 27
# ---------------
# [9.071134745278595, 0.8431561194422121]
# Iteração: 56
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 131953.62575465374
#        x: [ 9.323e+00  2.449e+01]
#      nit: 6
#      jac: [ 7.812e-03  5.859e-03]
#     nfev: 274
#     njev: 85
# ---------------
# [9.322541853810302, -0.2993209050998491]
# Iteração: 57
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 113161.17269824742
#        x: [ 2.449e+01 -2.993e-01]
#      nit: 1
#      jac: [ 0.000e+00  9.766e-04]
#     nfev: 134
#     njev: 41
# ---------------
# [24.486339392869883, 3.7526049742355667]
# Iteração: 58
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 113707.2200240744
#        x: [ 1.305e+01 -7.771e+00]
#      nit: 4
#      jac: [ 3.906e-03 -1.953e-03]
#     nfev: 203
#     njev: 64
# ---------------
# [13.054728624480235, 3.750595556110669]
# Iteração: 59
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 114069.62272242867
#        x: [-7.768e+00  1.058e+01]
#      nit: 7
#      jac: [ 0.000e+00  9.766e-04]
#     nfev: 105
#     njev: 35
# ---------------
# [-7.767517956750524, -1.948947972636872]
# Iteração: 60
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 133948.1897478522
#        x: [ 1.059e+01  1.097e+01]
#      nit: 4
#      jac: [ 1.953e-03  0.000e+00]
#     nfev: 133
#     njev: 41
# ---------------
# [10.591146136521493, -2.0426502958536275]
# Iteração: 61
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 134482.61129734103
#        x: [ 1.096e+01  1.143e+01]
#      nit: 6
#      jac: [ 1.953e-03  0.000e+00]
#     nfev: 154
#     njev: 48
# ---------------
# [10.960660441275314, 4.187100576036256]
# Iteração: 62
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 135007.66468939485
#        x: [ 1.142e+01  1.188e+01]
#      nit: 5
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 60
#     njev: 20
# ---------------
# [11.424967891721545, -0.9097200834887715]
# Iteração: 63
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 135520.13201706513
#        x: [ 1.189e+01  1.238e+01]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 159
#     njev: 53
# ---------------
# [11.8904428725834, -2.1831750130351635]
# Iteração: 64
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 136016.47946147644
#        x: [ 1.238e+01  1.296e+01]
#      nit: 5
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 48
#     njev: 16
# ---------------
# [12.377166575578501, -1.020206031882008]
# Iteração: 65
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 136492.8447311101
#        x: [ 1.296e+01  1.352e+01]
#      nit: 8
#      jac: [ 1.953e-03 -1.953e-03]
#     nfev: 114
#     njev: 38
# ---------------
# [12.95894205594922, 2.7315377334635205]
# Iteração: 66
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 136945.0379835917
#        x: [ 1.352e+01  1.413e+01]
#      nit: 6
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 51
#     njev: 17
# ---------------
# [13.516338387509252, -3.8293353139386666]
# Iteração: 67
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 137368.56325007405
#        x: [ 1.412e+01  1.478e+01]
#      nit: 5
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 81
#     njev: 27
# ---------------
# [14.11929484655084, -1.1116301420701324]
# Iteração: 68
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 137758.6687375507
#        x: [ 1.476e+01  1.541e+01]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 75
#     njev: 25
# ---------------
# [14.760666897664587, -2.075906634654474]
# Iteração: 69
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 138110.43483828945
#        x: [ 1.539e+01  1.601e+01]
#      nit: 5
#      jac: [-1.953e-03  0.000e+00]
#     nfev: 130
#     njev: 40
# ---------------
# [15.3868526606151, -4.660574310004257]
# Iteração: 70
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 138418.9070173569
#        x: [ 1.600e+01  1.658e+01]
#      nit: 5
#      jac: [-1.953e-03  0.000e+00]
#     nfev: 197
#     njev: 62
# ---------------
# [15.997416072773587, -4.516386392959454]
# Iteração: 71
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 138679.27560486854
#        x: [ 1.656e+01  1.707e+01]
#      nit: 8
#      jac: [ 0.000e+00 -1.953e-03]
#     nfev: 230
#     njev: 73
# ---------------
# [16.564200167505447, 0.5697910824551844]
# Iteração: 72
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 138887.09866019862
#        x: [ 1.703e+01  1.750e+01]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 72
#     njev: 24
# ---------------
# [17.034655404185525, -4.927328007200595]
# Iteração: 73
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 139038.55106652173
#        x: [ 1.749e+01  1.780e+01]
#      nit: 14
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 147
#     njev: 49
# ---------------
# [17.488555758048232, -2.0605995207888705]
# Iteração: 74
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 139130.67509549053
#        x: [ 1.779e+01  1.791e+01]
#      nit: 8
#      jac: [ 1.172e-02  5.859e-03]
#     nfev: 266
#     njev: 85
# ---------------
# [17.791153350195746, 3.3749376018286714]
# Iteração: 75
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 139161.59731000027
#        x: [ 1.795e+01  1.788e+01]
#      nit: 7
#      jac: [ 7.812e-03  1.953e-03]
#     nfev: 84
#     njev: 28
# ---------------
# [17.945454582118785, -0.17650817278910136]
# Iteração: 76
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 139130.67535772108
#        x: [ 1.788e+01  1.777e+01]
#      nit: 7
#      jac: [ 1.953e-03  7.812e-03]
#     nfev: 241
#     njev: 79
# ---------------
# [17.87711785062986, -2.210631916044934]
# Iteração: 77
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 139038.55137927108
#        x: [ 1.779e+01  1.743e+01]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 66
#     njev: 22
# ---------------
# [17.794116016523652, -0.07406469411979444]
# Iteração: 78
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 138887.09919633786
#        x: [ 1.744e+01  1.707e+01]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 117
#     njev: 39
# ---------------
# [17.43919791896599, -1.6247053828628042]
# Iteração: 79
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 138679.27638209716
#        x: [ 1.706e+01  1.660e+01]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 99
#     njev: 33
# ---------------
# [17.055120625996352, -4.91272010599907]
# Iteração: 80
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 138418.90794373327
#        x: [ 1.658e+01  1.596e+01]
#      nit: 4
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 54
#     njev: 18
# ---------------
# [16.58348641390101, 3.4642955993607885]
# Iteração: 81
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 138110.43587772484
#        x: [ 1.601e+01  1.537e+01]
#      nit: 7
#      jac: [-3.906e-03 -1.953e-03]
#     nfev: 176
#     njev: 55
# ---------------
# [16.00509888353175, 2.6293142339009536]
# Iteração: 82
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 137758.66991434348
#        x: [ 1.537e+01  1.473e+01]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 63
#     njev: 21
# ---------------
# [15.36859943944629, 0.23187846445289928]
# Iteração: 83
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 137368.56449572934
#        x: [ 1.476e+01  1.412e+01]
#      nit: 9
#      jac: [ 1.953e-03 -3.906e-03]
#     nfev: 123
#     njev: 41
# ---------------
# [14.758820211073115, -1.0043832200777758]
# Iteração: 84
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 136945.03934748308
#        x: [ 1.413e+01  1.352e+01]
#      nit: 7
#      jac: [ 1.953e-03 -1.953e-03]
#     nfev: 191
#     njev: 61
# ---------------
# [14.126418801610782, 1.7418360331725822]
# Iteração: 85
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 136492.84617267543
#        x: [ 1.353e+01  1.293e+01]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 117
#     njev: 39
# ---------------
# [13.530796829176207, 1.6967140738113624]
# Iteração: 86
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 136016.4809659004
#        x: [ 1.293e+01  1.240e+01]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 66
#     njev: 22
# ---------------
# [12.931599729131541, 4.781320010305837]
# Iteração: 87
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 135520.13360415632
#        x: [ 1.239e+01  1.191e+01]
#      nit: 6
#      jac: [ 7.812e-03  3.906e-03]
#     nfev: 63
#     njev: 18
# ---------------
# [12.39303500425015, 1.0355593865129933]
# Iteração: 88
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 135007.66637190527
#        x: [ 1.189e+01  1.139e+01]
#      nit: 6
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 57
#     njev: 19
# ---------------
# [11.892782939739632, 4.435694202753016]
# Iteração: 89
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 134482.61292550404
#        x: [ 1.142e+01  1.098e+01]
#      nit: 7
#      jac: [ 1.953e-03  0.000e+00]
#     nfev: 174
#     njev: 54
# ---------------
# [11.417044965780137, -2.5296809504495865]
# Iteração: 90
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 133948.19141866302
#        x: [ 1.097e+01  1.059e+01]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 114
#     njev: 38
# ---------------
# [10.971012397891796, -3.249895496895082]
# Iteração: 91
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 133407.32443202607
#        x: [ 1.058e+01  1.022e+01]
#      nit: 9
#      jac: [ 1.953e-03  3.906e-03]
#     nfev: 195
#     njev: 61
# ---------------
# [10.584766427135559, -3.778689391605016]
# Iteração: 92
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 132862.66383166309
#        x: [ 1.022e+01  9.897e+00]
#      nit: 14
#      jac: [ 7.812e-03 -1.953e-03]
#     nfev: 180
#     njev: 60
# ---------------
# [10.221968553850498, 0.9181230295185161]
# Iteração: 93
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 132316.61650098246
#        x: [ 9.895e+00  9.588e+00]
#      nit: 6
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 45
#     njev: 15
# ---------------
# [9.895124563764908, 1.5055514699745896]
# Iteração: 94
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 131771.36954339157
#        x: [ 9.597e+00  9.309e+00]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 57
#     njev: 19
# ---------------
# [9.59725113687183, 3.047853445722229]
# Iteração: 95
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 131228.91402554253
#        x: [ 9.312e+00  9.070e+00]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 75
#     njev: 25
# ---------------
# [9.312041118680597, -3.310132731412714]
# Iteração: 96
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 130691.06674821163
#        x: [ 9.068e+00  8.818e+00]
#      nit: 9
#      jac: [-4.883e-03 -2.930e-03]
#     nfev: 159
#     njev: 49
# ---------------
# [9.06842810328755, 1.9217906597515855]
# Iteração: 97
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 130159.48934635204
#        x: [ 8.845e+00  8.634e+00]
#      nit: 9
#      jac: [-9.766e-04  0.000e+00]
#     nfev: 138
#     njev: 46
# ---------------
# [8.845210287118336, -1.2033950537846048]
# Iteração: 98
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 129635.70610449353
#        x: [ 8.636e+00  8.451e+00]
#      nit: 7
#      jac: [-9.766e-04 -9.766e-04]
#     nfev: 288
#     njev: 90
# ---------------
# [8.635735488882169, 3.5998214031956017]
# Iteração: 99
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 129121.11830315267
#        x: [ 8.453e+00  8.280e+00]
#      nit: 8
#      jac: [-1.953e-03  0.000e+00]
#     nfev: 133
#     njev: 41
# ---------------
# [8.452777774234713, -2.0655372848350453]
# Iteração: 100
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 128617.01760897957
#        x: [ 8.288e+00  8.125e+00]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 99
#     njev: 33
# ---------------
# [8.28847515216332, 1.3129657296767352]
# Iteração: 101
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 128124.59722271418
#        x: [ 8.121e+00  7.987e+00]
#      nit: 14
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 165
#     njev: 55
# ---------------
# [8.120810215241292, -2.7148684602620254]
# Iteração: 102
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 127644.96163049157
#        x: [ 7.992e+00  7.857e+00]
#      nit: 9
#      jac: [ 9.766e-04  2.930e-03]
#     nfev: 123
#     njev: 41
# ---------------
# [7.992298769239974, -3.2794506675404023]
# Iteração: 103
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 127179.13490093159
#        x: [ 7.854e+00  7.750e+00]
#      nit: 6
#      jac: [ 0.000e+00 -9.766e-04]
#     nfev: 154
#     njev: 48
# ---------------
# [7.853769749480547, -2.9644725486451984]
# Iteração: 104
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 126728.06780287015
#        x: [ 7.739e+00  7.656e+00]
#      nit: 12
#      jac: [ 5.859e-03  3.906e-03]
#     nfev: 296
#     njev: 93
# ---------------
# [7.738744209237817, -1.2275491430242247]
# Iteração: 105
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 126292.64385338596
#        x: [ 7.636e+00  7.541e+00]
#      nit: 7
#      jac: [ 1.953e-03  1.953e-03]
#     nfev: 180
#     njev: 56
# ---------------
# [7.635800981025814, 1.25421824508037]
# Iteração: 106
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 125873.68459448176
#        x: [ 7.551e+00  7.453e+00]
#      nit: 10
#      jac: [ 9.766e-04 -9.766e-04]
#     nfev: 102
#     njev: 34
# ---------------
# [7.55091249995654, -2.6158679085918535]
# Iteração: 107
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 125471.95408622731
#        x: [ 7.448e+00  7.377e+00]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 39
#     njev: 13
# ---------------
# [7.448035349084853, 1.286051563738165]
# Iteração: 108
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 125088.16261418379
#        x: [ 7.383e+00  7.295e+00]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 57
#     njev: 19
# ---------------
# [7.383348042391719, -1.6671465824820775]
# Iteração: 109
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 124722.96993095674
#        x: [ 7.294e+00  7.225e+00]
#      nit: 11
#      jac: [-9.766e-04 -9.766e-04]
#     nfev: 208
#     njev: 66
# ---------------
# [7.294376610404786, 4.689125710939255]
# Iteração: 110
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 124376.9880777749
#        x: [ 7.236e+00  7.169e+00]
#      nit: 4
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 51
#     njev: 17
# ---------------
# [7.2361833168747305, -4.242215084751226]
# Iteração: 111
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 124050.78376889488
#        x: [ 7.173e+00  7.115e+00]
#      nit: 11
#      jac: [ 3.906e-03 -9.766e-04]
#     nfev: 274
#     njev: 88
# ---------------
# [7.172998949479289, -4.975675310279042]
# Iteração: 112
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 123744.88034764916
#        x: [ 7.099e+00  7.084e+00]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 111
#     njev: 37
# ---------------
# [7.099241260327817, -0.6535232460383424]
# Iteração: 113
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 123459.75945891914
#        x: [ 7.086e+00  7.024e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 96
#     njev: 32
# ---------------
# [7.086246882133846, -4.969010644130691]
# Iteração: 114
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 123122.40001307114
#        x: [ 7.025e+00  1.891e+01]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 194
#     njev: 64
# ---------------
# [7.0254879280605955, 4.210004694900073]
# Iteração: 115
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 106921.50658780319
#        x: [ 1.892e+01  4.208e+00]
#      nit: 2
#      jac: [ 2.930e-03 -1.953e-03]
#     nfev: 129
#     njev: 39
# ---------------
# [18.922976970909, -4.545467889526419]
# Iteração: 116
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 106701.2278932542
#        x: [ 1.274e+01 -1.076e+01]
#      nit: 6
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 42
#     njev: 14
# ---------------
# [12.735868797875128, -0.9070365741992612]
# Iteração: 117
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 106576.73093135297
#        x: [-1.077e+01  6.897e+00]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 72
#     njev: 24
# ---------------
# [-10.765499388087838, -4.390394670915879]
# Iteração: 118
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 122360.0054272031
#        x: [ 6.902e+00  6.863e+00]
#      nit: 6
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 162
#     njev: 51
# ---------------
# [6.902262537245278, 2.3369706528233847]
# Iteração: 119
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 122207.52313950784
#        x: [ 6.865e+00  6.856e+00]
#      nit: 6
#      jac: [ 4.883e-03  2.930e-03]
#     nfev: 61
#     njev: 17
# ---------------
# [6.8654156824206645, 3.309045338923042]
# Iteração: 120
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 122078.12823555061
#        x: [ 6.850e+00  6.837e+00]
#      nit: 6
#      jac: [-2.930e-03 -9.766e-04]
#     nfev: 163
#     njev: 51
# ---------------
# [6.8499876619861695, -0.744376106363795]
# Iteração: 121
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 121972.00692980067
#        x: [ 6.825e+00  6.823e+00]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 39
#     njev: 13
# ---------------
# [6.82540417609866, -4.07442811694851]
# Iteração: 122
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 121889.31111316074
#        x: [ 6.823e+00  6.814e+00]
#      nit: 13
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 96
#     njev: 32
# ---------------
# [6.822960928309868, 0.7709517278076117]
# Iteração: 123
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 121830.15864267913
#        x: [ 6.810e+00  6.802e+00]
#      nit: 8
#      jac: [-3.906e-03 -1.953e-03]
#     nfev: 101
#     njev: 30
# ---------------
# [6.809607906584674, 3.5049044414995087]
# Iteração: 124
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 121794.63357349247
#        x: [ 6.811e+00  6.792e+00]
#      nit: 11
#      jac: [ 0.000e+00  9.766e-04]
#     nfev: 227
#     njev: 72
# ---------------
# [6.810536089923805, -3.6393311617477107]
# Iteração: 125
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 121782.78626908595
#        x: [ 6.794e+00  6.809e+00]
#      nit: 9
#      jac: [ 6.836e-03  9.766e-04]
#     nfev: 170
#     njev: 53
# ---------------
# [6.794038802827627, 0.3678216168508346]
# Iteração: 126
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 121794.63349948442
#        x: [ 6.809e+00  6.800e+00]
#      nit: 13
#      jac: [ 9.766e-04 -9.766e-04]
#     nfev: 132
#     njev: 44
# ---------------
# [6.808518639534757, 2.242272428770489]
# Iteração: 127
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 121830.15849970371
#        x: [ 6.798e+00  6.809e+00]
#      nit: 5
#      jac: [ 1.953e-03  1.953e-03]
#     nfev: 183
#     njev: 57
# ---------------
# [6.798397198459413, 1.560227821524629]
# Iteração: 128
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 121889.31088823685
#        x: [ 6.809e+00  6.821e+00]
#      nit: 8
#      jac: [ 2.930e-03  0.000e+00]
#     nfev: 129
#     njev: 38
# ---------------
# [6.809200377109624, 2.825171407696324]
# Iteração: 129
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 121972.00664326234
#        x: [ 6.817e+00  6.844e+00]
#      nit: 9
#      jac: [-1.953e-03  1.953e-03]
#     nfev: 182
#     njev: 57
# ---------------
# [6.816527400112391, 2.96496423003203]
# Iteração: 130
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 122078.12788044324
#        x: [ 6.831e+00  6.863e+00]
#      nit: 9
#      jac: [-9.766e-04  0.000e+00]
#     nfev: 161
#     njev: 50
# ---------------
# [6.830853525645224, -3.9462819286199693]
# Iteração: 131
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 122207.52271069009
#        x: [ 6.850e+00  6.884e+00]
#      nit: 7
#      jac: [-9.766e-04 -9.766e-04]
#     nfev: 153
#     njev: 47
# ---------------
# [6.850171045563107, 4.677238218234999]
# Iteração: 132
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 122360.00492112475
#        x: [ 6.868e+00  6.893e+00]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 63
#     njev: 21
# ---------------
# [6.868498479329935, 0.14646508955559767]
# Iteração: 133
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 122535.3537180555
#        x: [ 6.896e+00  6.922e+00]
#      nit: 12
#      jac: [ 0.000e+00  3.906e-03]
#     nfev: 102
#     njev: 34
# ---------------
# [6.895731440840285, -2.934759364610946]
# Iteração: 134
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 122733.31319020528
#        x: [ 6.914e+00  6.957e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 63
#     njev: 21
# ---------------
# [6.913823145873673, -2.8198500086324607]
# Iteração: 135
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 122953.5918400461
#        x: [ 6.968e+00  6.969e+00]
#      nit: 10
#      jac: [-9.766e-04 -9.766e-04]
#     nfev: 137
#     njev: 42
# ---------------
# [6.9679146111003485, 3.6139087055702266]
# Iteração: 136
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 123195.86187171948
#        x: [ 6.968e+00  7.031e+00]
#      nit: 7
#      jac: [ 9.766e-04  1.953e-03]
#     nfev: 159
#     njev: 49
# ---------------
# [6.96802569082299, 3.4085846159907405]
# Iteração: 137
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 123459.75857971306
#        x: [ 7.030e+00  7.071e+00]
#      nit: 11
#      jac: [ 1.953e-03  1.953e-03]
#     nfev: 219
#     njev: 69
# ---------------
# [7.029587100707139, -1.5150926189566514]
# Iteração: 138
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 123744.87939446929
#        x: [ 7.069e+00  7.121e+00]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 99
#     njev: 33
# ---------------
# [7.068701220936199, 0.1439698815495829]
# Iteração: 139
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 124050.78279480583
#        x: [ 7.120e+00  7.183e+00]
#      nit: 8
#      jac: [ 9.766e-04  3.906e-03]
#     nfev: 75
#     njev: 25
# ---------------
# [7.120254812515301, -0.42380795118198655]
# Iteração: 140
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 124376.9870359966
#        x: [ 7.169e+00  7.235e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 93
#     njev: 31
# ---------------
# [7.168636572867012, -1.2265965288515632]
# Iteração: 141
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 124722.96881827756
#        x: [ 7.238e+00  7.296e+00]
#      nit: 10
#      jac: [ 0.000e+00  1.953e-03]
#     nfev: 141
#     njev: 47
# ---------------
# [7.238463543344254, 1.450970525977624]
# Iteração: 142
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 125088.16144323624
#        x: [ 7.296e+00  7.376e+00]
#      nit: 10
#      jac: [ 9.766e-04  9.766e-04]
#     nfev: 227
#     njev: 72
# ---------------
# [7.2955263698266295, -3.5777578230182385]
# Iteração: 143
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 125471.95286807154
#        x: [ 7.373e+00  7.455e+00]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 138
#     njev: 46
# ---------------
# [7.373438375344451, 0.24987868770587163]
# Iteração: 144
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 125873.68339428541
#        x: [ 7.477e+00  7.513e+00]
#      nit: 8
#      jac: [ 5.859e-03 -3.906e-03]
#     nfev: 126
#     njev: 38
# ---------------
# [7.477210458089758, 4.204983243337777]
# Iteração: 145
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 126292.64261388892
#        x: [ 7.534e+00  7.622e+00]
#      nit: 5
#      jac: [ 3.906e-03  3.906e-03]
#     nfev: 60
#     njev: 16
# ---------------
# [7.5343932381034895, -2.872938488749349]
# Iteração: 146
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 126728.06644206608
#        x: [ 7.620e+00  7.743e+00]
#      nit: 15
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 183
#     njev: 61
# ---------------
# [7.619835996101697, 3.0834964833909613]
# Iteração: 147
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 127179.13347452154
#        x: [ 7.745e+00  7.862e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 120
#     njev: 40
# ---------------
# [7.744852239898125, -3.2139187414903034]
# Iteração: 148
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 127644.96016233624
#        x: [ 7.858e+00  7.990e+00]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 54
#     njev: 18
# ---------------
# [7.858399408752947, 0.09089174999128424]
# Iteração: 149
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 128124.59570686216
#        x: [ 7.990e+00  8.128e+00]
#      nit: 14
#      jac: [ 3.906e-03  2.930e-03]
#     nfev: 458
#     njev: 148
# ---------------
# [7.990432446820621, 2.2978134354879867]
# Iteração: 150
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 128617.01606571488
#        x: [ 8.119e+00  8.294e+00]
#      nit: 6
#      jac: [ 1.953e-03  0.000e+00]
#     nfev: 129
#     njev: 40
# ---------------
# [8.11898108315818, 4.363035256896632]
# Iteração: 151
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 129121.11673863606
#        x: [ 8.298e+00  8.447e+00]
#      nit: 8
#      jac: [-9.766e-04 -9.766e-04]
#     nfev: 161
#     njev: 50
# ---------------
# [8.298237660078524, 3.154613818601181]
# Iteração: 152
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 129635.70449661929
#        x: [ 8.442e+00  8.642e+00]
#      nit: 11
#      jac: [-1.953e-03 -1.953e-03]
#     nfev: 99
#     njev: 33
# ---------------
# [8.442231143765365, 0.5263141233609314]
# Iteração: 153
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 130159.4877298304
#        x: [ 8.656e+00  8.830e+00]
#      nit: 7
#      jac: [ 0.000e+00  9.766e-04]
#     nfev: 186
#     njev: 58
# ---------------
# [8.656030975441817, 1.2200428135716477]
# Iteração: 154
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 130691.06504079739
#        x: [ 8.835e+00  9.066e+00]
#      nit: 3
#      jac: [-9.766e-04 -9.766e-04]
#     nfev: 176
#     njev: 55
# ---------------
# [8.835015280759965, -1.8401377263747354]
# Iteração: 155
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 131228.91234353583
#        x: [ 9.058e+00  9.323e+00]
#      nit: 9
#      jac: [ 3.906e-03  1.953e-03]
#     nfev: 75
#     njev: 25
# ---------------
# [9.058222728733293, -2.371369227103075]
# Iteração: 156
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 131771.367850797
#        x: [ 9.326e+00  9.590e+00]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 63
#     njev: 21
# ---------------
# [9.326001801841691, 1.9879610552226543]
# Iteração: 157
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 132316.6148137654
#        x: [ 9.578e+00  9.892e+00]
#      nit: 3
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 27
#     njev: 9
# ---------------
# [9.578199409361284, 3.1545007553929754]
# Iteração: 158
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 132862.6621428239
#        x: [ 9.906e+00  1.021e+01]
#      nit: 12
#      jac: [-5.859e-03 -5.859e-03]
#     nfev: 129
#     njev: 43
# ---------------
# [9.905635866461536, 0.15227952278329582]
# Iteração: 159
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 133407.32273540038
#        x: [ 1.022e+01  1.057e+01]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 72
#     njev: 24
# ---------------
# [10.220399035998826, -0.3310279188016638]
# Iteração: 160
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 133948.18974159338
#        x: [ 1.058e+01  1.097e+01]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 117
#     njev: 39
# ---------------
# [10.581813101463776, -3.0619391942814045]
# Iteração: 161
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 134482.61128718208
#        x: [ 1.098e+01  1.142e+01]
#      nit: 6
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 60
#     njev: 20
# ---------------
# [10.97975081407405, -4.833582449866657]
# Iteração: 162
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 135007.66478298465
#        x: [ 1.144e+01  1.184e+01]
#      nit: 7
#      jac: [ 0.000e+00 -3.906e-03]
#     nfev: 75
#     njev: 25
# ---------------
# [11.435373927638167, -0.7003481283520516]
# Iteração: 163
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 135520.1320993404
# ...
# Iteração: 445
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 126292.64254868469
#        x: [ 7.542e+00  7.660e+00]
#      nit: 4
#      jac: [ 2.930e-03  5.859e-03]
#     nfev: 116
#     njev: 35
# ---------------
# [7.541665092026604, -0.554121196813119]
# Iteração: 446
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 126728.06642719898
#        x: [ 7.635e+00  7.751e+00]
#      nit: 9
#      jac: [-1.270e-02 -4.883e-03]
#     nfev: 83
#     njev: 24
# ---------------
# [7.634566533152418, 2.738422209890919]
# Iteração: 447
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 127179.1334984616
#        x: [ 7.748e+00  7.865e+00]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 96
#     njev: 32
# ---------------
# [7.747532699351555, -3.6361907591096387]
# Iteração: 448
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 127644.96022884583
#        x: [ 7.847e+00  8.012e+00]
#      nit: 4
#      jac: [-8.789e-03  1.953e-03]
#     nfev: 72
#     njev: 24
# ---------------
# [7.847229371257886, 1.0867792347406535]
# Iteração: 449
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 128124.59577547298
#        x: [ 8.001e+00  8.141e+00]
#      nit: 7
#      jac: [-9.766e-04  0.000e+00]
#     nfev: 170
#     njev: 53
# ---------------
# [8.001457165463409, 1.2612646940393288]
# Iteração: 450
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 128617.0160695524
#        x: [ 8.127e+00  8.288e+00]
#      nit: 8
#      jac: [ 1.953e-03  0.000e+00]
#     nfev: 150
#     njev: 50
# ---------------
# [8.126735061063107, -0.9850765626299909]
# Iteração: 451
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 129121.11679572807
#        x: [ 8.269e+00  8.470e+00]
#      nit: 8
#      jac: [ 9.766e-04  0.000e+00]
#     nfev: 189
#     njev: 59
# ---------------
# [8.269424817437306, -1.3462129026214296]
# Iteração: 452
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 129635.70455979771
#        x: [ 8.480e+00  8.630e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 108
#     njev: 36
# ---------------
# [8.479819522465622, 1.7229828984067987]
# Iteração: 453
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 130159.48778604591
#        x: [ 8.613e+00  8.877e+00]
#      nit: 5
#      jac: [ 2.930e-03  5.859e-03]
#     nfev: 61
#     njev: 17
# ---------------
# [8.612834102276528, 4.825387268924796]
# Iteração: 454
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 130691.06506960944
#        x: [ 8.856e+00  9.075e+00]
#      nit: 10
#      jac: [ 0.000e+00 -1.953e-03]
#     nfev: 208
#     njev: 66
# ---------------
# [8.856221350760695, 0.147392244952389]
# Iteração: 455
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 131228.91235564277
#        x: [ 9.081e+00  9.303e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 99
#     njev: 33
# ---------------
# [9.080781365203476, -1.9750606400650996]
# Iteração: 456
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 131771.36786870362
#        x: [ 9.317e+00  9.573e+00]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 51
#     njev: 17
# ---------------
# [9.317068036670609, -2.3788071816278245]
# Iteração: 457
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 132316.6148038471
#        x: [ 9.587e+00  9.889e+00]
#      nit: 14
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 126
#     njev: 42
# ---------------
# [9.586998103365554, -3.3535107948579688]
# Iteração: 458
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 132862.66212886063
#        x: [ 9.887e+00  1.023e+01]
#      nit: 7
#      jac: [-7.812e-03 -5.859e-03]
#     nfev: 137
#     njev: 42
# ---------------
# [9.88658363570489, -1.5241006952249094]
# Iteração: 459
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 133407.32272760276
#        x: [ 1.023e+01  1.058e+01]
#      nit: 11
#      jac: [ 1.172e-02  1.953e-03]
#     nfev: 135
#     njev: 45
# ---------------
# [10.226884581891298, 0.906297043041965]
# Iteração: 460
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 133948.18973882482
#        x: [ 1.058e+01  1.098e+01]
#      nit: 8
#      jac: [-1.953e-03 -1.953e-03]
#     nfev: 90
#     njev: 30
# ---------------
# [10.583020677560015, -1.9826421633758216]
# Iteração: 461
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 134482.61129861866
#        x: [ 1.099e+01  1.142e+01]
#      nit: 6
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 84
#     njev: 28
# ---------------
# [10.985155938282494, 0.18026660226508362]
# Iteração: 462
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 135173.54297484434
#        x: [ 1.138e+01  2.933e+01]
#      nit: 4
#      jac: [ 3.906e-03  1.953e-03]
#     nfev: 177
#     njev: 55
# ---------------
# [11.384605077381302, 2.6131335411036174]
# Iteração: 463
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 115294.97595747405
#        x: [ 2.936e+01  2.628e+00]
#      nit: 4
#      jac: [ 9.766e-04  9.766e-04]
#     nfev: 159
#     njev: 49
# ---------------
# [29.361008526547014, 4.6841990563397236]
# Iteração: 464
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 115791.32336152694
#        x: [ 1.642e+01 -8.428e+00]
#      nit: 3
#      jac: [ 2.930e-03  0.000e+00]
#     nfev: 162
#     njev: 50
# ---------------
# [16.41655515770455, 1.0877198387447793]
# Iteração: 465
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 116101.81038472138
#        x: [-8.406e+00  1.351e+01]
#      nit: 6
#      jac: [-3.906e-03 -3.906e-03]
#     nfev: 196
#     njev: 63
# ---------------
# [-8.405989905217774, 4.470082318221349]
# Iteração: 466
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 136945.03798088507
#        x: [ 1.351e+01  1.414e+01]
#      nit: 9
#      jac: [ 7.812e-03  7.812e-03]
#     nfev: 114
#     njev: 38
# ---------------
# [13.510082705945996, -0.4295350540376557]
# Iteração: 467
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 137368.56321718416
#        x: [ 1.414e+01  1.476e+01]
#      nit: 5
#      jac: [ 1.953e-03 -1.953e-03]
#     nfev: 195
#     njev: 61
# ---------------
# [14.135080837152039, -3.3080367704237137]
# Iteração: 468
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 137758.66868252214
#        x: [ 1.475e+01  1.540e+01]
#      nit: 2
#      jac: [-3.906e-03  0.000e+00]
#     nfev: 162
#     njev: 50
# ---------------
# [14.749664785204033, -1.3151795460005564]
# Iteração: 469
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 138110.43481731194
#        x: [ 1.539e+01  1.599e+01]
#      nit: 6
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 66
#     njev: 22
# ---------------
# [15.389255143885007, -1.1767970432678276]
# Iteração: 470
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 138418.90703505982
#        x: [ 1.598e+01  1.657e+01]
#      nit: 6
#      jac: [ 5.859e-03  1.953e-03]
#     nfev: 192
#     njev: 60
# ---------------
# [15.975386540956471, -2.6336228452185626]
# Iteração: 471
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 138679.27569596603
#        x: [ 1.655e+01  1.709e+01]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 72
#     njev: 24
# ---------------
# [16.551602603831324, 2.1270313819661837]
# Iteração: 472
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 138887.09863103484
#        x: [ 1.710e+01  1.748e+01]
#      nit: 5
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 45
#     njev: 15
# ---------------
# [17.09839754890603, -2.446136546499642]
# Iteração: 473
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 139038.5509570544
#        x: [ 1.749e+01  1.773e+01]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 126
#     njev: 42
# ---------------
# [17.49041098335562, 0.8222185273119447]
# Iteração: 474
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 139130.67510031335
#        x: [ 1.773e+01  1.792e+01]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 96
#     njev: 32
# ---------------
# [17.72933141508995, 2.4826113151703684]
# Iteração: 475
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 139161.59723203274
#        x: [ 1.793e+01  1.791e+01]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 96
#     njev: 32
# ---------------
# [17.925091496893728, 0.3838839742911073]
# Iteração: 476
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 139130.67575122233
#        x: [ 1.784e+01  1.780e+01]
#      nit: 5
#      jac: [-9.766e-03 -5.859e-03]
#     nfev: 143
#     njev: 44
# ---------------
# [17.844857130695736, -0.048756102654357925]
# Iteração: 477
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 139038.5517387017
#        x: [ 1.786e+01  1.746e+01]
#      nit: 5
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 66
#     njev: 22
# ---------------
# [17.862309190950743, 0.5846315868616845]
# Iteração: 478
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 138887.0991697266
#        x: [ 1.745e+01  1.707e+01]
#      nit: 6
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 105
#     njev: 35
# ---------------
# [17.446423964433496, -3.678923836089474]
# Iteração: 479
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 138679.27646674874
#        x: [ 1.710e+01  1.651e+01]
#      nit: 4
#      jac: [ 9.766e-03 -1.953e-03]
#     nfev: 168
#     njev: 52
# ---------------
# [17.104819023722744, -3.40383937267444]
# Iteração: 480
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 138418.90799071567
#        x: [ 1.653e+01  1.599e+01]
#      nit: 6
#      jac: [-1.953e-03  0.000e+00]
#     nfev: 253
#     njev: 81
# ---------------
# [16.533590528115663, 3.243781048991938]
# Iteração: 481
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 138110.43585481812
#        x: [ 1.598e+01  1.539e+01]
#      nit: 14
#      jac: [ 1.953e-03  3.906e-03]
#     nfev: 246
#     njev: 82
# ---------------
# [15.980943501494256, -1.8873854290092087]
# Iteração: 482
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 137758.6698504415
#        x: [ 1.538e+01  1.476e+01]
#      nit: 5
#      jac: [-1.953e-03 -3.906e-03]
#     nfev: 78
#     njev: 26
# ---------------
# [15.379147311171094, -4.795218864529116]
# Iteração: 483
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 137368.56450882278
#        x: [ 1.478e+01  1.412e+01]
#      nit: 5
#      jac: [-1.953e-03 -1.953e-03]
#     nfev: 155
#     njev: 48
# ---------------
# [14.775539260450651, -0.6951676103014126]
# Iteração: 484
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 136945.03935594147
#        x: [ 1.412e+01  1.352e+01]
#      nit: 16
#      jac: [ 3.906e-03  0.000e+00]
#     nfev: 373
#     njev: 121
# ---------------
# [14.124570846436924, 2.1834013071100884]
# Iteração: 485
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 136492.84628132542
#        x: [ 1.355e+01  1.289e+01]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 57
#     njev: 19
# ---------------
# [13.547266024520987, -3.000449649697452]
# Iteração: 486
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 136016.48102478177
#        x: [ 1.292e+01  1.239e+01]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 66
#     njev: 22
# ---------------
# [12.920136653480512, 3.932537174890655]
# Iteração: 487
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 135344.7590669406
#        x: [ 1.241e+01  2.832e+01]
#      nit: 4
#      jac: [ 0.000e+00  1.953e-03]
#     nfev: 168
#     njev: 52
# ---------------
# [12.405237491014658, -1.8395803163906543]
# Iteração: 488
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 114953.72421689407
#        x: [ 2.832e+01 -1.834e+00]
#      nit: 2
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 51
#     njev: 17
# ---------------
# [28.322476335022944, 3.2098932727824607]
# Iteração: 489
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 114428.6708330297
#        x: [ 1.565e+01 -9.604e+00]
#      nit: 4
#      jac: [-9.766e-04  5.859e-03]
#     nfev: 96
#     njev: 32
# ---------------
# [15.652067661982713, 4.516024296608732]
# Iteração: 490
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 114069.62385038556
#        x: [-9.594e+00  1.059e+01]
#      nit: 12
#      jac: [-9.766e-04  2.930e-03]
#     nfev: 281
#     njev: 90
# ---------------
# [-9.593982664782017, -2.8178609696334025]
# Iteração: 491
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 133407.32442433768
#        x: [ 1.058e+01  1.021e+01]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 96
#     njev: 32
# ---------------
# [10.582915539101121, 0.10785152895104133]
# Iteração: 492
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 132862.66394210354
#        x: [ 1.019e+01  9.924e+00]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 60
#     njev: 20
# ---------------
# [10.186605135015338, -2.0765143103075454]
# Iteração: 493
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 132316.61663028027
#        x: [ 9.930e+00  9.574e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 99
#     njev: 33
# ---------------
# [9.930354651790292, 4.084249640021312]
# Iteração: 494
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 131771.369639305
#        x: [ 9.556e+00  9.352e+00]
#      nit: 4
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 30
#     njev: 10
# ---------------
# [9.555511865738636, -1.8111469535442657]
# Iteração: 495
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 131228.9141041573
#        x: [ 9.341e+00  9.075e+00]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 63
#     njev: 21
# ---------------
# [9.341097839321707, -1.598238565418563]
# Iteração: 496
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 130691.06668124435
#        x: [ 9.075e+00  8.843e+00]
#      nit: 10
#      jac: [ 7.812e-03  3.906e-03]
#     nfev: 203
#     njev: 64
# ---------------
# [9.075019958473622, 0.5255904123884427]
# Iteração: 497
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 130159.48942164714
#        x: [ 8.862e+00  8.608e+00]
#      nit: 7
#      jac: [ 1.953e-03  0.000e+00]
#     nfev: 163
#     njev: 51
# ---------------
# [8.861899751654775, 1.9597333807806905]
# Iteração: 498
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 129635.70617522782
#        x: [ 8.610e+00  8.458e+00]
#      nit: 5
#      jac: [ 3.906e-03  1.953e-03]
#     nfev: 150
#     njev: 46
# ---------------
# 9240.926526546478

# %%
from matplotlib import animation
from matplotlib.animation import PillowWriter

def animate(i):
    xs = np.linspace(-5,5,500)
    ln1.set_data(xs, np.absolute(psi_g[0:500,i-1])**2)
    ln2.set_data(xs, np.absolute(psiExato[0:500,i-1])**2)
    time_text.set_text('$t=$'+'{:.1f}'.format(i/100))
    
fig, ax = plt.subplots(1, 1,figsize=(8,4))
ax.grid()
ln1, = plt.plot([], [], 'r-', lw=2, markersize=8, label='Origem')
ln2, = plt.plot([], [], 'b-', lw=2, markersize=8, label='Destino')
time_text = ax.text(0.85, 0.9, '', fontsize=15,
           bbox=dict(facecolor='white', edgecolor='black'))
ax.set_ylim(0, 1)
ax.set_xlim(-5,5)
title = ax.set_title('Resposta analítica')
ax.set_ylabel('$|\psi(x)|^2$', fontsize=20)
ax.set_xlabel('$x$', fontsize=20)
ax.legend(loc='upper left')
ax.set_title('')
plt.tight_layout()
ani = animation.FuncAnimation(fig, animate, frames=500, interval=200)
ani.save('500x500.gif',writer='pillow',fps=10,dpi=100)

# %%
t = np.linspace(-5, 5, 500)

minn = np.zeros((1, 500))

for i in range(0, 450):
    minn[0][i] = minimo[0][i+49]

plt.ylabel('Controle') 
plt.xlabel('Tempo') 
plt.plot(t, minn[0], color='r', marker='*', linewidth=1, markersize=1, label="Origem")
plt.legend(loc='upper right')
plt.savefig('500.png', format='png')
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_8992\1060170165.py:6: ComplexWarning: Casting complex values to real discards the imaginary part
#   minn[0][i] = minimo[0][i+49]
