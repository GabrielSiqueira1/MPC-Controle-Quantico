# %% [markdown]
# ## Comparações - Verificação da aproximação de Runge-Kutta
#
# No processo de controle quântico e no cálculo numérico, é necessário utilizar-se de aproximações, principalmente para a derivada parcial que compõe a equação de Heisenberg. Para os processos derivativos é de suma importância, atestar a eficiência numérica e para tal compara-se os métodos de Euler e de Runge-Kutta.

# %%
# Bilbiotecas para auxílio na programação matemática
import math, sys 
import numpy as np
import sympy as sp

from scipy import sparse # Produção das diagonais das matrizes
from scipy.sparse import diags 

# Plotagem 2D e 3D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm

from os import path # Suficiente para manipulação de arquivos
    
# Para solução exata
from scipy.special import hermite
from math import factorial

# %matplotlib inline
count = 0

# Para otimização dos sistemas
from scipy import optimize

# %% [markdown]
# ## Euler - Método simples

# %%
# Procedimentos iniciais

I = np.zeros((2,2))
H = np.zeros((2,2), dtype=np.complex_)

A = (1/2*np.pi)
B = (3/2*np.pi)

I = [[1, 0], [0, 1]]
H = [[A, 0], [0, B]]

# %%
# Euler: (\psi(t+delta(t))-\psi(t))/delta t

Psi_0 = [[complex(0.80,0)],[complex(0.60,0)]] # Ponto de partida
Psi_k = np.zeros((2,1000), dtype=np.complex_) # Armazenamento dos pontos
sup = np.zeros((2,1), dtype=np.complex_) 

t = 0

while int(round(t*100, 1)) < 1000: # teste de 10 segundos
    
    deltaT = 0.01
    sup = np.matmul((I - np.dot(deltaT,np.dot(complex(0,1),H))),Psi_0)

    Psi_k[0][int(round(t*100, 1))] = sup[0][0]
    Psi_k[1][int(round(t*100, 1))] = sup[1][0]
    
    Psi_0 = sup
    
    t = t + 0.01

# %%
ts = np.linspace(0, 10, 1000) #Simulação de 10 segundos

Real = [ele.real for ele in Psi_k[0]] 
Imag = [ele.imag for ele in Psi_k[0]] 

plt.scatter(ts, Imag) 
plt.ylabel('Imaginário') 
plt.xlabel('Tempo') 
plt.show()

# %%
plt.scatter(ts, Real) 
plt.ylabel('Real') 
plt.xlabel('Tempo') 
plt.show()

# %%
ts = np.linspace(0, 10, 1000) #Simulação de 10 segundos

Real = [ele.real for ele in Psi_k[1]] 
Imag = [ele.imag for ele in Psi_k[1]] 

plt.scatter(ts, Imag) 
plt.ylabel('Imaginário') 
plt.xlabel('Tempo') 
plt.show()

# %%
plt.scatter(ts, Real) 
plt.ylabel('Real') 
plt.xlabel('Tempo') 
plt.show()

# %% [markdown]
# ## Runge-Kutta - Método aprimorado de quarta-ordem

# %%
P = np.zeros((2,1000))
S = P.astype(complex)

def dpsidt(t,psi, H):
    return -1*np.matmul(np.dot(complex(0,1),H),psi)

def rungeKutta(t0, psi0, t, h, H):
    
    n = (int)((t-t0)/h)
    
    for i in range(1, n + 1):
        
        S[0][i-1] = psi0[0][0]
        S[1][i-1] = psi0[1][0]
        
        k1 = dpsidt(t0, psi0, H)
        k2 = dpsidt(t0 + 0.5 * h, psi0 + np.dot((0.5*h), k1), H)
        k3 = dpsidt(t0 + 0.5 * h, psi0 + np.dot((0.5*h), k2), H)
        k4 = dpsidt(t0 + h, psi0 + np.dot(h, k3), H)
 
        psi0 = psi0 + (h / 6.0)*(k1 + 2 * k2 + 2 * k3 + k4)
    
        t0 = t0 + h
        
    return S

# %%
tt = 10
t = 0

h = 0.01

psi0 = [[complex(0.80,0)],[complex(0.60,0)]]

E = np.zeros((2,2))
I = np.zeros((2,2))
R = np.zeros((2,2))
H = E.astype(complex)

A = (1/2*np.pi)
B = (3/2*np.pi)

I = [[1, 0], [0, 1]]
R = [[1, 0], [0, 1]]
H = [[A, 0], [0, B]]

Z = rungeKutta(t, psi0, tt, h, H)
print(Z)
# Out:
# [[ 0.8       +0.j          0.79990131-0.01256585j  0.79960525-0.02512861j
#   ... -0.7991119 -0.03768517j -0.79960525-0.02512861j
#   -0.79990131-0.01256586j]
#  [ 0.6       +0.j          0.59933392-0.02826387j  0.59733718-0.05646499j
#   ... -0.59401399-0.08454188j -0.59733702-0.05646614j
#   -0.59933382-0.02826503j]]

# %%
ts = np.linspace(0, 10, 1000)

x = [ele.real for ele in Z[0]] 
y = [ele.imag for ele in Z[0]] 
plt.scatter(ts, y) 
plt.ylabel('Imaginário') 
plt.xlabel('Tempo') 
plt.savefig('rk_imag0.png', format='png')
plt.show()

plt.scatter(ts, x) 
plt.ylabel('Real') 
plt.xlabel('Tempo') 
plt.savefig('rk_real0.png', format='png')
plt.show()

# %%
ts = np.linspace(0, 10, 1000)

x = [ele.real for ele in Z[1]] 
y = [ele.imag for ele in Z[1]] 
plt.scatter(ts, y) 
plt.ylabel('Imaginário') 
plt.xlabel('Tempo') 
plt.savefig('rk_imag1.png', format='png')
plt.show()

plt.scatter(ts, x) 
plt.ylabel('Real') 
plt.xlabel('Tempo') 
plt.savefig('rk_real1.png', format='png')
plt.show()

# %%
Psi_t = np.zeros((2,2))
Psi_tc = Psi_t.astype(complex)

t = np.linspace(0, 10, 1000) #Simulação de 10 segundos

A = np.exp(-(complex(0,1))*np.pi*t/2)
B = np.exp(-3*(complex(0,1))*np.pi*t/2)

Psi_tc = [[0.80*A], [0.60*B]]

x = [ele.real for ele in Psi_tc[0]] 
y = [ele.imag for ele in Psi_tc[0]] 
#plt.scatter(t, x) 
plt.ylabel('Real') 
plt.xlabel('Tempo') 

plt.plot(t, x[0], color='r', marker='o',  linewidth=5, markersize=1)

ts = np.linspace(0, 10, 1000)

x = [ele.real for ele in Z[0]] 
y = [ele.imag for ele in Z[0]] 

#plt.scatter(ts, x) 
plt.ylabel('Real') 
plt.xlabel('Tempo') 

plt.plot(ts, x, color='b', marker='o',  linewidth=1, markersize=1)

plt.savefig('comparative.png', format='png')
plt.show()

# %%
tt = 10
t = 0

h = 0.01

psi0 = [[complex(1/np.sqrt(2),0)],[complex(1/np.sqrt(2),0)]]

E = np.zeros((2,2))
I = np.zeros((2,2))
R = np.zeros((2,2))
H = E.astype(complex)

A = (1/2*np.pi)
B = (3/2*np.pi)

I = [[1, 0], [0, 1]]
R = [[1, 0], [0, 1]]
H = [[A, 0], [0, B]]

Z = rungeKutta(t, psi0, tt, h, H)
print(Z)

# %%
ts = np.linspace(0, 10, 1000)

x = [ele.real for ele in Z[0]] 
y = [ele.imag for ele in Z[0]] 
plt.scatter(ts, y) 
plt.ylabel('Imaginário') 
plt.xlabel('Tempo') 
plt.savefig('rk_imag2.png', format='png')
plt.show()

plt.scatter(ts, x) 
plt.ylabel('Real') 
plt.xlabel('Tempo') 
plt.savefig('rk_real2.png', format='png')
plt.show()
