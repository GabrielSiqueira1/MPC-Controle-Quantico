# %%
# Bilbiotecas para auxílio na programação matemática
import math, sys 
import numpy as np
import sympy as sp

from scipy import sparse # Produção das diagonais das matrizes
from scipy.sparse import diags 

# Plotagem 2D e 3D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm


from os import path # Suficiente para manipulação de arquivos
    
# Para solução exata
from scipy.special import hermite
from math import factorial

# %matplotlib inline
count = 0

# Para otimização dos sistemas
from scipy import optimize

import time

tempoInicial = time.time()

# %%
def N(n):
    return 1*1./np.sqrt(np.sqrt(np.pi)*2**n*factorial(n))

def psix(n, x):
    Hn=hermite(n)
    Px = N(n)*Hn(x)*np.exp(-0.5*x**2)
    return Px

def psixt(n, x, t):
    Hn=hermite(n)
    a = complex(0,1)
    Pxt = N(n)*Hn(x)*np.exp(-0.5*x**2)*np.exp(-a*(n+1/2)*t*np.pi)
    return Pxt

# %%
def CrankNicolson(M, O = 0, L = 1, T = 0.5):
    N = 2000 #São os pontos no intervalo de tempo
    
    #Pensando no poço quadrado infinito, temos essas duas limitações, onde L varia
    x0, xL = O, L

    P = np.pi
    #Discretização espacial
    dx = (xL - x0)/(P*M-1) 

    #Discretização temporal
    t0, tF = 0, T
    dt = (tF - t0)/(P*N-1)

    #Retorno dos números em um intervalo
    xs = np.linspace(x0, xL, M)
    ts = np.linspace(t0, tF, N)

    #Suponha um oscilador harmônico simples
    hbar = 1
    m = 1
    w = np.pi
    V = 1/2*m*w**2*xs**2

    #A partir da demonstração
    a = hbar/(4*m*dx**2) 
    b = 1j*hbar/dt - 2*a - 1/2*V
    c = 1j*hbar/dt + 2*a + 1/2*V

    #Obtenção da matriz
    ##Diagonais principais
    diagPrincipalA = b*np.ones((1,M)) #Cria uma matriz de 1's
    diagPrincipalB = c*np.ones((1,M))

    ##Diagonais secundárias, tem um tamanho a menos
    diagSecundariaA = a*np.ones((1,M-1))
    diagSecundariaB = (-a)*np.ones((1,M-1))

    diagonaisA = [diagPrincipalA, diagSecundariaA, diagSecundariaA]
    matrizA = sparse.diags(diagonaisA, [0, -1, 1], shape=(M,M)).toarray()
    
    diagonaisB = [diagPrincipalB, diagSecundariaB, diagSecundariaB]         
    matrizB = sparse.diags(diagonaisB, [0, -1, 1], shape=(M,M)).toarray()
    
    #Obtenção da matriz psi (Ela acumulará para o psi futuro)
    ps = np.zeros((M, N))
    psi_c = np.zeros((M, N))

    #Condição inicial
    ps[:,0] = 0.80 * psix(0, xs) + 0.60 * psix(1, xs) #A primeira coluna da matriz terá a equação inicial, em todas as posições
    psi_c = ps.astype(complex)
    #For para o acúmulo de resultados
    for k in range(1,N):
        b = np.matmul(matrizB, np.array(psi_c[0:M, k-1])) #Multiplicação de arrays já que houve uma conversão anterior
        psi_c[0:M, k] = np.linalg.solve(matrizA, b) #Matlab: x = A\b
        #plt.plot(xs, np.absolute(psi_c[0:M, k])**2)
    return psi_c

# %%
def multMatrizes(M, us, O = 0, L = 10, T = 10):
    N = 2000 #São os pontos no intervalo de tempo
    
    #Pensando no poço quadrado infinito, temos essas duas limitações, onde L varia
    x0, xL = O, L

    P = np.pi
    #Discretização espacial
    dx = (xL - x0)/(P*M-1) 

    #Discretização temporal
    t0, tF = 0, T
    dt = (tF - t0)/(P*N-1)

    #Retorno dos números em um intervalo
    xs = np.linspace(x0, xL, M)
    ts = np.linspace(t0, tF, N)
    
    #Suponha um oscilador harmônico simples
    hbar = 1
    m = 1
    w = np.pi
    V = 1/2*m*(w+us)**2*xs**2

    #A partir da demonstração
    a = hbar/(4*m*dx**2) 
    b = 1j*hbar/dt - 2*a - 1/2*V
    c = 1j*hbar/dt + 2*a + 1/2*V

    #Obtenção da matriz
    ##Diagonais principais
    diagPrincipalA = b*np.ones((1,M)) #Cria uma matriz de 1's
    diagPrincipalB = c*np.ones((1,M))

    ##Diagonais secundárias, tem um tamanho a menos
    diagSecundariaA = a*np.ones((1,M-1))
    diagSecundariaB = (-a)*np.ones((1,M-1))

    diagonaisA = [diagPrincipalA, diagSecundariaA, diagSecundariaA]
    matrizA = sparse.diags(diagonaisA, [0, -1, 1], shape=(M,M)).toarray()
    
    diagonaisB = [diagPrincipalB, diagSecundariaB, diagSecundariaB]         
    matrizB = sparse.diags(diagonaisB, [0, -1, 1], shape=(M,M)).toarray()

    return np.matmul(np.linalg.inv(matrizA), matrizB)

# %%
# Gradiente e função objetivo

def ExactSolution(M, T = 5, L = 5):
    N = 2000

    xs = np.linspace(-5, L, M)
    
    psiExato = np.zeros((M, N)).astype(complex)
    r=0
    for i in np.arange(-5, 5, 0.1):
        for j in np.arange(0, 20, 0.01):
            psiExato[r][int(j*100)] = 1/np.sqrt(2)*psixt(0,i,j)+1/np.sqrt(2)*psixt(1,i,j)
        r+=1
    return psiExato

def Objetivo(x, y, psi, psiExato):
    A = np.zeros((100,100))
    B = np.zeros((100,100))
    C = np.zeros((100,100))
    D = np.zeros((100,100))
    A = multMatrizes(M = 100, us = x[0])
    B = multMatrizes(M = 100, us = x[1])
    C = multMatrizes(M = 100, us = x[0])
    D = multMatrizes(M = 100, us = x[1])
    
    Y = np.matmul(A,psi[0:100, y])
    Z = np.matmul(B, Y)
    W = np.matmul(C, Z)
    X = np.matmul(D, W)
    
    return ((np.linalg.norm(np.array(psiExato[0:100, y])-np.array(psi[0:100, y])))**2+
            (np.linalg.norm(np.array(psiExato[0:100, y+1])-np.array(Y)))**2+
            (np.linalg.norm(np.array(psiExato[0:100, y+2])-np.array(Z)))**2+
            (np.linalg.norm(np.array(psiExato[0:100, y+3])-np.array(W)))**2+
            (np.linalg.norm(np.array(psiExato[0:100, y+4])-np.array(X)))**2)

# %%
import random

psi = np.zeros((100,2000))
psi_f = np.zeros((100,2000))
psi_g = psi_f.astype(complex)
psi = CrankNicolson(M = 100, O = -5, L = 5, T = 20)
psiExato = ExactSolution(M = 100)

# %%
xs = np.linspace(-5,5,100)

# %%
u1 = []
u2 = []
vetor = []
u1.append(random.uniform(-5, 5))
u1.append(random.uniform(-5, 5))
u1.append(random.uniform(-5, 5))
u1.append(random.uniform(-5, 5))
tempo = 0
xs = np.linspace(-5,5,100)
minimo = np.zeros((1, 2000)).astype(complex)

while tempo < 1998:
    print(u1)
    psi_g[0:100, tempo] = psi[0:100, tempo]
    plt.plot(xs, np.absolute(psi[0:100, tempo])**2)
    u2 = optimize.minimize(Objetivo, u1, args=(tempo, psi_g, psiExato), method='CG')
    print(f"Iteração: {tempo+1}")
    print(u2)
    print("---------------")
    minimo[0][tempo] = (u2.x[0])
    D = multMatrizes(M = 100, us = u2.x[0])
    psi[0:100, tempo+1] = np.matmul(D, psi[0:100, tempo])
    tempo += 1
    u1 = []
    u1.append(u2.x[0])
    u1.append(random.uniform(-5, 5))
    u1.append(random.uniform(-5, 5))
    u1.append(random.uniform(-5, 5))

tempoFinal = time.time() - tempoInicial
print(tempoFinal)
# Out:
# [-2.566194825897651, -1.6264266989047726, 1.4623942961518939, -3.248869886004919]
# Iteração: 1
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 1.6740079000487496
#        x: [-2.248e+00 -2.189e+00  1.462e+00 -3.249e+00]
#      nit: 10
#      jac: [ 4.068e-06  4.590e-06  0.000e+00  0.000e+00]
#     nfev: 100
#     njev: 20
# ---------------
# [-2.2483820337931166, 4.09348436373665, -3.1649849443826152, -1.3987485194528904]
# Iteração: 2
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 1.7035192031253583
#        x: [-4.059e+00 -2.195e+00 -3.165e+00 -1.399e+00]
#      nit: 13
#      jac: [-1.982e-06  1.311e-06  0.000e+00  0.000e+00]
#     nfev: 165
#     njev: 33
# ---------------
# [-4.059396251872561, -4.950267980216654, 2.6153083654634397, -3.532734820412072]
# Iteração: 3
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 1.744851428325545
#        x: [-4.066e+00 -4.087e+00  2.615e+00 -3.533e+00]
#      nit: 10
#      jac: [-9.537e-06 -7.853e-06  0.000e+00  0.000e+00]
#     nfev: 105
#     njev: 21
# ---------------
# [-4.066013531250315, 0.5956391826007943, 1.7867102803683608, 2.176085743854504]
# Iteração: 4
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 1.798011651735834
#        x: [-2.215e+00 -4.087e+00  1.787e+00  2.176e+00]
#      nit: 8
#      jac: [ 1.431e-06 -8.643e-07  0.000e+00  0.000e+00]
#     nfev: 95
#     njev: 19
# ---------------
# [-2.2153341845998, 2.55886102258383, -0.012493881213946345, 3.1319324311534356]
# Iteração: 5
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 1.8630119880112628
#        x: [-4.068e+00 -2.197e+00 -1.249e-02  3.132e+00]
#      nit: 18
#      jac: [-3.606e-06 -7.302e-07  0.000e+00  0.000e+00]
#     nfev: 210
#     njev: 42
# ---------------
# [-4.06844988788755, 2.9462020511632367, -2.354718209653772, -4.398365852878104]
# Iteração: 6
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 1.9398556575805945
#        x: [-2.215e+00 -2.197e+00 -2.355e+00 -4.398e+00]
#      nit: 7
#      jac: [ 3.740e-06  5.618e-06  0.000e+00  0.000e+00]
#     nfev: 85
#     njev: 17
# ---------------
# [-2.214633891765035, 4.79716056580048, 0.7650668251191073, 0.7390482975060007]
# Iteração: 7
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 2.0285423776303064
#        x: [-2.214e+00 -4.087e+00  7.651e-01  7.390e-01]
#      nit: 17
#      jac: [-3.278e-07  1.788e-07  0.000e+00  0.000e+00]
#     nfev: 180
#     njev: 36
# ---------------
# [-2.2144271927064927, -2.539338607404801, -1.8634967205255517, -0.6538186709060376]
# Iteração: 8
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 2.1290705764700593
#        x: [-2.214e+00 -2.197e+00 -1.863e+00 -6.538e-01]
#      nit: 9
#      jac: [ 2.444e-06  1.252e-06  0.000e+00  0.000e+00]
#     nfev: 110
#     njev: 22
# ---------------
# [-2.2143065669458655, 3.3855011149897116, -1.563624570003185, -2.20723307370445]
# Iteração: 9
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 2.2414384568846795
#        x: [-4.069e+00 -2.197e+00 -1.564e+00 -2.207e+00]
#      nit: 15
#      jac: [-1.818e-06  1.580e-06  0.000e+00  0.000e+00]
#     nfev: 155
#     njev: 31
# ---------------
# [-4.068977657280729, 4.356739758915587, -0.2219179700173992, 4.932108718750854]
# Iteração: 10
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 2.3656436523918867
#        x: [-2.214e+00 -2.196e+00 -2.219e-01  4.932e+00]
#      nit: 11
#      jac: [ 3.636e-06  3.844e-06  0.000e+00  0.000e+00]
#     nfev: 150
#     njev: 30
# ---------------
# [-2.214078828075632, 4.180882494442541, -2.549748595346093, -2.8298410698934084]
# Iteração: 11
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 2.5016834335032527
#        x: [-4.069e+00 -2.196e+00 -2.550e+00 -2.830e+00]
#      nit: 13
#      jac: [ 7.451e-06  7.212e-06  0.000e+00  0.000e+00]
#     nfev: 160
#     njev: 32
# ---------------
# [-4.069091420562627, -0.9866718124985754, 2.3086759363848923, 3.6942603960611002]
# Iteração: 12
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 2.649554584078691
#        x: [-4.070e+00 -2.196e+00  2.309e+00  3.694e+00]
#      nit: 15
#      jac: [ 1.192e-06 -9.716e-06  0.000e+00  0.000e+00]
#     nfev: 140
#     njev: 28
# ---------------
# [-4.069654456781837, -3.390182717905834, -0.3245328397606251, 3.201291286418826]
# Iteração: 13
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 2.809253950309224
#        x: [-4.070e+00 -4.087e+00 -3.245e-01  3.201e+00]
#      nit: 15
#      jac: [-2.503e-06  4.321e-06  0.000e+00  0.000e+00]
#     nfev: 185
#     njev: 37
# ---------------
# [-4.069624170384521, -4.815908180122069, 3.8147432962576318, 4.054590890362768]
# Iteração: 14
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 2.9807784754740485
#        x: [-4.070e+00 -4.087e+00  3.815e+00  4.055e+00]
#      nit: 7
#      jac: [ 5.245e-06  3.368e-06  0.000e+00  0.000e+00]
#     nfev: 95
#     njev: 19
# ---------------
# [-4.069679718153589, 1.1713969409861154, 4.691533710933177, -4.93604710952579]
# Iteração: 15
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 3.1641235376624812
#        x: [-4.070e+00 -2.196e+00  4.692e+00 -4.936e+00]
#      nit: 16
#      jac: [-4.888e-06  4.530e-06  0.000e+00  0.000e+00]
#     nfev: 180
#     njev: 36
# ---------------
# [-4.069947371563065, 1.1792646552967234, -0.6306276359531635, 1.4345370433038642]
# Iteração: 16
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 3.3592845715101296
#        x: [-4.070e+00 -2.196e+00 -6.306e-01  1.435e+00]
#      nit: 18
#      jac: [-1.669e-06  3.308e-06  0.000e+00  0.000e+00]
#     nfev: 205
#     njev: 41
# ---------------
# [-4.070142097590777, 2.4299426454090245, -2.252704014599863, -3.539048940538109]
# Iteração: 17
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 3.566256947868126
#        x: [-4.070e+00 -2.196e+00 -2.253e+00 -3.539e+00]
#      nit: 11
#      jac: [ 7.451e-07 -5.871e-06  0.000e+00  0.000e+00]
#     nfev: 170
#     njev: 34
# ---------------
# [-4.070465219819313, 4.538247973979345, -0.08115670358162497, 1.1992061904715197]
# Iteração: 18
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 3.785035603774331
#        x: [-4.070e+00 -2.195e+00 -8.116e-02  1.199e+00]
#      nit: 15
#      jac: [ 8.672e-06  3.427e-06  0.000e+00  0.000e+00]
#     nfev: 185
#     njev: 37
# ---------------
# [-4.070423421911057, -2.8474548095957166, -1.0564046645647762, 1.997977748787946]
# Iteração: 19
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4.01561484182748
#        x: [-4.071e+00 -2.195e+00 -1.056e+00  1.998e+00]
#      nit: 12
#      jac: [-5.007e-06  2.861e-06  0.000e+00  0.000e+00]
#     nfev: 130
#     njev: 26
# ---------------
# [-4.070964124218503, 1.3437638485645937, -0.21336085357791035, -4.060437113071792]
# Iteração: 20
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4.257988460739716
#        x: [-4.071e+00 -2.195e+00 -2.134e-01 -4.060e+00]
#      nit: 11
#      jac: [-8.345e-07  1.788e-06  0.000e+00  0.000e+00]
#     nfev: 135
#     njev: 27
# ---------------
# [-4.071101095754794, -4.615008032935427, 1.3064800514822608, -3.1795996847741215]
# Iteração: 21
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4.512150466420927
#        x: [-4.071e+00 -4.088e+00  1.306e+00 -3.180e+00]
#      nit: 11
#      jac: [-5.364e-07 -7.153e-07  0.000e+00  0.000e+00]
#     nfev: 105
#     njev: 21
# ---------------
# [-4.07137617234351, 0.6196309550833545, -2.944426374757029, -2.8129410193501805]
# Iteração: 22
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4.778093700652348
#        x: [-2.212e+00 -4.088e+00 -2.944e+00 -2.813e+00]
#      nit: 14
#      jac: [-1.609e-06  1.788e-07  0.000e+00  0.000e+00]
#     nfev: 155
#     njev: 31
# ---------------
# [-2.2115548313055386, 4.934596447660892, -4.894944802204142, -2.5645196481200117]
# Iteração: 23
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5.055810732092262
#        x: [-2.211e+00 -4.088e+00 -4.895e+00 -2.565e+00]
#      nit: 15
#      jac: [ 9.894e-06 -9.418e-06  0.000e+00  0.000e+00]
#     nfev: 170
#     njev: 34
# ---------------
# [-2.2112583819375966, 1.5186964526940976, -0.7098060531500483, 2.240990028493087]
# Iteração: 24
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5.345293584783728
#        x: [-2.211e+00 -2.195e+00 -7.098e-01  2.241e+00]
#      nit: 15
#      jac: [-4.649e-06 -3.219e-06  0.000e+00  0.000e+00]
#     nfev: 165
#     njev: 33
# ---------------
# [-2.2109647618941835, -4.9248785165585325, -0.34334701832463654, -4.074907645457387]
# Iteração: 25
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5.712025231999405
#        x: [-2.320e+00 -4.359e+00 -3.433e-01 -4.075e+00]
#      nit: 9
#      jac: [ 5.066e-06 -1.788e-06  0.000e+00  0.000e+00]
#     nfev: 95
#     njev: 19
# ---------------
# [-2.32017516854115, 0.4460441849934558, 2.196729909475846, 4.014507873500589]
# Iteração: 26
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 14.60304622681343
#        x: [-1.970e+00 -2.195e+00  2.197e+00  4.015e+00]
#      nit: 12
#      jac: [ 9.537e-06  5.364e-06  0.000e+00  0.000e+00]
#     nfev: 145
#     njev: 29
# ---------------
# [-1.9703617077495417, 0.42817077922425373, 1.0969414857886592, 2.3251096070076036]
# Iteração: 27
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 14.931150529248102
#        x: [-2.399e+00 -2.026e+00  1.097e+00  2.325e+00]
#      nit: 7
#      jac: [ 2.861e-06  2.742e-06  0.000e+00  0.000e+00]
#     nfev: 115
#     njev: 23
# ---------------
# [-2.399383816758383, -2.8822477315487793, 3.24479977833648, 0.2201063828408074]
# Iteração: 28
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 15.266459528465326
#        x: [-1.920e+00 -2.760e+00  3.245e+00  2.201e-01]
#      nit: 10
#      jac: [ 3.099e-06  9.894e-06  0.000e+00  0.000e+00]
#     nfev: 105
#     njev: 21
# ---------------
# [-1.9202463703308528, 3.400677716926843, -2.371207034869003, -4.0174688218727885]
# Iteração: 29
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 15.613755934509708
#        x: [-3.884e+00 -2.217e+00 -2.371e+00 -4.017e+00]
#      nit: 11
#      jac: [ 5.722e-06 -7.868e-06  0.000e+00  0.000e+00]
#     nfev: 150
#     njev: 30
# ---------------
# [-3.883692840884392, 3.9452108397188184, -4.81407603354109, 3.174515346532811]
# Iteração: 30
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 15.90845906651934
#        x: [-2.335e+00 -2.165e+00 -4.814e+00  3.175e+00]
#      nit: 13
#      jac: [-9.537e-06  9.298e-06  0.000e+00  0.000e+00]
#     nfev: 175
#     njev: 35
# ---------------
# [-2.335212340553343, -3.089682583749449, 3.1158337634691406, -1.9622398495522164]
# Iteração: 31
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 7.701976406518183
#        x: [-2.241e+00 -2.186e+00  3.116e+00 -1.962e+00]
#      nit: 12
#      jac: [ 2.146e-06  3.219e-06  0.000e+00  0.000e+00]
#     nfev: 165
#     njev: 33
# ---------------
# [-2.2412064680959354, -2.315563752401937, -0.024587530309250205, 2.3285059899396012]
# Iteração: 32
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 8.085227450668397
#        x: [-2.217e+00 -2.191e+00 -2.459e-02  2.329e+00]
#      nit: 10
#      jac: [ 2.384e-07  7.153e-07  0.000e+00  0.000e+00]
#     nfev: 100
#     njev: 20
# ---------------
# [-2.217073336067627, -1.2214047768260174, 4.338987327780421, -0.9618827527469245]
# Iteração: 33
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 8.480130188879091
#        x: [-2.210e+00 -2.192e+00  4.339e+00 -9.619e-01]
#      nit: 9
#      jac: [-8.464e-06  3.815e-06  0.000e+00  0.000e+00]
#     nfev: 110
#     njev: 22
# ---------------
# [-2.210429922075822, 0.7867270258571866, -1.2419678459152408, -3.7728710060761204]
# Iteração: 34
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 8.88666973446116
#        x: [-2.208e+00 -2.193e+00 -1.242e+00 -3.773e+00]
#      nit: 16
#      jac: [-3.695e-06 -5.841e-06  0.000e+00  0.000e+00]
#     nfev: 160
#     njev: 32
# ---------------
# [-2.207985039072993, 3.2794626812274927, -2.8609158481427768, 2.2712934346234483]
# Iteração: 35
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 9.304839622818166
#        x: [-4.076e+00 -2.193e+00 -2.861e+00  2.271e+00]
#      nit: 14
#      jac: [-8.345e-07 -6.080e-06  0.000e+00  0.000e+00]
#     nfev: 170
#     njev: 34
# ---------------
# [-4.076031064878371, -1.6543667154151342, 1.214873306226715, 4.982140204381555]
# Iteração: 36
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 9.734626763628103
#        x: [-4.076e+00 -2.193e+00  1.215e+00  4.982e+00]
#      nit: 7
#      jac: [-2.623e-06  2.623e-06  0.000e+00  0.000e+00]
#     nfev: 75
#     njev: 15
# ---------------
# [-4.076394674640414, 0.2104898517743914, 1.9727449466917522, 0.019809047978148975]
# Iteração: 37
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 10.176014182296642
#        x: [-4.077e+00 -2.193e+00  1.973e+00  1.981e-02]
#      nit: 12
#      jac: [-6.795e-06 -3.934e-06  0.000e+00  0.000e+00]
#     nfev: 140
#     njev: 28
# ---------------
# [-4.077053416851084, 2.6169040858023767, 4.890650857447392, 1.3387880253250906]
# Iteração: 38
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 10.628983362455935
#        x: [-4.077e+00 -2.192e+00  4.891e+00  1.339e+00]
#      nit: 11
#      jac: [ 1.073e-06 -7.033e-06  0.000e+00  0.000e+00]
#     nfev: 180
#     njev: 36
# ---------------
# [-4.077329601919264, -2.4506189932438325, -4.536228735502057, -2.456524771041196]
# Iteração: 39
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 11.093514775355072
#        x: [-4.078e+00 -2.192e+00 -4.536e+00 -2.457e+00]
#      nit: 11
#      jac: [ 6.199e-06 -3.934e-06  0.000e+00  0.000e+00]
#     nfev: 120
#     njev: 24
# ---------------
# [-4.077662188421148, 1.9295234976214832, -0.9108509442913713, 2.7769346790861977]
# Iteração: 40
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 11.569587225455013
#        x: [-4.078e+00 -2.192e+00 -9.109e-01  2.777e+00]
#      nit: 13
#      jac: [ 3.695e-06 -5.960e-07  0.000e+00  0.000e+00]
#     nfev: 165
#     njev: 33
# ---------------
# [-4.078164349990426, -1.4743114432041815, -3.826385815236053, 1.0392264751762035]
# Iteração: 41
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 12.057178541805989
#        x: [-4.079e+00 -2.192e+00 -3.826e+00  1.039e+00]
#      nit: 12
#      jac: [-4.292e-06  5.960e-06  0.000e+00  0.000e+00]
#     nfev: 130
#     njev: 26
# ---------------
# [-4.078659362789525, 1.8936085658753798, -4.33252411825667, 1.058468554497603]
# Iteração: 42
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 12.556265510204454
#        x: [-4.079e+00 -2.192e+00 -4.333e+00  1.058e+00]
#      nit: 9
#      jac: [-2.146e-06 -3.934e-06  0.000e+00  0.000e+00]
#     nfev: 130
#     njev: 26
# ---------------
# [-4.079224798192592, 2.0200023801929863, 4.901638194706708, -1.2365307347774523]
# Iteração: 43
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 13.066823616841885
#        x: [-4.080e+00 -2.191e+00  4.902e+00 -1.237e+00]
#      nit: 14
#      jac: [ 5.245e-06 -3.695e-06  0.000e+00  0.000e+00]
#     nfev: 175
#     njev: 35
# ---------------
# [-4.07950620618079, 4.541514994194774, -3.6265739860093493, -3.3674134829628652]
# Iteração: 44
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 13.588826835761758
#        x: [-2.203e+00 -2.191e+00 -3.627e+00 -3.367e+00]
#      nit: 14
#      jac: [-7.868e-06 -2.742e-06  0.000e+00  0.000e+00]
#     nfev: 180
#     njev: 36
# ---------------
# [-2.2032327911874465, 4.094134628060729, -4.179809134073842, -1.0119327144079895]
# Iteração: 45
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 14.12224746674872
#        x: [-4.081e+00 -2.191e+00 -4.180e+00 -1.012e+00]
#      nit: 12
#      jac: [ 1.788e-06 -2.861e-06  0.000e+00  0.000e+00]
#     nfev: 170
#     njev: 34
# ---------------
# [-4.080556455974005, -1.3828293836651473, -2.978564010676185, 1.2463181775190488]
# Iteração: 46
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 14.667056622649378
#        x: [-4.081e+00 -2.191e+00 -2.979e+00  1.246e+00]
#      nit: 8
#      jac: [ 2.027e-06  4.768e-06  0.000e+00  0.000e+00]
#     nfev: 100
#     njev: 20
# ---------------
# [-4.080859717008561, 2.05462090361603, 4.30816061732429, -4.6944553657955135]
# Iteração: 47
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 15.223223824047118
#        x: [-4.081e+00 -2.191e+00  4.308e+00 -4.694e+00]
#      nit: 12
#      jac: [ 1.907e-06 -3.576e-07  0.000e+00  0.000e+00]
#     nfev: 165
#     njev: 33
# ---------------
# [-4.0814901607368546, -4.259441881165015, 4.072305695677226, -0.38981267552896703]
# Iteração: 48
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 15.790716826025147
#        x: [-4.082e+00 -4.092e+00  4.072e+00 -3.898e-01]
#      nit: 8
#      jac: [-3.457e-06  9.298e-06  0.000e+00  0.000e+00]
#     nfev: 95
#     njev: 19
# ---------------
# [-4.082159892556333, -0.06993928321390808, -2.6803269696113317, -2.5450079777776624]
# Iteração: 49
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 16.369502043445028
#        x: [-4.082e+00 -2.191e+00 -2.680e+00 -2.545e+00]
#      nit: 9
#      jac: [-3.099e-06 -2.623e-06  0.000e+00  0.000e+00]
#     nfev: 115
#     njev: 23
# ---------------
# [-4.082361365053663, 4.904014910966085, 1.8420377742924563, 0.0795974742995531]
# Iteração: 50
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 16.959543872459726
#        x: [-4.083e+00 -2.191e+00  1.842e+00  7.960e-02]
#      nit: 18
#      jac: [-7.153e-06 -2.623e-06  0.000e+00  0.000e+00]
#     nfev: 240
#     njev: 48
# ---------------
# [-4.082935052925712, 1.9175260472067404, 0.5573267800621009, -2.5970727657850077]
# Iteração: 51
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 17.560804619757455
#        x: [-4.083e+00 -2.190e+00  5.573e-01 -2.597e+00]
#      nit: 13
#      jac: [ 9.060e-06  3.815e-06  0.000e+00  0.000e+00]
#     nfev: 180
#     njev: 36
# ---------------
# [-4.0830678373178175, -2.8969948929461733, -0.5422389494089952, -2.2614473743629]
# Iteração: 52
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 18.17324484466811
#        x: [-4.084e+00 -2.190e+00 -5.422e-01 -2.261e+00]
#      nit: 12
#      jac: [ 8.583e-06  5.245e-06  0.000e+00  0.000e+00]
#     nfev: 165
#     njev: 33
# ---------------
# [-4.08376881750989, -1.045150920040221, 3.1371975108069527, 0.7941283421289054]
# Iteração: 53
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 18.796823039276596
#        x: [-4.085e+00 -2.190e+00  3.137e+00  7.941e-01]
#      nit: 8
#      jac: [-9.537e-07 -7.153e-07  0.000e+00  0.000e+00]
#     nfev: 115
#     njev: 23
# ---------------
# [-4.084605343707174, -4.4792896286329285, -4.792512620970081, -3.4038354239986757]
# Iteração: 54
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 19.567620452436902
#        x: [-3.976e+00 -4.369e+00 -4.793e+00 -3.404e+00]
#      nit: 8
#      jac: [-1.431e-06  4.530e-06  0.000e+00  0.000e+00]
#     nfev: 85
#     njev: 17
# ---------------
# [-3.976336853932, 0.4838353981245005, -3.9858364002191102, -2.9033174217404714]
# Iteração: 55
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 25.835081727055403
#        x: [-4.324e+00 -2.185e+00 -3.986e+00 -2.903e+00]
#      nit: 11
#      jac: [-7.629e-06  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 140
#     njev: 28
# ---------------
# [-4.324297806561208, -0.03789691990341737, -2.8335841342237575, -2.505338831436]
# Iteração: 56
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 26.49434915914669
#        x: [-3.904e+00 -2.021e+00 -2.834e+00 -2.505e+00]
#      nit: 8
#      jac: [ 6.676e-06  8.106e-06  0.000e+00  0.000e+00]
#     nfev: 100
#     njev: 20
# ---------------
# [-3.904155805155748, 1.0702955358121784, 4.053486883420494, 3.80890608429406]
# Iteração: 57
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 27.160844881508776
#        x: [-4.378e+00 -2.775e+00  4.053e+00  3.809e+00]
#      nit: 17
#      jac: [-2.861e-06  1.431e-06  0.000e+00  0.000e+00]
#     nfev: 240
#     njev: 48
# ---------------
# [-4.377997456739425, -3.510522706901904, 4.484021174234826, 3.1962779360155817]
# Iteração: 58
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 27.838496661448822
#        x: [-3.922e+00 -4.040e+00  4.484e+00  3.196e+00]
#      nit: 9
#      jac: [-7.153e-06 -3.815e-06  0.000e+00  0.000e+00]
#     nfev: 140
#     njev: 28
# ---------------
# [-3.9219252230016184, 4.941216253584319, 0.038342858075004926, -3.896707482755981]
# Iteração: 59
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 28.39214259366031
#        x: [-2.345e+00 -2.157e+00  3.834e-02 -3.897e+00]
#      nit: 13
#      jac: [-8.821e-06 -5.722e-06  0.000e+00  0.000e+00]
#     nfev: 230
#     njev: 46
# ---------------
# [-2.345133047000016, -4.216175797829564, -3.7484581609943013, 2.1744323141736217]
# Iteração: 60
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 23.470431805379523
#        x: [-2.234e+00 -4.102e+00 -3.748e+00  2.174e+00]
#      nit: 4
#      jac: [ 4.768e-06 -3.815e-06  0.000e+00  0.000e+00]
#     nfev: 65
#     njev: 13
# ---------------
# [-2.2339942556144896, 0.5184828752017268, -2.531454910462708, -0.6660048690969624]
# Iteração: 61
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 24.181293330444895
#        x: [-2.205e+00 -2.187e+00 -2.531e+00 -6.660e-01]
#      nit: 8
#      jac: [-2.384e-06  5.007e-06  0.000e+00  0.000e+00]
#     nfev: 115
#     njev: 23
# ---------------
# [-2.2054889714947974, 2.698776997003467, 2.3580296182961433, 0.3581479442228277]
# Iteração: 62
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 24.9028479632983
#        x: [-2.197e+00 -2.189e+00  2.358e+00  3.581e-01]
#      nit: 13
#      jac: [ 3.099e-06  6.676e-06  0.000e+00  0.000e+00]
#     nfev: 185
#     njev: 37
# ---------------
# [-2.197142104500724, -3.024186309222643, 1.404844572141366, -3.881213283212497]
# Iteração: 63
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 25.635001034240283
#        x: [-2.194e+00 -2.190e+00  1.405e+00 -3.881e+00]
#      nit: 12
#      jac: [-1.669e-06 -3.576e-06  0.000e+00  0.000e+00]
#     nfev: 180
#     njev: 36
# ---------------
# [-2.194404835888079, -0.3478251309949334, 1.6869144890691237, 4.4570638144736385]
# Iteração: 64
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 26.377685720845985
#        x: [-2.193e+00 -2.190e+00  1.687e+00  4.457e+00]
#      nit: 11
#      jac: [-2.384e-07  1.907e-06  0.000e+00  0.000e+00]
#     nfev: 145
#     njev: 29
# ---------------
# [-2.1934949380070417, 3.3167729538015376, 1.4660467192081317, -2.5130493354472714]
# Iteração: 65
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 27.13083224963119
#        x: [-4.090e+00 -2.190e+00  1.466e+00 -2.513e+00]
#      nit: 8
#      jac: [ 9.537e-07  4.768e-07  0.000e+00  0.000e+00]
#     nfev: 115
#     njev: 23
# ---------------
# [-4.09042623773614, -0.5071946963276419, -1.2819587815235423, 1.1561958903685081]
# Iteração: 66
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 27.89436726035949
#        x: [-4.091e+00 -2.190e+00 -1.282e+00  1.156e+00]
#      nit: 11
#      jac: [ 0.000e+00  2.623e-06  0.000e+00  0.000e+00]
#     nfev: 140
#     njev: 28
# ---------------
# [-4.090964505086268, 1.8965764638735632, -1.7446302505221087, -3.490417746676786]
# Iteração: 67
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 28.668214269892566
#        x: [-4.092e+00 -2.190e+00 -1.745e+00 -3.490e+00]
#      nit: 11
#      jac: [-3.815e-06  5.484e-06  0.000e+00  0.000e+00]
#     nfev: 150
#     njev: 30
# ---------------
# [-4.091501135371695, 0.26538609773156985, 4.521570131709648, -3.693233416888513]
# Iteração: 68
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 29.45229366023016
#        x: [-4.092e+00 -2.191e+00  4.522e+00 -3.693e+00]
#      nit: 11
#      jac: [ 2.861e-06 -2.384e-07  0.000e+00  0.000e+00]
#     nfev: 135
#     njev: 27
# ---------------
# [-4.092015909485222, -0.8887895479721166, 1.159629406383603, -2.7998303474017927]
# Iteração: 69
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 30.246522676081213
#        x: [-4.093e+00 -2.191e+00  1.160e+00 -2.800e+00]
#      nit: 12
#      jac: [ 0.000e+00  1.192e-06  0.000e+00  0.000e+00]
#     nfev: 155
#     njev: 31
# ---------------
# [-4.092545064639583, 2.1200629396768313, 0.735323505815165, -2.2836191654481586]
# Iteração: 70
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 31.050815357620348
#        x: [-4.093e+00 -2.191e+00  7.353e-01 -2.284e+00]
#      nit: 13
#      jac: [ 0.000e+00  2.384e-07  0.000e+00  0.000e+00]
#     nfev: 175
#     njev: 35
# ---------------
# [-4.093070569466908, 3.8399256693642307, -3.4451014667256405, -0.7352997268327099]
# Iteração: 71
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 31.86508248011745
#        x: [-2.190e+00 -2.191e+00 -3.445e+00 -7.353e-01]
#      nit: 11
#      jac: [ 5.960e-06  5.722e-06  0.000e+00  0.000e+00]
#     nfev: 160
#     njev: 32
# ---------------
# [-2.1896679996785866, -2.098692175344107, 1.0234174183977167, -2.909923162820738]
# Iteração: 72
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 32.689231494989144
#        x: [-2.189e+00 -2.192e+00  1.023e+00 -2.910e+00]
#      nit: 3
#      jac: [ 4.292e-06 -5.722e-06  0.000e+00  0.000e+00]
#     nfev: 45
#     njev: 9
# ---------------
# [-2.188932818412816, 3.520527676010385, -1.657831058781738, -2.876415952034157]
# Iteração: 73
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 33.52316643516289
#        x: [-4.094e+00 -2.192e+00 -1.658e+00 -2.876e+00]
#      nit: 12
#      jac: [-4.768e-07  9.537e-07  0.000e+00  0.000e+00]
#     nfev: 180
#     njev: 36
# ---------------
# [-4.09432675712263, -4.463079626342017, -2.3848993922742068, 0.481783217074538]
# Iteração: 74
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 34.3667879387108
#        x: [-4.095e+00 -4.091e+00 -2.385e+00  4.818e-01]
#      nit: 9
#      jac: [ 2.861e-06 -1.431e-06  0.000e+00  0.000e+00]
#     nfev: 120
#     njev: 24
# ---------------
# [-4.094834717343151, -2.2037932137759775, -2.4462507598449323, 1.3291562854699759]
# Iteração: 75
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 35.219993168566745
#        x: [-4.096e+00 -2.193e+00 -2.446e+00  1.329e+00]
#      nit: 3
#      jac: [-1.431e-06  9.537e-07  0.000e+00  0.000e+00]
#     nfev: 45
#     njev: 9
# ---------------
# [-4.095573156842989, 2.8769162487356015, 0.41530698996930937, 2.0904876211574566]
# Iteração: 76
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 36.08267566451349
#        x: [-4.096e+00 -2.194e+00  4.153e-01  2.090e+00]
#      nit: 11
#      jac: [ 6.676e-06 -1.907e-06  0.000e+00  0.000e+00]
#     nfev: 165
#     njev: 33
# ---------------
# [-4.0958368801978455, -4.209922395774015, 4.362244924302541, 1.5400493418942975]
# Iteração: 77
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 36.954725374318386
#        x: [-4.097e+00 -4.089e+00  4.362e+00  1.540e+00]
#      nit: 4
#      jac: [-9.537e-07  9.060e-06  0.000e+00  0.000e+00]
#     nfev: 55
#     njev: 11
# ---------------
# [-4.09674681289504, 3.6227654539647816, -0.7160395800256634, 4.244526982714595]
# Iteração: 78
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 37.836028522159054
#        x: [-2.187e+00 -2.195e+00 -7.160e-01  4.245e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 160
#     njev: 32
# ---------------
# [-2.186513491398514, 1.583959646003513, 1.6805519914019085, 4.56224742626576]
# Iteração: 79
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 38.726467680691286
#        x: [-2.186e+00 -2.196e+00  1.681e+00  4.562e+00]
#      nit: 12
#      jac: [ 4.768e-07 -9.537e-07  0.000e+00  0.000e+00]
#     nfev: 170
#     njev: 34
# ---------------
# [-2.1858863725723987, 1.3321623631874147, 2.8262307029638247, 4.9372213496408985]
# Iteração: 80
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 39.625921792629434
#        x: [-2.186e+00 -2.196e+00  2.826e+00  4.937e+00]
#      nit: 12
#      jac: [-9.060e-06  9.060e-06  0.000e+00  0.000e+00]
#     nfev: 165
#     njev: 33
# ---------------
# [-2.1860254841952895, 2.760523003135262, 4.512923456209718, 0.09056680227319003]
# Iteração: 81
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 40.53426601645205
#        x: [-2.185e+00 -2.197e+00  4.513e+00  9.057e-02]
#      nit: 12
#      jac: [ 9.537e-07  1.431e-06  0.000e+00  0.000e+00]
#     nfev: 180
#     njev: 36
# ---------------
# [-2.184702753976624, -1.8843594517218145, 2.598631906160045, -4.373124375804221]
# Iteração: 82
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 41.45137153699992
#        x: [-2.185e+00 -2.198e+00  2.599e+00 -4.373e+00]
#      nit: 8
#      jac: [-6.199e-06 -1.907e-06  0.000e+00  0.000e+00]
#     nfev: 130
#     njev: 26
# ---------------
# [-2.1845653162310836, -3.359633183372109, 3.124453905699987, -4.021833298150407]
# Iteração: 83
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 42.377105401066366
#        x: [-2.184e+00 -4.084e+00  3.124e+00 -4.022e+00]
#      nit: 9
#      jac: [-4.292e-06 -8.583e-06  0.000e+00  0.000e+00]
#     nfev: 140
#     njev: 28
# ---------------
# [-2.184486812851004, 1.825319711076392, 0.9855011074307649, -2.0088601022722474]
# Iteração: 84
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 43.31133125326289
#        x: [-2.183e+00 -2.201e+00  9.855e-01 -2.009e+00]
#      nit: 13
#      jac: [ 2.384e-06 -3.338e-06  0.000e+00  0.000e+00]
#     nfev: 195
#     njev: 39
# ---------------
# [-2.18334600989496, -0.8639921864289937, -3.1646196694403117, -0.9846150447674571]
# Iteração: 85
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 44.25390844844706
#        x: [-2.184e+00 -2.202e+00 -3.165e+00 -9.846e-01]
#      nit: 8
#      jac: [ 9.537e-07  1.431e-06  0.000e+00  0.000e+00]
#     nfev: 105
#     njev: 21
# ---------------
# [-2.1835443815245816, -0.3813786980590326, -1.9861927150308913, -1.338054388724157]
# Iteração: 86
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 45.20469231519414
#        x: [-2.183e+00 -2.204e+00 -1.986e+00 -1.338e+00]
#      nit: 9
#      jac: [ 2.861e-06 -1.431e-06  0.000e+00  0.000e+00]
#     nfev: 130
#     njev: 26
# ---------------
# [-2.1829801211776525, -3.7188050118822504, 4.265777200094634, 2.5637902873087492]
# Iteração: 87
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 46.16353459412371
#        x: [-2.183e+00 -4.078e+00  4.266e+00  2.564e+00]
#      nit: 8
#      jac: [ 7.153e-06 -3.815e-06  0.000e+00  0.000e+00]
#     nfev: 115
#     njev: 23
# ---------------
# [-2.1828103493731015, 0.5968518858625105, -3.8549690209676104, 0.4018723504556867]
# Iteração: 88
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 47.13028275064517
#        x: [-2.182e+00 -2.208e+00 -3.855e+00  4.019e-01]
#      nit: 9
#      jac: [ 9.537e-07 -7.629e-06  0.000e+00  0.000e+00]
#     nfev: 135
#     njev: 27
# ---------------
# [-2.1823094981172897, -3.016662612577411, 1.6678190340638306, 2.528492686622899]
# Iteração: 89
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 48.1047802800159
#        x: [-2.183e+00 -2.209e+00  1.668e+00  2.528e+00]
#      nit: 10
#      jac: [-4.292e-06  9.537e-07  0.000e+00  0.000e+00]
#     nfev: 150
#     njev: 30
# ---------------
# [-2.1828011344354254, 2.0897582346959496, 1.4246016898199931, 1.3537530680925167]
# Iteração: 90
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 49.08686691450774
#        x: [-2.181e+00 -2.213e+00  1.425e+00  1.354e+00]
#      nit: 14
#      jac: [ 6.199e-06 -7.153e-06  0.000e+00  0.000e+00]
#     nfev: 210
#     njev: 42
# ---------------
# [-2.1813942537725994, -1.6628782492156926, 4.310610162501002, 3.870915355038761]
# Iteração: 91
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 50.07637800987621
#        x: [-2.182e+00 -2.215e+00  4.311e+00  3.871e+00]
#      nit: 7
#      jac: [-9.060e-06 -9.060e-06  0.000e+00  0.000e+00]
#     nfev: 115
#     njev: 23
# ---------------
# [-2.1822211329069963, 0.07423720596975159, -2.160599859661195, -1.712376996456615]
# Iteração: 92
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 51.07314461100069
#        x: [-2.182e+00 -2.218e+00 -2.161e+00 -1.712e+00]
#      nit: 10
#      jac: [ 4.292e-06 -2.384e-06  0.000e+00  0.000e+00]
#     nfev: 160
#     njev: 32
# ---------------
# [-2.181630597868473, 2.157253207444949, -0.0717904549690882, -0.37017204992709196]
# Iteração: 93
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 52.07699456542454
#        x: [-2.182e+00 -2.221e+00 -7.179e-02 -3.702e-01]
#      nit: 16
#      jac: [-4.768e-06 -1.907e-06  0.000e+00  0.000e+00]
#     nfev: 230
#     njev: 46
# ---------------
# [-2.182114757182699, 1.9658394688770837, 0.30655017276202123, 2.7927692595908127]
# Iteração: 94
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 53.08775111372272
#        x: [-2.182e+00 -2.225e+00  3.066e-01  2.793e+00]
#      nit: 15
#      jac: [-8.583e-06  2.384e-06  0.000e+00  0.000e+00]
#     nfev: 220
#     njev: 44
# ---------------
# [-2.1822627271936423, -0.3070963846921506, -4.527513695167629, 3.073100208619495]
# Iteração: 95
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 54.10523404368713
#        x: [-2.181e+00 -2.230e+00 -4.528e+00  3.073e+00]
#      nit: 13
#      jac: [ 2.861e-06  3.338e-06  0.000e+00  0.000e+00]
#     nfev: 185
#     njev: 37
# ---------------
# [-2.1814590477442715, 1.2103688406714062, 1.9580983042524114, -2.3232903160837926]
# Iteração: 96
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 55.12925804746119
#        x: [-4.102e+00 -4.047e+00  1.958e+00 -2.323e+00]
#      nit: 8
#      jac: [-4.768e-07  2.384e-06  0.000e+00  0.000e+00]
#     nfev: 145
#     njev: 29
# ---------------
# [-4.10151871670049, -1.4618867936670488, 0.5270746065326906, 0.549716054520152]
# Iteração: 97
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 56.159633279866966
#        x: [-4.100e+00 -2.242e+00  5.271e-01  5.497e-01]
#      nit: 10
#      jac: [ 4.768e-06  2.861e-06  0.000e+00  0.000e+00]
#     nfev: 165
#     njev: 33
# ---------------
# [-4.100213431129813, 2.788398470192705, 3.117143339897007, 2.999445833500233]
# Iteração: 98
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 57.19616719762162
#        x: [-4.100e+00 -2.250e+00  3.117e+00  2.999e+00]
#      nit: 13
#      jac: [-2.861e-06  8.106e-06  0.000e+00  0.000e+00]
#     nfev: 195
#     njev: 39
# ---------------
# [-4.100258519625224, -3.831325914515263, -0.34524978869395184, 4.828936940320256]
# Iteração: 99
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 58.2386629084841
#        x: [-4.100e+00 -4.023e+00 -3.452e-01  4.829e+00]
#      nit: 6
#      jac: [ 4.292e-06 -2.384e-06  0.000e+00  0.000e+00]
#     nfev: 110
#     njev: 22
# ---------------
# [-4.0996055617004155, 0.9514851341987294, -4.72349469602775, -4.6943731952975085]
# Iteração: 100
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 59.28691794921481
#        x: [-4.098e+00 -2.273e+00 -4.723e+00 -4.694e+00]
#      nit: 13
#      jac: [ 3.815e-06  4.768e-06  0.000e+00  0.000e+00]
#     nfev: 215
#     njev: 43
# ---------------
# [-4.098454031799271, -1.70283660730746, -3.6485372682903296, -4.793335512750244]
# Iteração: 101
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 60.34072568951822
#        x: [-4.098e+00 -2.290e+00 -3.649e+00 -4.793e+00]
#      nit: 8
#      jac: [ 4.768e-06 -2.861e-06  0.000e+00  0.000e+00]
#     nfev: 155
#     njev: 31
# ---------------
# [-4.097827494183289, 1.8564788189071102, 3.3220308318509666, -0.46210128491382196]
# Iteração: 102
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 61.39987358015527
#        x: [-4.095e+00 -2.311e+00  3.322e+00 -4.621e-01]
#      nit: 8
#      jac: [ 4.292e-06  2.861e-06  0.000e+00  0.000e+00]
#     nfev: 155
#     njev: 31
# ---------------
# [-4.095133159823374, -3.739140383229833, 4.222503360515576, -2.2112069231661113]
# Iteração: 103
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 62.464142674180586
#        x: [-4.092e+00 -3.944e+00  4.223e+00 -2.211e+00]
#      nit: 8
#      jac: [ 4.768e-07 -9.537e-06  0.000e+00  0.000e+00]
#     nfev: 150
#     njev: 30
# ---------------
# [-4.092279518476719, 0.105181165153442, -3.2406894010207257, 2.2981470908864488]
# Iteração: 104
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 63.53330570599594
#        x: [-2.192e+00 -2.386e+00 -3.241e+00  2.298e+00]
#      nit: 9
#      jac: [-3.815e-06 -2.384e-06  0.000e+00  0.000e+00]
#     nfev: 190
#     njev: 38
# ---------------
# [-2.192152545241565, -1.8789316443551165, 2.561420840481045, 3.290052615903077]
# Iteração: 105
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 64.60711607783968
#        x: [-2.197e+00 -2.459e+00  2.561e+00  3.290e+00]
#      nit: 8
#      jac: [-4.768e-06  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 165
#     njev: 33
# ---------------
# [-2.1972518446675156, -2.4049862777948885, 1.3806031056280057, 0.9729020554007564]
# Iteração: 106
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 65.68529046701374
#        x: [-2.203e+00 -2.605e+00  1.381e+00  9.729e-01]
#      nit: 4
#      jac: [-8.583e-06  1.907e-06  0.000e+00  0.000e+00]
#     nfev: 90
#     njev: 18
# ---------------
# [-2.2026041488642054, -0.5339149894051518, -4.925645783984862, 1.4733396050670589]
# Iteração: 107
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 66.76743938825837
#        x: [-2.229e+00 -3.132e+00 -4.926e+00  1.473e+00]
#      nit: 15
#      jac: [-1.907e-06  1.907e-06  0.000e+00  0.000e+00]
#     nfev: 350
#     njev: 70
# ---------------
# [-2.229438604458294, 0.9010930147812646, -0.5951100679797197, -1.3037740152566557]
# Iteração: 108
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 67.85295744504941
#        x: [-2.567e+00 -3.141e+00 -5.951e-01 -1.304e+00]
#      nit: 8
#      jac: [ 2.861e-06  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 175
#     njev: 35
# ---------------
# [-2.567098899352191, -3.865135922862132, 1.5732030018553802, -1.4246134257769505]
# Iteração: 109
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 68.94073416654658
#        x: [-3.142e+00 -3.140e+00  1.573e+00 -1.425e+00]
#      nit: 3
#      jac: [-1.907e-06  5.722e-06  0.000e+00  0.000e+00]
#     nfev: 120
#     njev: 24
# ---------------
# [-3.142164906385949, -3.0153023699389845, 3.24593960301687, -4.941908391135989]
# Iteração: 110
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 70.02981012352922
#        x: [-3.142e+00 -3.141e+00  3.246e+00 -4.942e+00]
#      nit: 2
#      jac: [ 9.537e-07  1.907e-06  0.000e+00  0.000e+00]
#     nfev: 45
#     njev: 9
# ---------------
# [-3.141516407850793, -2.712696085484867, -3.922919521551168, -3.0805819183858563]
# Iteração: 111
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 71.11805826259592
#        x: [-3.142e+00 -3.142e+00 -3.923e+00 -3.081e+00]
#      nit: 4
#      jac: [ 0.000e+00 -4.768e-06  0.000e+00  0.000e+00]
#     nfev: 115
#     njev: 23
# ---------------
# [-3.1415624784143135, -1.0494211165980003, 1.6811906418554656, -3.506354080471763]
# Iteração: 112
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 72.45383327786064
#        x: [-3.142e+00 -3.141e+00  1.681e+00 -3.506e+00]
#      nit: 5
#      jac: [ 0.000e+00  2.861e-06  0.000e+00  0.000e+00]
#     nfev: 100
#     njev: 20
# ---------------
# [-3.1415913118871766, 4.733072547401466, -0.3551468291875137, 1.533460871300635]
# Iteração: 113
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 68.34770327613171
#        x: [-3.142e+00 -3.142e+00 -3.551e-01  1.533e+00]
#      nit: 5
#      jac: [-5.722e-06 -6.676e-06  0.000e+00  0.000e+00]
#     nfev: 90
#     njev: 18
# ---------------
# [-3.1417517106475827, 0.5139263960182223, -2.902978439305619, -4.886439218576043]
# Iteração: 114
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 69.48228011357642
#        x: [-3.142e+00  3.166e-01 -2.903e+00 -4.886e+00]
#      nit: 3
#      jac: [ 9.537e-07 -1.907e-06  0.000e+00  0.000e+00]
#     nfev: 65
#     njev: 13
# ---------------
# [-3.1417750173373262, 1.571575789005827, -0.7623221737773118, 2.8189866077151313]
# Iteração: 115
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 70.56699182901569
#        x: [-3.142e+00  6.310e-01 -7.623e-01  2.819e+00]
#      nit: 7
#      jac: [ 1.907e-06  9.537e-06  0.000e+00  0.000e+00]
#     nfev: 85
#     njev: 17
# ---------------
# [-3.141823654727463, -2.8566243857994387, 0.18282987160317088, 4.8692562749297394]
# Iteração: 116
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 71.5331996980864
#        x: [-3.142e+00 -3.142e+00  1.828e-01  4.869e+00]
#      nit: 2
#      jac: [-9.537e-07 -1.907e-06  0.000e+00  0.000e+00]
#     nfev: 55
#     njev: 11
# ---------------
# [-3.1416024022860567, 3.91572867495225, -4.105742563367948, 1.5029492621364486]
# Iteração: 117
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 72.50191720984573
#        x: [-3.142e+00  1.217e+00 -4.106e+00  1.503e+00]
#      nit: 3
#      jac: [ 0.000e+00  4.768e-06  0.000e+00  0.000e+00]
#     nfev: 45
#     njev: 9
# ---------------
# [-3.141596151554046, -4.876383035488548, -4.016212489333614, -4.068166869602454]
# Iteração: 118
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 78.52569843726428
#        x: [-3.142e+00 -3.142e+00 -4.016e+00 -4.068e+00]
#      nit: 6
#      jac: [ 0.000e+00 -3.815e-06  0.000e+00  0.000e+00]
#     nfev: 75
#     njev: 15
# ---------------
# [-3.1415920560110577, 3.0486108032681596, 3.671497764463057, 1.2112891040661964]
# Iteração: 119
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 79.76211272848415
#        x: [-3.142e+00  1.790e+00  3.671e+00  1.211e+00]
#      nit: 4
#      jac: [ 0.000e+00 -9.537e-07  0.000e+00  0.000e+00]
#     nfev: 50
#     njev: 10
# ---------------
# [-3.1415920560110577, 1.3225996437045868, -3.2295370512471866, 0.37210667207219306]
# Iteração: 120
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 80.7689472494548
#        x: [-3.142e+00  2.056e+00 -3.230e+00  3.721e-01]
#      nit: 5
#      jac: [-9.537e-07 -9.537e-07  0.000e+00  0.000e+00]
#     nfev: 95
#     njev: 19
# ---------------
# [-3.1415920560110577, 2.1071563668373354, -2.401586792263565, -0.2026337756999954]
# Iteração: 121
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 81.75309892053015
#        x: [-3.142e+00  2.315e+00 -2.402e+00 -2.026e-01]
#      nit: 2
#      jac: [-9.537e-07  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 50
#     njev: 10
# ---------------
# [-3.1415940537860907, 0.14125953345725328, 1.3876502418721604, -3.9734933409343043]
# Iteração: 122
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 82.40634652639017
#        x: [-3.142e+00 -3.142e+00  1.388e+00 -3.973e+00]
#      nit: 2
#      jac: [-9.537e-07  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 60
#     njev: 12
# ---------------
# [-3.1415940537860907, 2.4024404407806523, 4.734757336368505, 0.8275732010999448]
# Iteração: 123
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 83.64650456570749
#        x: [-3.142e+00  2.817e+00  4.735e+00  8.276e-01]
#      nit: 5
#      jac: [ 2.861e-06 -9.537e-06  0.000e+00  0.000e+00]
#     nfev: 50
#     njev: 10
# ---------------
# [-3.141603443457461, 0.8543046703130344, 4.825528054565066, 2.760135778505112]
# Iteração: 124
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 84.55262112523857
#        x: [-3.142e+00  3.065e+00  4.826e+00  2.760e+00]
#      nit: 8
#      jac: [-9.537e-07 -5.722e-06  0.000e+00  0.000e+00]
#     nfev: 65
#     njev: 13
# ---------------
# [-3.141585150308839, 2.05631912857452, 1.4168673970944017, -4.0018154120725455]
# Iteração: 125
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 85.4297952086733
#        x: [-3.142e+00  3.312e+00  1.417e+00 -4.002e+00]
#      nit: 9
#      jac: [-2.861e-06  1.907e-06  0.000e+00  0.000e+00]
#     nfev: 70
#     njev: 14
# ---------------
# [-3.1415664633351126, 3.1523209392661347, -3.025542591196557, 0.504676469940561]
# Iteração: 126
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 85.09452600236935
#        x: [ 1.976e+00  1.296e+00 -3.026e+00  5.047e-01]
#      nit: 20
#      jac: [-1.907e-06  3.815e-06  0.000e+00  0.000e+00]
#     nfev: 300
#     njev: 60
# ---------------
# [1.9764877858255716, -3.6314076775128434, -0.5264361417209944, 4.354871132576616]
# Iteração: 127
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 85.18072820162345
#        x: [ 1.824e+00 -6.121e+00 -5.264e-01  4.355e+00]
#      nit: 12
#      jac: [-7.629e-06  8.583e-06  0.000e+00  0.000e+00]
#     nfev: 145
#     njev: 29
# ---------------
# [1.8244145236445317, 2.622132563803076, 1.4924895016738118, -3.01466705140113]
# Iteração: 128
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 84.4810311494777
#        x: [ 1.078e+00 -1.371e+00  1.492e+00 -3.015e+00]
#      nit: 16
#      jac: [ 9.537e-06 -2.861e-06  0.000e+00  0.000e+00]
#     nfev: 175
#     njev: 35
# ---------------
# [1.078171832634268, 1.8686937485577095, -1.2131716469276688, -1.5711445514790245]
# Iteração: 129
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 84.11662213641856
#        x: [ 5.946e-02 -1.722e+00 -1.213e+00 -1.571e+00]
#      nit: 9
#      jac: [-9.537e-07  1.907e-06  0.000e+00  0.000e+00]
#     nfev: 115
#     njev: 23
# ---------------
# [0.05945810469254579, -3.053570046183812, 0.9885054072331547, -0.07411240901020832]
# Iteração: 130
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 84.15385460669475
#        x: [-7.589e-01 -1.611e+00  9.885e-01 -7.411e-02]
#      nit: 18
#      jac: [ 6.676e-06 -9.537e-06  0.000e+00  0.000e+00]
#     nfev: 195
#     njev: 39
# ---------------
# [-0.7589373675800485, -3.154651563815566, -2.7226615340898697, 3.867267251814102]
# Iteração: 131
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 84.28730128082239
#        x: [-1.206e+00 -4.748e+00 -2.723e+00  3.867e+00]
#      nit: 14
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 270
#     njev: 54
# ---------------
# [-1.2059819912173202, -2.249308811438453, 1.2464098920264268, 3.5361837688749684]
# Iteração: 132
# ...
# [-3.141592680804837, -3.2957687278761028, -2.4460587006825243, -0.6106648366166834]
# Iteração: 1964
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 100.66555359324455
#        x: [-3.142e+00 -9.609e+00 -2.446e+00 -6.107e-01]
#      nit: 2
#      jac: [ 0.000e+00  1.907e-06  0.000e+00  0.000e+00]
#     nfev: 95
#     njev: 19
# ---------------
# [-3.141592680804837, -4.828506574903191, -3.6764922053264937, 0.7181220773963171]
# Iteração: 1965
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 100.40932176497378
#        x: [-3.142e+00 -9.687e+00 -3.676e+00  7.181e-01]
#      nit: 2
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 51
#     njev: 10
# ---------------
# [-3.141592680804837, 0.3310844153935246, -1.9963688701145599, -1.2542182325731668]
# Iteração: 1966
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 100.16014304993578
#        x: [-3.142e+00  3.482e+00 -1.996e+00 -1.254e+00]
#      nit: 2
#      jac: [ 0.000e+00 -1.907e-06  0.000e+00  0.000e+00]
#     nfev: 55
#     njev: 11
# ---------------
# [-3.141592680804837, 1.7217685057329852, -2.2643588922687528, -2.7116777250059307]
# Iteração: 1967
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 99.91867674276367
#        x: [-3.142e+00  3.560e+00 -2.264e+00 -2.712e+00]
#      nit: 2
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 45
#     njev: 9
# ---------------
# [-3.141592680804837, 2.9175086185006647, -0.18442784955873393, 4.429291035873906]
# Iteração: 1968
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 99.6855557093387
#        x: [-3.142e+00  3.639e+00 -1.844e-01  4.429e+00]
#      nit: 2
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 30
#     njev: 6
# ---------------
# [-3.141592680804837, -3.5914284262438345, 0.12061863674385886, 1.762694423560129]
# Iteração: 1969
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 99.46138369534161
#        x: [-3.142e+00 -1.000e+01  1.206e-01  1.763e+00]
#      nit: 2
#      jac: [ 0.000e+00  9.537e-07  0.000e+00  0.000e+00]
#     nfev: 76
#     njev: 15
# ---------------
# [-3.141592680804837, -3.413411162596154, -2.307688451895035, -0.5409181306352941]
# Iteração: 1970
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 99.24673266522842
#        x: [-3.142e+00 -1.008e+01 -2.308e+00 -5.409e-01]
#      nit: 2
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 82
#     njev: 16
# ---------------
# [-3.141592680804837, 1.4891535781818055, 2.5730949649293366, 4.322964950259543]
# Iteração: 1971
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 99.04214015909169
#        x: [-3.142e+00  3.876e+00  2.573e+00  4.323e+00]
#      nit: 3
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 60
#     njev: 12
# ---------------
# [-3.141592680804837, -4.779326267972368, -1.321924553003747, 4.623805186746701]
# Iteração: 1972
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 98.84810664466168
#        x: [-3.142e+00 -1.024e+01 -1.322e+00  4.624e+00]
#      nit: 2
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 61
#     njev: 12
# ---------------
# [-3.141592680804837, -0.6940100651128951, -3.518833349489563, -3.357628822433456]
# Iteração: 1973
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 98.66509285901915
#        x: [-3.142e+00  4.037e+00 -3.519e+00 -3.358e+00]
#      nit: 2
#      jac: [ 0.000e+00 -9.537e-07  0.000e+00  0.000e+00]
#     nfev: 51
#     njev: 10
# ---------------
# [-3.141592680804837, -4.099197372665714, 2.681484793119683, -0.01165129833172962]
# Iteração: 1974
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 98.49351713668278
#        x: [-3.142e+00 -1.040e+01  2.681e+00 -1.165e-02]
#      nit: 2
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 61
#     njev: 12
# ---------------
# [-3.141592680804837, -2.870972207174801, -3.4460391678721, 4.644393249696284]
# Iteração: 1975
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 98.33375270450534
#        x: [-3.142e+00  4.200e+00 -3.446e+00  4.644e+00]
#      nit: 2
#      jac: [ 0.000e+00  1.907e-06  0.000e+00  0.000e+00]
#     nfev: 91
#     njev: 18
# ---------------
# [-3.141592680804837, 4.977265076593435, -4.822285211281421, 2.0217718857453377]
# Iteração: 1976
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 98.18612492093622
#        x: [-3.142e+00  4.284e+00 -4.822e+00  2.022e+00]
#      nit: 2
#      jac: [ 0.000e+00  6.676e-06  0.000e+00  0.000e+00]
#     nfev: 25
#     njev: 5
# ---------------
# [-3.141592680804837, -3.4630108465643406, 3.2624487670030042, -4.708204057085869]
# Iteração: 1977
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 97.80847132020881
#        x: [-3.142e+00 -1.070e+01  3.262e+00 -4.708e+00]
#      nit: 2
#      jac: [ 0.000e+00 -9.537e-07  0.000e+00  0.000e+00]
#     nfev: 96
#     njev: 19
# ---------------
# [-3.141592680804837, 2.7468256355605796, -1.532875240064988, -0.9459434834822025]
# Iteração: 1978
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 88.77829967149766
#        x: [-3.142e+00  7.507e+00 -1.533e+00 -9.459e-01]
#      nit: 3
#      jac: [ 0.000e+00  9.537e-07  0.000e+00  0.000e+00]
#     nfev: 85
#     njev: 17
# ---------------
# [-3.141592680804837, -1.2961557947767197, -4.462759786215935, -3.1038080259729863]
# Iteração: 1979
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 89.79702956535353
#        x: [-3.142e+00  3.998e+00 -4.463e+00 -3.104e+00]
#      nit: 2
#      jac: [ 0.000e+00  8.583e-06  0.000e+00  0.000e+00]
#     nfev: 61
#     njev: 12
# ---------------
# [-3.141592680804837, 4.407522656078477, 2.8500784786568953, -0.6838838209422153]
# Iteração: 1980
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 89.76952218380306
#        x: [-3.142e+00  4.075e+00  2.850e+00 -6.839e-01]
#      nit: 2
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 25
#     njev: 5
# ---------------
# [-3.141592680804837, 2.9011207554516636, -2.366147101047673, -3.8375547958239418]
# Iteração: 1981
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 84.90823633613877
#        x: [-3.142e+00  4.724e+00 -2.366e+00 -3.838e+00]
#      nit: 2
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 30
#     njev: 6
# ---------------
# [-3.141592680804837, -3.819265818038385, -4.565995605715648, 3.1503175388346314]
# Iteração: 1982
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 84.79238541777545
#        x: [-3.142e+00 -1.110e+01 -4.566e+00  3.150e+00]
#      nit: 2
#      jac: [ 0.000e+00  1.907e-06  0.000e+00  0.000e+00]
#     nfev: 90
#     njev: 18
# ---------------
# [-3.141592680804837, 4.947035469457958, 1.5643474098200087, -0.5075762227876979]
# Iteração: 1983
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 97.50847715722371
#        x: [-3.142e+00  4.915e+00  1.564e+00 -5.076e-01]
#      nit: 2
#      jac: [ 0.000e+00 -9.537e-07  0.000e+00  0.000e+00]
#     nfev: 25
#     njev: 5
# ---------------
# [-3.141592680804837, 0.4518809544586766, -4.798801826963776, 0.0023260612433908534]
# Iteração: 1984
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 97.46292613452133
#        x: [-3.142e+00  5.014e+00 -4.799e+00  2.326e-03]
#      nit: 3
#      jac: [ 0.000e+00  2.861e-06  0.000e+00  0.000e+00]
#     nfev: 50
#     njev: 10
# ---------------
# [-3.141592680804837, -2.2338991356385005, 2.9342979833297615, 0.03514419252548784]
# Iteração: 1985
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 102.36800880302776
#        x: [-3.142e+00  6.416e+02  2.934e+00  3.514e-02]
#      nit: 8
#      jac: [ 0.000e+00 -9.537e-07  0.000e+00  0.000e+00]
#     nfev: 340
#     njev: 68
# ---------------
# [-3.141592680804837, 1.5620142669096442, -3.8183688848605413, -4.205039690342701]
# Iteração: 1986
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 97.40871354029821
#        x: [-3.142e+00  5.224e+00 -3.818e+00 -4.205e+00]
#      nit: 2
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 50
#     njev: 10
# ---------------
# [-3.141592680804837, 2.6655956005160553, 1.9203769905480828, -4.846405065729939]
# Iteração: 1987
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 97.39930982907248
#        x: [-3.142e+00  5.334e+00  1.920e+00 -4.846e+00]
#      nit: 3
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 45
#     njev: 9
# ---------------
# [-3.141592680804837, -0.01383290853154584, -0.5232631115426969, -2.3997278647735687]
# Iteração: 1988
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 97.40106762308002
#        x: [-3.142e+00  5.449e+00 -5.233e-01 -2.400e+00]
#      nit: 2
#      jac: [ 0.000e+00 -9.537e-07  0.000e+00  0.000e+00]
#     nfev: 30
#     njev: 6
# ---------------
# [-3.141592680804837, -0.07668483359730338, -1.7620809639316173, 2.2939378697025106]
# Iteração: 1989
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 97.41339312027748
#        x: [-3.142e+00  5.569e+00 -1.762e+00  2.294e+00]
#      nit: 2
#      jac: [ 0.000e+00 -1.907e-06  0.000e+00  0.000e+00]
#     nfev: 30
#     njev: 6
# ---------------
# [-3.141592680804837, -2.078081719918533, -2.5526564950502904, -0.13970602481259498]
# Iteração: 1990
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 97.43559921640768
#        x: [-3.142e+00  5.695e+00 -2.553e+00 -1.397e-01]
#      nit: 3
#      jac: [ 0.000e+00 -6.676e-06  0.000e+00  0.000e+00]
#     nfev: 50
#     njev: 10
# ---------------
# [-3.141592680804837, -0.9774382978626281, 3.4110440258857775, 0.8564901182638129]
# Iteração: 1991
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 97.46690527858917
#        x: [-3.142e+00  5.827e+00  3.411e+00  8.565e-01]
#      nit: 1
#      jac: [ 0.000e+00  2.861e-06  0.000e+00  0.000e+00]
#     nfev: 57
#     njev: 11
# ---------------
# [-3.141592680804837, -1.2506893231322556, 1.081674874118125, 0.14165775788013146]
# Iteração: 1992
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 97.50643930463593
#        x: [-3.142e+00  5.965e+00  1.082e+00  1.417e-01]
#      nit: 5
#      jac: [ 0.000e+00 -9.537e-07  0.000e+00  0.000e+00]
#     nfev: 90
#     njev: 18
# ---------------
# [-3.141592680804837, 2.419452460838958, -0.32134874521736023, -2.7840311984659474]
# Iteração: 1993
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 97.55324350250663
#        x: [-3.142e+00  6.110e+00 -3.213e-01 -2.784e+00]
#      nit: 1
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00]
#     nfev: 45
#     njev: 9
# ---------------
# [-3.141592680804837, 4.2832332521014465, -1.985762425956409, -4.98615060771473]
# Iteração: 1994
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 97.60628455640452
#        x: [-3.142e+00  6.263e+00 -1.986e+00 -4.986e+00]
#      nit: 8
#      jac: [ 0.000e+00 -2.861e-06  0.000e+00  0.000e+00]
#     nfev: 50
#     njev: 10
# ---------------
# [-3.141592680804837, -3.9213318756323003, 0.20040740831380077, 2.924122198231787]
# Iteração: 1995
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 115.84399325688393
#        x: [-3.142e+00 -3.142e+00  2.004e-01  2.924e+00]
#      nit: 2
#      jac: [ 0.000e+00 -1.907e-06  0.000e+00  0.000e+00]
#     nfev: 40
#     njev: 8
# ---------------
# [-3.141592680804837, 4.6995630955397, 0.3613024192176333, -1.0704640393846176]
# Iteração: 1996
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 97.72667161994623
#        x: [-3.142e+00  6.594e+00  3.613e-01 -1.070e+00]
#      nit: 10
#      jac: [ 0.000e+00 -6.676e-06  0.000e+00  0.000e+00]
#     nfev: 55
#     njev: 11
# ---------------
# [-3.141592680804837, -1.8796684883099566, -4.688691633238552, 1.753531111410048]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 16
#      14 psi_g[0:100, tempo] = psi[0:100, tempo]
#      15 plt.plot(xs, np.absolute(psi[0:100, tempo])**2)
# ---> 16 u2 = optimize.minimize(Objetivo, u1, args=(tempo, psi_g, psiExato), method='CG')
#      17 print(f"Iteração: {tempo+1}")
#      18 print(u2)
#
# File ~\scoop\apps\miniconda3\current\lib\site-packages\scipy\optimize\_minimize.py:689, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     687     res = _minimize_powell(fun, x0, args, callback, bounds, **options)
#     688 elif meth == 'cg':
# --> 689     res = _minimize_cg(fun, x0, args, jac, callback, **options)
#     690 elif meth == 'bfgs':
#     691     res = _minimize_bfgs(fun, x0, args, jac, callback, **options)
#
# File ~\scoop\apps\miniconda3\current\lib\site-packages\scipy\optimize\_optimize.py:1686, in _minimize_cg(fun, x0, args, jac, callback, gtol, norm, eps, maxiter, disp, return_all, finite_diff_rel_step, **unknown_options)
#    1683 if maxiter is None:
#    1684     maxiter = len(x0) * 200
# -> 1686 sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#    1687                               finite_diff_rel_step=finite_diff_rel_step)
#    1689 f = sf.fun
#    1690 myfprime = sf.grad
#
# File ~\scoop\apps\miniconda3\current\lib\site-packages\scipy\optimize\_optimize.py:332, in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     328     bounds = (-np.inf, np.inf)
#     330 # ScalarFunction caches. Reuse of fun(x) during grad
#     331 # calculation reduces overall function evaluations.
# --> 332 sf = ScalarFunction(fun, x0, args, grad, hess,
#     333                     finite_diff_rel_step, bounds, epsilon=epsilon)
#     335 return sf
#
# File ~\scoop\apps\miniconda3\current\lib\site-packages\scipy\optimize\_differentiable_functions.py:158, in ScalarFunction.__init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#     155     self.f = fun_wrapped(self.x)
#     157 self._update_fun_impl = update_fun
# --> 158 self._update_fun()
#     160 # Gradient evaluation
#     161 if callable(grad):
#
# File ~\scoop\apps\miniconda3\current\lib\site-packages\scipy\optimize\_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File ~\scoop\apps\miniconda3\current\lib\site-packages\scipy\optimize\_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File ~\scoop\apps\miniconda3\current\lib\site-packages\scipy\optimize\_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# Cell In[5], line 35, in Objetivo(x, y, psi, psiExato)
#      28 W = np.matmul(C, Z)
#      29 X = np.matmul(D, W)
#      31 return ((np.linalg.norm(np.array(psiExato[0:100, y])-np.array(psi[0:100, y])))**2+
#      32         (np.linalg.norm(np.array(psiExato[0:100, y+1])-np.array(Y)))**2+
#      33         (np.linalg.norm(np.array(psiExato[0:100, y+2])-np.array(Z)))**2+
#      34         (np.linalg.norm(np.array(psiExato[0:100, y+3])-np.array(W)))**2+
# ---> 35         (np.linalg.norm(np.array(psiExato[0:100, y+4])-np.array(X)))**2)
#
# IndexError: index 2000 is out of bounds for axis 1 with size 2000

# %%
from matplotlib import animation
from matplotlib.animation import PillowWriter

def animate(i):
    xs = np.linspace(-5,5,100)
    ln1.set_data(xs, np.absolute(psi_g[0:100,i-1])**2)
    ln2.set_data(xs, np.absolute(psiExato[0:100,i-1])**2)
    time_text.set_text('$t=$'+'{:.1f}'.format(i/100))
    
fig, ax = plt.subplots(1, 1,figsize=(8,4))
ax.grid()
ln1, = plt.plot([], [], 'r-', lw=2, markersize=8, label='Origem')
ln2, = plt.plot([], [], 'b-', lw=2, markersize=8, label='Destino')
time_text = ax.text(0.85, 0.9, '', fontsize=15,
           bbox=dict(facecolor='white', edgecolor='black'))
ax.set_ylim(0, 1)
ax.set_xlim(-5,5)
title = ax.set_title('Resposta analítica')
ax.set_ylabel('$|\psi(x)|^2$', fontsize=20)
ax.set_xlabel('$x$', fontsize=20)
ax.legend(loc='upper left')
ax.set_title('')
plt.tight_layout()
ani = animation.FuncAnimation(fig, animate, frames=2000, interval=2000)
ani.save('100x100.gif',writer='pillow',fps=20,dpi=100)
