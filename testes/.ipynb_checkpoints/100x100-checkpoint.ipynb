# %%
# Bilbiotecas para auxílio na programação matemática
import math, sys 
import numpy as np
import sympy as sp

from scipy import sparse # Produção das diagonais das matrizes
from scipy.sparse import diags 

# Plotagem 2D e 3D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm


from os import path # Suficiente para manipulação de arquivos
    
# Para solução exata
from scipy.special import hermite
from math import factorial

# %matplotlib inline
count = 0

# Para otimização dos sistemas
from scipy import optimize

import time

tempoInicial = time.time()

# %%
def N(n):
    return 1*1./np.sqrt(np.sqrt(np.pi)*2**n*factorial(n))

def psix(n, x):
    Hn=hermite(n)
    Px = N(n)*Hn(x)*np.exp(-0.5*x**2)
    return Px

def psixt(n, x, t):
    Hn=hermite(n)
    a = complex(0,1)
    Pxt = N(n)*Hn(x)*np.exp(-0.5*x**2)*np.exp(-a*(n+1/2)*t*np.pi)
    return Pxt

# %%
def CrankNicolson(M, O = 0, L = 1, T = 0.5):
    N = 100 #São os pontos no intervalo de tempo
    
    #Pensando no poço quadrado infinito, temos essas duas limitações, onde L varia
    x0, xL = O, L

    P = 3.141111111111111111111111111
    #Discretização espacial
    dx = (xL - x0)/(P*M-1) 

    #Discretização temporal
    t0, tF = 0, T
    dt = (tF - t0)/(P*N-1)

    #Retorno dos números em um intervalo
    xs = np.linspace(x0, xL, M)
    ts = np.linspace(t0, tF, N)

    #Suponha um oscilador harmônico simples
    hbar = 1
    m = 1
    w = np.pi
    V = 1/2*m*w**2*xs**2

    #A partir da demonstração
    a = hbar/(4*m*dx**2) 
    b = 1j*hbar/dt - 2*a - 1/2*V
    c = 1j*hbar/dt + 2*a + 1/2*V

    #Obtenção da matriz
    ##Diagonais principais
    diagPrincipalA = b*np.ones((1,M)) #Cria uma matriz de 1's
    diagPrincipalB = c*np.ones((1,M))

    ##Diagonais secundárias, tem um tamanho a menos
    diagSecundariaA = a*np.ones((1,M-1))
    diagSecundariaB = (-a)*np.ones((1,M-1))

    diagonaisA = [diagPrincipalA, diagSecundariaA, diagSecundariaA]
    matrizA = sparse.diags(diagonaisA, [0, -1, 1], shape=(M,M)).toarray()
    
    diagonaisB = [diagPrincipalB, diagSecundariaB, diagSecundariaB]         
    matrizB = sparse.diags(diagonaisB, [0, -1, 1], shape=(M,M)).toarray()
    
    #Obtenção da matriz psi (Ela acumulará para o psi futuro)
    ps = np.zeros((M, N))
    psi_c = np.zeros((M, N))

    #Condição inicial
    ps[:,0] = 0.80 * psix(0, xs) + 0.60 * psix(1, xs) #A primeira coluna da matriz terá a equação inicial, em todas as posições
    psi_c = ps.astype(complex)
    #For para o acúmulo de resultados
    for k in range(1,N):
        b = np.matmul(matrizB, np.array(psi_c[0:M, k-1])) #Multiplicação de arrays já que houve uma conversão anterior
        psi_c[0:M, k] = np.linalg.solve(matrizA, b) #Matlab: x = A\b
        #plt.plot(xs, np.absolute(psi_c[0:M, k])**2)
    return psi_c

# %%
def multMatrizes(M, us, O = -5, L = 5, T = 10):
    N = 100 #São os pontos no intervalo de tempo
    
    #Pensando no poço quadrado infinito, temos essas duas limitações, onde L varia
    x0, xL = O, L

    P = 3.141111111111111111111111111
    #Discretização espacial
    dx = (xL - x0)/(P*M-1) 

    #Discretização temporal
    t0, tF = 0, T
    dt = (tF - t0)/(P*N-1)

    #Retorno dos números em um intervalo
    xs = np.linspace(x0, xL, M)
    ts = np.linspace(t0, tF, N)
    
    #Suponha um oscilador harmônico simples
    hbar = 1
    m = 1
    w = np.pi
    #V = us #V(x,u(t))
    V = 1/2*m*w**2*xs**2+us

    #A partir da demonstração
    a = hbar/(4*m*dx**2) 
    b = 1j*hbar/dt - 2*a - 1/2*V
    c = 1j*hbar/dt + 2*a + 1/2*V

    #Obtenção da matriz
    ##Diagonais principais
    diagPrincipalA = b*np.ones((1,M)) #Cria uma matriz de 1's
    diagPrincipalB = c*np.ones((1,M))

    ##Diagonais secundárias, tem um tamanho a menos
    diagSecundariaA = a*np.ones((1,M-1))
    diagSecundariaB = (-a)*np.ones((1,M-1))

    diagonaisA = [diagPrincipalA, diagSecundariaA, diagSecundariaA]
    matrizA = sparse.diags(diagonaisA, [0, -1, 1], shape=(M,M)).toarray()
    
    diagonaisB = [diagPrincipalB, diagSecundariaB, diagSecundariaB]         
    matrizB = sparse.diags(diagonaisB, [0, -1, 1], shape=(M,M)).toarray()

    return np.matmul(np.linalg.inv(matrizA), matrizB)

# %%
# Gradiente e função objetivo

def ExactSolution(M, T = 5, L = 5):
    N = 100

    xs = np.linspace(-5, L, M)
    ts = np.linspace(0, N/10, T)
    
    psiExato = np.zeros((M, N)).astype(complex)
    r=0
    for i in np.arange(-5, 5, 0.1):
        for j in np.arange(0, 10, 0.1):
            psiExato[r][int(j*10)] = 1/np.sqrt(2)*psixt(0,i,j)+1/np.sqrt(2)*psixt(1,i,j)
        r+=1
    return psiExato

def Objetivo(x, y, psi, psiExato):
    A = np.zeros((100,100))
    B = np.zeros((100,100))
    A = multMatrizes(M = 100, us = x[0])
    B = multMatrizes(M = 100, us = x[1])
    return ((np.linalg.norm(np.array(psiExato[0:100, y])-np.array(psi)))**2+
            (np.linalg.norm(np.array(psiExato[0:100, y+1])-np.array(np.matmul(A,psi))))**2+
            (np.linalg.norm(np.array(psiExato[0:100, y+2])-np.array(np.matmul(np.matmul(B,A),psi))))**2)

# %%
import random

psi = np.zeros((100,100))
psi_f = np.zeros((100,100))
psi_g = psi_f.astype(complex)
psi = CrankNicolson(M = 100, O = -5, L = 5, T = 10)
psiExato = ExactSolution(M = 100)

# %%
xs = np.linspace(-5,5,100)
plt.plot(xs, np.absolute(psi[0:100,0:100])**2)
# Out:
# [<matplotlib.lines.Line2D at 0x1c204cbf4f0>,
#  <matplotlib.lines.Line2D at 0x1c204cbf550>,
#  <matplotlib.lines.Line2D at 0x1c204cbf580>,
#  <matplotlib.lines.Line2D at 0x1c204cbf670>,
#  <matplotlib.lines.Line2D at 0x1c204cbf760>,
#  <matplotlib.lines.Line2D at 0x1c204cbf850>,
#  <matplotlib.lines.Line2D at 0x1c204cbf940>,
#  <matplotlib.lines.Line2D at 0x1c204cbfa30>,
#  <matplotlib.lines.Line2D at 0x1c204cbfb20>,
#  <matplotlib.lines.Line2D at 0x1c204cbfc10>,
#  <matplotlib.lines.Line2D at 0x1c204cbfd00>,
#  <matplotlib.lines.Line2D at 0x1c204cbf520>,
#  <matplotlib.lines.Line2D at 0x1c204cbfdf0>,
#  <matplotlib.lines.Line2D at 0x1c204cbffa0>,
#  <matplotlib.lines.Line2D at 0x1c204cd00d0>,
#  <matplotlib.lines.Line2D at 0x1c204cd01c0>,
#  <matplotlib.lines.Line2D at 0x1c204cd02b0>,
#  <matplotlib.lines.Line2D at 0x1c204cd03a0>,
#  <matplotlib.lines.Line2D at 0x1c204cd0490>,
#  <matplotlib.lines.Line2D at 0x1c204cd0580>,
#  <matplotlib.lines.Line2D at 0x1c204cd0670>,
#  <matplotlib.lines.Line2D at 0x1c204cd0760>,
#  <matplotlib.lines.Line2D at 0x1c204cd0850>,
#  <matplotlib.lines.Line2D at 0x1c204cd0940>,
#  <matplotlib.lines.Line2D at 0x1c204cd0a30>,
#  <matplotlib.lines.Line2D at 0x1c204cd0b20>,
#  <matplotlib.lines.Line2D at 0x1c204cd0c10>,
#  <matplotlib.lines.Line2D at 0x1c204cd0d00>,
#  <matplotlib.lines.Line2D at 0x1c204cd0df0>,
#  <matplotlib.lines.Line2D at 0x1c204cd0ee0>,
#  <matplotlib.lines.Line2D at 0x1c204cd0fd0>,
#  <matplotlib.lines.Line2D at 0x1c204cdb100>,
#  <matplotlib.lines.Line2D at 0x1c204cdb1f0>,
#  <matplotlib.lines.Line2D at 0x1c204cdb2e0>,
#  <matplotlib.lines.Line2D at 0x1c204cdb3d0>,
#  <matplotlib.lines.Line2D at 0x1c204cdb4c0>,
#  <matplotlib.lines.Line2D at 0x1c204cdb5e0>,
#  <matplotlib.lines.Line2D at 0x1c204cdb6d0>,
#  <matplotlib.lines.Line2D at 0x1c204cdb7c0>,
#  <matplotlib.lines.Line2D at 0x1c204cdb8b0>,
#  <matplotlib.lines.Line2D at 0x1c204cdb9a0>,
#  <matplotlib.lines.Line2D at 0x1c204cdba90>,
#  <matplotlib.lines.Line2D at 0x1c204cdbb80>,
#  <matplotlib.lines.Line2D at 0x1c204cdbc70>,
#  <matplotlib.lines.Line2D at 0x1c204cdbd60>,
#  <matplotlib.lines.Line2D at 0x1c204cdbe50>,
#  <matplotlib.lines.Line2D at 0x1c204cdbf40>,
#  <matplotlib.lines.Line2D at 0x1c204ce2070>,
#  <matplotlib.lines.Line2D at 0x1c204ce2160>,
#  <matplotlib.lines.Line2D at 0x1c204ce2250>,
#  <matplotlib.lines.Line2D at 0x1c204ce2340>,
#  <matplotlib.lines.Line2D at 0x1c204ce2430>,
#  <matplotlib.lines.Line2D at 0x1c204ce2520>,
#  <matplotlib.lines.Line2D at 0x1c204ce2610>,
#  <matplotlib.lines.Line2D at 0x1c204ce2700>,
#  <matplotlib.lines.Line2D at 0x1c204ce27f0>,
#  <matplotlib.lines.Line2D at 0x1c204ce28e0>,
#  <matplotlib.lines.Line2D at 0x1c204ce29d0>,
#  <matplotlib.lines.Line2D at 0x1c204ce2ac0>,
#  <matplotlib.lines.Line2D at 0x1c204ce2bb0>,
#  <matplotlib.lines.Line2D at 0x1c204ce2ca0>,
#  <matplotlib.lines.Line2D at 0x1c204ce2d90>,
#  <matplotlib.lines.Line2D at 0x1c204ce2e80>,
#  <matplotlib.lines.Line2D at 0x1c204ce2f70>,
#  <matplotlib.lines.Line2D at 0x1c204cea0a0>,
#  <matplotlib.lines.Line2D at 0x1c204cea190>,
#  <matplotlib.lines.Line2D at 0x1c204cea280>,
#  <matplotlib.lines.Line2D at 0x1c204cea370>,
#  <matplotlib.lines.Line2D at 0x1c204cea460>,
#  <matplotlib.lines.Line2D at 0x1c204cea550>,
#  <matplotlib.lines.Line2D at 0x1c204cea640>,
#  <matplotlib.lines.Line2D at 0x1c204cea730>,
#  <matplotlib.lines.Line2D at 0x1c204cea820>,
#  <matplotlib.lines.Line2D at 0x1c204cea910>,
#  <matplotlib.lines.Line2D at 0x1c204ceaa00>,
#  <matplotlib.lines.Line2D at 0x1c204ceaaf0>,
#  <matplotlib.lines.Line2D at 0x1c204ceabe0>,
#  <matplotlib.lines.Line2D at 0x1c204ceacd0>,
#  <matplotlib.lines.Line2D at 0x1c204ceadc0>,
#  <matplotlib.lines.Line2D at 0x1c204ceaeb0>,
#  <matplotlib.lines.Line2D at 0x1c204ceafa0>,
#  <matplotlib.lines.Line2D at 0x1c204cf20d0>,
#  <matplotlib.lines.Line2D at 0x1c204cf21c0>,
#  <matplotlib.lines.Line2D at 0x1c204cf22b0>,
#  <matplotlib.lines.Line2D at 0x1c204cf23a0>,
#  <matplotlib.lines.Line2D at 0x1c204cf2490>,
#  <matplotlib.lines.Line2D at 0x1c204cf2580>,
#  <matplotlib.lines.Line2D at 0x1c204cf2670>,
#  <matplotlib.lines.Line2D at 0x1c204cf2760>,
#  <matplotlib.lines.Line2D at 0x1c204cf2850>,
#  <matplotlib.lines.Line2D at 0x1c204cf2940>,
#  <matplotlib.lines.Line2D at 0x1c204cf2a30>,
#  <matplotlib.lines.Line2D at 0x1c204cf2b20>,
#  <matplotlib.lines.Line2D at 0x1c204cf2c10>,
#  <matplotlib.lines.Line2D at 0x1c204cf2d00>,
#  <matplotlib.lines.Line2D at 0x1c204cf2df0>,
#  <matplotlib.lines.Line2D at 0x1c204cf2ee0>,
#  <matplotlib.lines.Line2D at 0x1c204cf2fd0>,
#  <matplotlib.lines.Line2D at 0x1c204cf9100>,
#  <matplotlib.lines.Line2D at 0x1c204cf91f0>]

# %%
u1 = []
u2 = []
vetor = []
u1.append(random.uniform(-5, 5))
u1.append(random.uniform(-5, 5))
tempo = 0
xs = np.linspace(-5,5,100)
minimo = np.zeros((1, 100)).astype(complex)

while tempo < 98:
    print(u1)
    psi_g[0:100, tempo] = psi[0:100, tempo]
    plt.plot(xs, np.absolute(psi[0:100, tempo])**2)
    u2 = optimize.minimize(Objetivo, u1, args=(tempo, psi, psiExato), method='CG')
    print(f"Iteração: {tempo+1}")
    print(u2)
    print("---------------")
    minimo[0][tempo] = (u2.x[0])
    D = multMatrizes(M = 100, us = u2.x[0])
    psi = np.matmul(D, psi)
    tempo += 1
    u1 = []
    u1.append(u2.x[0])
    u1.append(random.uniform(-5, 5))

tempoFinal = time.time() - tempoInicial
print(tempoFinal)
# Out:
# [-3.0640172452987793, -1.7888693328908212]
# Iteração: 1
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5587.288366874377
#        x: [-1.593e+02  7.491e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 117
#     njev: 39
# ---------------
# [-159.30486296221807, 1.5009087099423235]
# Iteração: 2
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4973.894737006918
#        x: [ 7.491e+00  7.175e+00]
#      nit: 15
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 195
#     njev: 65
# ---------------
# [7.491155428840651, 4.92438072077076]
# Iteração: 3
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4918.727032089264
#        x: [ 7.175e+00  6.990e+00]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 30
#     njev: 10
# ---------------
# [7.17496028655647, -1.4314253898086693]
# Iteração: 4
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4884.766705531185
#        x: [ 6.989e+00  6.905e+00]
#      nit: 14
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 96
#     njev: 32
# ---------------
# [6.989483152291187, 1.5361323056005105]
# Iteração: 5
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4873.3057192145425
#        x: [ 6.905e+00  6.905e+00]
#      nit: 19
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 129
#     njev: 43
# ---------------
# [6.90453252254656, -3.8023104059000277]
# Iteração: 6
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4884.766644699713
#        x: [ 6.905e+00  6.990e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 63
#     njev: 21
# ---------------
# [6.904504185376714, 0.6528078188377542]
# Iteração: 7
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4918.726912430031
#        x: [ 6.990e+00  7.175e+00]
#      nit: 15
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 93
#     njev: 31
# ---------------
# [6.98969242924165, 4.769558051077826]
# Iteração: 8
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4973.894562741294
#        x: [ 7.175e+00  7.492e+00]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 63
#     njev: 21
# ---------------
# [7.174779901610716, 2.236710538715325]
# Iteração: 9
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5048.01993113135
#        x: [ 7.492e+00  8.003e+00]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 45
#     njev: 15
# ---------------
# [7.491591806888382, 4.365825692369768]
# Iteração: 10
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5137.686525899524
#        x: [ 8.003e+00  8.822e+00]
#      nit: 5
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 36
#     njev: 12
# ---------------
# [8.002865538246683, 3.7392709415330145]
# Iteração: 11
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 5237.849684998664
#        x: [ 8.822e+00  1.014e+01]
#      nit: 4
#      jac: [ 1.831e-04  6.104e-05]
#     nfev: 69
#     njev: 19
# ---------------
# [8.821566612849075, -4.195941792625927]
# Iteração: 12
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 5340.876636514912
#        x: [ 1.014e+01  1.226e+01]
#      nit: 8
#      jac: [-6.104e-05 -6.104e-05]
#     nfev: 93
#     njev: 31
# ---------------
# [10.143057832456114, 3.423883001587855]
# Iteração: 13
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5434.930209062541
#        x: [ 1.226e+01  1.530e+01]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 54
#     njev: 18
# ---------------
# [12.2590121355831, 0.4491259065853832]
# Iteração: 14
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5503.138367455491
#        x: [ 1.530e+01  1.814e+01]
#      nit: 14
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 117
#     njev: 39
# ---------------
# [15.296887025459512, 2.278767667123388]
# Iteração: 15
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5528.339065403547
#        x: [ 1.814e+01  1.814e+01]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 51
#     njev: 17
# ---------------
# [18.140921921467232, 3.5768132539985817]
# Iteração: 16
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5503.13849778082
#        x: [ 1.814e+01  1.530e+01]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 90
#     njev: 30
# ---------------
# [18.13963068737772, 3.5647591372177416]
# Iteração: 17
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 5434.93043312945
#        x: [ 1.530e+01  1.226e+01]
#      nit: 11
#      jac: [ 6.104e-05  1.221e-04]
#     nfev: 189
#     njev: 59
# ---------------
# [15.296619770430304, 0.7118863820706745]
# Iteração: 18
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5340.876905751367
#        x: [ 1.226e+01  1.014e+01]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 75
#     njev: 25
# ---------------
# [12.258831081505125, -2.1784350658773177]
# Iteração: 19
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5237.849961370022
#        x: [ 1.014e+01  8.821e+00]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 66
#     njev: 22
# ---------------
# [10.143775616062026, -2.2204366109341587]
# Iteração: 20
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5137.6867845755
#        x: [ 8.821e+00  8.003e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 192
#     njev: 62
# ---------------
# [8.820962071043885, 3.3162557621402193]
# Iteração: 21
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5048.020155601018
#        x: [ 8.003e+00  7.492e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 93
#     njev: 31
# ---------------
# [8.002893734948689, -0.15415807671050175]
# Iteração: 22
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4973.89474146762
#        x: [ 7.492e+00  7.174e+00]
#      nit: 15
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 102
#     njev: 34
# ---------------
# [7.491766793635425, 0.3774782402922252]
# Iteração: 23
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 4918.7270372328085
#        x: [ 7.175e+00  6.990e+00]
#      nit: 13
#      jac: [-6.104e-05  0.000e+00]
#     nfev: 207
#     njev: 65
# ---------------
# [7.174540646226143, -3.5376647853478573]
# Iteração: 24
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4884.766710093839
#        x: [ 6.990e+00  6.905e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 63
#     njev: 21
# ---------------
# [6.989736001480733, 1.9772587201420242]
# Iteração: 25
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4873.305722119153
#        x: [ 6.905e+00  6.904e+00]
#      nit: 13
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 75
#     njev: 25
# ---------------
# [6.9045746238440335, -2.699225210801143]
# Iteração: 26
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4884.766645287271
#        x: [ 6.904e+00  6.990e+00]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 66
#     njev: 22
# ---------------
# [6.904405821875998, -1.9012771603632594]
# Iteração: 27
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4918.726910630217
#        x: [ 6.990e+00  7.175e+00]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 57
#     njev: 19
# ---------------
# [6.990069478205966, -4.475702442075834]
# Iteração: 28
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4973.894559114871
#        x: [ 7.175e+00  7.491e+00]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 57
#     njev: 19
# ---------------
# [7.174868302788174, 0.8288296548437657]
# Iteração: 29
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5048.019926561285
#        x: [ 7.491e+00  8.003e+00]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 66
#     njev: 22
# ---------------
# [7.49107538150422, 0.5649978144470076]
# Iteração: 30
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5137.6865214631525
#        x: [ 8.003e+00  8.821e+00]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 84
#     njev: 28
# ---------------
# [8.002871979216152, 2.449989740822888]
# Iteração: 31
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5237.849681750167
#        x: [ 8.822e+00  1.014e+01]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 87
#     njev: 29
# ---------------
# [8.821562775630225, -2.5806942306448977]
# Iteração: 32
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5340.876635323904
#        x: [ 1.014e+01  1.226e+01]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 60
#     njev: 20
# ---------------
# [10.143535518506615, 1.9984904586240084]
# Iteração: 33
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5434.930210278246
#        x: [ 1.226e+01  1.530e+01]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 93
#     njev: 31
# ---------------
# [12.258850370743604, -3.816043242642224]
# Iteração: 34
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5503.138370705372
#        x: [ 1.530e+01  1.814e+01]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 75
#     njev: 25
# ---------------
# [15.29655843924861, 2.7570303173027133]
# Iteração: 35
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5528.339069372885
#        x: [ 1.814e+01  1.814e+01]
#      nit: 6
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 54
#     njev: 18
# ---------------
# [18.14053143220891, -0.8023158001139983]
# Iteração: 36
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5503.138500788277
#        x: [ 1.814e+01  1.530e+01]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 108
#     njev: 36
# ---------------
# [18.140060418931295, 2.3661771148282913]
# Iteração: 37
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 5434.930433874851
#        x: [ 1.530e+01  1.226e+01]
#      nit: 13
#      jac: [ 6.104e-05  6.104e-05]
#     nfev: 198
#     njev: 62
# ---------------
# [15.29659824796629, 3.2893156956313945]
# Iteração: 38
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5340.876903867364
#        x: [ 1.226e+01  1.014e+01]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 69
#     njev: 23
# ---------------
# [12.25915881938511, 1.5299978385537605]
# Iteração: 39
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5237.849957417917
#        x: [ 1.014e+01  8.821e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 63
#     njev: 21
# ---------------
# [10.143318499805922, 1.0541104756748174]
# Iteração: 40
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5137.686779656392
#        x: [ 8.821e+00  8.003e+00]
#      nit: 14
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 81
#     njev: 27
# ---------------
# [8.821367580111525, -3.10699609472161]
# Iteração: 41
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5048.0201510417155
#        x: [ 8.003e+00  7.492e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 66
#     njev: 22
# ---------------
# [8.002579812117183, 0.5426105362527291]
# Iteração: 42
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4973.894738458938
#        x: [ 7.492e+00  7.175e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 105
#     njev: 35
# ---------------
# [7.4918300069372865, 1.881853551798697]
# Iteração: 43
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 4918.727036578173
#        x: [ 7.175e+00  6.990e+00]
#      nit: 9
#      jac: [ 1.221e-04  1.221e-04]
#     nfev: 216
#     njev: 68
# ---------------
# [7.174608880837702, 0.5230643697653745]
# Iteração: 44
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4884.766711953165
#        x: [ 6.990e+00  6.905e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 72
#     njev: 24
# ---------------
# [6.989744597031497, -2.568427929840549]
# Iteração: 45
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4873.305726019119
#        x: [ 6.905e+00  6.905e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 57
#     njev: 19
# ---------------
# [6.904638665694099, 0.9061384670389003]
# Iteração: 46
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4884.766650235079
#        x: [ 6.904e+00  6.990e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 63
#     njev: 21
# ---------------
# [6.904445655458132, -4.717395215627267]
# Iteração: 47
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4918.726915432985
#        x: [ 6.990e+00  7.175e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 78
#     njev: 26
# ---------------
# [6.989850808699135, 3.699940189558962]
# Iteração: 48
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4973.894562656218
#        x: [ 7.175e+00  7.492e+00]
#      nit: 13
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 90
#     njev: 30
# ---------------
# [7.17458467489314, 2.62725482511512]
# Iteração: 49
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5048.019928156533
#        x: [ 7.491e+00  8.003e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 78
#     njev: 26
# ---------------
# [7.491343471903222, 2.7824910668428977]
# Iteração: 50
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 5137.686520841137
#        x: [ 8.003e+00  8.821e+00]
#      nit: 9
#      jac: [ 0.000e+00  6.104e-05]
#     nfev: 93
#     njev: 31
# ---------------
# [8.003082407465342, -2.8557291685186903]
# Iteração: 51
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5237.849679110499
#        x: [ 8.822e+00  1.014e+01]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 78
#     njev: 26
# ---------------
# [8.8215523532698, -2.0145303427452363]
# Iteração: 52
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5340.8766313900705
#        x: [ 1.014e+01  1.226e+01]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 111
#     njev: 37
# ---------------
# [10.143287548977275, 2.6268450537227617]
# Iteração: 53
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5434.930206190507
#        x: [ 1.226e+01  1.530e+01]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 96
#     njev: 32
# ---------------
# [12.258732151453247, -3.6325464033365398]
# Iteração: 54
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5503.13836794455
#        x: [ 1.530e+01  1.814e+01]
#      nit: 6
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 54
#     njev: 18
# ---------------
# [15.296813606502324, 0.6965052917448382]
# Iteração: 55
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5528.339069103025
#        x: [ 1.814e+01  1.814e+01]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 60
#     njev: 20
# ---------------
# [18.13996409524725, 4.48029041413179]
# Iteração: 56
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5503.138503222588
#        x: [ 1.814e+01  1.530e+01]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 96
#     njev: 32
# ---------------
# [18.140560067868396, 4.970727729213319]
# Iteração: 57
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5434.930438070088
#        x: [ 1.530e+01  1.226e+01]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 81
#     njev: 27
# ---------------
# [15.296966545605741, 2.2309833727939052]
# Iteração: 58
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5340.876908268638
#        x: [ 1.226e+01  1.014e+01]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 123
#     njev: 41
# ---------------
# [12.258868979566216, 1.7058113142259668]
# Iteração: 59
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5237.849960554999
#        x: [ 1.014e+01  8.821e+00]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 78
#     njev: 26
# ---------------
# [10.143517843327917, -0.7633716545499656]
# Iteração: 60
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5137.686780564738
#        x: [ 8.821e+00  8.003e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 81
#     njev: 27
# ---------------
# [8.821383352986885, -3.1058308119005105]
# Iteração: 61
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5048.020149392314
#        x: [ 8.003e+00  7.491e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 72
#     njev: 24
# ---------------
# [8.002758080071704, -3.2878757132214123]
# Iteração: 62
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4973.894734642348
#        x: [ 7.491e+00  7.175e+00]
#      nit: 14
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 90
#     njev: 30
# ---------------
# [7.491313605367671, 3.252596894560874]
# Iteração: 63
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4918.727031539793
#        x: [ 7.175e+00  6.990e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 93
#     njev: 31
# ---------------
# [7.174879423690991, -3.003797207365558]
# Iteração: 64
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4884.766706952461
#        x: [ 6.990e+00  6.904e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 57
#     njev: 19
# ---------------
# [6.989876181774604, 4.783777903156274]
# Iteração: 65
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4873.305722238112
#        x: [ 6.904e+00  6.905e+00]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 51
#     njev: 17
# ---------------
# [6.90429671316203, 3.3349986263380753]
# Iteração: 66
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 4884.7666485252
#        x: [ 6.904e+00  6.990e+00]
#      nit: 10
#      jac: [-6.104e-05 -6.104e-05]
#     nfev: 84
#     njev: 28
# ---------------
# [6.904497695461835, -2.320925944264295]
# Iteração: 67
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4918.726916103036
#        x: [ 6.990e+00  7.175e+00]
#      nit: 13
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 66
#     njev: 22
# ---------------
# [6.989815023409447, -3.9000562222498125]
# Iteração: 68
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4973.894565445693
#        x: [ 7.175e+00  7.491e+00]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 63
#     njev: 21
# ---------------
# [7.174767977364722, 2.4672054414250946]
# Iteração: 69
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5048.01993233736
#        x: [ 7.491e+00  8.003e+00]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 60
#     njev: 20
# ---------------
# [7.491385955101557, -1.8631100579272664]
# Iteração: 70
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5137.686525397516
#        x: [ 8.003e+00  8.821e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 69
#     njev: 23
# ---------------
# [8.003082606963403, 0.1849377631875191]
# Iteração: 71
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5237.849682953108
#        x: [ 8.821e+00  1.014e+01]
#      nit: 13
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 114
#     njev: 38
# ---------------
# [8.821159595388151, 2.3483360062140424]
# Iteração: 72
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5340.876633511596
#        x: [ 1.014e+01  1.226e+01]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 69
#     njev: 23
# ---------------
# [10.143574392642476, 3.9522903074951703]
# Iteração: 73
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5434.930205945132
#        x: [ 1.226e+01  1.530e+01]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 102
#     njev: 34
# ---------------
# [12.258979843364553, 0.9255360890589346]
# Iteração: 74
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5503.138365340538
#        x: [ 1.530e+01  1.814e+01]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 72
#     njev: 24
# ---------------
# [15.296669618506654, 0.4814518356510886]
# Iteração: 75
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5528.339065144592
#        x: [ 1.814e+01  1.814e+01]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 69
#     njev: 23
# ---------------
# [18.139855654875884, -1.2082332620092662]
# Iteração: 76
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5503.1384995846865
#        x: [ 1.814e+01  1.530e+01]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 84
#     njev: 28
# ---------------
# [18.14102516616942, 3.5402134261231026]
# Iteração: 77
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5434.930436328283
#        x: [ 1.530e+01  1.226e+01]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 84
#     njev: 28
# ---------------
# [15.296107616295163, 1.5364291949259954]
# Iteração: 78
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5340.876909141601
#        x: [ 1.226e+01  1.014e+01]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 72
#     njev: 24
# ---------------
# [12.259343540080499, -0.32911185168832446]
# Iteração: 79
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5237.849963805894
#        x: [ 1.014e+01  8.821e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 63
#     njev: 21
# ---------------
# [10.14345937964427, -4.696334011913942]
# Iteração: 80
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 5137.686785281518
#        x: [ 8.821e+00  8.003e+00]
#      nit: 11
#      jac: [ 0.000e+00  6.104e-05]
#     nfev: 75
#     njev: 25
# ---------------
# [8.820988115013021, -2.5532639884249564]
# Iteração: 81
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5048.020154316209
#        x: [ 8.003e+00  7.492e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 63
#     njev: 21
# ---------------
# [8.002814615198588, 1.9417339435254757]
# Iteração: 82
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4973.894738505802
#        x: [ 7.492e+00  7.175e+00]
#      nit: 13
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 84
#     njev: 28
# ---------------
# [7.491687167674388, -1.6927941653030687]
# Iteração: 83
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4918.727033365843
#        x: [ 7.175e+00  6.990e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 66
#     njev: 22
# ---------------
# [7.174622646182569, 0.8126354927858959]
# Iteração: 84
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4884.766706288584
#        x: [ 6.990e+00  6.904e+00]
#      nit: 17
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 78
#     njev: 26
# ---------------
# [6.989950372335078, 1.4159096193541787]
# Iteração: 85
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4873.30571927209
#        x: [ 6.904e+00  6.904e+00]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 102
#     njev: 34
# ---------------
# [6.904448508252644, -1.8186360212666122]
# Iteração: 86
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4884.766644001107
#        x: [ 6.905e+00  6.990e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 96
#     njev: 32
# ---------------
# [6.904549652254527, 1.6113400338236827]
# Iteração: 87
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4918.726911125542
#        x: [ 6.990e+00  7.175e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 78
#     njev: 26
# ---------------
# [6.98980217297328, 4.591093894611372]
# Iteração: 88
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4973.894561185003
#        x: [ 7.175e+00  7.491e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 69
#     njev: 23
# ---------------
# [7.174773420075777, -4.279236893970172]
# Iteração: 89
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5048.01992971554
#        x: [ 7.492e+00  8.003e+00]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 60
#     njev: 20
# ---------------
# [7.491524798686675, -2.349179527430103]
# Iteração: 90
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5137.686524946672
#        x: [ 8.003e+00  8.821e+00]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 78
#     njev: 26
# ---------------
# [8.002803141350684, -3.5826577180357813]
# Iteração: 91
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5237.849684704101
#        x: [ 8.821e+00  1.014e+01]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 63
#     njev: 21
# ---------------
# [8.82125736877637, -2.2130243852719413]
# Iteração: 92
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5340.876636982795
#        x: [ 1.014e+01  1.226e+01]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 66
#     njev: 22
# ---------------
# [10.143667682555039, 3.1886555673049237]
# Iteração: 93
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 5434.930210111847
#        x: [ 1.226e+01  1.530e+01]
#      nit: 7
#      jac: [ 0.000e+00  6.104e-05]
#     nfev: 144
#     njev: 44
# ---------------
# [12.259078826430779, 1.0133698141170866]
# Iteração: 94
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 5503.138368776891
#        x: [ 1.530e+01  1.814e+01]
#      nit: 5
#      jac: [-1.221e-04  0.000e+00]
#     nfev: 168
#     njev: 52
# ---------------
# [15.295166413157576, 3.029830220357466]
# Iteração: 95
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5528.339066392397
#        x: [ 1.814e+01  1.814e+01]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 81
#     njev: 27
# ---------------
# [18.14176191725574, 4.594977673035443]
# Iteração: 96
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 5503.138497994421
#        x: [ 1.814e+01  1.530e+01]
#      nit: 10
#      jac: [-6.104e-05  0.000e+00]
#     nfev: 108
#     njev: 36
# ---------------
# [18.139955314762187, -3.73133916681636]
# Iteração: 97
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5434.93043256632
#        x: [ 1.530e+01  1.226e+01]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 72
#     njev: 24
# ---------------
# [15.296915732390742, 4.7013794172823395]
# Iteração: 98
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5340.876904577988
#        x: [ 1.226e+01  1.014e+01]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 87
#     njev: 29
# ---------------
# 62.71371030807495

# %%
from matplotlib import animation
from matplotlib.animation import PillowWriter

def animate(i):
    xs = np.linspace(-5,5,100)
    ln1.set_data(xs, np.absolute(psi_g[0:100,i-1])**2)
    ln2.set_data(xs, np.absolute(psiExato[0:100,i-1])**2)
    time_text.set_text('$t=$'+'{:.1f}'.format(i/100))
    
fig, ax = plt.subplots(1, 1,figsize=(8,4))
ax.grid()
ln1, = plt.plot([], [], 'r-', lw=2, markersize=8, label='Origem')
ln2, = plt.plot([], [], 'b-', lw=2, markersize=8, label='Destino')
time_text = ax.text(0.85, 0.9, '', fontsize=15,
           bbox=dict(facecolor='white', edgecolor='black'))
ax.set_ylim(0, 1)
ax.set_xlim(-5,5)
title = ax.set_title('Resposta analítica')
ax.set_ylabel('$|\psi(x)|^2$', fontsize=20)
ax.set_xlabel('$x$', fontsize=20)
ax.legend(loc='upper left')
ax.set_title('')
plt.tight_layout()
ani = animation.FuncAnimation(fig, animate, frames=100, interval=200)
ani.save('100x100.gif',writer='pillow',fps=10,dpi=100)

# %%
t = np.linspace(-5, 5, 100)

minn = np.zeros((1, 100))

for i in range(0, 50):
    minn[0][i] = minimo[0][i+49]

plt.ylabel('Controle') 
plt.xlabel('Tempo') 
plt.plot(t, minn[0], color='r', marker='*', linewidth=1, markersize=1, label="Origem")
plt.legend(loc='upper right')
plt.savefig('100.png', format='png')
# Out:
# C:\Users\Gabriel\AppData\Local\Temp\ipykernel_11716\2947550352.py:6: ComplexWarning: Casting complex values to real discards the imaginary part
#   minn[0][i] = minimo[0][i+49]
