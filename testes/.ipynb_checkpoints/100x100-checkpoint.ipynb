# %%
# Bilbiotecas para auxílio na programação matemática
import math, sys 
import numpy as np
import sympy as sp

from scipy import sparse # Produção das diagonais das matrizes
from scipy.sparse import diags 

# Plotagem 2D e 3D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm


from os import path # Suficiente para manipulação de arquivos
    
# Para solução exata
from scipy.special import hermite
from math import factorial

# %matplotlib inline
count = 0

# Para otimização dos sistemas
from scipy import optimize

import time

tempoInicial = time.time()

# %%
def N(n):
    return 1*1./np.sqrt(np.sqrt(np.pi)*2**n*factorial(n))

def psix(n, x):
    Hn=hermite(n)
    Px = N(n)*Hn(x)*np.exp(-0.5*x**2)
    return Px

def psixt(n, x, t):
    Hn=hermite(n)
    a = complex(0,1)
    Pxt = N(n)*Hn(x)*np.exp(-0.5*x**2)*np.exp(-a*(n+1/2)*t*np.pi)
    return Pxt

# %%
def CrankNicolson(M, O = 0, L = 1, T = 0.5):
    N = 100 #São os pontos no intervalo de tempo
    
    #Pensando no poço quadrado infinito, temos essas duas limitações, onde L varia
    x0, xL = O, L

    P = 3.141111111111111111111111111
    #Discretização espacial
    dx = (xL - x0)/(P*M-1) 

    #Discretização temporal
    t0, tF = 0, T
    dt = (tF - t0)/(P*N-1)

    #Retorno dos números em um intervalo
    xs = np.linspace(x0, xL, M)
    ts = np.linspace(t0, tF, N)

    #Suponha um oscilador harmônico simples
    hbar = 1
    m = 1
    w = np.pi
    V = 1/2*m*w**2*xs**2

    #A partir da demonstração
    a = hbar/(4*m*dx**2) 
    b = 1j*hbar/dt - 2*a - 1/2*V
    c = 1j*hbar/dt + 2*a + 1/2*V

    #Obtenção da matriz
    ##Diagonais principais
    diagPrincipalA = b*np.ones((1,M)) #Cria uma matriz de 1's
    diagPrincipalB = c*np.ones((1,M))

    ##Diagonais secundárias, tem um tamanho a menos
    diagSecundariaA = a*np.ones((1,M-1))
    diagSecundariaB = (-a)*np.ones((1,M-1))

    diagonaisA = [diagPrincipalA, diagSecundariaA, diagSecundariaA]
    matrizA = sparse.diags(diagonaisA, [0, -1, 1], shape=(M,M)).toarray()
    
    diagonaisB = [diagPrincipalB, diagSecundariaB, diagSecundariaB]         
    matrizB = sparse.diags(diagonaisB, [0, -1, 1], shape=(M,M)).toarray()
    
    #Obtenção da matriz psi (Ela acumulará para o psi futuro)
    ps = np.zeros((M, N))
    psi_c = np.zeros((M, N))

    #Condição inicial
    ps[:,0] = 0.80 * psix(0, xs) + 0.60 * psix(1, xs) #A primeira coluna da matriz terá a equação inicial, em todas as posições
    psi_c = ps.astype(complex)
    #For para o acúmulo de resultados
    for k in range(1,N):
        b = np.matmul(matrizB, np.array(psi_c[0:M, k-1])) #Multiplicação de arrays já que houve uma conversão anterior
        psi_c[0:M, k] = np.linalg.solve(matrizA, b) #Matlab: x = A\b
        #plt.plot(xs, np.absolute(psi_c[0:M, k])**2)
    return psi_c

# %%
def multMatrizes(M, us, O = -5, L = 5, T = 10):
    N = 100 #São os pontos no intervalo de tempo
    
    #Pensando no poço quadrado infinito, temos essas duas limitações, onde L varia
    x0, xL = O, L

    P = 3.141111111111111111111111111
    #Discretização espacial
    dx = (xL - x0)/(P*M-1) 

    #Discretização temporal
    t0, tF = 0, T
    dt = (tF - t0)/(P*N-1)

    #Retorno dos números em um intervalo
    xs = np.linspace(x0, xL, M)
    ts = np.linspace(t0, tF, N)
    
    #Suponha um oscilador harmônico simples
    hbar = 1
    m = 1
    w = np.pi
    #V = us #V(x,u(t))
    V = 1/2*m*w**2*xs**2+us

    #A partir da demonstração
    a = hbar/(4*m*dx**2) 
    b = 1j*hbar/dt - 2*a - 1/2*V
    c = 1j*hbar/dt + 2*a + 1/2*V

    #Obtenção da matriz
    ##Diagonais principais
    diagPrincipalA = b*np.ones((1,M)) #Cria uma matriz de 1's
    diagPrincipalB = c*np.ones((1,M))

    ##Diagonais secundárias, tem um tamanho a menos
    diagSecundariaA = a*np.ones((1,M-1))
    diagSecundariaB = (-a)*np.ones((1,M-1))

    diagonaisA = [diagPrincipalA, diagSecundariaA, diagSecundariaA]
    matrizA = sparse.diags(diagonaisA, [0, -1, 1], shape=(M,M)).toarray()
    
    diagonaisB = [diagPrincipalB, diagSecundariaB, diagSecundariaB]         
    matrizB = sparse.diags(diagonaisB, [0, -1, 1], shape=(M,M)).toarray()

    return np.matmul(np.linalg.inv(matrizA), matrizB)

# %%
# Gradiente e função objetivo

def ExactSolution(M, T = 5, L = 5):
    N = 100

    xs = np.linspace(-5, L, M)
    ts = np.linspace(0, N/10, T)
    
    psiExato = np.zeros((M, N)).astype(complex)
    r=0
    for i in np.arange(-5, 5, 0.1):
        for j in np.arange(0, 10, 0.1):
            psiExato[r][int(j*10)] = 1/np.sqrt(2)*psixt(0,i,j)+1/np.sqrt(2)*psixt(1,i,j)
        r+=1
    return psiExato

def Objetivo(x, y, psi, psiExato):
    A = np.zeros((100,100))
    B = np.zeros((100,100))
    A = multMatrizes(M = 100, us = x[0])
    B = multMatrizes(M = 100, us = x[1])
    return ((np.linalg.norm(np.array(psiExato[0:100, y])-np.array(psi)))**2+
            (np.linalg.norm(np.array(psiExato[0:100, y+1])-np.array(np.matmul(A,psi))))**2+
            (np.linalg.norm(np.array(psiExato[0:100, y+2])-np.array(np.matmul(np.matmul(B,A),psi))))**2)

# %%
import random

psi = np.zeros((100,100))
psi_f = np.zeros((100,100))
psi_g = psi_f.astype(complex)
psi = CrankNicolson(M = 100, O = -5, L = 5, T = 10)
psiExato = ExactSolution(M = 100)

# %%
xs = np.linspace(-5,5,100)
plt.plot(xs, np.absolute(psi[0:100,0:100])**2)
# Out:
# [<matplotlib.lines.Line2D at 0x2846cc7b640>,
#  <matplotlib.lines.Line2D at 0x2846cc7b6a0>,
#  <matplotlib.lines.Line2D at 0x2846cc7b6d0>,
#  <matplotlib.lines.Line2D at 0x2846cc7b7c0>,
#  <matplotlib.lines.Line2D at 0x2846cc7b8b0>,
#  <matplotlib.lines.Line2D at 0x2846cc7b9a0>,
#  <matplotlib.lines.Line2D at 0x2846cc7ba90>,
#  <matplotlib.lines.Line2D at 0x2846cc7bb80>,
#  <matplotlib.lines.Line2D at 0x2846cc7bc70>,
#  <matplotlib.lines.Line2D at 0x2846cc7bd60>,
#  <matplotlib.lines.Line2D at 0x2846cc7be50>,
#  <matplotlib.lines.Line2D at 0x2846cc7b670>,
#  <matplotlib.lines.Line2D at 0x2846cc7bf40>,
#  <matplotlib.lines.Line2D at 0x2846cc90130>,
#  <matplotlib.lines.Line2D at 0x2846cc90220>,
#  <matplotlib.lines.Line2D at 0x2846cc90310>,
#  <matplotlib.lines.Line2D at 0x2846cc90400>,
#  <matplotlib.lines.Line2D at 0x2846cc904f0>,
#  <matplotlib.lines.Line2D at 0x2846cc905e0>,
#  <matplotlib.lines.Line2D at 0x2846cc906d0>,
#  <matplotlib.lines.Line2D at 0x2846cc907c0>,
#  <matplotlib.lines.Line2D at 0x2846cc908b0>,
#  <matplotlib.lines.Line2D at 0x2846cc909a0>,
#  <matplotlib.lines.Line2D at 0x2846cc90a90>,
#  <matplotlib.lines.Line2D at 0x2846cc90b80>,
#  <matplotlib.lines.Line2D at 0x2846cc90c70>,
#  <matplotlib.lines.Line2D at 0x2846cc90d60>,
#  <matplotlib.lines.Line2D at 0x2846cc90e50>,
#  <matplotlib.lines.Line2D at 0x2846cc90f40>,
#  <matplotlib.lines.Line2D at 0x2846cc9b070>,
#  <matplotlib.lines.Line2D at 0x2846cc9b160>,
#  <matplotlib.lines.Line2D at 0x2846cc9b250>,
#  <matplotlib.lines.Line2D at 0x2846cc9b340>,
#  <matplotlib.lines.Line2D at 0x2846cc9b430>,
#  <matplotlib.lines.Line2D at 0x2846cc9b520>,
#  <matplotlib.lines.Line2D at 0x2846cc9b610>,
#  <matplotlib.lines.Line2D at 0x2846cc9b700>,
#  <matplotlib.lines.Line2D at 0x2846cc9b7f0>,
#  <matplotlib.lines.Line2D at 0x2846cc9b8e0>,
#  <matplotlib.lines.Line2D at 0x2846cc9b9d0>,
#  <matplotlib.lines.Line2D at 0x2846cc9bac0>,
#  <matplotlib.lines.Line2D at 0x2846cc9bbb0>,
#  <matplotlib.lines.Line2D at 0x2846cc9bca0>,
#  <matplotlib.lines.Line2D at 0x2846cc9bd90>,
#  <matplotlib.lines.Line2D at 0x2846cc9be80>,
#  <matplotlib.lines.Line2D at 0x2846cc9bf70>,
#  <matplotlib.lines.Line2D at 0x2846cca20a0>,
#  <matplotlib.lines.Line2D at 0x2846cca2190>,
#  <matplotlib.lines.Line2D at 0x2846cca2280>,
#  <matplotlib.lines.Line2D at 0x2846cca2370>,
#  <matplotlib.lines.Line2D at 0x2846cca2460>,
#  <matplotlib.lines.Line2D at 0x2846cca2550>,
#  <matplotlib.lines.Line2D at 0x2846cca2640>,
#  <matplotlib.lines.Line2D at 0x2846cca2730>,
#  <matplotlib.lines.Line2D at 0x2846cca2850>,
#  <matplotlib.lines.Line2D at 0x2846cca2940>,
#  <matplotlib.lines.Line2D at 0x2846cca2a30>,
#  <matplotlib.lines.Line2D at 0x2846cca2b20>,
#  <matplotlib.lines.Line2D at 0x2846cca2c10>,
#  <matplotlib.lines.Line2D at 0x2846cca2d00>,
#  <matplotlib.lines.Line2D at 0x2846cca2df0>,
#  <matplotlib.lines.Line2D at 0x2846cca2ee0>,
#  <matplotlib.lines.Line2D at 0x2846cca2fd0>,
#  <matplotlib.lines.Line2D at 0x2846ccaa100>,
#  <matplotlib.lines.Line2D at 0x2846ccaa1f0>,
#  <matplotlib.lines.Line2D at 0x2846ccaa2e0>,
#  <matplotlib.lines.Line2D at 0x2846ccaa3d0>,
#  <matplotlib.lines.Line2D at 0x2846ccaa4c0>,
#  <matplotlib.lines.Line2D at 0x2846ccaa5b0>,
#  <matplotlib.lines.Line2D at 0x2846ccaa6a0>,
#  <matplotlib.lines.Line2D at 0x2846ccaa790>,
#  <matplotlib.lines.Line2D at 0x2846ccaa880>,
#  <matplotlib.lines.Line2D at 0x2846ccaa970>,
#  <matplotlib.lines.Line2D at 0x2846ccaaa60>,
#  <matplotlib.lines.Line2D at 0x2846ccaab50>,
#  <matplotlib.lines.Line2D at 0x2846ccaac40>,
#  <matplotlib.lines.Line2D at 0x2846ccaad30>,
#  <matplotlib.lines.Line2D at 0x2846ccaae20>,
#  <matplotlib.lines.Line2D at 0x2846ccaaf10>,
#  <matplotlib.lines.Line2D at 0x2846ccb2040>,
#  <matplotlib.lines.Line2D at 0x2846ccb2130>,
#  <matplotlib.lines.Line2D at 0x2846ccb2220>,
#  <matplotlib.lines.Line2D at 0x2846ccb2310>,
#  <matplotlib.lines.Line2D at 0x2846ccb2400>,
#  <matplotlib.lines.Line2D at 0x2846ccb24f0>,
#  <matplotlib.lines.Line2D at 0x2846ccb25e0>,
#  <matplotlib.lines.Line2D at 0x2846ccb26d0>,
#  <matplotlib.lines.Line2D at 0x2846ccb27c0>,
#  <matplotlib.lines.Line2D at 0x2846ccb28b0>,
#  <matplotlib.lines.Line2D at 0x2846ccb29a0>,
#  <matplotlib.lines.Line2D at 0x2846ccb2a90>,
#  <matplotlib.lines.Line2D at 0x2846ccb2b80>,
#  <matplotlib.lines.Line2D at 0x2846ccb2c70>,
#  <matplotlib.lines.Line2D at 0x2846ccb2d60>,
#  <matplotlib.lines.Line2D at 0x2846ccb2e50>,
#  <matplotlib.lines.Line2D at 0x2846ccb2f40>,
#  <matplotlib.lines.Line2D at 0x2846ccba070>,
#  <matplotlib.lines.Line2D at 0x2846ccba160>,
#  <matplotlib.lines.Line2D at 0x2846ccba250>,
#  <matplotlib.lines.Line2D at 0x2846ccba340>]

# %%
u1 = []
u2 = []
vetor = []
u1.append(random.uniform(-5, 5))
u1.append(random.uniform(-5, 5))
tempo = 0
xs = np.linspace(-5,5,100)
minimo = np.zeros((1, 100)).astype(complex)

while tempo < 98:
    print(u1)
    psi_g[0:100, tempo] = psi[0:100, tempo]
    plt.plot(xs, np.absolute(psi[0:100, tempo])**2)
    u2 = optimize.minimize(Objetivo, u1, args=(tempo, psi, psiExato), method='CG')
    print(f"Iteração: {tempo+1}")
    print(u2)
    print("---------------")
    minimo[0][tempo] = (u2.x[0])
    D = multMatrizes(M = 100, us = u2.x[0])
    psi = np.matmul(D, psi)
    tempo += 1
    u1 = []
    u1.append(u2.x[0])
    u1.append(random.uniform(-5, 5))

tempoFinal = time.time() - tempoInicial
print(tempoFinal)
# Out:
# [-4.419906675311797, 1.6896852137877936]
# Iteração: 1
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5587.288366872512
#        x: [-1.593e+02  7.491e+00]
#      nit: 14
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 132
#     njev: 44
# ---------------
# [-159.30498086260516, -2.4898608608850283]
# Iteração: 2
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4973.894737004029
#        x: [ 7.491e+00  7.175e+00]
#      nit: 16
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 186
#     njev: 62
# ---------------
# [7.491208900785325, -2.0130546708105426]
# Iteração: 3
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4918.727032077042
#        x: [ 7.175e+00  6.990e+00]
#      nit: 13
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 90
#     njev: 30
# ---------------
# [7.174602601124357, -2.947983607662079]
# Iteração: 4
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4884.766705518403
#        x: [ 6.990e+00  6.904e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 72
#     njev: 24
# ---------------
# [6.989932548902098, 0.7874621053264992]
# Iteração: 5
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4873.3057192181695
#        x: [ 6.905e+00  6.904e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 63
#     njev: 21
# ---------------
# [6.904545124560997, 2.708812026689536]
# Iteração: 6
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4884.766644701459
#        x: [ 6.904e+00  6.990e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 72
#     njev: 24
# ---------------
# [6.9044496172021645, -4.936971816717055]
# Iteração: 7
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4918.726912422274
#        x: [ 6.990e+00  7.175e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 135
#     njev: 45
# ---------------
# [6.989843831257044, -1.5727501323147894]
# Iteração: 8
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4973.894562736143
#        x: [ 7.175e+00  7.491e+00]
#      nit: 14
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 75
#     njev: 25
# ---------------
# [7.174645096065759, -1.6294394782204815]
# Iteração: 9
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5048.019931136699
#        x: [ 7.492e+00  8.003e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 75
#     njev: 25
# ---------------
# [7.491692741715362, 4.889302924284747]
# Iteração: 10
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5137.686525895214
#        x: [ 8.003e+00  8.821e+00]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 54
#     njev: 18
# ---------------
# [8.002783905128782, -3.496060521460085]
# Iteração: 11
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5237.8496849686035
#        x: [ 8.821e+00  1.014e+01]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 69
#     njev: 23
# ---------------
# [8.821324800099791, -4.359070506444138]
# Iteração: 12
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5340.87663650773
#        x: [ 1.014e+01  1.226e+01]
#      nit: 6
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 69
#     njev: 23
# ---------------
# [10.143166265218325, 3.916446480887883]
# Iteração: 13
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5434.930209053877
#        x: [ 1.226e+01  1.530e+01]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 66
#     njev: 22
# ---------------
# [12.259446001588586, -1.0855153019296706]
# Iteração: 14
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5503.138367480069
#        x: [ 1.530e+01  1.814e+01]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 54
#     njev: 18
# ---------------
# [15.295504162547392, -1.3823172323929644]
# Iteração: 15
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5528.339065386265
#        x: [ 1.814e+01  1.814e+01]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 90
#     njev: 30
# ---------------
# [18.14114613047562, -4.011938561222693]
# Iteração: 16
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5503.138497753868
#        x: [ 1.814e+01  1.530e+01]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 75
#     njev: 25
# ---------------
# [18.1407602433633, -2.4098018504574883]
# Iteração: 17
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5434.930433145649
#        x: [ 1.530e+01  1.226e+01]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 81
#     njev: 27
# ---------------
# [15.296546746984214, -4.7760753336247905]
# Iteração: 18
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5340.87690575972
#        x: [ 1.226e+01  1.014e+01]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 69
#     njev: 23
# ---------------
# [12.258734714278198, -0.9163036656996564]
# Iteração: 19
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5237.84996136605
#        x: [ 1.014e+01  8.821e+00]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 63
#     njev: 21
# ---------------
# [10.143300492875705, -4.486123800237958]
# Iteração: 20
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5137.686784572828
#        x: [ 8.821e+00  8.003e+00]
#      nit: 16
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 129
#     njev: 43
# ---------------
# [8.821324242965918, 0.40280634072194843]
# Iteração: 21
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5048.020155606009
#        x: [ 8.003e+00  7.491e+00]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 54
#     njev: 18
# ---------------
# [8.003005828382747, 2.999768126674124]
# Iteração: 22
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 4973.894741480036
#        x: [ 7.491e+00  7.175e+00]
#      nit: 11
#      jac: [ 6.104e-05  6.104e-05]
#     nfev: 163
#     njev: 51
# ---------------
# [7.491415494403533, -2.042092869305414]
# Iteração: 23
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4918.727037231651
#        x: [ 7.175e+00  6.990e+00]
#      nit: 13
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 75
#     njev: 25
# ---------------
# [7.174664605980256, -4.378390198227102]
# Iteração: 24
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4884.76671009393
#        x: [ 6.990e+00  6.904e+00]
#      nit: 15
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 90
#     njev: 30
# ---------------
# [6.989970336959151, -0.44155555042244465]
# Iteração: 25
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 4873.305722118751
#        x: [ 6.904e+00  6.904e+00]
#      nit: 14
#      jac: [ 6.104e-05  0.000e+00]
#     nfev: 204
#     njev: 64
# ---------------
# [6.904387116424192, -3.7646907704778467]
# Iteração: 26
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4884.766645287479
#        x: [ 6.904e+00  6.990e+00]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 54
#     njev: 18
# ---------------
# [6.904381916489117, 0.48782805921474104]
# Iteração: 27
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4918.726910634836
#        x: [ 6.990e+00  7.175e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 75
#     njev: 25
# ---------------
# [6.990002136023312, -3.66104545525469]
# Iteração: 28
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4973.894559080269
#        x: [ 7.175e+00  7.492e+00]
#      nit: 15
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 93
#     njev: 31
# ---------------
# [7.174618918421966, -1.022642463434705]
# Iteração: 29
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5048.019926538038
#        x: [ 7.492e+00  8.003e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 81
#     njev: 27
# ---------------
# [7.491550091167661, -1.133701507957542]
# Iteração: 30
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 5137.6865214735
#        x: [ 8.003e+00  8.821e+00]
#      nit: 13
#      jac: [ 6.104e-05 -6.104e-05]
#     nfev: 197
#     njev: 62
# ---------------
# [8.00317815824659, -3.913461744529969]
# Iteração: 31
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5237.84968175492
#        x: [ 8.821e+00  1.014e+01]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 81
#     njev: 27
# ---------------
# [8.820927572949914, 0.07757865949023035]
# Iteração: 32
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 5340.876636099809
#        x: [ 1.014e+01  1.226e+01]
#      nit: 7
#      jac: [-3.662e-04 -4.883e-04]
#     nfev: 155
#     njev: 48
# ---------------
# [10.14460870526181, 3.219656747827397]
# Iteração: 33
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5434.930210407829
#        x: [ 1.226e+01  1.530e+01]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 54
#     njev: 18
# ---------------
# [12.25818957776979, -3.852701669272338]
# Iteração: 34
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5503.138370717911
#        x: [ 1.530e+01  1.814e+01]
#      nit: 6
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 60
#     njev: 20
# ---------------
# [15.29586356438639, 1.690846413051962]
# Iteração: 35
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5528.339069382055
#        x: [ 1.814e+01  1.814e+01]
#      nit: 14
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 129
#     njev: 43
# ---------------
# [18.14120765913862, -4.1933962712615935]
# Iteração: 36
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5503.138500802925
#        x: [ 1.814e+01  1.530e+01]
#      nit: 13
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 123
#     njev: 41
# ---------------
# [18.14016688600325, 2.670238573444646]
# Iteração: 37
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5434.930433876172
#        x: [ 1.530e+01  1.226e+01]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 102
#     njev: 34
# ---------------
# [15.296184087911731, -1.671401720560881]
# Iteração: 38
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5340.876903873324
#        x: [ 1.226e+01  1.014e+01]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 63
#     njev: 21
# ---------------
# [12.25906965336816, 1.4714976131075321]
# Iteração: 39
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5237.849957417466
#        x: [ 1.014e+01  8.821e+00]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 87
#     njev: 29
# ---------------
# [10.143620919516577, -2.5299432695244506]
# Iteração: 40
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5137.686779659231
#        x: [ 8.821e+00  8.003e+00]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 60
#     njev: 20
# ---------------
# [8.821367573222247, 1.551483816713386]
# Iteração: 41
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5048.0201510331235
#        x: [ 8.003e+00  7.492e+00]
#      nit: 14
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 96
#     njev: 32
# ---------------
# [8.002736806770034, 0.9795710694317492]
# Iteração: 42
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4973.894738453218
#        x: [ 7.491e+00  7.175e+00]
#      nit: 13
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 105
#     njev: 35
# ---------------
# [7.491494513851429, 4.685559054636514]
# Iteração: 43
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4918.727036567014
#        x: [ 7.175e+00  6.990e+00]
#      nit: 5
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 36
#     njev: 12
# ---------------
# [7.174688770823043, -0.3566058759689925]
# Iteração: 44
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4884.76671195127
#        x: [ 6.990e+00  6.904e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 99
#     njev: 33
# ---------------
# [6.989813228425737, 4.532282472237359]
# Iteração: 45
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4873.3057260289315
#        x: [ 6.904e+00  6.905e+00]
#      nit: 6
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 45
#     njev: 15
# ---------------
# [6.904374554686692, 1.297737334594954]
# Iteração: 46
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4884.76665024712
#        x: [ 6.905e+00  6.990e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 81
#     njev: 27
# ---------------
# [6.904834179301387, -0.1199907206526234]
# Iteração: 47
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4918.7269154420965
#        x: [ 6.990e+00  7.175e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 84
#     njev: 28
# ---------------
# [6.989651564384146, -3.2843147763814082]
# Iteração: 48
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4973.894562656167
#        x: [ 7.175e+00  7.492e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 72
#     njev: 24
# ---------------
# [7.174553404510866, -3.017223350747027]
# Iteração: 49
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5048.019928146785
#        x: [ 7.492e+00  8.003e+00]
#      nit: 14
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 96
#     njev: 32
# ---------------
# [7.491767521195816, 0.4092341981247767]
# Iteração: 50
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 5137.686520833511
#        x: [ 8.003e+00  8.821e+00]
#      nit: 9
#      jac: [ 6.104e-05  6.104e-05]
#     nfev: 231
#     njev: 73
# ---------------
# [8.002593893880784, -2.4379623061598443]
# Iteração: 51
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5237.849679106533
#        x: [ 8.821e+00  1.014e+01]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 78
#     njev: 26
# ---------------
# [8.821397508246777, 3.3756058510302385]
# Iteração: 52
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5340.876631371104
#        x: [ 1.014e+01  1.226e+01]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 54
#     njev: 18
# ---------------
# [10.143542820908323, -0.2656879034957349]
# Iteração: 53
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5434.930206189111
#        x: [ 1.226e+01  1.530e+01]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 57
#     njev: 19
# ---------------
# [12.259169237018957, -0.6809561091504621]
# Iteração: 54
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5503.138367943411
#        x: [ 1.530e+01  1.814e+01]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 69
#     njev: 23
# ---------------
# [15.296021767659491, 0.9625498111481914]
# Iteração: 55
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5528.33906910426
#        x: [ 1.814e+01  1.814e+01]
#      nit: 6
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 81
#     njev: 27
# ---------------
# [18.140889775847477, -3.834520239119006]
# Iteração: 56
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5503.13850321699
#        x: [ 1.814e+01  1.530e+01]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 132
#     njev: 44
# ---------------
# [18.139877850292322, -3.0454562366683446]
# Iteração: 57
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5434.930438070871
#        x: [ 1.530e+01  1.226e+01]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 90
#     njev: 30
# ---------------
# [15.296993520725819, 2.4706846006805074]
# Iteração: 58
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 5340.8769082687895
#        x: [ 1.226e+01  1.014e+01]
#      nit: 11
#      jac: [ 0.000e+00  6.104e-05]
#     nfev: 99
#     njev: 33
# ---------------
# [12.258867940346315, -0.6701709626753019]
# Iteração: 59
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5237.84996055624
#        x: [ 1.014e+01  8.821e+00]
#      nit: 13
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 93
#     njev: 31
# ---------------
# [10.143593197954527, 2.915453537275944]
# Iteração: 60
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5137.686780564971
#        x: [ 8.821e+00  8.003e+00]
#      nit: 13
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 84
#     njev: 28
# ---------------
# [8.82097377074432, -3.8080095678163826]
# Iteração: 61
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5048.02014940017
#        x: [ 8.003e+00  7.491e+00]
#      nit: 14
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 96
#     njev: 32
# ---------------
# [8.003199555689502, 0.8262927831991842]
# Iteração: 62
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4973.894734643658
#        x: [ 7.492e+00  7.174e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 72
#     njev: 24
# ---------------
# [7.491538461755308, -0.8672224543715661]
# Iteração: 63
#  message: Desired error not necessarily achieved due to precision loss.
#  success: False
#   status: 2
#      fun: 4918.7270315653595
#        x: [ 7.175e+00  6.989e+00]
#      nit: 10
#      jac: [ 6.104e-05 -6.104e-05]
#     nfev: 176
#     njev: 55
# ---------------
# [7.174932608892192, 1.5711443679481887]
# Iteração: 64
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4884.766706974544
#        x: [ 6.989e+00  6.905e+00]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 54
#     njev: 18
# ---------------
# [6.989425788189582, -3.1879302455776317]
# Iteração: 65
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4873.305722234972
#        x: [ 6.905e+00  6.904e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 81
#     njev: 27
# ---------------
# [6.904543546647006, -2.922236415410394]
# Iteração: 66
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4884.766648525133
#        x: [ 6.905e+00  6.990e+00]
#      nit: 13
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 78
#     njev: 26
# ---------------
# [6.904533648723306, 1.727398789639249]
# Iteração: 67
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4918.726916103316
#        x: [ 6.990e+00  7.175e+00]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 66
#     njev: 22
# ---------------
# [6.989723104741676, 4.939312680857828]
# Iteração: 68
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4973.894565456087
#        x: [ 7.174e+00  7.492e+00]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 60
#     njev: 20
# ---------------
# [7.174468783423774, -4.303316094686059]
# Iteração: 69
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5048.0199323382185
#        x: [ 7.492e+00  8.003e+00]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 57
#     njev: 19
# ---------------
# [7.491575528867033, -0.7438550791027767]
# Iteração: 70
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5137.68652539968
#        x: [ 8.003e+00  8.821e+00]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 51
#     njev: 17
# ---------------
# [8.003124612677095, 2.3092402914614922]
# Iteração: 71
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5237.8496829548585
#        x: [ 8.821e+00  1.014e+01]
#      nit: 5
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 42
#     njev: 14
# ---------------
# [8.821163530652397, 1.5504489263218089]
# Iteração: 72
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5340.876633520846
#        x: [ 1.014e+01  1.226e+01]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 99
#     njev: 33
# ---------------
# [10.143162102258163, -3.1528917630538533]
# Iteração: 73
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5434.930205951012
#        x: [ 1.226e+01  1.530e+01]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 72
#     njev: 24
# ---------------
# [12.259447937702491, -1.2131121957275717]
# Iteração: 74
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5503.138365335888
#        x: [ 1.530e+01  1.814e+01]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 84
#     njev: 28
# ---------------
# [15.296467860524361, -0.49402105116531203]
# Iteração: 75
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5528.339065146342
#        x: [ 1.814e+01  1.814e+01]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 105
#     njev: 35
# ---------------
# [18.140823416653067, 0.10757124718166189]
# Iteração: 76
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5503.13849958754
#        x: [ 1.814e+01  1.530e+01]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 78
#     njev: 26
# ---------------
# [18.140047676638336, 4.75742711425357]
# Iteração: 77
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5434.930436325661
#        x: [ 1.530e+01  1.226e+01]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 60
#     njev: 20
# ---------------
# [15.296226940793755, -0.32101585292797097]
# Iteração: 78
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5340.876909144346
#        x: [ 1.226e+01  1.014e+01]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 66
#     njev: 22
# ---------------
# [12.25945603395892, -3.9153974450840368]
# Iteração: 79
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5237.849963812399
#        x: [ 1.014e+01  8.821e+00]
#      nit: 13
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 90
#     njev: 30
# ---------------
# [10.143357807948107, 3.1825679627372434]
# Iteração: 80
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5137.686785273886
#        x: [ 8.821e+00  8.003e+00]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 57
#     njev: 19
# ---------------
# [8.821138946929311, 2.0739526364963226]
# Iteração: 81
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5048.02015430995
#        x: [ 8.003e+00  7.492e+00]
#      nit: 13
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 96
#     njev: 32
# ---------------
# [8.0029870791499, 3.196063876337929]
# Iteração: 82
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4973.894738502267
#        x: [ 7.492e+00  7.175e+00]
#      nit: 13
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 87
#     njev: 29
# ---------------
# [7.491552996233726, 2.679729813222746]
# Iteração: 83
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4918.727033364043
#        x: [ 7.174e+00  6.990e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 96
#     njev: 32
# ---------------
# [7.174470685775214, 3.439030049079161]
# Iteração: 84
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4884.766706289051
#        x: [ 6.990e+00  6.904e+00]
#      nit: 15
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 120
#     njev: 40
# ---------------
# [6.98988765923029, -3.0809240079625]
# Iteração: 85
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4873.305719271889
#        x: [ 6.905e+00  6.904e+00]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 45
#     njev: 15
# ---------------
# [6.904534833136554, -1.0085735687339268]
# Iteração: 86
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4884.766644000971
#        x: [ 6.905e+00  6.990e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 93
#     njev: 31
# ---------------
# [6.904506231345023, 4.227717647615162]
# Iteração: 87
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4918.726911125455
#        x: [ 6.990e+00  7.175e+00]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 72
#     njev: 24
# ---------------
# [6.989815603982425, 0.1723093571719989]
# Iteração: 88
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 4973.89456117924
#        x: [ 7.175e+00  7.492e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 87
#     njev: 29
# ---------------
# [7.174567817712265, -4.861730601165148]
# Iteração: 89
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5048.019929718184
#        x: [ 7.492e+00  8.003e+00]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 48
#     njev: 16
# ---------------
# [7.491824582011722, 2.1322012638248333]
# Iteração: 90
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5137.686524950161
#        x: [ 8.003e+00  8.821e+00]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 42
#     njev: 14
# ---------------
# [8.002716141636304, -0.7351253743336548]
# Iteração: 91
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5237.849684717094
#        x: [ 8.821e+00  1.014e+01]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 66
#     njev: 22
# ---------------
# [8.820868508144246, 1.132190427228517]
# Iteração: 92
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5340.876636988245
#        x: [ 1.014e+01  1.226e+01]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 96
#     njev: 32
# ---------------
# [10.143849394405075, 2.5503965293610715]
# Iteração: 93
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5434.93021014921
#        x: [ 1.226e+01  1.530e+01]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 66
#     njev: 22
# ---------------
# [12.259838163073065, -1.0457462752151212]
# Iteração: 94
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5503.138368763099
#        x: [ 1.530e+01  1.814e+01]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 84
#     njev: 28
# ---------------
# [15.295854936550564, 3.4235711101990205]
# Iteração: 95
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5528.339066312912
#        x: [ 1.814e+01  1.814e+01]
#      nit: 8
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 78
#     njev: 26
# ---------------
# [18.1401850122376, -4.820444777694387]
# Iteração: 96
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5503.138497987242
#        x: [ 1.814e+01  1.530e+01]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 66
#     njev: 22
# ---------------
# [18.140461864063088, 0.5182830609952926]
# Iteração: 97
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5434.930432558703
#        x: [ 1.530e+01  1.226e+01]
#      nit: 7
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 57
#     njev: 19
# ---------------
# [15.296231019246477, 0.5740837879956997]
# Iteração: 98
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 5340.87690457617
#        x: [ 1.226e+01  1.014e+01]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00]
#     nfev: 66
#     njev: 22
# ---------------
# 34.985140562057495

# %%
from matplotlib import animation
from matplotlib.animation import PillowWriter

def animate(i):
    xs = np.linspace(-5,5,100)
    ln1.set_data(xs, np.absolute(psi_g[0:100,i-1])**2)
    ln2.set_data(xs, np.absolute(psiExato[0:100,i-1])**2)
    time_text.set_text('$t=$'+'{:.1f}'.format(i/100))
    
fig, ax = plt.subplots(1, 1,figsize=(8,4))
ax.grid()
ln1, = plt.plot([], [], 'r-', lw=2, markersize=8, label='Origem')
ln2, = plt.plot([], [], 'b-', lw=2, markersize=8, label='Destino')
time_text = ax.text(0.85, 0.9, '', fontsize=15,
           bbox=dict(facecolor='white', edgecolor='black'))
ax.set_ylim(0, 1)
ax.set_xlim(-5,5)
title = ax.set_title('Resposta analítica')
ax.set_ylabel('$|\psi(x)|^2$', fontsize=20)
ax.set_xlabel('$x$', fontsize=20)
ax.legend(loc='upper left')
ax.set_title('')
plt.tight_layout()
ani = animation.FuncAnimation(fig, animate, frames=100, interval=200)
ani.save('100x100.gif',writer='pillow',fps=10,dpi=100)

# %%
t = np.linspace(-5, 5, 100)

plt.ylabel('Controle') 
plt.xlabel('Tempo') 
plt.plot(t, minimo[0], color='r', marker='*', linewidth=1, markersize=1, label="Origem")
plt.legend(loc='upper right')
plt.savefig('100.png', format='png')
# Out:
# C:\Users\Gabriel\scoop\apps\miniconda3\current\lib\site-packages\matplotlib\cbook\__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
