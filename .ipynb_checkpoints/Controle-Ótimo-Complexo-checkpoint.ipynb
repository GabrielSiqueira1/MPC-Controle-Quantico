# %% [markdown]
# ### Controle Quântico Ótimo - Utilização do BFGS para ajuste do caminho percorrido por uma partícula
#
# Nessa etapa, é necessário avaliar, a partir da equação de Heisenberg, com o método de Runge-Kutta e com o controle MPC, como a curva de origem ajusta-se a curva de destino. Além disso, é interessantíssimo a avaliação a partir do estado estacionário e ainda verificar como ocorre o ajuste de fases.

# %%
# Bilbiotecas para auxílio na programação matemática
import math, sys 
import numpy as np
import sympy as sp

from scipy import sparse # Produção das diagonais das matrizes
from scipy.sparse import diags 

# Plotagem 2D e 3D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm


from os import path # Suficiente para manipulação de arquivos
    
# Para solução exata
from scipy.special import hermite
from math import factorial

# %matplotlib inline
count = 0

# Para otimização dos sistemas
from scipy import optimize

import random

# %% [markdown]
# Abaixo se dão os requisitos básicos para a instauração do teste. Se tem formas de subtrair e somar matrizes, a manipulação das derivadas com o Runge-Kutta além da própria proposta da função objetivo.

# %%
def somar(A, B):
    C = []
    nLinhasA, nLinhasB = len(A), len(B)
    nColA, nColB = len(A[0]), len(B[0])
    
    for i in range (nLinhasA):
        linha = [0]*nColA
        C.append(linha)
        for j in range(nColA):
            C[i][j] = A[i][j] + B[i][j]

    return C

def sub(A, B):
    C = []
    nLinhasA, nLinhasB = len(A), len(B)
    nColA, nColB = len(A[0]), len(B[0])
    
    for i in range (nLinhasA):
        linha = [0]*nColA
        C.append(linha)
        for j in range(nColA):
            C[i][j] = A[i][j] - B[i][j]

    return C


#################################################################

## d (psi) / dt = -i * H * |psi>
def dpsidt(t,psi, H):
    A = np.zeros((2,2), dtype=np.complex_)
    A = np.dot(complex(0,1),H) # i * H
    return -1*np.matmul(A,psi)

# Runge-Kutta de quarta ordem
def rungeKutta(psi0, h, H, t = 2, t0 = 0):
    
    n = (int)((t-t0))
    S = np.zeros((2,int(t)), dtype=np.complex_)
    r = 0
    
    for i in range(0, n):
        
        S[0][r] = psi0[0][0]
        S[1][r] = psi0[1][0]
        
        k1 = dpsidt(t0, psi0, H)
        k2 = dpsidt(t0 + 0.5 * h, somar(psi0, np.dot((0.5*h), k1)), H)
        k3 = dpsidt(t0 + 0.5 * h, somar(psi0, np.dot((0.5*h), k2)), H)
        k4 = dpsidt(t0 + h, somar(psi0, np.dot(h, k3)), H)
        
        ## y(i+1) = y(i) + h/6*(k1+2*k2+2*k3+k4)
        
        A = somar(np.dot(2,k3), k4)
        B = somar(np.dot(2,k2), k1)
        C = somar(A, B)
 
        psi0 = somar(psi0,np.dot((h / 6.0),(C)))
    
        t0 = t0 + h
        
        r = r + 1
        
    return S

def fo(x, D, H, i, psi0):
    
    H1 = np.zeros((2,2), dtype=np.complex_)
    
    ## Tamanho do horizonte
    tam = 3
    
    M = np.zeros((2,1),dtype=np.complex_)
    M = [[psi0[0][0]], [psi0[1][0]]] 
    
    Result = np.zeros((2,1),dtype=np.complex_)
    
    Return = 0
    
    ## Função-Objetivo (Return) = ||somatorio (Matriz_Origem - Matriz_Destino)||^2
    for p in range(0+i, tam+i):
        H1 = [[0, x[p-i]], [x[p-i], 0]] # Controle
        Z = np.zeros((2,1),dtype=np.complex_)
        Z[0][0] = D[0][0]*np.exp(-1*complex(0,1)*(1/2*np.pi)*p/100)
        Z[1][0] = D[1][0]*np.exp(-1*complex(0,1)*(3/2*np.pi)*p/100)
        Return += np.linalg.norm(M-Z)**2
        Result = rungeKutta(M, h, somar(H,H1), t = (p-i)+2, t0 = 0)
        M = Result
    
    return Return

def real_to_complex(z):      # real vector of length 2n -> complex of length n
    return z[:len(z)//2] + 1j * z[len(z)//2:]

def complex_to_real(z):      # complex vector of length n -> real of length 2n
    return np.concatenate((np.real(z), np.imag(z)))

# %% [markdown]
# Para o funcionamento do MPC, cria-se um looping que consiste em uma otimização não linear, com o apoio da biblioteca de otimização do pyhton, de forma a obter o melhor resultado para o ajuste da curva. Com esse valor em mãos, utiliza-se para os pontos da próxima iteração do método de controle além de efetivar o ajuste realizando o Runge-Kutta com o valor otimizado.

# %%
# Horizonte de análise
tam = 3
i = 0 # Iteração
h = 0.01 # Fator Runge-Kutta

# Proposta dos pontos - chutes iniciais
x = []
x.append(random.uniform(-1., 1.)+1j*random.uniform(-1., 1.))
for l in range(1, tam):
    x.append(x[0])

# Função de origem e destino
psi0 = [[complex(0.80,7.0)],[complex(0.60,7.0)]]
psid = [[complex(1/np.sqrt(2),0)],[complex(1/np.sqrt(2),0)]]


H = np.zeros((2,2), dtype=np.complex_) # Hamiltoniano
A = (1/2*np.pi)
B = (3/2*np.pi)
H = [[A, 0], [0, B]]

D = np.zeros((2,1), dtype=np.complex_) # Matriz destino
D[0][0] = psid[0][0]
D[1][0] = psid[1][0]

Resp = np.zeros((2, 2000), dtype=np.complex_)
Constantes = np.zeros((2, 2000), dtype=np.complex_)

while i < 2000:
    
    Resp[0][i] = psi0[0][0]
    Resp[1][i] = psi0[1][0]
    
    # Constantes da função de onda
    Constantes[0][i] = psi0[0][0] / np.exp(-1*complex(0,1)*(1/2*np.pi)*i/100)
    Constantes[1][i] = psi0[1][0] / np.exp(-1*complex(0,1)*(3/2*np.pi)*i/100)
    
    resultado = optimize.minimize(lambda z: fo(real_to_complex(z), D, H, i, psi0), x0=complex_to_real(x), method='CG')
    
    print(resultado)
    
    x = []
    x.append(resultado.x[0])
    for l in range(1, tam):
        x.append(x[0])
    
    ## Hamiltoniano corntrolado
    u = np.zeros((2,1), dtype=np.complex_)
    u = [[0, resultado.x[0]],[np.conj(resultado.x[0]), 0]]
    H = somar(H, u)
    
    ## Adaptação da onda ao controle
    psi_t = np.zeros((2,2), dtype=np.complex_)
    psi_t = rungeKutta(psi0, h, H, t = 2, t0 = 0)
    
    psi0[0][0] = psi_t[0][1]
    psi0[1][0] = psi_t[1][1]
    
    H = [[A, 0], [0, B]]
    
    i = i + 1
# Out:
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 300.7692531238594
#        x: [ 9.166e+01  8.259e+01  3.006e-02 -1.556e+02 -1.326e+02
#             4.534e-01]
#      nit: 13
#      jac: [ 3.815e-06  3.815e-06  0.000e+00  0.000e+00  3.815e-06
#             0.000e+00]
#     nfev: 406
#     njev: 58
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 256.5660460321475
#        x: [ 7.456e+01  5.980e+01  9.166e+01 -1.549e+02 -1.164e+02
#             0.000e+00]
#      nit: 12
#      jac: [-3.815e-06  0.000e+00  0.000e+00  3.815e-06  0.000e+00
#             0.000e+00]
#     nfev: 378
#     njev: 54
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 253.16410426219107
#        x: [ 6.647e+01 -5.205e+00  7.456e+01 -1.621e+02 -9.993e+01
#             0.000e+00]
#      nit: 20
#      jac: [ 3.815e-06  3.815e-06  0.000e+00  7.629e-06  0.000e+00
#             0.000e+00]
#     nfev: 658
#     njev: 94
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 270.29947983671315
#        x: [ 7.059e+01 -5.855e+01  6.647e+01 -1.747e+02 -1.011e+02
#             0.000e+00]
#      nit: 18
#      jac: [ 0.000e+00  3.815e-06  0.000e+00 -3.815e-06  3.815e-06
#             0.000e+00]
#     nfev: 574
#     njev: 82
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 307.61039556517017
#        x: [ 8.083e+01  6.007e+01  7.059e+01 -1.860e+02 -1.392e+02
#             0.000e+00]
#      nit: 14
#      jac: [ 0.000e+00 -3.815e-06  0.000e+00  3.815e-06  0.000e+00
#             0.000e+00]
#     nfev: 427
#     njev: 61
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 348.4555069663584
#        x: [ 9.251e+01  8.922e+01  8.083e+01 -1.857e+02 -1.492e+02
#             0.000e+00]
#      nit: 10
#      jac: [ 0.000e+00 -3.815e-06  0.000e+00  0.000e+00 -3.815e-06
#             0.000e+00]
#     nfev: 301
#     njev: 43
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 369.12351183651754
#        x: [ 1.009e+02  9.901e+01  9.251e+01 -1.734e+02 -1.217e+02
#             0.000e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  3.815e-06
#             0.000e+00]
#     nfev: 322
#     njev: 46
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 322.42738885730387
#        x: [ 9.901e+01  9.175e+01  1.009e+02 -1.598e+02 -1.219e+02
#             0.000e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00 -7.629e-06
#             0.000e+00]
#     nfev: 427
#     njev: 61
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 258.6184563813423
#        x: [ 8.331e+01  7.198e+01  9.901e+01 -1.538e+02 -1.308e+02
#             0.000e+00]
#      nit: 9
#      jac: [ 0.000e+00  7.629e-06  0.000e+00  0.000e+00  0.000e+00
#             0.000e+00]
#     nfev: 329
#     njev: 47
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 236.82056669928969
#        x: [ 6.815e+01  3.771e+01  8.331e+01 -1.578e+02 -1.074e+02
#             0.000e+00]
#      nit: 17
#      jac: [ 0.000e+00  1.907e-06  0.000e+00 -3.815e-06  0.000e+00
#             0.000e+00]
#     nfev: 567
#     njev: 81
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 244.76422621657332
#        x: [ 6.608e+01 -4.149e+01  6.815e+01 -1.669e+02 -9.858e+01
#             0.000e+00]
#      nit: 17
#      jac: [ 7.629e-06  0.000e+00  0.000e+00 -5.722e-06  3.815e-06
#             0.000e+00]
#     nfev: 553
#     njev: 79
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 268.578706748509
#        x: [ 7.401e+01 -6.842e+01  6.608e+01 -1.798e+02 -1.048e+02
#             0.000e+00]
#      nit: 18
#      jac: [ 0.000e+00  3.815e-06  0.000e+00  3.815e-06 -3.815e-06
#             0.000e+00]
#     nfev: 602
#     njev: 86
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 309.2355571339031
#        x: [ 8.577e+01  7.233e+01  7.401e+01 -1.873e+02 -1.495e+02
#             0.000e+00]
#      nit: 13
#      jac: [ 7.629e-06  3.815e-06  0.000e+00  0.000e+00 -3.815e-06
#             0.000e+00]
#     nfev: 385
#     njev: 55
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 347.525331877622
#        x: [ 9.717e+01  9.719e+01  8.577e+01 -1.812e+02 -1.337e+02
#             0.000e+00]
#      nit: 10
#      jac: [-3.815e-06  7.629e-06  0.000e+00  7.629e-06 -7.629e-06
#             0.000e+00]
#     nfev: 301
#     njev: 43
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 338.60184284514725
#        x: [ 1.023e+02  9.959e+01  9.717e+01 -1.666e+02 -1.176e+02
#             0.000e+00]
#      nit: 12
#      jac: [ 0.000e+00 -3.815e-06  0.000e+00  0.000e+00  7.629e-06
#             0.000e+00]
#     nfev: 357
#     njev: 51
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 276.54234583009907
#        x: [ 9.368e+01  8.452e+01  1.023e+02 -1.555e+02 -1.268e+02
#             0.000e+00]
#      nit: 11
#      jac: [ 7.629e-06  0.000e+00  0.000e+00  0.000e+00 -3.815e-06
#             0.000e+00]
#     nfev: 350
#     njev: 50
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 230.50814962765156
#        x: [ 7.509e+01  5.642e+01  9.368e+01 -1.551e+02 -1.200e+02
#             0.000e+00]
#      nit: 10
#      jac: [ 0.000e+00  3.815e-06  0.000e+00  3.815e-06  0.000e+00
#             0.000e+00]
#     nfev: 336
#     njev: 48
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 225.23042527408404
#        x: [ 6.484e+01 -1.610e+01  7.509e+01 -1.613e+02 -1.012e+02
#             0.000e+00]
#      nit: 20
#      jac: [ 7.629e-06  3.815e-06  0.000e+00  7.629e-06  3.815e-06
#             0.000e+00]
#     nfev: 665
#     njev: 95
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 240.63117615633956
#        x: [ 6.780e+01 -5.228e+01  6.484e+01 -1.715e+02 -9.864e+01
#             0.000e+00]
#      nit: 17
#      jac: [ 0.000e+00  3.815e-06  0.000e+00  3.815e-06  5.722e-06
#             0.000e+00]
#     nfev: 553
#     njev: 79
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 268.3833377227631
#        x: [ 7.814e+01 -7.625e+01  6.780e+01 -1.832e+02 -1.108e+02
#             0.000e+00]
#      nit: 18
#      jac: [ 0.000e+00  3.815e-06  0.000e+00  0.000e+00  3.815e-06
#             0.000e+00]
#     nfev: 588
#     njev: 84
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 310.6697970551554
#        x: [ 9.058e+01  8.505e+01  7.814e+01 -1.860e+02 -1.481e+02
#             0.000e+00]
#      nit: 13
#      jac: [-7.629e-06  0.000e+00  0.000e+00  0.000e+00  7.629e-06
#             0.000e+00]
#     nfev: 406
#     njev: 58
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 334.9353369899148
#        x: [ 1.006e+02  1.022e+02  9.058e+01 -1.751e+02 -1.229e+02
#             0.000e+00]
#      nit: 11
#      jac: [-3.815e-06  0.000e+00  0.000e+00 -3.815e-06  3.815e-06
#             0.000e+00]
#     nfev: 329
#     njev: 47
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 300.78351020422036
#        x: [ 1.010e+02  9.648e+01  1.006e+02 -1.605e+02 -1.166e+02
#             0.000e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00 -3.815e-06
#             0.000e+00]
#     nfev: 378
#     njev: 54
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 239.05101906470378
#        x: [ 8.636e+01  7.440e+01  1.010e+02 -1.541e+02 -1.302e+02
#             0.000e+00]
#      nit: 9
#      jac: [-1.907e-06 -3.815e-06  0.000e+00 -1.907e-06  3.815e-06
#             0.000e+00]
#     nfev: 308
#     njev: 44
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 213.30357440983562
#        x: [ 6.898e+01  3.475e+01  8.636e+01 -1.580e+02 -1.107e+02
#             0.000e+00]
#      nit: 15
#      jac: [ 3.815e-06  1.907e-06  0.000e+00  7.629e-06  1.907e-06
#             0.000e+00]
#     nfev: 490
#     njev: 70
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 218.42110900648177
#        x: [ 6.416e+01 -3.462e+01  6.898e+01 -1.647e+02 -9.873e+01
#             0.000e+00]
#      nit: 16
#      jac: [ 3.815e-06  0.000e+00  0.000e+00  7.629e-06  1.907e-06
#             0.000e+00]
#     nfev: 525
#     njev: 75
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 238.97621292080794
#        x: [ 7.072e+01 -5.968e+01  6.416e+01 -1.753e+02 -1.001e+02
#             0.000e+00]
#      nit: 15
#      jac: [-3.815e-06  9.537e-06  0.000e+00  0.000e+00 -3.815e-06
#             0.000e+00]
#     nfev: 469
#     njev: 67
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 267.71503547913255
#        x: [ 8.248e+01 -8.339e+01  7.072e+01 -1.848e+02 -1.198e+02
#             0.000e+00]
#      nit: 16
#      jac: [ 0.000e+00 -7.629e-06  0.000e+00  3.815e-06 -7.629e-06
#             0.000e+00]
#     nfev: 539
#     njev: 77
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 309.0495024649908
#        x: [ 9.484e+01  9.625e+01  8.248e+01 -1.823e+02 -1.363e+02
#             0.000e+00]
#      nit: 12
#      jac: [ 7.629e-06  3.815e-06  0.000e+00  0.000e+00  0.000e+00
#             0.000e+00]
#     nfev: 357
#     njev: 51
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 312.2455743849346
#        x: [ 1.024e+02  1.040e+02  9.484e+01 -1.683e+02 -1.159e+02
#             0.000e+00]
#      nit: 14
#      jac: [ 3.815e-06  0.000e+00  0.000e+00  0.000e+00  3.815e-06
#             0.000e+00]
#     nfev: 441
#     njev: 63
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 262.58050645957894
#        x: [ 9.714e+01  9.056e+01  1.024e+02 -1.563e+02 -1.185e+02
#             0.000e+00]
#      nit: 9
#      jac: [-7.629e-06 -3.815e-06  0.000e+00  3.815e-06  3.815e-06
#             0.000e+00]
#     nfev: 280
#     njev: 40
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 212.9746552228495
#        x: [ 7.903e+01  6.101e+01  9.714e+01 -1.556e+02 -1.263e+02
#             0.000e+00]
#      nit: 8
#      jac: [-3.815e-06  0.000e+00  0.000e+00 -3.815e-06  0.000e+00
#             0.000e+00]
#     nfev: 287
#     njev: 41
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 203.15057616029088
#        x: [ 6.557e+01 -3.499e+00  7.903e+01 -1.611e+02 -1.046e+02
#             0.000e+00]
#      nit: 18
#      jac: [ 0.000e+00  7.629e-06  0.000e+00  0.000e+00  1.907e-06
#             0.000e+00]
#     nfev: 651
#     njev: 93
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 215.06276100845068
#        x: [ 6.531e+01 -4.298e+01  6.557e+01 -1.677e+02 -9.744e+01
#             0.000e+00]
#      nit: 15
#      jac: [ 0.000e+00  1.907e-06  0.000e+00  0.000e+00 -3.815e-06
#             0.000e+00]
#     nfev: 497
#     njev: 71
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 238.26704619037417
#        x: [ 7.427e+01 -6.558e+01  6.531e+01 -1.781e+02 -1.034e+02
#             0.000e+00]
#      nit: 16
#      jac: [ 3.815e-06  3.815e-06  0.000e+00  3.815e-06 -3.815e-06
#             0.000e+00]
#     nfev: 525
#     njev: 75
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 276.328241078809
#        x: [ 8.673e+01  5.700e+01  7.427e+01 -1.844e+02 -1.339e+02
#             0.000e+00]
#      nit: 15
#      jac: [ 0.000e+00 -7.629e-06  0.000e+00  0.000e+00  3.815e-06
#             0.000e+00]
#     nfev: 497
#     njev: 71
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 300.5070714241304
#        x: [ 9.821e+01  1.035e+02  8.673e+01 -1.768e+02 -1.245e+02
#             0.000e+00]
#      nit: 12
#      jac: [ 0.000e+00 -3.815e-06  0.000e+00  3.815e-06 -3.815e-06
#             0.000e+00]
#     nfev: 371
#     njev: 53
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 283.2028224857693
#        x: [ 1.021e+02  1.025e+02  9.821e+01 -1.621e+02 -1.123e+02
#             0.000e+00]
#      nit: 11
#      jac: [-7.629e-06  3.815e-06  0.000e+00  0.000e+00 -3.815e-06
#             0.000e+00]
#     nfev: 357
#     njev: 51
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 229.29091775972836
#        x: [ 9.149e+01  8.257e+01  1.021e+02 -1.549e+02 -1.224e+02
#             0.000e+00]
#      nit: 12
#      jac: [-3.815e-06  0.000e+00  0.000e+00  0.000e+00  5.722e-06
#             0.000e+00]
#     nfev: 371
#     njev: 53
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 196.7155514475191
#        x: [ 7.323e+01  4.433e+01  9.149e+01 -1.587e+02 -1.182e+02
#             0.000e+00]
#      nit: 11
#      jac: [ 0.000e+00  1.907e-06  0.000e+00 -1.907e-06 -1.907e-06
#             0.000e+00]
#     nfev: 371
#     njev: 53
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 197.46527405562813
#        x: [ 6.447e+01 -2.304e+01  7.323e+01 -1.635e+02 -1.008e+02
#             0.000e+00]
#      nit: 19
#      jac: [-3.815e-06  0.000e+00  0.000e+00 -7.629e-06  0.000e+00
#             0.000e+00]
#     nfev: 630
#     njev: 90
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 213.69955122471305
#        x: [ 6.765e+01 -4.885e+01  6.447e+01 -1.702e+02 -9.765e+01
#             0.000e+00]
#      nit: 14
#      jac: [-3.815e-06  0.000e+00  0.000e+00 -3.815e-06  3.815e-06
#             0.000e+00]
#     nfev: 462
#     njev: 66
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 237.11604050328987
#        x: [ 7.813e+01 -7.103e+01  6.765e+01 -1.799e+02 -1.092e+02
#             0.000e+00]
#      nit: 13
#      jac: [-3.815e-06 -7.629e-06  0.000e+00  0.000e+00 -7.629e-06
#             0.000e+00]
#     nfev: 427
#     njev: 61
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 273.34443587399875
#        x: [ 9.067e+01  8.468e+01  7.813e+01 -1.817e+02 -1.315e+02
#             0.000e+00]
#      nit: 13
#      jac: [ 0.000e+00 -3.815e-06  0.000e+00  3.815e-06  3.815e-06
#             0.000e+00]
#     nfev: 406
#     njev: 58
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 284.49302616567246
#        x: [ 1.004e+02  1.072e+02  9.067e+01 -1.701e+02 -1.157e+02
#             0.000e+00]
#      nit: 12
#      jac: [-3.815e-06  3.815e-06  0.000e+00 -3.815e-06  0.000e+00
#             0.000e+00]
#     nfev: 434
#     njev: 62
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 252.13643518591553
#        x: [ 9.987e+01  9.826e+01  1.004e+02 -1.576e+02 -1.118e+02
#             0.000e+00]
#      nit: 12
#      jac: [ 0.000e+00  1.907e-06  0.000e+00  0.000e+00  5.722e-06
#             0.000e+00]
#     nfev: 371
#     njev: 53
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 203.7868922404159
#        x: [ 8.530e+01  7.251e+01  9.987e+01 -1.563e+02 -1.258e+02
#             0.000e+00]
#      nit: 10
#      jac: [ 0.000e+00  3.815e-06  0.000e+00  0.000e+00  7.629e-06
#             0.000e+00]
#     nfev: 385
#     njev: 55
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 187.33717037054987
#        x: [ 6.961e+01  2.294e+01  8.530e+01 -1.620e+02 -1.108e+02
#             0.000e+00]
#      nit: 15
#      jac: [ 1.907e-06  3.815e-06  0.000e+00 -3.815e-06  7.629e-06
#             0.000e+00]
#     nfev: 518
#     njev: 74
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 194.93064125980425
#        x: [ 6.507e+01 -3.127e+01  6.961e+01 -1.654e+02 -9.850e+01
#             0.000e+00]
#      nit: 17
#      jac: [ 5.722e-06  3.815e-06  0.000e+00  5.722e-06  3.815e-06
#             0.000e+00]
#     nfev: 567
#     njev: 81
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 213.08882888556252
#        x: [ 7.080e+01 -5.365e+01  6.507e+01 -1.725e+02 -9.976e+01
#             0.000e+00]
#      nit: 14
#      jac: [ 3.815e-06 -7.629e-06  0.000e+00  3.815e-06 -7.629e-06
#             0.000e+00]
#     nfev: 448
#     njev: 64
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 234.25508406885524
#        x: [ 8.208e+01 -7.755e+01  7.080e+01 -1.803e+02 -1.182e+02
#             0.000e+00]
#      nit: 15
#      jac: [-3.815e-06 -3.815e-06  0.000e+00 -3.815e-06  7.629e-06
#             0.000e+00]
#     nfev: 511
#     njev: 73
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 266.3234124037125
#        x: [ 9.406e+01  9.985e+01  8.208e+01 -1.770e+02 -1.241e+02
#             0.000e+00]
#      nit: 12
#      jac: [-3.815e-06 -3.815e-06  0.000e+00  3.815e-06 -3.815e-06
#             0.000e+00]
#     nfev: 378
#     njev: 54
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 262.59607753819336
#        x: [ 1.010e+02  1.074e+02  9.406e+01 -1.635e+02 -1.103e+02
#             0.000e+00]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00  0.000e+00 -3.815e-06 -7.629e-06
#             0.000e+00]
#     nfev: 322
#     njev: 46
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 222.92014230339095
#        x: [ 9.581e+01  9.189e+01  1.010e+02 -1.559e+02 -1.145e+02
#             0.000e+00]
#      nit: 9
#      jac: [ 3.815e-06 -5.722e-06  0.000e+00  0.000e+00  3.815e-06
#             0.000e+00]
#     nfev: 294
#     njev: 42
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 186.785275391134
#        x: [ 7.985e+01  5.976e+01  9.581e+01 -1.598e+02 -1.249e+02
#             0.000e+00]
#      nit: 11
#      jac: [ 0.000e+00  1.907e-06  0.000e+00 -1.907e-06  1.907e-06
#             0.000e+00]
#     nfev: 371
#     njev: 53
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 182.53936872460153
#        x: [ 6.806e+01 -1.875e+00  7.985e+01 -1.643e+02 -1.054e+02
#             0.000e+00]
#      nit: 13
#      jac: [ 9.537e-06 -3.815e-06  0.000e+00 -1.907e-06 -9.537e-06
#             0.000e+00]
#     nfev: 462
#     njev: 66
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 194.23800424412735
#        x: [ 6.691e+01 -3.692e+01  6.806e+01 -1.670e+02 -9.795e+01
#             0.000e+00]
#      nit: 16
#      jac: [ 0.000e+00  7.629e-06  0.000e+00  0.000e+00 -3.815e-06
#             0.000e+00]
#     nfev: 511
#     njev: 73
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 211.96368923511272
#        x: [ 7.445e+01 -5.840e+01  6.691e+01 -1.742e+02 -1.044e+02
#             0.000e+00]
#      nit: 17
#      jac: [-3.815e-06  0.000e+00  0.000e+00 -5.722e-06 -1.907e-06
#             0.000e+00]
#     nfev: 539
#     njev: 77
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 228.85033706418065
#        x: [ 8.595e+01 -8.740e+01  7.445e+01 -1.788e+02 -1.301e+02
#             0.000e+00]
#      nit: 15
#      jac: [-1.907e-06  1.907e-06  0.000e+00 -3.815e-06 -5.722e-06
#             0.000e+00]
#     nfev: 483
#     njev: 69
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 254.13077723994763
#        x: [ 9.656e+01  1.073e+02  8.595e+01 -1.706e+02 -1.161e+02
#             0.000e+00]
#      nit: 11
#      jac: [ 3.815e-06  1.907e-06  0.000e+00  3.815e-06  1.907e-06
#             0.000e+00]
#     nfev: 336
#     njev: 48
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 237.50593339064437
#        x: [ 9.987e+01  1.043e+02  9.656e+01 -1.586e+02 -1.084e+02
#             0.000e+00]
#      nit: 10
#      jac: [ 1.907e-06 -3.815e-06  0.000e+00 -1.907e-06 -3.815e-06
#             0.000e+00]
#     nfev: 378
#     njev: 54
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 198.49240555749438
#        x: [ 9.075e+01  8.382e+01  9.987e+01 -1.574e+02 -1.199e+02
#             0.000e+00]
#      nit: 12
#      jac: [-1.907e-06  1.907e-06  0.000e+00  0.000e+00  7.629e-06
#             0.000e+00]
#     nfev: 371
#     njev: 53
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 177.2170833293256
#        x: [ 7.597e+01  4.418e+01  9.075e+01 -1.638e+02 -1.190e+02
#             0.000e+00]
#      nit: 12
#      jac: [-1.907e-06 -1.907e-06  0.000e+00  0.000e+00  1.907e-06
#             0.000e+00]
#     nfev: 399
#     njev: 57
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 180.8208791356571
#        x: [ 6.813e+01 -1.609e+01  7.597e+01 -1.655e+02 -1.019e+02
#             0.000e+00]
#      nit: 18
#      jac: [-9.537e-06 -7.629e-06  0.000e+00  3.815e-06 -7.629e-06
#             0.000e+00]
#     nfev: 602
#     njev: 86
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 194.0348917392358
#        x: [ 6.969e+01 -4.160e+01  6.813e+01 -1.684e+02 -9.959e+01
#             0.000e+00]
#      nit: 16
#      jac: [-3.815e-06 -1.907e-06  0.000e+00 -1.907e-06  0.000e+00
#             0.000e+00]
#     nfev: 511
#     njev: 73
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 208.9479290940778
#        x: [ 7.837e+01 -6.488e+01  6.969e+01 -1.752e+02 -1.127e+02
#             0.000e+00]
#      nit: 14
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00 -1.907e-06
#             0.000e+00]
#     nfev: 476
#     njev: 68
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 234.71592187080503
#        x: [ 8.945e+01  8.796e+01  7.837e+01 -1.750e+02 -1.201e+02
#             0.000e+00]
#      nit: 15
#      jac: [ 3.815e-06 -5.722e-06  0.000e+00  0.000e+00  5.722e-06
#             0.000e+00]
#     nfev: 490
#     njev: 70
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 236.97628085041868
#        x: [ 9.773e+01  1.092e+02  8.945e+01 -1.638e+02 -1.101e+02
#             0.000e+00]
#      nit: 10
#      jac: [-7.629e-06  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#             0.000e+00]
#     nfev: 315
#     njev: 45
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 212.48780378024793
#        x: [ 9.699e+01  9.867e+01  9.773e+01 -1.568e+02 -1.103e+02
#             0.000e+00]
#      nit: 12
#      jac: [ 0.000e+00 -1.907e-06  0.000e+00  0.000e+00 -3.815e-06
#             0.000e+00]
#     nfev: 385
#     njev: 55
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 180.76950554570155
#        x: [ 8.583e+01  7.344e+01  9.699e+01 -1.616e+02 -1.256e+02
#             0.000e+00]
#      nit: 12
#      jac: [ 0.000e+00  1.907e-06  0.000e+00  0.000e+00 -1.907e-06
#             0.000e+00]
#     nfev: 392
#     njev: 56
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 173.0207138427064
#        x: [ 7.393e+01  2.543e+01  8.583e+01 -1.665e+02 -1.121e+02
#             0.000e+00]
#      nit: 16
#      jac: [ 3.815e-06  1.907e-06  0.000e+00  5.722e-06 -7.629e-06
#             0.000e+00]
#     nfev: 532
#     njev: 76
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 180.76229976411122
#        x: [ 6.942e+01 -2.399e+01  7.393e+01 -1.661e+02 -1.005e+02
#             0.000e+00]
#      nit: 15
#      jac: [ 3.815e-06  3.815e-06  0.000e+00  5.722e-06 -3.815e-06
#             0.000e+00]
#     nfev: 490
#     njev: 70
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 192.75603291433788
#        x: [ 7.311e+01 -4.669e+01  6.942e+01 -1.698e+02 -1.041e+02
#             0.000e+00]
#      nit: 15
#      jac: [ 0.000e+00  0.000e+00  0.000e+00 -1.907e-06  7.629e-06
#             0.000e+00]
#     nfev: 497
#     njev: 71
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 202.85876021158253
#        x: [ 8.225e+01 -7.606e+01  7.311e+01 -1.745e+02 -1.253e+02
#             0.000e+00]
#      nit: 16
#      jac: [-3.815e-06  0.000e+00  0.000e+00  3.815e-06  7.629e-06
#             0.000e+00]
#     nfev: 525
#     njev: 75
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 223.830585326017
#        x: [ 9.214e+01  1.040e+02  8.225e+01 -1.691e+02 -1.153e+02
#             0.000e+00]
#      nit: 11
#      jac: [ 0.000e+00  9.537e-06  0.000e+00 -3.815e-06  0.000e+00
#             0.000e+00]
#     nfev: 350
#     njev: 50
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 216.68404333100284
#        x: [ 9.724e+01  1.068e+02  9.214e+01 -1.588e+02 -1.075e+02
#             0.000e+00]
#      nit: 10
#      jac: [ 3.815e-06 -3.815e-06  0.000e+00  3.815e-06  0.000e+00
#             0.000e+00]
#     nfev: 315
#     njev: 45
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 190.66321048197028
#        x: [ 9.304e+01  9.128e+01  9.724e+01 -1.590e+02 -1.161e+02
#             0.000e+00]
#      nit: 10
#      jac: [-1.907e-06  0.000e+00  0.000e+00 -1.907e-06 -3.815e-06
#             0.000e+00]
#     nfev: 322
#     njev: 46
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 170.68819905190728
#        x: [ 8.207e+01  5.934e+01  9.304e+01 -1.665e+02 -1.257e+02
#             0.000e+00]
#      nit: 10
#      jac: [-7.629e-06 -7.629e-06  0.000e+00  0.000e+00  0.000e+00
#             0.000e+00]
#     nfev: 329
#     njev: 47
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 172.0799196238122
#        x: [ 7.349e+01  4.716e+00  8.207e+01 -1.672e+02 -1.067e+02
#             0.000e+00]
#      nit: 18
#      jac: [-1.907e-06  3.815e-06  0.000e+00  1.907e-06  3.815e-06
#             0.000e+00]
#     nfev: 609
#     njev: 87
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 180.5515049993021
#        x: [ 7.161e+01 -2.989e+01  7.349e+01 -1.663e+02 -1.017e+02
#             0.000e+00]
#      nit: 16
#      jac: [ 3.815e-06  0.000e+00  0.000e+00  7.629e-06  3.815e-06
#             0.000e+00]
#     nfev: 525
#     njev: 75
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 188.71596207059656
#        x: [ 7.678e+01 -5.482e+01  7.161e+01 -1.706e+02 -1.126e+02
#             0.000e+00]
#      nit: 12
#      jac: [ 7.629e-06 -5.722e-06  0.000e+00  5.722e-06 -7.629e-06
#             0.000e+00]
#     nfev: 406
#     njev: 58
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 206.18726945880945
#        x: [ 8.566e+01  6.363e+01  7.678e+01 -1.714e+02 -1.159e+02
#             0.000e+00]
#      nit: 18
#      jac: [-3.815e-06  3.815e-06  0.000e+00  3.815e-06  1.907e-06
#             0.000e+00]
#     nfev: 609
#     njev: 87
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 209.25525031147393
#        x: [ 9.345e+01  1.080e+02  8.566e+01 -1.626e+02 -1.100e+02
#             0.000e+00]
#      nit: 9
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  7.629e-06
#             0.000e+00]
#     nfev: 287
#     njev: 41
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 196.28029248228526
#        x: [ 9.519e+01  1.015e+02  9.345e+01 -1.578e+02 -1.091e+02
#             0.000e+00]
#      nit: 11
#      jac: [ 0.000e+00  0.000e+00  0.000e+00 -1.907e-06  0.000e+00
#             0.000e+00]
#     nfev: 343
#     njev: 49
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 174.36468730535412
#        x: [ 8.916e+01  8.197e+01  9.519e+01 -1.645e+02 -1.249e+02
#             0.000e+00]
#      nit: 12
#      jac: [-1.907e-06  0.000e+00  0.000e+00  1.907e-06 -7.629e-06
#             0.000e+00]
#     nfev: 455
#     njev: 65
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 167.1752835882607
#        x: [ 8.000e+01  4.203e+01  8.916e+01 -1.695e+02 -1.186e+02
#             0.000e+00]
#      nit: 14
#      jac: [ 5.722e-06  7.629e-06  0.000e+00  0.000e+00 -9.537e-06
#             0.000e+00]
#     nfev: 469
#     njev: 67
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 172.2327886399659
#        x: [ 7.418e+01 -9.694e+00  8.000e+01 -1.664e+02 -1.041e+02
#             0.000e+00]
#      nit: 19
#      jac: [ 0.000e+00 -3.815e-06  0.000e+00  0.000e+00  5.722e-06
#             0.000e+00]
#     nfev: 651
#     njev: 93
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 178.07786272334113
#        x: [ 7.436e+01 -3.678e+01  7.418e+01 -1.665e+02 -1.064e+02
#             0.000e+00]
#      nit: 12
#      jac: [-1.907e-06  0.000e+00  0.000e+00  3.815e-06  0.000e+00
#             0.000e+00]
#     nfev: 399
#     njev: 57
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 180.72351402900614
#        x: [ 8.021e+01 -6.954e+01  7.436e+01 -1.699e+02 -1.265e+02
#             0.000e+00]
#      nit: 13
#      jac: [ 7.629e-06 -3.815e-06  0.000e+00  7.629e-06 -3.815e-06
#             0.000e+00]
#     nfev: 441
#     njev: 63
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 195.38021721802886
#        x: [ 8.802e+01  9.962e+01  8.021e+01 -1.659e+02 -1.137e+02
#             0.000e+00]
#      nit: 13
#      jac: [ 1.907e-06  0.000e+00  0.000e+00  0.000e+00 -9.537e-06
#             0.000e+00]
#     nfev: 413
#     njev: 59
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 192.8442995865039
#        x: [ 9.312e+01  1.059e+02  8.802e+01 -1.585e+02 -1.076e+02
#             0.000e+00]
#      nit: 12
#      jac: [ 0.000e+00 -1.907e-06  0.000e+00  0.000e+00 -3.815e-06
#             0.000e+00]
#     nfev: 385
#     njev: 55
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 178.7933742455446
#        x: [ 9.247e+01  9.446e+01  9.312e+01 -1.617e+02 -1.154e+02
#             0.000e+00]
#      nit: 10
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  3.815e-06  7.629e-06
#             0.000e+00]
#     nfev: 315
#     njev: 45
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 165.26578317837507
#        x: [ 8.638e+01  6.860e+01  9.247e+01 -1.703e+02 -1.301e+02
#             0.000e+00]
#      nit: 9
#      jac: [ 0.000e+00 -1.907e-06  0.000e+00 -1.907e-06  9.537e-06
#             0.000e+00]
#     nfev: 371
#     njev: 53
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 167.04722206800545
#        x: [ 7.944e+01  2.315e+01  8.638e+01 -1.693e+02 -1.112e+02
#             0.000e+00]
#      nit: 16
#      jac: [ 7.629e-06  7.629e-06  0.000e+00  0.000e+00  5.722e-06
#             0.000e+00]
#     nfev: 539
#     njev: 77
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 170.93186036453795
#        x: [ 7.560e+01 -1.871e+01  7.944e+01 -1.649e+02 -1.049e+02
#             0.000e+00]
#      nit: 16
#      jac: [ 1.907e-06 -3.815e-06  0.000e+00  0.000e+00 -1.907e-06
#             0.000e+00]
#     nfev: 546
#     njev: 78
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 171.48741602273194
#        x: [ 7.711e+01 -4.879e+01  7.560e+01 -1.664e+02 -1.158e+02
#             0.000e+00]
#      nit: 14
#      jac: [ 5.722e-06  1.907e-06  0.000e+00 -5.722e-06 -1.907e-06
#             0.000e+00]
#     nfev: 476
#     njev: 68
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 170.32558256652146
#        x: [ 8.279e+01 -9.091e+01  7.711e+01 -1.668e+02 -1.394e+02
#             0.000e+00]
#      nit: 18
#      jac: [ 0.000e+00 -9.537e-06  0.000e+00 -3.815e-06  5.722e-06
#             0.000e+00]
#     nfev: 637
#     njev: 91
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 182.33613703916103
#        x: [ 8.882e+01  1.046e+02  8.279e+01 -1.604e+02 -1.095e+02
#             0.000e+00]
#      nit: 11
#      jac: [ 3.815e-06 -3.815e-06  0.000e+00  9.537e-06 -3.815e-06
#             0.000e+00]
#     nfev: 343
#     njev: 49
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 177.44036295307785
#        x: [ 9.175e+01  1.007e+02  8.882e+01 -1.595e+02 -1.096e+02
#             0.000e+00]
#      nit: 12
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  0.000e+00
#             0.000e+00]
#     nfev: 385
#     njev: 55
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 166.17388431808922
#        x: [ 9.024e+01  8.585e+01  9.175e+01 -1.688e+02 -1.259e+02
#             0.000e+00]
#      nit: 11
#      jac: [ 1.907e-06  0.000e+00  0.000e+00  0.000e+00  3.815e-06
#             0.000e+00]
#     nfev: 371
#     njev: 53
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 163.28916649423377
#        x: [ 8.515e+01  5.144e+01  9.024e+01 -1.729e+02 -1.234e+02
#             0.000e+00]
#      nit: 12
#      jac: [-5.722e-06  0.000e+00  0.000e+00  0.000e+00  1.907e-06
#             0.000e+00]
#     nfev: 476
#     njev: 68
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 166.7628466414157
#        x: [ 7.981e+01  6.444e+00  8.515e+01 -1.666e+02 -1.072e+02
#             0.000e+00]
#      nit: 17
#      jac: [-3.815e-06  3.815e-06  0.000e+00  1.907e-06  3.815e-06
#             0.000e+00]
#     nfev: 595
#     njev: 85
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 165.6274439606155
#        x: [ 7.721e+01 -2.966e+01  7.981e+01 -1.634e+02 -1.099e+02
#             0.000e+00]
#      nit: 15
#      jac: [ 3.815e-06 -9.537e-06  0.000e+00  0.000e+00 -5.722e-06
#             0.000e+00]
#     nfev: 504
#     njev: 72
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 160.30589789270525
#        x: [ 7.916e+01 -6.898e+01  7.721e+01 -1.649e+02 -1.318e+02
#             0.000e+00]
#      nit: 15
#      jac: [-1.907e-06  0.000e+00  0.000e+00  0.000e+00  1.907e-06
#             0.000e+00]
#     nfev: 525
#     njev: 75
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 169.08567659638018
#        x: [ 8.399e+01  9.559e+01  7.916e+01 -1.618e+02 -1.117e+02
#             0.000e+00]
#      nit: 12
#      jac: [ 1.907e-06  3.815e-06  0.000e+00  1.907e-06  1.907e-06
#             0.000e+00]
#     nfev: 399
#     njev: 57
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 169.58243676885684
#        x: [ 8.834e+01  1.022e+02  8.399e+01 -1.583e+02 -1.078e+02
#             0.000e+00]
#      nit: 11
#      jac: [ 1.907e-06  1.907e-06  0.000e+00 -3.815e-06  3.815e-06
#             0.000e+00]
#     nfev: 357
#     njev: 51
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 165.31237329536765
#        x: [ 9.057e+01  9.432e+01  8.834e+01 -1.657e+02 -1.166e+02
#             0.000e+00]
#      nit: 14
#      jac: [ 0.000e+00  7.629e-06  0.000e+00 -1.907e-06  3.815e-06
#             0.000e+00]
#     nfev: 441
#     njev: 63
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 159.96286252325132
#        x: [ 8.923e+01  7.304e+01  9.057e+01 -1.749e+02 -1.334e+02
#             0.000e+00]
#      nit: 10
#      jac: [ 3.815e-06 -1.907e-06  0.000e+00 -1.907e-06 -1.907e-06
#             0.000e+00]
#     nfev: 350
#     njev: 50
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 163.99193205072316
#        x: [ 8.515e+01  3.542e+01  8.923e+01 -1.710e+02 -1.138e+02
#             0.000e+00]
#      nit: 14
#      jac: [ 3.815e-06 -9.537e-06  0.000e+00 -3.815e-06  7.629e-06
#             0.000e+00]
#     nfev: 483
#     njev: 69
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 162.93608820422506
#        x: [ 8.044e+01 -6.543e+00  8.515e+01 -1.629e+02 -1.075e+02
#             0.000e+00]
#      nit: 17
#      jac: [-1.907e-06  1.907e-06  0.000e+00  0.000e+00 -9.537e-06
#             0.000e+00]
#     nfev: 602
#     njev: 86
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 154.9764925939107
#        x: [ 7.822e+01 -4.798e+01  8.044e+01 -1.617e+02 -1.209e+02
#             0.000e+00]
#      nit: 11
#      jac: [ 1.907e-06 -1.907e-06  0.000e+00  5.722e-06 -7.629e-06
#             0.000e+00]
#     nfev: 392
#     njev: 56
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 156.45251713944208
#        x: [ 7.992e+01  6.620e+01  7.822e+01 -1.614e+02 -1.105e+02
#             0.000e+00]
#      nit: 12
#      jac: [ 0.000e+00 -9.537e-06  0.000e+00 -3.815e-06 -5.722e-06
#             0.000e+00]
#     nfev: 441
#     njev: 63
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 157.78545230045648
#        x: [ 8.375e+01  9.913e+01  7.992e+01 -1.579e+02 -1.082e+02
#             0.000e+00]
#      nit: 14
#      jac: [ 0.000e+00  3.815e-06  0.000e+00  3.815e-06  0.000e+00
#             0.000e+00]
#     nfev: 441
#     njev: 63
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 159.33366813491594
#        x: [ 8.784e+01  9.734e+01  8.375e+01 -1.620e+02 -1.104e+02
#             0.000e+00]
#      nit: 14
#      jac: [ 1.907e-06  0.000e+00  0.000e+00  0.000e+00 -5.722e-06
#             0.000e+00]
#     nfev: 455
#     njev: 65
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 157.40592792052297
#        x: [ 9.041e+01  8.657e+01  8.784e+01 -1.741e+02 -1.278e+02
#             0.000e+00]
#      nit: 12
#      jac: [ 3.815e-06  0.000e+00  0.000e+00  0.000e+00 -3.815e-06
#             0.000e+00]
#     nfev: 399
#     njev: 57
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 160.3113297352911
#        x: [ 8.954e+01  5.704e+01  9.041e+01 -1.762e+02 -1.258e+02
#             0.000e+00]
#      nit: 10
#      jac: [ 1.907e-06 -3.815e-06  0.000e+00 -3.815e-06  3.815e-06
#             0.000e+00]
#     nfev: 350
#     njev: 50
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 162.32049438152094
#        x: [ 8.556e+01  2.585e+01  8.954e+01 -1.659e+02 -1.082e+02
#             0.000e+00]
#      nit: 14
#      jac: [ 5.722e-06  1.907e-06  0.000e+00  0.000e+00 -3.815e-06
#             0.000e+00]
#     nfev: 497
#     njev: 71
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 153.30890551372664
#        x: [ 8.048e+01 -2.563e+01  8.556e+01 -1.593e+02 -1.132e+02
#             0.000e+00]
#      nit: 17
#      jac: [ 0.000e+00  3.815e-06  0.000e+00  3.815e-06 -7.629e-06
#             0.000e+00]
#     nfev: 609
#     njev: 87
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 140.4364502911722
#        x: [ 7.785e+01 -7.328e+01  8.048e+01 -1.591e+02 -1.379e+02
#             0.000e+00]
#      nit: 14
#      jac: [ 1.907e-06 -3.815e-06  0.000e+00  0.000e+00 -3.815e-06
#             0.000e+00]
#     nfev: 525
#     njev: 75
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 145.16151206029662
#        x: [ 7.923e+01  8.992e+01  7.785e+01 -1.572e+02 -1.086e+02
#             0.000e+00]
#      nit: 11
#      jac: [-3.815e-06  7.629e-06  0.000e+00 -3.815e-06  0.000e+00
#             0.000e+00]
#     nfev: 385
#     njev: 55
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 148.8886172131633
#        x: [ 8.322e+01  9.616e+01  7.923e+01 -1.586e+02 -1.070e+02
#             0.000e+00]
#      nit: 11
#      jac: [ 0.000e+00 -1.907e-06  0.000e+00  0.000e+00  3.815e-06
#             0.000e+00]
#     nfev: 371
#     njev: 53
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 152.4731217940512
#        x: [ 8.847e+01  9.199e+01  8.322e+01 -1.703e+02 -1.176e+02
#             0.000e+00]
#      nit: 13
#      jac: [-1.907e-06  1.907e-06  0.000e+00  0.000e+00  7.629e-06
#             0.000e+00]
#     nfev: 427
#     njev: 61
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 154.82257461375121
#        x: [ 9.149e+01  7.477e+01  8.847e+01 -1.796e+02 -1.349e+02
#             0.000e+00]
#      nit: 10
#      jac: [ 3.815e-06  1.907e-06  0.000e+00 -3.815e-06  7.629e-06
#             0.000e+00]
#     nfev: 350
#     njev: 50
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 161.43469041935538
#        x: [ 9.056e+01  4.681e+01  9.149e+01 -1.721e+02 -1.140e+02
#             0.000e+00]
#      nit: 16
#      jac: [ 0.000e+00  1.907e-06  0.000e+00 -1.907e-06  5.722e-06
#             0.000e+00]
#     nfev: 539
#     njev: 77
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 154.78494894284444
#        x: [ 8.543e+01  2.013e+01  9.056e+01 -1.597e+02 -1.069e+02
#             0.000e+00]
#      nit: 18
#      jac: [ 3.815e-06  3.815e-06  0.000e+00  0.000e+00  9.537e-06
#             0.000e+00]
#     nfev: 644
#     njev: 92
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 138.20036131083347
#        x: [ 7.894e+01 -5.106e+01  8.543e+01 -1.558e+02 -1.259e+02
#             0.000e+00]
#      nit: 14
#      jac: [-5.722e-06  0.000e+00  0.000e+00 -7.629e-06  1.907e-06
#             0.000e+00]
#     nfev: 497
#     njev: 71
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 134.0615317113401
#        x: [ 7.594e+01  6.726e+01  7.894e+01 -1.554e+02 -1.063e+02
#             0.000e+00]
#      nit: 13
#      jac: [-1.907e-06 -5.722e-06  0.000e+00  1.907e-06  5.722e-06
#             0.000e+00]
#     nfev: 462
#     njev: 66
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 136.27729519132356
#        x: [ 7.791e+01  9.056e+01  7.594e+01 -1.555e+02 -1.051e+02
#             0.000e+00]
#      nit: 14
#      jac: [ 3.815e-06  3.815e-06  0.000e+00 -7.629e-06 -7.629e-06
#             0.000e+00]
#     nfev: 448
#     njev: 64
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 143.26027090351425
#        x: [ 8.390e+01  9.193e+01  7.791e+01 -1.647e+02 -1.096e+02
#             0.000e+00]
#      nit: 12
#      jac: [ 3.815e-06 -3.815e-06  0.000e+00  1.907e-06  0.000e+00
#             0.000e+00]
#     nfev: 406
#     njev: 58
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 148.9219812268027
#        x: [ 9.037e+01  8.551e+01  8.390e+01 -1.789e+02 -1.277e+02
#             0.000e+00]
#      nit: 12
#      jac: [ 3.815e-06  0.000e+00  0.000e+00 -1.907e-06  9.537e-06
#             0.000e+00]
#     nfev: 413
#     njev: 59
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 157.23010048453486
#        x: [ 9.350e+01  6.223e+01  9.037e+01 -1.792e+02 -1.257e+02
#             0.000e+00]
#      nit: 11
#      jac: [-3.815e-06 -9.537e-06  0.000e+00 -7.629e-06 -9.537e-06
#             0.000e+00]
#     nfev: 378
#     njev: 54
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 157.6130686261222
#        x: [ 9.129e+01  4.775e+01  9.350e+01 -1.645e+02 -1.060e+02
#             0.000e+00]
#      nit: 18
#      jac: [ 1.907e-06  3.815e-06  0.000e+00 -3.815e-06 -9.537e-06
#             0.000e+00]
#     nfev: 623
#     njev: 89
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 140.80160105655642
#        x: [ 8.365e+01 -1.924e+01  9.129e+01 -1.539e+02 -1.141e+02
#             0.000e+00]
#      nit: 23
#      jac: [ 0.000e+00  3.815e-06  0.000e+00  0.000e+00  0.000e+00
#             0.000e+00]
#     nfev: 812
#     njev: 116
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 121.96319037964739
#        x: [ 7.538e+01 -7.672e+01  8.365e+01 -1.522e+02 -1.387e+02
#             0.000e+00]
#      nit: 17
#      jac: [ 0.000e+00 -1.907e-06  0.000e+00  0.000e+00  0.000e+00
#             0.000e+00]
#     nfev: 616
#     njev: 88
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 123.90052909956202
#        x: [ 7.310e+01  7.771e+01  7.538e+01 -1.523e+02 -1.026e+02
#             0.000e+00]
#      nit: 15
#      jac: [ 9.537e-06  0.000e+00  0.000e+00  7.629e-06 -1.907e-06
#             0.000e+00]
#     nfev: 518
#     njev: 74
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 130.77649418536632
#        x: [ 7.753e+01  8.680e+01  7.310e+01 -1.580e+02 -1.038e+02
#             0.000e+00]
#      nit: 15
#      jac: [ 0.000e+00  0.000e+00  0.000e+00 -1.907e-06  5.722e-06
#             0.000e+00]
#     nfev: 504
#     njev: 72
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 140.44392698734964
#        x: [ 8.608e+01  8.779e+01  7.753e+01 -1.735e+02 -1.153e+02
#             0.000e+00]
#      nit: 14
#      jac: [ 3.815e-06  1.907e-06  0.000e+00  7.629e-06  3.815e-06
#             0.000e+00]
#     nfev: 455
#     njev: 65
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 149.12696715518814
#        x: [ 9.320e+01  7.626e+01  8.608e+01 -1.835e+02 -1.328e+02
#             0.000e+00]
#      nit: 9
#      jac: [-1.907e-06  0.000e+00  0.000e+00 -1.907e-06 -3.815e-06
#             0.000e+00]
#     nfev: 322
#     njev: 46
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 158.31873857251205
#        x: [ 9.568e+01  5.997e+01  9.320e+01 -1.733e+02 -1.124e+02
#             0.000e+00]
#      nit: 12
#      jac: [-1.907e-06  0.000e+00  0.000e+00 -1.907e-06  5.722e-06
#             0.000e+00]
#     nfev: 427
#     njev: 61
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 146.67338958176003
#        x: [ 9.073e+01  5.264e+01  9.568e+01 -1.561e+02 -1.011e+02
#             0.000e+00]
#      nit: 14
#      jac: [-3.815e-06  5.722e-06  0.000e+00 -3.815e-06  7.629e-06
#             0.000e+00]
#     nfev: 476
#     njev: 68
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 122.92286834560849
#        x: [ 7.936e+01 -5.085e+01  9.073e+01 -1.486e+02 -1.257e+02
#             0.000e+00]
#      nit: 16
#      jac: [-5.722e-06 -3.815e-06  0.000e+00  9.537e-06  7.629e-06
#             0.000e+00]
#     nfev: 553
#     njev: 79
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 113.82026536082819
#        x: [ 7.044e+01  5.092e+01  7.936e+01 -1.486e+02 -9.847e+01
#             0.000e+00]
#      nit: 16
#      jac: [-3.815e-06  1.907e-06  0.000e+00  0.000e+00  0.000e+00
#             0.000e+00]
#     nfev: 574
#     njev: 82
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 117.16555673677772
#        x: [ 7.057e+01  7.324e+01  7.044e+01 -1.512e+02 -9.808e+01
#             0.000e+00]
#      nit: 17
#      jac: [ 0.000e+00  0.000e+00  0.000e+00  0.000e+00  5.722e-06
#             0.000e+00]
#     nfev: 595
#     njev: 85
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 128.0088142124564
#        x: [ 7.878e+01  8.254e+01  7.057e+01 -1.639e+02 -1.046e+02
#             0.000e+00]
#      nit: 13
#      jac: [ 3.815e-06 -1.907e-06  0.000e+00  0.000e+00  5.722e-06
#             0.000e+00]
#     nfev: 434
#     njev: 62
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 139.66230469856987
#        x: [ 8.915e+01  8.322e+01  7.878e+01 -1.812e+02 -1.214e+02
#             0.000e+00]
#      nit: 13
#      jac: [ 0.000e+00 -1.907e-06  0.000e+00  1.907e-06  3.815e-06
#             0.000e+00]
#     nfev: 448
#     njev: 64
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 152.16558194247585
#        x: [ 9.647e+01  6.889e+01  8.915e+01 -1.826e+02 -1.248e+02
#             0.000e+00]
#      nit: 13
#      jac: [-1.907e-06 -1.907e-06  0.000e+00 -1.907e-06  9.537e-06
#             0.000e+00]
#     nfev: 448
#     njev: 64
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 153.5989847564047
#        x: [ 9.722e+01  6.767e+01  9.647e+01 -1.646e+02 -1.023e+02
#             0.000e+00]
#      nit: 13
#      jac: [-7.629e-06  1.907e-06  0.000e+00 -1.907e-06  7.629e-06
#             0.000e+00]
#     nfev: 434
#     njev: 62
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 130.7146000846862
#        x: [ 8.806e+01  5.439e+01  9.722e+01 -1.482e+02 -9.833e+01
#             0.000e+00]
#      nit: 14
#      jac: [ 0.000e+00  5.722e-06  0.000e+00 -1.907e-06  5.722e-06
#             0.000e+00]
#     nfev: 483
#     njev: 69
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 106.93282773297489
#        x: [ 7.286e+01 -7.011e+01  8.806e+01 -1.441e+02 -1.306e+02
#             0.000e+00]
#      nit: 20
#      jac: [ 0.000e+00 -1.907e-06  0.000e+00 -5.722e-06  2.861e-06
#             0.000e+00]
#     nfev: 721
#     njev: 103
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
# ...
#  success: True
#   status: 0
#      fun: 93.8334565710995
#        x: [ 1.480e-01  1.611e-01  1.677e-01  3.005e+00  1.560e+00
#             0.000e+00]
#      nit: 11
#      jac: [-5.722e-06  1.907e-06  0.000e+00  2.861e-06  5.722e-06
#             0.000e+00]
#     nfev: 308
#     njev: 44
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 93.90369044150853
#        x: [ 1.640e-01  1.821e-01  1.480e-01  1.610e+00  7.227e-01
#             0.000e+00]
#      nit: 11
#      jac: [ 3.815e-06  8.583e-06  0.000e+00  1.907e-06  8.583e-06
#             0.000e+00]
#     nfev: 315
#     njev: 45
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 93.92588923049213
#        x: [ 1.581e-01  1.899e-01  1.640e-01  2.151e-01 -1.139e-01
#             0.000e+00]
#      nit: 7
#      jac: [ 4.768e-06  0.000e+00  0.000e+00 -4.768e-06 -8.583e-06
#             0.000e+00]
#     nfev: 196
#     njev: 28
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 93.90003669570599
#        x: [ 1.522e-01  2.032e-01  1.581e-01 -1.179e+00 -9.500e-01
#             0.000e+00]
#      nit: 14
#      jac: [ 9.537e-07  9.537e-07  0.000e+00 -7.629e-06 -9.537e-07
#             0.000e+00]
#     nfev: 371
#     njev: 53
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 93.82616729323021
#        x: [ 1.608e-01  2.202e-01  1.522e-01 -2.572e+00 -1.787e+00
#             0.000e+00]
#      nit: 14
#      jac: [ 5.722e-06  3.815e-06  0.000e+00  6.676e-06  7.629e-06
#             0.000e+00]
#     nfev: 357
#     njev: 51
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 93.70434510213937
#        x: [ 1.507e-01  2.303e-01  1.608e-01 -3.970e+00 -2.626e+00
#             0.000e+00]
#      nit: 18
#      jac: [ 0.000e+00 -9.537e-07  0.000e+00 -9.537e-07 -6.676e-06
#             0.000e+00]
#     nfev: 525
#     njev: 75
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 93.53474682448706
#        x: [ 1.585e-01  2.484e-01  1.507e-01 -5.371e+00 -3.467e+00
#             0.000e+00]
#      nit: 15
#      jac: [ 3.815e-06  3.815e-06  0.000e+00 -9.537e-07  9.537e-06
#             0.000e+00]
#     nfev: 392
#     njev: 56
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 93.31750911046811
#        x: [ 1.540e-01  2.595e-01  1.585e-01 -6.776e+00 -4.311e+00
#             0.000e+00]
#      nit: 15
#      jac: [ 1.907e-06 -1.907e-06  0.000e+00  3.815e-06  1.907e-06
#             0.000e+00]
#     nfev: 399
#     njev: 57
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 93.05291448130697
#        x: [ 1.589e-01  2.753e-01  1.540e-01 -8.189e+00 -5.160e+00
#             0.000e+00]
#      nit: 20
#      jac: [ 1.907e-06  3.815e-06  0.000e+00 -5.722e-06  0.000e+00
#             0.000e+00]
#     nfev: 532
#     njev: 76
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 92.74121287529181
#        x: [ 1.523e-01  2.865e-01  1.589e-01 -9.608e+00 -6.013e+00
#             0.000e+00]
#      nit: 17
#      jac: [ 0.000e+00  1.907e-06  0.000e+00  3.815e-06  7.629e-06
#             0.000e+00]
#     nfev: 455
#     njev: 65
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 92.38280169980658
#        x: [ 1.536e-01  3.026e-01  1.523e-01 -1.104e+01 -6.873e+00
#             0.000e+00]
#      nit: 20
#      jac: [-4.768e-06  2.861e-06  0.000e+00  7.629e-06 -1.907e-06
#             0.000e+00]
#     nfev: 553
#     njev: 79
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 91.97802684773362
#        x: [ 1.593e-01  3.177e-01  1.536e-01 -1.248e+01 -7.739e+00
#             0.000e+00]
#      nit: 15
#      jac: [-3.815e-06  4.768e-06  0.000e+00  5.722e-06 -2.861e-06
#             0.000e+00]
#     nfev: 448
#     njev: 64
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 91.52730531318309
#        x: [ 1.685e-01  3.281e-01  1.593e-01 -1.393e+01 -8.613e+00
#             0.000e+00]
#      nit: 17
#      jac: [ 5.722e-06  0.000e+00  0.000e+00 -5.722e-06  1.907e-06
#             0.000e+00]
#     nfev: 504
#     njev: 72
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 91.03111004076166
#        x: [ 1.507e-01  3.331e-01  1.685e-01 -1.539e+01 -9.496e+00
#             0.000e+00]
#      nit: 18
#      jac: [-9.537e-07 -3.815e-06  0.000e+00  9.537e-07 -3.815e-06
#             0.000e+00]
#     nfev: 532
#     njev: 76
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 90.49018648160495
#        x: [ 1.565e-01  3.493e-01  1.507e-01 -1.687e+01 -1.039e+01
#             0.000e+00]
#      nit: 14
#      jac: [-3.815e-06 -3.815e-06  0.000e+00  7.629e-06  9.537e-06
#             0.000e+00]
#     nfev: 406
#     njev: 58
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 89.90493388925657
#        x: [ 1.704e-01  3.619e-01  1.565e-01 -1.837e+01 -1.129e+01
#             0.000e+00]
#      nit: 12
#      jac: [ 6.676e-06 -5.722e-06  0.000e+00  6.676e-06 -9.537e-06
#             0.000e+00]
#     nfev: 336
#     njev: 48
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 89.2759356083941
#        x: [ 1.563e-01  3.674e-01  1.704e-01 -1.989e+01 -1.221e+01
#             0.000e+00]
#      nit: 13
#      jac: [ 2.861e-06 -1.907e-06  0.000e+00  3.815e-06  5.722e-06
#             0.000e+00]
#     nfev: 364
#     njev: 52
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 88.60415018072294
#        x: [ 1.649e-01  3.806e-01  1.563e-01 -2.143e+01 -1.314e+01
#             0.000e+00]
#      nit: 11
#      jac: [ 5.722e-06 -9.537e-07  0.000e+00  0.000e+00  7.629e-06
#             0.000e+00]
#     nfev: 329
#     njev: 47
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 87.89009965023118
#        x: [ 1.553e-01  3.891e-01  1.649e-01 -2.299e+01 -1.408e+01
#             0.000e+00]
#      nit: 20
#      jac: [ 0.000e+00  0.000e+00  0.000e+00 -9.537e-07  1.907e-06
#             0.000e+00]
#     nfev: 574
#     njev: 82
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 87.13477171170194
#        x: [ 1.653e-01  4.021e-01  1.553e-01 -2.457e+01 -1.504e+01
#             0.000e+00]
#      nit: 17
#      jac: [ 1.907e-06 -1.907e-06  0.000e+00 -3.815e-06 -9.537e-07
#             0.000e+00]
#     nfev: 504
#     njev: 72
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 86.33880405348495
#        x: [ 1.588e-01  4.095e-01  1.653e-01 -2.618e+01 -1.602e+01
#             0.000e+00]
#      nit: 17
#      jac: [-1.907e-06 -3.815e-06  0.000e+00  1.907e-06 -9.537e-06
#             0.000e+00]
#     nfev: 476
#     njev: 68
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 85.50329111833085
#        x: [ 1.703e-01  4.219e-01  1.588e-01 -2.783e+01 -1.701e+01
#             0.000e+00]
#      nit: 16
#      jac: [ 1.907e-06  0.000e+00  0.000e+00  0.000e+00  1.907e-06
#             0.000e+00]
#     nfev: 462
#     njev: 66
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 84.62897815133243
#        x: [ 1.602e-01  4.270e-01  1.703e-01 -2.950e+01 -1.803e+01
#             0.000e+00]
#      nit: 18
#      jac: [-3.815e-06  0.000e+00  0.000e+00 -9.537e-06 -7.629e-06
#             0.000e+00]
#     nfev: 532
#     njev: 76
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 83.7171479785855
#        x: [ 1.671e-01  4.395e-01  1.602e-01 -3.121e+01 -1.907e+01
#             0.000e+00]
#      nit: 12
#      jac: [-5.722e-06  5.722e-06  0.000e+00 -3.815e-06 -7.629e-06
#             0.000e+00]
#     nfev: 350
#     njev: 50
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 82.76864386253615
#        x: [ 1.770e-01  4.450e-01  1.671e-01 -3.296e+01 -2.013e+01
#             0.000e+00]
#      nit: 16
#      jac: [ 0.000e+00 -9.537e-07  0.000e+00 -7.629e-06  9.537e-06
#             0.000e+00]
#     nfev: 490
#     njev: 70
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 81.78457108995484
#        x: [ 1.774e-01  4.454e-01  1.770e-01 -3.474e+01 -2.122e+01
#             0.000e+00]
#      nit: 12
#      jac: [ 3.815e-06 -2.861e-06  0.000e+00  4.768e-06 -4.768e-06
#             0.000e+00]
#     nfev: 378
#     njev: 54
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 80.76626330297456
#        x: [ 1.746e-01  4.474e-01  1.774e-01 -3.658e+01 -2.234e+01
#             0.000e+00]
#      nit: 12
#      jac: [ 4.768e-06  1.907e-06  0.000e+00 -3.815e-06 -4.768e-06
#             0.000e+00]
#     nfev: 371
#     njev: 53
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 79.71501290010066
#        x: [ 1.708e-01  4.499e-01  1.746e-01 -3.846e+01 -2.349e+01
#             0.000e+00]
#      nit: 13
#      jac: [-9.537e-07  2.861e-06  0.000e+00  0.000e+00 -9.537e-07
#             0.000e+00]
#     nfev: 392
#     njev: 56
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 78.63213964555997
#        x: [ 1.872e-01  4.538e-01  1.708e-01 -4.040e+01 -2.468e+01
#             0.000e+00]
#      nit: 11
#      jac: [ 4.768e-06 -2.861e-06  0.000e+00  0.000e+00 -5.722e-06
#             0.000e+00]
#     nfev: 315
#     njev: 45
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 77.5187590820614
#        x: [ 1.634e-01  4.500e-01  1.872e-01 -4.239e+01 -2.590e+01
#             0.000e+00]
#      nit: 13
#      jac: [-9.537e-06  2.861e-06  0.000e+00  8.583e-06  0.000e+00
#             0.000e+00]
#     nfev: 469
#     njev: 67
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 76.37692317280504
#        x: [ 1.982e-01  4.585e-01  1.634e-01 -4.445e+01 -2.717e+01
#             0.000e+00]
#      nit: 11
#      jac: [-9.537e-07 -2.861e-06  0.000e+00  3.815e-06 -4.768e-06
#             0.000e+00]
#     nfev: 343
#     njev: 49
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 75.20731890630205
#        x: [ 1.921e-01  4.487e-01  1.982e-01 -4.658e+01 -2.848e+01
#             0.000e+00]
#      nit: 17
#      jac: [ 0.000e+00  3.815e-06  0.000e+00 -1.907e-06  0.000e+00
#             0.000e+00]
#     nfev: 532
#     njev: 76
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 74.01230646721606
#        x: [ 2.068e-01  4.405e-01  1.921e-01 -4.878e+01 -2.985e+01
#             0.000e+00]
#      nit: 17
#      jac: [ 9.537e-06  3.815e-06  0.000e+00 -5.722e-06  6.676e-06
#             0.000e+00]
#     nfev: 504
#     njev: 72
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 72.79336579645292
#        x: [ 1.971e-01  4.214e-01  2.068e-01 -5.106e+01 -3.126e+01
#             0.000e+00]
#      nit: 17
#      jac: [ 7.629e-06  0.000e+00  0.000e+00  2.861e-06  1.907e-06
#             0.000e+00]
#     nfev: 490
#     njev: 70
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 71.55280929443737
#        x: [ 2.024e-01  4.103e-01  1.971e-01 -5.344e+01 -3.275e+01
#             0.000e+00]
#      nit: 20
#      jac: [ 5.722e-06  0.000e+00  0.000e+00  0.000e+00 -9.537e-07
#             0.000e+00]
#     nfev: 602
#     njev: 86
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 70.29246168584493
#        x: [ 2.044e-01  3.929e-01  2.024e-01 -5.592e+01 -3.429e+01
#             0.000e+00]
#      nit: 14
#      jac: [-9.537e-07 -7.629e-06  0.000e+00  7.629e-06  9.537e-07
#             0.000e+00]
#     nfev: 420
#     njev: 60
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 69.01466431653085
#        x: [ 2.104e-01  3.786e-01  2.044e-01 -5.850e+01 -3.592e+01
#             0.000e+00]
#      nit: 16
#      jac: [-8.583e-06 -1.907e-06  0.000e+00  3.815e-06 -4.768e-06
#             0.000e+00]
#     nfev: 497
#     njev: 71
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 67.72189174493073
#        x: [ 2.625e-01  3.594e-01  2.104e-01 -6.121e+01 -3.763e+01
#             0.000e+00]
#      nit: 14
#      jac: [ 8.583e-06  9.537e-07  0.000e+00  3.815e-06 -7.629e-06
#             0.000e+00]
#     nfev: 448
#     njev: 64
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 66.41649999417064
#        x: [ 2.147e-01  3.074e-01  2.625e-01 -6.405e+01 -3.943e+01
#             0.000e+00]
#      nit: 14
#      jac: [-2.861e-06  9.537e-06  0.000e+00  5.722e-06 -5.722e-06
#             0.000e+00]
#     nfev: 462
#     njev: 66
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 65.1033135076423
#        x: [ 2.634e-01  2.822e-01  2.147e-01 -6.704e+01 -4.133e+01
#             0.000e+00]
#      nit: 15
#      jac: [-9.537e-07  5.722e-06  0.000e+00 -2.861e-06  1.907e-06
#             0.000e+00]
#     nfev: 497
#     njev: 71
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 63.78464714534263
#        x: [ 2.785e-01  2.241e-01  2.634e-01 -7.020e+01 -4.336e+01
#             0.000e+00]
#      nit: 14
#      jac: [ 9.537e-07  9.537e-07  0.000e+00  0.000e+00  9.537e-06
#             0.000e+00]
#     nfev: 462
#     njev: 66
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 62.46588369951748
#        x: [ 3.106e-01  1.574e-01  2.785e-01 -7.353e+01 -4.552e+01
#             0.000e+00]
#      nit: 14
#      jac: [ 9.537e-06  3.815e-06  0.000e+00  0.000e+00 -9.537e-07
#             0.000e+00]
#     nfev: 532
#     njev: 76
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 61.15265347134029
#        x: [ 2.649e-01  6.504e-02  3.106e-01 -7.706e+01 -4.782e+01
#             0.000e+00]
#      nit: 13
#      jac: [-9.537e-06  0.000e+00  0.000e+00  9.537e-07 -4.768e-06
#             0.000e+00]
#     nfev: 427
#     njev: 61
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 59.85294941155176
#        x: [ 4.148e-01  6.364e-03  2.649e-01 -8.081e+01 -5.029e+01
#             0.000e+00]
#      nit: 13
#      jac: [ 4.768e-06  9.537e-07  0.000e+00  0.000e+00 -5.722e-06
#             0.000e+00]
#     nfev: 462
#     njev: 66
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 58.574090368498
#        x: [ 3.510e-01 -1.589e-01  4.148e-01 -8.479e+01 -5.294e+01
#             0.000e+00]
#      nit: 13
#      jac: [ 0.000e+00 -2.861e-06  0.000e+00 -3.338e-06  4.768e-07
#             0.000e+00]
#     nfev: 504
#     njev: 72
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 57.331748959909355
#        x: [ 4.967e-01 -2.744e-01  3.510e-01 -8.900e+01 -5.578e+01
#             0.000e+00]
#      nit: 13
#      jac: [ 4.768e-06  1.431e-06  0.000e+00 -4.768e-07 -4.768e-07
#             0.000e+00]
#     nfev: 441
#     njev: 63
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 56.141400996528176
#        x: [ 5.065e-01 -4.905e-01  4.967e-01 -9.342e+01 -5.880e+01
#             0.000e+00]
#      nit: 14
#      jac: [ 4.768e-06  0.000e+00  0.000e+00  9.537e-07 -2.384e-06
#             0.000e+00]
#     nfev: 483
#     njev: 69
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 55.03031903005717
#        x: [ 6.753e-01 -6.994e-01  5.065e-01 -9.801e+01 -6.197e+01
#             0.000e+00]
#      nit: 15
#      jac: [ 3.815e-06 -4.768e-07  0.000e+00  5.722e-06 -9.537e-06
#             0.000e+00]
#     nfev: 511
#     njev: 73
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 54.03434420468457
#        x: [ 8.219e-01 -9.954e-01  6.753e-01 -1.026e+02 -6.518e+01
#             0.000e+00]
#      nit: 11
#      jac: [ 7.629e-06  0.000e+00  0.000e+00  5.722e-06  5.245e-06
#             0.000e+00]
#     nfev: 385
#     njev: 55
#  message: Optimization terminated successfully.
#  success: True
#   status: 0
#      fun: 53.20766056526585
#        x: [ 9.473e-01 -1.328e+00  8.219e-01 -1.069e+02 -6.818e+01
#             0.000e+00]
#      nit: 9
#      jac: [-4.768e-07 -8.583e-06  0.000e+00  4.768e-07  8.106e-06
#             0.000e+00]
#     nfev: 357
#     njev: 51

# %% [markdown]
# ## Gráficos - Avaliação da defasagem
#
# Conforme o livro, introdução à computação quântica de Thomas Wong (2022), a defasagem apresentada por um sistema quântico não tem significado físico se for a mesma para todo o sistema, ou seja, todas as componentes devem ter a mesma diferença de fases. Para realizar essa avaliação, se faz necessário propor uma diferença entre a curva original e o destino, tanto na parte real quanto imaginária, além de realizar a diferença entre essas partes.

# %%
ts = np.linspace(0, 20, 2000) # Tempo em x 

RealO = [ele.real for ele in Resp[0]] 
ImagO = [ele.imag for ele in Resp[0]] 

sup = []
for i in range(0, 2000):
    sup.append(1/np.sqrt(2)*np.exp(-1*complex(0,1)*(1/2*np.pi)*i/100))
RealS = [ele.real for ele in sup]
ImagS = [ele.imag for ele in sup]

sub = []
for i in range(0, 2000):
    sub.append(abs(Resp[0][i] - sup[i]))

# Plotagem
plt.ylabel('Real') 
plt.xlabel('Tempo') 
plt.plot(ts, RealO, color='r', marker='*', linewidth=1, markersize=1)
plt.plot(ts, RealS, color='b', marker='o',  linewidth=1, markersize=1)
plt.savefig('rk_otimo1_cx.png', format='png')
plt.show()

# %%
plt.ylabel('Imaginário') 
plt.xlabel('Tempo') 
plt.plot(ts, ImagO, color='r', marker='*', linewidth=1, markersize=1)
plt.plot(ts, ImagS, color='b', marker='o',  linewidth=1, markersize=1)
plt.savefig('rk_otimo2_cx.png', format='png')
plt.show()

# %%
ts = np.linspace(0, 20, 2000) # Tempo em x 

RealO = [ele.real for ele in Resp[1]] 
ImagO = [ele.imag for ele in Resp[1]] 

sup = []
for i in range(0, 2000):
    sup.append(1/np.sqrt(2)*np.exp(-3*complex(0,1)*(1/2*np.pi)*i/100))
RealS = [ele.real for ele in sup]
ImagS = [ele.imag for ele in sup]

subr = []
for i in range(0, 2000):
    subr.append(abs(Resp[1][i] - sup[i]))

# Plotagem
plt.ylabel('Real') 
plt.xlabel('Tempo') 
plt.plot(ts, RealO, color='r', marker='*', linewidth=1, markersize=1)
plt.plot(ts, RealS, color='b', marker='o',  linewidth=1, markersize=1)
plt.savefig('rk_otimo3_cx.png', format='png')
plt.show()

# %%
plt.ylabel('Imaginário') 
plt.xlabel('Tempo') 
plt.plot(ts, ImagO, color='r', marker='*', linewidth=1, markersize=1)
plt.plot(ts, ImagS, color='b', marker='o',  linewidth=1, markersize=1)
plt.savefig('rk_otimo4_cx.png', format='png')
plt.show()

# %%
plt.ylabel('Defasagens') 
plt.xlabel('Tempo') 
plt.plot(ts, sub, color='y', marker='o',  linewidth=1, markersize=1)
plt.plot(ts, subr, color='m', marker='o',  linewidth=1, markersize=1)
plt.savefig('phases_cx.png', format='png')
plt.show()

# %% [markdown]
# #### Valor da defasagem

# %%
print(subr[999])
# Out:
# 2.4767349002280086

# %% [markdown]
# ## Gráficos - Avaliação das constantes da função de onda
#
# Outra interpretação pertinente é a obtenção das constantes de onda, pois o objetivo inicial da pesquisa é sair de uma constante e chegar em um estado de forma que estas estajam em total equilíbrio. Para realizar a plotagem com os diversos números complexos se faz o uso do número absoluto que para o estudo do conjunto complexo representa o seu tamanho, dessa forma, é possível indentificar se o estado inicial alcançou o final desejado.

# %%
ts = np.linspace(0, 20, 2000) # Tempo em x 
const = []
for i in range(0, 2000):
    const.append(1/np.sqrt(2))

# Plotagem
plt.ylabel('Constantes') 
plt.xlabel('Tempo') 
plt.plot(ts, abs(Constantes[0]), color='r', marker='*', linewidth=1, markersize=1)
plt.plot(ts, abs(Constantes[1]), color='b', marker='o',  linewidth=1, markersize=1)
plt.plot(ts, const, color='g', marker='o',  linewidth=1, markersize=1)
plt.savefig('const_cx.png', format='png')
plt.show()

# %% [markdown]
# ## Gráficos - Avaliação da densidade de probabilidade para encontrar uma partícula no ponto x
#
# Conforme descrito durante os capítulos 1, 2 e 3 do livro Mecânica Quântica por David Griffths, a estatística é um dos principais pontos para o entendimento da mecânica quântica, dessa forma é interessante entender qual é a probabilidade de uma partícula estar em um determinado lugar em um certo tempo e para tal se define:$$\int |\Psi(x,t)|^{2}dx = 1$$ Ainda nessa perspectiva, foi definido que o resultado da equação de Schrödinger pode ser definido a partir da escolha do potêncial V(x,t) e ainda que os enumeros resultados podem formar outros por meio de uma combinação linear de forma que o conjunto do quadrado das constantes que o formam, em sua soma resultam em 1. Isso define a probabilidade de um estado. Para este estudo considerou-se dois estados: $$0.80\psi_0(x,t)+0.60\psi_1(x,t)$$ de forma que para o primeiro estado a probabilidade é de 64% enquanto para o segundo é de 36%.
#
# Se torna claro que a probabilidade total deve ser 1 e definindo o produto interno como $\int |\Psi(x,t)|^{2}dx = <\Psi | \Psi> = 1 = \sum_n |c_n|²$ podemos verificar se o ajuste da pesquisa está correto avaliando as constantes que são alteradas conforme o tempo de acordo com o gráfico apresentado acima.

# %%
# Plotagem

dp = []
for i in range(0, 2000):
    dp.append((abs(Constantes[0][i])**2+abs(Constantes[1][i])**2))
    
plt.ylabel('Densidade probabilidade') 
plt.xlabel('Tempo') 
plt.plot(ts, dp, color='r', marker='*', linewidth=1, markersize=1)
plt.savefig('dp_cx.png', format='png')
plt.show()

# %%
print(dp)
# Out:
# [99.00000000000001, 98.11325357106332, 97.83567331617022, 97.69024059282606, 97.48688165933129, 97.05377157444573, 96.13860857278705, 94.67007027365864, 93.36994941038425, 92.87855386707312, 92.71980300457625, 92.58641102124851, 92.33508581047566, 91.76354914695489, 90.62780217293135, 89.13847956212143, 88.23745147294406, 87.97777591789432, 87.86398890748329, 87.71808317668605, 87.39547558702225, 86.66263407165343, 85.36370629776883, 84.05566453905203, 83.51509445997613, 83.36229068734715, 83.26063685635151, 83.08550830098685, 82.67211199200312, 81.77730865324878, 80.42880626110748, 79.43483345498791, 79.12363668027538, 79.01469458252333, 78.90826938791106, 78.68982217148019, 78.17158444993802, 77.14517579729079, 75.88763467793767, 75.2150528306843, 75.02273461554628, 74.92878684128486, 74.80581376047294, 74.53095814931638, 73.90257321989097, 72.80831200787966, 71.76002553170275, 71.32930608207592, 71.19198782490079, 71.09808560422509, 70.94762181534456, 70.60412293072042, 69.87452851947094, 68.80311779937645, 68.01559142579237, 67.73336812489032, 67.61839667866265, 67.51410846641475, 67.32468695576318, 66.90327186653006, 66.10378091050579, 65.15194661793387, 64.60001461305723, 64.39716003871986, 64.28725921452403, 64.16274098978664, 63.922846678166906, 63.42298490828453, 62.61265019197151, 61.84565818641923, 61.4613964282356, 61.29560657007946, 61.17942841914526, 61.024444827984965, 60.725622709727865, 60.165874348592, 59.41844146962784, 58.84040337087411, 58.555673511867205, 58.40298077083051, 58.27123215556004, 58.07696201959564, 57.72019775241107, 57.14491099206575, 56.513927929488545, 56.07993954886012, 55.844739843194866, 55.691180890287455, 55.536045794748134, 55.29974824412483, 54.9044932538863, 54.367725809595555, 53.85649501525516, 53.50981526866516, 53.293976755086035, 53.131028431027666, 52.949585683685115, 52.68054367084258, 52.28455905062924, 51.81371363421222, 51.38825039847977, 51.082997373454845, 50.87155539405316, 50.69659170774504, 50.496090854653836, 50.21822957134033, 49.852046015332924, 49.43444461311449, 49.053250139548936, 48.76182682566834, 48.550935616041286, 48.371434082901224, 48.16961806840983, 47.9087488306086, 47.57014982855419, 47.17536183250484, 46.80457172113172, 46.51892940228468, 46.31712402738829, 46.15025612352452, 45.96688362397811, 45.72653009513327, 45.39026898360793, 44.98800309140332, 44.611414042981664, 44.34145739511355, 44.16880560023637, 44.03040276529556, 43.871169493610736, 43.631208900111986, 43.270204925655, 42.83749545859081, 42.46239473371188, 42.233861693050756, 42.106861218880994, 42.00021530062462, 41.852395601867485, 41.58816465475653, 41.17958826715045, 40.71163691802737, 40.36709452474305, 40.20524086921128, 40.122526277561256, 40.0391596858894, 39.88505361801681, 39.579044553504986, 39.108472458533, 38.623242299783854, 38.34644379513567, 38.25110160689741, 38.20040068448386, 38.13049353266304, 37.96165072236947, 37.60792064376197, 37.07721302080098, 36.6022015514027, 36.408082090487895, 36.35814060358028, 36.329421338597925, 36.272897692461626, 36.10110299450166, 35.717278209268116, 35.143128854893334, 34.681709503799226, 34.54494362261423, 34.51995894839381, 34.50895393604938, 34.48184281452296, 34.36004056724191, 34.02434483167529, 33.44861834373231, 32.92182147261013, 32.76586186856972, 32.74904298334558, 32.733920439649935, 32.72909797961881, 32.6952831958663, 32.54008569112787, 32.15861806008505, 31.577332411593943, 31.209785714000034, 31.16685235266625, 31.165778443985054, 31.150086286266436, 31.150014321032586, 31.149094694308047, 31.149041327917587, 31.149003820373036, 31.149003639966736, 31.149003527290404, 31.149003525272057, 31.149003522475596, 31.149003520384653, 31.14900351817635, 31.149003515925756, 31.1490035136449, 31.149003511368647, 31.149003509059128, 31.149003506747793, 31.149003504425227, 31.14900350209988, 31.149003499758212, 31.149003497424022, 31.14900349507206, 31.149003492722514, 31.149003490362503, 31.149003488005235, 31.14900348564993, 31.1 ...
