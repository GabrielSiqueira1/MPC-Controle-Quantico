# %% [markdown]
# ### Controle Quântico Ótimo - Utilização do CG para ajuste do caminho percorrido por uma partícula
#
# Nessa etapa, é necessário avaliar, a partir da equação de Heisenberg, com o método de Runge-Kutta e com o controle MPC, como a curva de origem ajusta-se a curva de destino. Além disso, é interessantíssimo a avaliação a partir do estado estacionário e ainda verificar como ocorre o ajuste de fases.

# %%
# Bilbiotecas para auxílio na programação matemática
import math, sys 
import numpy as np
import sympy as sp

from scipy import sparse # Produção das diagonais das matrizes
from scipy.sparse import diags 

# Plotagem 2D e 3D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm


from os import path # Suficiente para manipulação de arquivos
    
# Para solução exata
from scipy.special import hermite
from math import factorial

# %matplotlib inline
count = 0

# Para otimização dos sistemas
from scipy import optimize

import random

# %% [markdown]
# Abaixo se dão os requisitos básicos para a instauração do teste. Se tem formas de subtrair e somar matrizes, a manipulação das derivadas com o Runge-Kutta além da própria proposta da função objetivo.

# %%
def somar(A, B):
    C = []
    nLinhasA, nLinhasB = len(A), len(B)
    nColA, nColB = len(A[0]), len(B[0])
    
    for i in range (nLinhasA):
        linha = [0]*nColA
        C.append(linha)
        for j in range(nColA):
            C[i][j] = A[i][j] + B[i][j]

    return C

def sub(A, B):
    C = []
    nLinhasA, nLinhasB = len(A), len(B)
    nColA, nColB = len(A[0]), len(B[0])
    
    for i in range (nLinhasA):
        linha = [0]*nColA
        C.append(linha)
        for j in range(nColA):
            C[i][j] = A[i][j] - B[i][j]

    return C


#################################################################

## d (psi) / dt = -i * H * |psi>
def dpsidt(t,psi, H):
    A = np.zeros((2,2), dtype=np.complex_)
    A = np.dot(complex(0,1),H) # i * H
    return -1*np.matmul(A,psi)

# Runge-Kutta de quarta ordem
def rungeKutta(psi0, h, H, t = 2, t0 = 0):
    
    n = (int)((t-t0))
    S = np.zeros((2,int(t)), dtype=np.complex_)
    r = 0
    
    for i in range(0, n):
        
        S[0][r] = psi0[0][0]
        S[1][r] = psi0[1][0]
        
        k1 = dpsidt(t0, psi0, H)
        k2 = dpsidt(t0 + 0.5 * h, somar(psi0, np.dot((0.5*h), k1)), H)
        k3 = dpsidt(t0 + 0.5 * h, somar(psi0, np.dot((0.5*h), k2)), H)
        k4 = dpsidt(t0 + h, somar(psi0, np.dot(h, k3)), H)
        
        ## y(i+1) = y(i) + h/6*(k1+2*k2+2*k3+k4)
        
        A = somar(np.dot(2,k3), k4)
        B = somar(np.dot(2,k2), k1)
        C = somar(A, B)
 
        psi0 = somar(psi0,np.dot((h / 6.0),(C)))
    
        t0 = t0 + h
        
        r = r + 1
        
    return S

def fo(x, D, H, i, psi0):
    
    H1 = np.zeros((2,2), dtype=np.complex_)
    
    ## Tamanho do horizonte
    tam = 3
    
    M = np.zeros((2,1),dtype=np.complex_)
    M = [[psi0[0][0]], [psi0[1][0]]] 
    
    Result = np.zeros((2,1),dtype=np.complex_)
    
    Return = 0

    Z = np.zeros((2,1),dtype=np.complex_)
    Z[0][0] = D[0][0]*np.exp(-1*complex(0,1)*(1/2*np.pi)*i/100)
    Z[1][0] = D[1][0]*np.exp(-1*complex(0,1)*(3/2*np.pi)*i/100)
    Return += np.linalg.norm(M-Z)**2
    Result = rungeKutta(M, h, somar(H,H1), t = 2, t0 = 0)
    M = Result
    
    teste = tam + i
    
    ## Função-Objetivo (Return) = ||somatorio (Matriz_Origem - Matriz_Destino)||^2
    for p in range(i, teste):
        H1 = [[0, x[p-i]], [x[p-i], 0]] # Controle
        Z = np.zeros((2,1),dtype=np.complex_)
        Z[0][0] = D[0][0]*np.exp(-1*complex(0,1)*(1/2*np.pi)*(p+1)/100)
        Z[1][0] = D[1][0]*np.exp(-1*complex(0,1)*(3/2*np.pi)*(p+1)/100)
        Return += np.linalg.norm(M-Z)**2
        Result = rungeKutta(M, h, somar(H,H1), t = (p-i)+3, t0 = 0)
        M = Result
    
    return Return

# %% [markdown]
# Para o funcionamento do MPC, cria-se um looping que consiste em uma otimização não linear, com o apoio da biblioteca de otimização do pyhton, de forma a obter o melhor resultado para o ajuste da curva. Com esse valor em mãos, utiliza-se para os pontos da próxima iteração do método de controle além de efetivar o ajuste realizando o Runge-Kutta com o valor otimizado.

# %%
# Horizonte de análise
tam = 3
i = 0 # Iteração
h = 0.01 # Fator Runge-Kutta

# Proposta dos pontos
x = []
x.append(random.uniform(-1, 1))
for l in range(1, tam):
    x.append(x[0])

# Função de origem e destino
psi0 = [[complex(0.80,0.0)],[complex(0.60,0.0)]]
psid = [[complex(1/np.sqrt(2),0)],[complex(1/np.sqrt(2),0)]]


H = np.zeros((2,2), dtype=np.complex_) # Hamiltoniano
A = (1/2*np.pi)
B = (3/2*np.pi)
H = [[A, 0], [0, B]]

D = np.zeros((2,1), dtype=np.complex_) # Matriz destino
D[0][0] = psid[0][0]
D[1][0] = psid[1][0]

Resp = np.zeros((2, 2000), dtype=np.complex_)
Constantes = np.zeros((2, 2000), dtype=np.complex_)
Pico = np.zeros((2, 2000), dtype=np.complex_)
Obj = np.zeros((1,2000), dtype=np.complex_)
aly1 = 0
aly2 = 1
Pico[1][i] = complex(0.60,0.0)

while i < 2000:
    
    print("Iteração = ", i)
    
    Resp[0][i] = psi0[0][0]
    Resp[1][i] = psi0[1][0]
    
    # Constantes da função de onda
    Constantes[0][i] = psi0[0][0] / np.exp(-1*complex(0,1)*(1/2*np.pi)*i/100)
    Constantes[1][i] = psi0[1][0] / np.exp(-3*complex(0,1)*(1/2*np.pi)*i/100)
    
    # Picos
    
    if(i == aly1*(100/(1/2))):
        Pico[0][i] = psi0[0][0]
        aly1=aly1+1
        
    if(i == aly2*(100)):
        Pico[1][i] = psi0[1][0]
        aly2=aly2+2
    
    # Função objetivo
    Obj[0][i] = fo(x, D, H, i, psi0)
    
    resultado = optimize.minimize(fo, x, args=(D, H, i, psi0), method='CG')
    
    x = []
    for l in range(0, tam):
        x.append(resultado.x[l])
    
    ## Hamiltoniano corntrolado
    u = np.zeros((2,1), dtype=np.complex_)
    u = [[0, resultado.x[0]],[resultado.x[0], 0]]
    H = somar(H, u)
    
    ## Adaptação da onda ao controle
    psi_t = np.zeros((2,2), dtype=np.complex_)
    psi_t = rungeKutta(psi0, h, H, t = 2, t0 = 0)
    
    psi0[0][0] = psi_t[0][1]
    psi0[1][0] = psi_t[1][1]
    
    H = [[A, 0], [0, B]]
    
    i += 1
# Out:
# Iteração =  0
# Iteração =  1
# Iteração =  2
# Iteração =  3
# Iteração =  4
# Iteração =  5
# Iteração =  6
# Iteração =  7
# Iteração =  8
# Iteração =  9
# Iteração =  10
# Iteração =  11
# Iteração =  12
# Iteração =  13
# Iteração =  14
# Iteração =  15
# Iteração =  16
# Iteração =  17
# Iteração =  18
# Iteração =  19
# Iteração =  20
# Iteração =  21
# Iteração =  22
# Iteração =  23
# Iteração =  24
# Iteração =  25
# Iteração =  26
# Iteração =  27
# Iteração =  28
# Iteração =  29
# Iteração =  30
# Iteração =  31
# Iteração =  32
# Iteração =  33
# Iteração =  34
# Iteração =  35
# Iteração =  36
# Iteração =  37
# Iteração =  38
# Iteração =  39
# Iteração =  40
# Iteração =  41
# Iteração =  42
# Iteração =  43
# Iteração =  44
# Iteração =  45
# Iteração =  46
# Iteração =  47
# Iteração =  48
# Iteração =  49
# Iteração =  50
# Iteração =  51
# Iteração =  52
# Iteração =  53
# Iteração =  54
# Iteração =  55
# Iteração =  56
# Iteração =  57
# Iteração =  58
# Iteração =  59
# Iteração =  60
# Iteração =  61
# Iteração =  62
# Iteração =  63
# Iteração =  64
# Iteração =  65
# Iteração =  66
# Iteração =  67
# Iteração =  68
# Iteração =  69
# Iteração =  70
# Iteração =  71
# Iteração =  72
# Iteração =  73
# Iteração =  74
# Iteração =  75
# Iteração =  76
# Iteração =  77
# Iteração =  78
# Iteração =  79
# Iteração =  80
# Iteração =  81
# Iteração =  82
# Iteração =  83
# Iteração =  84
# Iteração =  85
# Iteração =  86
# Iteração =  87
# Iteração =  88
# Iteração =  89
# Iteração =  90
# Iteração =  91
# Iteração =  92
# Iteração =  93
# Iteração =  94
# Iteração =  95
# Iteração =  96
# Iteração =  97
# Iteração =  98
# Iteração =  99
# Iteração =  100
# Iteração =  101
# Iteração =  102
# Iteração =  103
# Iteração =  104
# Iteração =  105
# Iteração =  106
# Iteração =  107
# Iteração =  108
# Iteração =  109
# Iteração =  110
# Iteração =  111
# Iteração =  112
# Iteração =  113
# Iteração =  114
# Iteração =  115
# Iteração =  116
# Iteração =  117
# Iteração =  118
# Iteração =  119
# Iteração =  120
# Iteração =  121
# Iteração =  122
# Iteração =  123
# Iteração =  124
# Iteração =  125
# Iteração =  126
# Iteração =  127
# Iteração =  128
# Iteração =  129
# Iteração =  130
# Iteração =  131
# Iteração =  132
# Iteração =  133
# Iteração =  134
# Iteração =  135
# Iteração =  136
# Iteração =  137
# Iteração =  138
# Iteração =  139
# Iteração =  140
# Iteração =  141
# Iteração =  142
# Iteração =  143
# Iteração =  144
# Iteração =  145
# Iteração =  146
# Iteração =  147
# Iteração =  148
# Iteração =  149
# Iteração =  150
# Iteração =  151
# Iteração =  152
# Iteração =  153
# Iteração =  154
# Iteração =  155
# Iteração =  156
# Iteração =  157
# Iteração =  158
# Iteração =  159
# Iteração =  160
# Iteração =  161
# Iteração =  162
# Iteração =  163
# Iteração =  164
# Iteração =  165
# Iteração =  166
# Iteração =  167
# Iteração =  168
# Iteração =  169
# Iteração =  170
# Iteração =  171
# Iteração =  172
# Iteração =  173
# Iteração =  174
# Iteração =  175
# Iteração =  176
# Iteração =  177
# Iteração =  178
# Iteração =  179
# Iteração =  180
# Iteração =  181
# Iteração =  182
# Iteração =  183
# Iteração =  184
# Iteração =  185
# Iteração =  186
# Iteração =  187
# Iteração =  188
# Iteração =  189
# Iteração =  190
# Iteração =  191
# Iteração =  192
# Iteração =  193
# Iteração =  194
# Iteração =  195
# Iteração =  196
# Iteração =  197
# Iteração =  198
# Iteração =  199
# Iteração =  200
# Iteração =  201
# Iteração =  202
# Iteração =  203
# Iteração =  204
# Iteração =  205
# Iteração =  206
# Iteração =  207
# Iteração =  208
# Iteração =  209
# Iteração =  210
# Iteração =  211
# Iteração =  212
# Iteração =  213
# Iteração =  214
# Iteração =  215
# Iteração =  216
# Iteração =  217
# Iteração =  218
# Iteração =  219
# Iteração =  220
# Iteração =  221
# Iteração =  222
# Iteração =  223
# Iteração =  224
# Iteração =  225
# Iteração =  226
# Iteração =  227
# Iteração =  228
# Iteração =  229
# Iteração =  230
# Iteração =  231
# Iteração =  232
# Iteração =  233
# Iteração =  234
# Iteração =  235
# Iteração =  236
# Iteração =  237
# Iteração =  238
# Iteração =  239
# Iteração =  240
# Iteração =  241
# Iteração =  242
# Iteração =  243
# Iteração =  244
# Iteração =  245
# Iteração =  246
# Iteração =  247
# Iteração =  248
# Iteração =  249
# Iteração =  250
# Iteração =  251
# Iteração =  252
# Iteração =  253
# Iteração =  254
# Iteração =  255
# Iteração =  256
# Iteração =  257
# Iteração =  258
# Iteração =  259
# Iteração =  260
# Iteração =  261
# Iteração =  262
# Iteração =  263
# Iteração =  264
# Iteração =  265
# Iteração =  266
# Iteração =  267
# Iteração =  268
# Iteração =  269
# Iteração =  270
# Iteração =  271
# Iteração =  272
# Iteração =  273
# Iteração =  274
# Iteração =  275
# Iteração =  276
# Iteração =  277
# Iteração =  278
# Iteração =  279
# Iteração =  280
# Iteração =  281
# Iteração =  282
# Iteração =  283
# Iteração =  284
# Iteração =  285
# Iteração =  286
# Iteração =  287
# Iteração =  288
# Iteração =  289
# Iteração =  290
# Iteração =  291
# Iteração =  292
# Iteração =  293
# Iteração =  294
# Iteração =  295
# Iteração =  296
# Iteração =  297
# Iteração =  298
# Iteração =  299
# Iteração =  300
# Iteração =  301
# Iteração =  302
# Iteração =  303
# Iteração =  304
# Iteração =  305
# Iteração =  306
# Iteração =  307
# Iteração =  308
# Iteração =  309
# Iteração =  310
# Iteração =  311
# Iteração =  312
# Iteração =  313
# Iteração =  314
# Iteração =  315
# Iteração =  316
# Iteração =  317
# Iteração =  318
# Iteração =  319
# Iteração =  320
# Iteração =  321
# Iteração =  322
# Iteração =  323
# Iteração =  324
# Iteração =  325
# Iteração =  326
# Iteração =  327
# Iteração =  328
# Iteração =  329
# Iteração =  330
# Iteração =  331
# Iteração =  332
# Iteração =  333
# Iteração =  334
# Iteração =  335
# Iteração =  336
# Iteração =  337
# Iteração =  338
# Iteração =  339
# Iteração =  340
# Iteração =  341
# Iteração =  342
# Iteração =  343
# Iteração =  344
# Iteração =  345
# Iteração =  346
# Iteração =  347
# Iteração =  348
# Iteração =  349
# Iteração =  350
# Iteração =  351
# Iteração =  352
# Iteração =  353
# Iteração =  354
# Iteração =  355
# Iteração =  356
# Iteração =  357
# Iteração =  358
# Iteração =  359
# Iteração =  360
# Iteração =  361
# Iteração =  362
# Iteração =  363
# Iteração =  364
# Iteração =  365
# Iteração =  366
# Iteração =  367
# Iteração =  368
# Iteração =  369
# Iteração =  370
# Iteração =  371
# Iteração =  372
# Iteração =  373
# Iteração =  374
# Iteração =  375
# Iteração =  376
# Iteração =  377
# Iteração =  378
# Iteração =  379
# Iteração =  380
# Iteração =  381
# Iteração =  382
# Iteração =  383
# Iteração =  384
# Iteração =  385
# Iteração =  386
# Iteração =  387
# Iteração =  388
# Iteração =  389
# Iteração =  390
# Iteração =  391
# Iteração =  392
# Iteração =  393
# Iteração =  394
# Iteração =  395
# Iteração =  396
# Iteração =  397
# Iteração =  398
# Iteração =  399
# Iteração =  400
# Iteração =  401
# Iteração =  402
# Iteração =  403
# Iteração =  404
# Iteração =  405
# Iteração =  406
# Iteração =  407
# Iteração =  408
# Iteração =  409
# Iteração =  410
# Iteração =  411
# Iteração =  412
# Iteração =  413
# Iteração =  414
# Iteração =  415
# Iteração =  416
# Iteração =  417
# Iteração =  418
# Iteração =  419
# Iteração =  420
# Iteração =  421
# Iteração =  422
# Iteração =  423
# Iteração =  424
# Iteração =  425
# Iteração =  426
# Iteração =  427
# Iteração =  428
# Iteração =  429
# Iteração =  430
# Iteração =  431
# Iteração =  432
# Iteração =  433
# Iteração =  434
# Iteração =  435
# Iteração =  436
# Iteração =  437
# Iteração =  438
# Iteração =  439
# Iteração =  440
# Iteração =  441
# Iteração =  442
# Iteração =  443
# Iteração =  444
# Iteração =  445
# Iteração =  446
# Iteração =  447
# Iteração =  448
# Iteração =  449
# Iteração =  450
# Iteração =  451
# Iteração =  452
# Iteração =  453
# Iteração =  454
# Iteração =  455
# Iteração =  456
# Iteração =  457
# Iteração =  458
# Iteração =  459
# Iteração =  460
# Iteração =  461
# Iteração =  462
# Iteração =  463
# Iteração =  464
# Iteração =  465
# Iteração =  466
# Iteração =  467
# Iteração =  468
# Iteração =  469
# Iteração =  470
# Iteração =  471
# Iteração =  472
# Iteração =  473
# Iteração =  474
# Iteração =  475
# Iteração =  476
# Iteração =  477
# Iteração =  478
# Iteração =  479
# Iteração =  480
# Iteração =  481
# Iteração =  482
# Iteração =  483
# Iteração =  484
# Iteração =  485
# Iteração =  486
# Iteração =  487
# Iteração =  488
# Iteração =  489
# Iteração =  490
# Iteração =  491
# Iteração =  492
# Iteração =  493
# Iteração =  494
# Iteração =  495
# Iteração =  496
# Iteração =  497
# Iteração =  498
# Iteração =  499
# Iteração =  500
# Iteração =  501
# Iteração =  502
# Iteração =  503
# Iteração =  504
# Iteração =  505
# Iteração =  506
# Iteração =  507
# Iteração =  508
# Iteração =  509
# Iteração =  510
# Iteração =  511
# Iteração =  512
# Iteração =  513
# Iteração =  514
# Iteração =  515
# Iteração =  516
# Iteração =  517
# Iteração =  518
# Iteração =  519
# Iteração =  520
# Iteração =  521
# Iteração =  522
# Iteração =  523
# Iteração =  524
# Iteração =  525
# Iteração =  526
# Iteração =  527
# Iteração =  528
# Iteração =  529
# Iteração =  530
# Iteração =  531
# Iteração =  532
# Iteração =  533
# Iteração =  534
# Iteração =  535
# Iteração =  536
# Iteração =  537
# Iteração =  538
# Iteração =  539
# Iteração =  540
# Iteração =  541
# Iteração =  542
# Iteração =  543
# Iteração =  544
# Iteração =  545
# Iteração =  546
# Iteração =  547
# Iteração =  548
# Iteração =  549
# Iteração =  550
# Iteração =  551
# Iteração =  552
# Iteração =  553
# Iteração =  554
# Iteração =  555
# Iteração =  556
# Iteração =  557
# Iteração =  558
# Iteração =  559
# Iteração =  560
# Iteração =  561
# Iteração =  562
# Iteração =  563
# Iteração =  564
# Iteração =  565
# Iteração =  566
# Iteração =  567
# Iteração =  568
# Iteração =  569
# Iteração =  570
# Iteração =  571
# Iteração =  572
# Iteração =  573
# Iteração =  574
# Iteração =  575
# Iteração =  576
# Iteração =  577
# Iteração =  578
# Iteração =  579
# Iteração =  580
# Iteração =  581
# Iteração =  582
# Iteração =  583
# Iteração =  584
# Iteração =  585
# Iteração =  586
# Iteração =  587
# Iteração =  588
# Iteração =  589
# Iteração =  590
# Iteração =  591
# Iteração =  592
# Iteração =  593
# Iteração =  594
# Iteração =  595
# Iteração =  596
# Iteração =  597
# Iteração =  598
# Iteração =  599
# Iteração =  600
# Iteração =  601
# Iteração =  602
# Iteração =  603
# Iteração =  604
# Iteração =  605
# Iteração =  606
# Iteração =  607
# Iteração =  608
# Iteração =  609
# Iteração =  610
# Iteração =  611
# Iteração =  612
# Iteração =  613
# Iteração =  614
# Iteração =  615
# Iteração =  616
# Iteração =  617
# Iteração =  618
# Iteração =  619
# Iteração =  620
# Iteração =  621
# Iteração =  622
# Iteração =  623
# Iteração =  624
# Iteração =  625
# Iteração =  626
# Iteração =  627
# Iteração =  628
# Iteração =  629
# Iteração =  630
# Iteração =  631
# Iteração =  632
# Iteração =  633
# Iteração =  634
# Iteração =  635
# Iteração =  636
# Iteração =  637
# Iteração =  638
# Iteração =  639
# Iteração =  640
# Iteração =  641
# Iteração =  642
# Iteração =  643
# Iteração =  644
# Iteração =  645
# Iteração =  646
# Iteração =  647
# Iteração =  648
# Iteração =  649
# Iteração =  650
# Iteração =  651
# Iteração =  652
# Iteração =  653
# Iteração =  654
# Iteração =  655
# Iteração =  656
# Iteração =  657
# Iteração =  658
# Iteração =  659
# Iteração =  660
# Iteração =  661
# Iteração =  662
# Iteração =  663
# Iteração =  664
# Iteração =  665
# Iteração =  666
# Iteração =  667
# Iteração =  668
# Iteração =  669
# Iteração =  670
# Iteração =  671
# Iteração =  672
# Iteração =  673
# Iteração =  674
# Iteração =  675
# Iteração =  676
# Iteração =  677
# Iteração =  678
# Iteração =  679
# Iteração =  680
# Iteração =  681
# Iteração =  682
# Iteração =  683
# Iteração =  684
# Iteração =  685
# Iteração =  686
# Iteração =  687
# Iteração =  688
# Iteração =  689
# Iteração =  690
# Iteração =  691
# Iteração =  692
# Iteração =  693
# Iteração =  694
# Iteração =  695
# Iteração =  696
# Iteração =  697
# Iteração =  698
# Iteração =  699
# Iteração =  700
# Iteração =  701
# Iteração =  702
# Iteração =  703
# Iteração =  704
# Iteração =  705
# Iteração =  706
# Iteração =  707
# Iteração =  708
# Iteração =  709
# Iteração =  710
# Iteração =  711
# Iteração =  712
# Iteração =  713
# Iteração =  714
# Iteração =  715
# Iteração =  716
# Iteração =  717
# Iteração =  718
# Iteração =  719
# Iteração =  720
# Iteração =  721
# Iteração =  722
# Iteração =  723
# Iteração =  724
# Iteração =  725
# Iteração =  726
# Iteração =  727
# Iteração =  728
# Iteração =  729
# Iteração =  730
# Iteração =  731
# Iteração =  732
# Iteração =  733
# Iteração =  734
# Iteração =  735
# Iteração =  736
# Iteração =  737
# Iteração =  738
# Iteração =  739
# Iteração =  740
# Iteração =  741
# Iteração =  742
# Iteração =  743
# Iteração =  744
# Iteração =  745
# Iteração =  746
# Iteração =  747
# Iteração =  748
# Iteração =  749
# Iteração =  750
# Iteração =  751
# Iteração =  752
# Iteração =  753
# Iteração =  754
# Iteração =  755
# Iteração =  756
# Iteração =  757
# Iteração =  758
# Iteração =  759
# Iteração =  760
# Iteração =  761
# Iteração =  762
# Iteração =  763
# Iteração =  764
# Iteração =  765
# Iteração =  766
# Iteração =  767
# Iteração =  768
# Iteração =  769
# Iteração =  770
# Iteração =  771
# Iteração =  772
# Iteração =  773
# Iteração =  774
# Iteração =  775
# Iteração =  776
# Iteração =  777
# Iteração =  778
# Iteração =  779
# Iteração =  780
# Iteração =  781
# Iteração =  782
# Iteração =  783
# Iteração =  784
# Iteração =  785
# Iteração =  786
# Iteração =  787
# Iteração =  788
# Iteração =  789
# Iteração =  790
# Iteração =  791
# Iteração =  792
# Iteração =  793
# Iteração =  794
# Iteração =  795
# Iteração =  796
# Iteração =  797
# Iteração =  798
# Iteração =  799
# Iteração =  800
# Iteração =  801
# Iteração =  802
# Iteração =  803
# Iteração =  804
# Iteração =  805
# Iteração =  806
# Iteração =  807
# Iteração =  808
# Iteração =  809
# Iteração =  810
# Iteração =  811
# Iteração =  812
# Iteração =  813
# Iteração =  814
# Iteração =  815
# Iteração =  816
# Iteração =  817
# Iteração =  818
# Iteração =  819
# Iteração =  820
# Iteração =  821
# Iteração =  822
# Iteração =  823
# Iteração =  824
# Iteração =  825
# Iteração =  826
# Iteração =  827
# Iteração =  828
# Iteração =  829
# Iteração =  830
# Iteração =  831
# Iteração =  832
# Iteração =  833
# Iteração =  834
# Iteração =  835
# Iteração =  836
# Iteração =  837
# Iteração =  838
# Iteração =  839
# Iteração =  840
# Iteração =  841
# Iteração =  842
# Iteração =  843
# Iteração =  844
# Iteração =  845
# Iteração =  846
# Iteração =  847
# Iteração =  848
# Iteração =  849
# Iteração =  850
# Iteração =  851
# Iteração =  852
# Iteração =  853
# Iteração =  854
# Iteração =  855
# Iteração =  856
# Iteração =  857
# Iteração =  858
# Iteração =  859
# Iteração =  860
# Iteração =  861
# Iteração =  862
# Iteração =  863
# Iteração =  864
# Iteração =  865
# Iteração =  866
# Iteração =  867
# Iteração =  868
# Iteração =  869
# Iteração =  870
# Iteração =  871
# Iteração =  872
# Iteração =  873
# Iteração =  874
# Iteração =  875
# Iteração =  876
# Iteração =  877
# Iteração =  878
# Iteração =  879
# Iteração =  880
# Iteração =  881
# Iteração =  882
# Iteração =  883
# Iteração =  884
# Iteração =  885
# Iteração =  886
# Iteração =  887
# Iteração =  888
# Iteração =  889
# Iteração =  890
# Iteração =  891
# Iteração =  892
# Iteração =  893
# Iteração =  894
# Iteração =  895
# Iteração =  896
# Iteração =  897
# Iteração =  898
# Iteração =  899
# Iteração =  900
# Iteração =  901
# Iteração =  902
# Iteração =  903
# Iteração =  904
# Iteração =  905
# Iteração =  906
# Iteração =  907
# Iteração =  908
# Iteração =  909
# Iteração =  910
# Iteração =  911
# Iteração =  912
# Iteração =  913
# Iteração =  914
# Iteração =  915
# Iteração =  916
# Iteração =  917
# Iteração =  918
# Iteração =  919
# Iteração =  920
# Iteração =  921
# Iteração =  922
# Iteração =  923
# Iteração =  924
# Iteração =  925
# Iteração =  926
# Iteração =  927
# Iteração =  928
# Iteração =  929
# Iteração =  930
# Iteração =  931
# Iteração =  932
# Iteração =  933
# Iteração =  934
# Iteração =  935
# Iteração =  936
# Iteração =  937
# Iteração =  938
# Iteração =  939
# Iteração =  940
# Iteração =  941
# Iteração =  942
# Iteração =  943
# Iteração =  944
# Iteração =  945
# Iteração =  946
# Iteração =  947
# Iteração =  948
# Iteração =  949
# Iteração =  950
# Iteração =  951
# Iteração =  952
# Iteração =  953
# Iteração =  954
# Iteração =  955
# Iteração =  956
# Iteração =  957
# Iteração =  958
# Iteração =  959
# Iteração =  960
# Iteração =  961
# Iteração =  962
# Iteração =  963
# Iteração =  964
# Iteração =  965
# Iteração =  966
# Iteração =  967
# Iteração =  968
# Iteração =  969
# Iteração =  970
# Iteração =  971
# Iteração =  972
# Iteração =  973
# Iteração =  974
# Iteração =  975
# Iteração =  976
# Iteração =  977
# Iteração =  978
# Iteração =  979
# Iteração =  980
# Iteração =  981
# Iteração =  982
# Iteração =  983
# Iteração =  984
# Iteração =  985
# Iteração =  986
# Iteração =  987
# Iteração =  988
# Iteração =  989
# Iteração =  990
# Iteração =  991
# Iteração =  992
# Iteração =  993
# Iteração =  994
# Iteração =  995
# Iteração =  996
# Iteração =  997
# Iteração =  998
# Iteração =  999
# Iteração =  1000
# Iteração =  1001
# Iteração =  1002
# Iteração =  1003
# Iteração =  1004
# Iteração =  1005
# Iteração =  1006
# Iteração =  1007
# Iteração =  1008
# Iteração =  1009
# Iteração =  1010
# Iteração =  1011
# Iteração =  1012
# Iteração =  1013
# Iteração =  1014
# Iteração =  1015
# Iteração =  1016
# Iteração =  1017
# Iteração =  1018
# Iteração =  1019
# Iteração =  1020
# Iteração =  1021
# Iteração =  1022
# Iteração =  1023
# Iteração =  1024
# Iteração =  1025
# Iteração =  1026
# Iteração =  1027
# Iteração =  1028
# Iteração =  1029
# Iteração =  1030
# Iteração =  1031
# Iteração =  1032
# Iteração =  1033
# Iteração =  1034
# Iteração =  1035
# Iteração =  1036
# Iteração =  1037
# Iteração =  1038
# Iteração =  1039
# Iteração =  1040
# Iteração =  1041
# Iteração =  1042
# Iteração =  1043
# Iteração =  1044
# Iteração =  1045
# Iteração =  1046
# Iteração =  1047
# Iteração =  1048
# Iteração =  1049
# Iteração =  1050
# Iteração =  1051
# Iteração =  1052
# Iteração =  1053
# Iteração =  1054
# Iteração =  1055
# Iteração =  1056
# Iteração =  1057
# Iteração =  1058
# Iteração =  1059
# Iteração =  1060
# Iteração =  1061
# Iteração =  1062
# Iteração =  1063
# Iteração =  1064
# Iteração =  1065
# Iteração =  1066
# Iteração =  1067
# Iteração =  1068
# Iteração =  1069
# Iteração =  1070
# Iteração =  1071
# Iteração =  1072
# Iteração =  1073
# Iteração =  1074
# Iteração =  1075
# Iteração =  1076
# Iteração =  1077
# Iteração =  1078
# Iteração =  1079
# Iteração =  1080
# Iteração =  1081
# Iteração =  1082
# Iteração =  1083
# Iteração =  1084
# Iteração =  1085
# Iteração =  1086
# Iteração =  1087
# Iteração =  1088
# Iteração =  1089
# Iteração =  1090
# Iteração =  1091
# Iteração =  1092
# Iteração =  1093
# Iteração =  1094
# Iteração =  1095
# Iteração =  1096
# Iteração =  1097
# Iteração =  1098
# Iteração =  1099
# Iteração =  1100
# Iteração =  1101
# Iteração =  1102
# Iteração =  1103
# Iteração =  1104
# Iteração =  1105
# Iteração =  1106
# Iteração =  1107
# Iteração =  1108
# Iteração =  1109
# Iteração =  1110
# Iteração =  1111
# Iteração =  1112
# Iteração =  1113
# Iteração =  1114
# Iteração =  1115
# Iteração =  1116
# Iteração =  1117
# Iteração =  1118
# Iteração =  1119
# Iteração =  1120
# Iteração =  1121
# Iteração =  1122
# Iteração =  1123
# Iteração =  1124
# Iteração =  1125
# Iteração =  1126
# Iteração =  1127
# Iteração =  1128
# Iteração =  1129
# Iteração =  1130
# Iteração =  1131
# Iteração =  1132
# Iteração =  1133
# Iteração =  1134
# Iteração =  1135
# Iteração =  1136
# Iteração =  1137
# Iteração =  1138
# Iteração =  1139
# Iteração =  1140
# Iteração =  1141
# Iteração =  1142
# Iteração =  1143
# Iteração =  1144
# Iteração =  1145
# Iteração =  1146
# Iteração =  1147
# Iteração =  1148
# Iteração =  1149
# Iteração =  1150
# Iteração =  1151
# Iteração =  1152
# Iteração =  1153
# Iteração =  1154
# Iteração =  1155
# Iteração =  1156
# Iteração =  1157
# Iteração =  1158
# Iteração =  1159
# Iteração =  1160
# Iteração =  1161
# Iteração =  1162
# Iteração =  1163
# Iteração =  1164
# Iteração =  1165
# Iteração =  1166
# Iteração =  1167
# Iteração =  1168
# Iteração =  1169
# Iteração =  1170
# Iteração =  1171
# Iteração =  1172
# Iteração =  1173
# Iteração =  1174
# Iteração =  1175
# Iteração =  1176
# Iteração =  1177
# Iteração =  1178
# Iteração =  1179
# Iteração =  1180
# Iteração =  1181
# Iteração =  1182
# Iteração =  1183
# Iteração =  1184
# Iteração =  1185
# Iteração =  1186
# Iteração =  1187
# Iteração =  1188
# Iteração =  1189
# Iteração =  1190
# Iteração =  1191
# Iteração =  1192
# Iteração =  1193
# Iteração =  1194
# Iteração =  1195
# Iteração =  1196
# Iteração =  1197
# Iteração =  1198
# Iteração =  1199
# Iteração =  1200
# Iteração =  1201
# Iteração =  1202
# Iteração =  1203
# Iteração =  1204
# Iteração =  1205
# Iteração =  1206
# Iteração =  1207
# Iteração =  1208
# Iteração =  1209
# Iteração =  1210
# Iteração =  1211
# Iteração =  1212
# Iteração =  1213
# Iteração =  1214
# Iteração =  1215
# Iteração =  1216
# Iteração =  1217
# Iteração =  1218
# Iteração =  1219
# Iteração =  1220
# Iteração =  1221
# Iteração =  1222
# Iteração =  1223
# Iteração =  1224
# Iteração =  1225
# Iteração =  1226
# Iteração =  1227
# Iteração =  1228
# Iteração =  1229
# Iteração =  1230
# Iteração =  1231
# Iteração =  1232
# Iteração =  1233
# Iteração =  1234
# Iteração =  1235
# Iteração =  1236
# Iteração =  1237
# Iteração =  1238
# Iteração =  1239
# Iteração =  1240
# Iteração =  1241
# Iteração =  1242
# Iteração =  1243
# Iteração =  1244
# Iteração =  1245
# Iteração =  1246
# Iteração =  1247
# Iteração =  1248
# Iteração =  1249
# Iteração =  1250
# Iteração =  1251
# Iteração =  1252
# Iteração =  1253
# Iteração =  1254
# Iteração =  1255
# Iteração =  1256
# Iteração =  1257
# Iteração =  1258
# Iteração =  1259
# Iteração =  1260
# Iteração =  1261
# Iteração =  1262
# Iteração =  1263
# Iteração =  1264
# Iteração =  1265
# Iteração =  1266
# Iteração =  1267
# Iteração =  1268
# Iteração =  1269
# Iteração =  1270
# Iteração =  1271
# Iteração =  1272
# Iteração =  1273
# Iteração =  1274
# Iteração =  1275
# Iteração =  1276
# Iteração =  1277
# Iteração =  1278
# Iteração =  1279
# Iteração =  1280
# Iteração =  1281
# Iteração =  1282
# Iteração =  1283
# Iteração =  1284
# Iteração =  1285
# Iteração =  1286
# Iteração =  1287
# Iteração =  1288
# Iteração =  1289
# Iteração =  1290
# Iteração =  1291
# Iteração =  1292
# Iteração =  1293
# Iteração =  1294
# Iteração =  1295
# Iteração =  1296
# Iteração =  1297
# Iteração =  1298
# Iteração =  1299
# Iteração =  1300
# Iteração =  1301
# Iteração =  1302
# Iteração =  1303
# Iteração =  1304
# Iteração =  1305
# Iteração =  1306
# Iteração =  1307
# Iteração =  1308
# Iteração =  1309
# Iteração =  1310
# Iteração =  1311
# Iteração =  1312
# Iteração =  1313
# Iteração =  1314
# Iteração =  1315
# Iteração =  1316
# Iteração =  1317
# Iteração =  1318
# Iteração =  1319
# Iteração =  1320
# Iteração =  1321
# Iteração =  1322
# Iteração =  1323
# Iteração =  1324
# Iteração =  1325
# Iteração =  1326
# Iteração =  1327
# Iteração =  1328
# Iteração =  1329
# Iteração =  1330
# Iteração =  1331
# Iteração =  1332
# Iteração =  1333
# Iteração =  1334
# Iteração =  1335
# Iteração =  1336
# Iteração =  1337
# Iteração =  1338
# Iteração =  1339
# Iteração =  1340
# Iteração =  1341
# Iteração =  1342
# Iteração =  1343
# Iteração =  1344
# Iteração =  1345
# Iteração =  1346
# Iteração =  1347
# Iteração =  1348
# Iteração =  1349
# Iteração =  1350
# Iteração =  1351
# Iteração =  1352
# Iteração =  1353
# Iteração =  1354
# Iteração =  1355
# Iteração =  1356
# Iteração =  1357
# Iteração =  1358
# Iteração =  1359
# Iteração =  1360
# Iteração =  1361
# Iteração =  1362
# Iteração =  1363
# Iteração =  1364
# Iteração =  1365
# Iteração =  1366
# Iteração =  1367
# Iteração =  1368
# Iteração =  1369
# Iteração =  1370
# Iteração =  1371
# Iteração =  1372
# Iteração =  1373
# Iteração =  1374
# Iteração =  1375
# Iteração =  1376
# Iteração =  1377
# Iteração =  1378
# Iteração =  1379
# Iteração =  1380
# Iteração =  1381
# Iteração =  1382
# Iteração =  1383
# Iteração =  1384
# Iteração =  1385
# Iteração =  1386
# Iteração =  1387
# Iteração =  1388
# Iteração =  1389
# Iteração =  1390
# Iteração =  1391
# Iteração =  1392
# Iteração =  1393
# Iteração =  1394
# Iteração =  1395
# Iteração =  1396
# Iteração =  1397
# Iteração =  1398
# Iteração =  1399
# Iteração =  1400
# Iteração =  1401
# Iteração =  1402
# Iteração =  1403
# Iteração =  1404
# Iteração =  1405
# Iteração =  1406
# Iteração =  1407
# Iteração =  1408
# Iteração =  1409
# Iteração =  1410
# Iteração =  1411
# Iteração =  1412
# Iteração =  1413
# Iteração =  1414
# Iteração =  1415
# Iteração =  1416
# Iteração =  1417
# Iteração =  1418
# Iteração =  1419
# Iteração =  1420
# Iteração =  1421
# Iteração =  1422
# Iteração =  1423
# Iteração =  1424
# Iteração =  1425
# Iteração =  1426
# Iteração =  1427
# Iteração =  1428
# Iteração =  1429
# Iteração =  1430
# Iteração =  1431
# Iteração =  1432
# Iteração =  1433
# Iteração =  1434
# Iteração =  1435
# Iteração =  1436
# Iteração =  1437
# Iteração =  1438
# Iteração =  1439
# Iteração =  1440
# Iteração =  1441
# Iteração =  1442
# Iteração =  1443
# Iteração =  1444
# Iteração =  1445
# Iteração =  1446
# Iteração =  1447
# Iteração =  1448
# Iteração =  1449
# Iteração =  1450
# Iteração =  1451
# Iteração =  1452
# Iteração =  1453
# Iteração =  1454
# Iteração =  1455
# Iteração =  1456
# Iteração =  1457
# Iteração =  1458
# Iteração =  1459
# Iteração =  1460
# Iteração =  1461
# Iteração =  1462
# Iteração =  1463
# Iteração =  1464
# Iteração =  1465
# Iteração =  1466
# Iteração =  1467
# Iteração =  1468
# Iteração =  1469
# Iteração =  1470
# Iteração =  1471
# Iteração =  1472
# Iteração =  1473
# Iteração =  1474
# Iteração =  1475
# Iteração =  1476
# Iteração =  1477
# Iteração =  1478
# Iteração =  1479
# Iteração =  1480
# Iteração =  1481
# Iteração =  1482
# Iteração =  1483
# Iteração =  1484
# Iteração =  1485
# Iteração =  1486
# Iteração =  1487
# Iteração =  1488
# Iteração =  1489
# Iteração =  1490
# Iteração =  1491
# Iteração =  1492
# Iteração =  1493
# Iteração =  1494
# Iteração =  1495
# Iteração =  1496
# Iteração =  1497
# Iteração =  1498
# Iteração =  1499
# Iteração =  1500
# Iteração =  1501
# Iteração =  1502
# Iteração =  1503
# Iteração =  1504
# Iteração =  1505
# Iteração =  1506
# Iteração =  1507
# Iteração =  1508
# Iteração =  1509
# Iteração =  1510
# Iteração =  1511
# Iteração =  1512
# Iteração =  1513
# Iteração =  1514
# Iteração =  1515
# Iteração =  1516
# Iteração =  1517
# Iteração =  1518
# Iteração =  1519
# Iteração =  1520
# Iteração =  1521
# Iteração =  1522
# Iteração =  1523
# Iteração =  1524
# Iteração =  1525
# Iteração =  1526
# Iteração =  1527
# Iteração =  1528
# Iteração =  1529
# Iteração =  1530
# Iteração =  1531
# Iteração =  1532
# Iteração =  1533
# Iteração =  1534
# Iteração =  1535
# Iteração =  1536
# Iteração =  1537
# Iteração =  1538
# Iteração =  1539
# Iteração =  1540
# Iteração =  1541
# Iteração =  1542
# Iteração =  1543
# Iteração =  1544
# Iteração =  1545
# Iteração =  1546
# Iteração =  1547
# Iteração =  1548
# Iteração =  1549
# Iteração =  1550
# Iteração =  1551
# Iteração =  1552
# Iteração =  1553
# Iteração =  1554
# Iteração =  1555
# Iteração =  1556
# Iteração =  1557
# Iteração =  1558
# Iteração =  1559
# Iteração =  1560
# Iteração =  1561
# Iteração =  1562
# Iteração =  1563
# Iteração =  1564
# Iteração =  1565
# Iteração =  1566
# Iteração =  1567
# Iteração =  1568
# Iteração =  1569
# Iteração =  1570
# Iteração =  1571
# Iteração =  1572
# Iteração =  1573
# Iteração =  1574
# Iteração =  1575
# Iteração =  1576
# Iteração =  1577
# Iteração =  1578
# Iteração =  1579
# Iteração =  1580
# Iteração =  1581
# Iteração =  1582
# Iteração =  1583
# Iteração =  1584
# Iteração =  1585
# Iteração =  1586
# Iteração =  1587
# Iteração =  1588
# Iteração =  1589
# Iteração =  1590
# Iteração =  1591
# Iteração =  1592
# Iteração =  1593
# Iteração =  1594
# Iteração =  1595
# Iteração =  1596
# Iteração =  1597
# Iteração =  1598
# Iteração =  1599
# Iteração =  1600
# Iteração =  1601
# Iteração =  1602
# Iteração =  1603
# Iteração =  1604
# Iteração =  1605
# Iteração =  1606
# Iteração =  1607
# Iteração =  1608
# Iteração =  1609
# Iteração =  1610
# Iteração =  1611
# Iteração =  1612
# Iteração =  1613
# Iteração =  1614
# Iteração =  1615
# Iteração =  1616
# Iteração =  1617
# Iteração =  1618
# Iteração =  1619
# Iteração =  1620
# Iteração =  1621
# Iteração =  1622
# Iteração =  1623
# Iteração =  1624
# Iteração =  1625
# Iteração =  1626
# Iteração =  1627
# Iteração =  1628
# Iteração =  1629
# Iteração =  1630
# Iteração =  1631
# Iteração =  1632
# Iteração =  1633
# Iteração =  1634
# Iteração =  1635
# Iteração =  1636
# Iteração =  1637
# Iteração =  1638
# Iteração =  1639
# Iteração =  1640
# Iteração =  1641
# Iteração =  1642
# Iteração =  1643
# Iteração =  1644
# Iteração =  1645
# Iteração =  1646
# Iteração =  1647
# Iteração =  1648
# Iteração =  1649
# Iteração =  1650
# Iteração =  1651
# Iteração =  1652
# Iteração =  1653
# Iteração =  1654
# Iteração =  1655
# Iteração =  1656
# Iteração =  1657
# Iteração =  1658
# Iteração =  1659
# Iteração =  1660
# Iteração =  1661
# Iteração =  1662
# Iteração =  1663
# Iteração =  1664
# Iteração =  1665
# Iteração =  1666
# Iteração =  1667
# Iteração =  1668
# Iteração =  1669
# Iteração =  1670
# Iteração =  1671
# Iteração =  1672
# Iteração =  1673
# Iteração =  1674
# Iteração =  1675
# Iteração =  1676
# Iteração =  1677
# Iteração =  1678
# Iteração =  1679
# Iteração =  1680
# Iteração =  1681
# Iteração =  1682
# Iteração =  1683
# Iteração =  1684
# Iteração =  1685
# Iteração =  1686
# Iteração =  1687
# Iteração =  1688
# Iteração =  1689
# Iteração =  1690
# Iteração =  1691
# Iteração =  1692
# Iteração =  1693
# Iteração =  1694
# Iteração =  1695
# Iteração =  1696
# Iteração =  1697
# Iteração =  1698
# Iteração =  1699
# Iteração =  1700
# Iteração =  1701
# Iteração =  1702
# Iteração =  1703
# Iteração =  1704
# Iteração =  1705
# Iteração =  1706
# Iteração =  1707
# Iteração =  1708
# Iteração =  1709
# Iteração =  1710
# Iteração =  1711
# Iteração =  1712
# Iteração =  1713
# Iteração =  1714
# Iteração =  1715
# Iteração =  1716
# Iteração =  1717
# Iteração =  1718
# Iteração =  1719
# Iteração =  1720
# Iteração =  1721
# Iteração =  1722
# Iteração =  1723
# Iteração =  1724
# Iteração =  1725
# Iteração =  1726
# Iteração =  1727
# Iteração =  1728
# Iteração =  1729
# Iteração =  1730
# Iteração =  1731
# Iteração =  1732
# Iteração =  1733
# Iteração =  1734
# Iteração =  1735
# Iteração =  1736
# Iteração =  1737
# Iteração =  1738
# Iteração =  1739
# Iteração =  1740
# Iteração =  1741
# Iteração =  1742
# Iteração =  1743
# Iteração =  1744
# Iteração =  1745
# Iteração =  1746
# Iteração =  1747
# Iteração =  1748
# Iteração =  1749
# Iteração =  1750
# Iteração =  1751
# Iteração =  1752
# Iteração =  1753
# Iteração =  1754
# Iteração =  1755
# Iteração =  1756
# Iteração =  1757
# Iteração =  1758
# Iteração =  1759
# Iteração =  1760
# Iteração =  1761
# Iteração =  1762
# Iteração =  1763
# Iteração =  1764
# Iteração =  1765
# Iteração =  1766
# Iteração =  1767
# Iteração =  1768
# Iteração =  1769
# Iteração =  1770
# Iteração =  1771
# Iteração =  1772
# Iteração =  1773
# Iteração =  1774
# Iteração =  1775
# Iteração =  1776
# Iteração =  1777
# Iteração =  1778
# Iteração =  1779
# Iteração =  1780
# Iteração =  1781
# Iteração =  1782
# Iteração =  1783
# Iteração =  1784
# Iteração =  1785
# Iteração =  1786
# Iteração =  1787
# Iteração =  1788
# Iteração =  1789
# Iteração =  1790
# Iteração =  1791
# Iteração =  1792
# Iteração =  1793
# Iteração =  1794
# Iteração =  1795
# Iteração =  1796
# Iteração =  1797
# Iteração =  1798
# Iteração =  1799
# Iteração =  1800
# Iteração =  1801
# Iteração =  1802
# Iteração =  1803
# Iteração =  1804
# Iteração =  1805
# Iteração =  1806
# Iteração =  1807
# Iteração =  1808
# Iteração =  1809
# Iteração =  1810
# Iteração =  1811
# Iteração =  1812
# Iteração =  1813
# Iteração =  1814
# Iteração =  1815
# Iteração =  1816
# Iteração =  1817
# Iteração =  1818
# Iteração =  1819
# Iteração =  1820
# Iteração =  1821
# Iteração =  1822
# Iteração =  1823
# Iteração =  1824
# Iteração =  1825
# Iteração =  1826
# Iteração =  1827
# Iteração =  1828
# Iteração =  1829
# Iteração =  1830
# Iteração =  1831
# Iteração =  1832
# Iteração =  1833
# Iteração =  1834
# Iteração =  1835
# Iteração =  1836
# Iteração =  1837
# Iteração =  1838
# Iteração =  1839
# Iteração =  1840
# Iteração =  1841
# Iteração =  1842
# Iteração =  1843
# Iteração =  1844
# Iteração =  1845
# Iteração =  1846
# Iteração =  1847
# Iteração =  1848
# Iteração =  1849
# Iteração =  1850
# Iteração =  1851
# Iteração =  1852
# Iteração =  1853
# Iteração =  1854
# Iteração =  1855
# Iteração =  1856
# Iteração =  1857
# Iteração =  1858
# Iteração =  1859
# Iteração =  1860
# Iteração =  1861
# Iteração =  1862
# Iteração =  1863
# Iteração =  1864
# Iteração =  1865
# Iteração =  1866
# Iteração =  1867
# Iteração =  1868
# Iteração =  1869
# Iteração =  1870
# Iteração =  1871
# Iteração =  1872
# Iteração =  1873
# Iteração =  1874
# Iteração =  1875
# Iteração =  1876
# Iteração =  1877
# Iteração =  1878
# Iteração =  1879
# Iteração =  1880
# Iteração =  1881
# Iteração =  1882
# Iteração =  1883
# Iteração =  1884
# Iteração =  1885
# Iteração =  1886
# Iteração =  1887
# Iteração =  1888
# Iteração =  1889
# Iteração =  1890
# Iteração =  1891
# Iteração =  1892
# Iteração =  1893
# Iteração =  1894
# Iteração =  1895
# Iteração =  1896
# Iteração =  1897
# Iteração =  1898
# Iteração =  1899
# Iteração =  1900
# Iteração =  1901
# Iteração =  1902
# Iteração =  1903
# Iteração =  1904
# Iteração =  1905
# Iteração =  1906
# Iteração =  1907
# Iteração =  1908
# Iteração =  1909
# Iteração =  1910
# Iteração =  1911
# Iteração =  1912
# Iteração =  1913
# Iteração =  1914
# Iteração =  1915
# Iteração =  1916
# Iteração =  1917
# Iteração =  1918
# Iteração =  1919
# Iteração =  1920
# Iteração =  1921
# Iteração =  1922
# Iteração =  1923
# Iteração =  1924
# Iteração =  1925
# Iteração =  1926
# Iteração =  1927
# Iteração =  1928
# Iteração =  1929
# Iteração =  1930
# Iteração =  1931
# Iteração =  1932
# Iteração =  1933
# Iteração =  1934
# Iteração =  1935
# Iteração =  1936
# Iteração =  1937
# Iteração =  1938
# Iteração =  1939
# Iteração =  1940
# Iteração =  1941
# Iteração =  1942
# Iteração =  1943
# Iteração =  1944
# Iteração =  1945
# Iteração =  1946
# Iteração =  1947
# Iteração =  1948
# Iteração =  1949
# Iteração =  1950
# Iteração =  1951
# Iteração =  1952
# Iteração =  1953
# Iteração =  1954
# Iteração =  1955
# Iteração =  1956
# Iteração =  1957
# Iteração =  1958
# Iteração =  1959
# Iteração =  1960
# Iteração =  1961
# Iteração =  1962
# Iteração =  1963
# Iteração =  1964
# Iteração =  1965
# Iteração =  1966
# Iteração =  1967
# Iteração =  1968
# Iteração =  1969
# Iteração =  1970
# Iteração =  1971
# Iteração =  1972
# Iteração =  1973
# Iteração =  1974
# Iteração =  1975
# Iteração =  1976
# Iteração =  1977
# Iteração =  1978
# Iteração =  1979
# Iteração =  1980
# Iteração =  1981
# Iteração =  1982
# Iteração =  1983
# Iteração =  1984
# Iteração =  1985
# Iteração =  1986
# Iteração =  1987
# Iteração =  1988
# Iteração =  1989
# Iteração =  1990
# Iteração =  1991
# Iteração =  1992
# Iteração =  1993
# Iteração =  1994
# Iteração =  1995
# Iteração =  1996
# Iteração =  1997
# Iteração =  1998
# Iteração =  1999

# %% [markdown]
# ## Gráficos - Avaliação da defasagem
#
# Conforme o livro, introdução à computação quântica de Thomas Wong (2022), a defasagem apresentada por um sistema quântico não tem significado físico se for a mesma para todo o sistema, ou seja, todas as componentes devem ter a mesma diferença de fases. Para realizar essa avaliação, se faz necessário propor uma diferença entre a curva original e o destino, tanto na parte real quanto imaginária, além de realizar a diferença entre essas partes.

# %%
ts = np.linspace(0, 20, 2000) # Tempo em x 

RealO = [ele.real for ele in Resp[0]] 
ImagO = [ele.imag for ele in Resp[0]] 

sup = []
for i in range(0, 2000):
    sup.append(1/np.sqrt(2)*np.exp(-1*complex(0,1)*(1/2*np.pi)*i/100))
RealS = [ele.real for ele in sup]
ImagS = [ele.imag for ele in sup]

sub = []
for i in range(0, 2000):
    sub.append(abs(Resp[0][i] - sup[i]))

# Plotagem
plt.ylabel('Real') 
plt.xlabel('Tempo') 
plt.plot(ts, RealO, color='r', marker='*', linewidth=1, markersize=1)
plt.plot(ts, RealS, color='b', marker='o',  linewidth=1, markersize=1)
plt.savefig('rk_otimo1.png', format='png')
plt.show()

# %%
plt.ylabel('Imaginário') 
plt.xlabel('Tempo') 
plt.plot(ts, ImagO, color='r', marker='*', linewidth=1, markersize=1)
plt.plot(ts, ImagS, color='b', marker='o',  linewidth=1, markersize=1)
plt.savefig('rk_otimo2.png', format='png')
plt.show()

# %%
ts = np.linspace(0, 20, 2000) # Tempo em x 

RealO = [ele.real for ele in Resp[1]] 
ImagO = [ele.imag for ele in Resp[1]] 

sup = []
for i in range(0, 2000):
    sup.append(1/np.sqrt(2)*np.exp(-3*complex(0,1)*(1/2*np.pi)*i/100))
RealS = [ele.real for ele in sup]
ImagS = [ele.imag for ele in sup]

subr = []
for i in range(0, 2000):
    subr.append(abs(Resp[1][i] - sup[i]))

# Plotagem
plt.ylabel('Real') 
plt.xlabel('Tempo') 
plt.plot(ts, RealO, color='r', marker='*', linewidth=1, markersize=1)
plt.plot(ts, RealS, color='b', marker='o',  linewidth=1, markersize=1)
plt.savefig('rk_otimo3.png', format='png')
plt.show()

# %%
plt.ylabel('Imaginário') 
plt.xlabel('Tempo') 
plt.plot(ts, ImagO, color='r', marker='*', linewidth=1, markersize=1)
plt.plot(ts, ImagS, color='b', marker='o',  linewidth=1, markersize=1)
plt.savefig('rk_otimo4.png', format='png')
plt.show()

# %%
plt.ylabel('Defasagens') 
plt.xlabel('Tempo') 
plt.plot(ts, sub, color='y', marker='o',  linewidth=1, markersize=1)
plt.plot(ts, subr, color='m', marker='o',  linewidth=1, markersize=1)
plt.savefig('phases.png', format='png')
plt.show()

# %% [markdown]
# #### Valor da defasagem

# %%
print(subr[999])
# Out:
# 0.09416746719735627

# %% [markdown]
# ## Gráficos - Avaliação das constantes da função de onda
#
# Outra interpretação pertinente é a obtenção das constantes de onda, pois o objetivo inicial da pesquisa é sair de uma constante e chegar em um estado de forma que estas estajam em total equilíbrio. Para realizar a plotagem com os diversos números complexos se faz o uso do número absoluto que para o estudo do conjunto complexo representa o seu tamanho, dessa forma, é possível indentificar se o estado inicial alcançou o final desejado.

# %%
ts = np.linspace(0, 20, 2000) # Tempo em x 
const = []
for i in range(0, 2000):
    const.append(1/np.sqrt(2))

# Plotagem
plt.ylabel('Constantes') 
plt.xlabel('Tempo') 
plt.plot(ts, abs(Constantes[0]), color='r', marker='*', linewidth=1, markersize=1)
plt.plot(ts, abs(Constantes[1]), color='b', marker='o',  linewidth=1, markersize=1)
plt.plot(ts, const, color='g', marker='o',  linewidth=1, markersize=1)
plt.savefig('const.png', format='png')
plt.show()

# %% [markdown]
# ## Gráficos - Avaliação da densidade de probabilidade para encontrar uma partícula no ponto x
#
# Conforme descrito durante os capítulos 1, 2 e 3 do livro Mecânica Quântica por David Griffths, a estatística é um dos principais pontos para o entendimento da mecânica quântica, dessa forma é interessante entender qual é a probabilidade de uma partícula estar em um determinado lugar em um certo tempo e para tal se define:$$\int |\Psi(x,t)|^{2}dx = 1$$ Ainda nessa perspectiva, foi definido que o resultado da equação de Schrödinger pode ser definido a partir da escolha do potêncial V(x,t) e ainda que os enumeros resultados podem formar outros por meio de uma combinação linear de forma que o conjunto do quadrado das constantes que o formam, em sua soma resultam em 1. Isso define a probabilidade de um estado. Para este estudo considerou-se dois estados: $$0.80\psi_0(x,t)+0.60\psi_1(x,t)$$ de forma que para o primeiro estado a probabilidade é de 64% enquanto para o segundo é de 36%.
#
# Se torna claro que a probabilidade total deve ser 1 e definindo o produto interno como $\int |\Psi(x,t)|^{2}dx = <\Psi | \Psi> = 1 = \sum_n |c_n|²$ podemos verificar se o ajuste da pesquisa está correto avaliando as constantes que são alteradas conforme o tempo de acordo com o gráfico apresentado acima.

# %%
# Plotagem

dp = []
for i in range(0, 2000):
    dp.append((abs(Constantes[0][i])**2+abs(Constantes[1][i])**2))
    
plt.ylabel('Densidade probabilidade') 
plt.xlabel('Tempo') 
plt.plot(ts, dp, color='r', marker='*', linewidth=1, markersize=1)
plt.savefig('dp.png', format='png')
plt.show()

# %%
print(dp)
# Out:
# [1.0, 0.9999999998739056, 0.9999999997767879, 0.9999999996892373, 0.9999999996050919, 0.9999999995224398, 0.9999999994399789, 0.9999999993577906, 0.9999999992758778, 0.9999999991941912, 0.9999999991126589, 0.9999999990312098, 0.9999999989497859, 0.999999998868351, 0.9999999987868902, 0.9999999987054056, 0.9999999986239101, 0.9999999985424209, 0.9999999984609542, 0.9999999983795237, 0.999999998298136, 0.9999999982167944, 0.9999999981354972, 0.9999999980542421, 0.9999999979730249, 0.9999999978918415, 0.9999999978106895, 0.9999999977295673, 0.9999999976484741, 0.99999999756741, 0.9999999974863756, 0.9999999974053709, 0.9999999973243963, 0.9999999972434523, 0.9999999971625384, 0.9999999970816545, 0.9999999970007991, 0.9999999969199724, 0.9999999968391728, 0.9999999967584006, 0.9999999966776538, 0.9999999965969326, 0.9999999965162352, 0.9999999964355617, 0.9999999963549111, 0.9999999962742825, 0.9999999961936751, 0.9999999961130881, 0.99999999603252, 0.999999995951971, 0.999999995871439, 0.9999999957909232, 0.9999999957104231, 0.9999999956299375, 0.9999999955494648, 0.9999999954690044, 0.9999999953885554, 0.9999999953081165, 0.9999999952276862, 0.9999999951472645, 0.9999999950668494, 0.9999999949864398, 0.9999999949060348, 0.9999999948256328, 0.9999999947452334, 0.9999999946648351, 0.9999999945844371, 0.9999999945040385, 0.9999999944236372, 0.9999999943432327, 0.9999999942628242, 0.9999999941824105, 0.9999999941019897, 0.9999999940215623, 0.9999999939411264, 0.9999999938606808, 0.9999999937802252, 0.9999999936997586, 0.9999999936192792, 0.9999999935387872, 0.999999993458281, 0.9999999933777601, 0.9999999932972241, 0.9999999932166718, 0.9999999931361019, 0.9999999930555146, 0.9999999929749088, 0.9999999928942844, 0.9999999928136407, 0.9999999927329766, 0.9999999926522922, 0.9999999925715868, 0.9999999924908598, 0.9999999924101328, 0.9999999923293721, 0.9999999922486117, 0.9999999921678039, 0.9999999920869966, 0.999999992006189, 0.9999999919253084, 0.9999999918444277, 0.999999991763547, 0.999999991682412, 0.9999999916013051, 0.9999999915202348, 0.9999999914391953, 0.9999999913581555, 0.9999999912771225, 0.9999999911960897, 0.999999991115029, 0.9999999910339343, 0.9999999909528048, 0.9999999908716426, 0.9999999907904529, 0.9999999907092406, 0.99999999062801, 0.9999999905467651, 0.9999999904655064, 0.9999999903842356, 0.9999999903029526, 0.9999999902216583, 0.9999999901403527, 0.9999999900590357, 0.9999999899777081, 0.9999999898963713, 0.999999989815026, 0.999999989733674, 0.9999999896523161, 0.999999989570954, 0.9999999894895888, 0.9999999894082221, 0.9999999893268543, 0.9999999892454876, 0.9999999891641236, 0.9999999890827627, 0.9999999890014073, 0.9999999889200581, 0.999999988838717, 0.9999999887573854, 0.9999999886760644, 0.9999999885947559, 0.9999999885134614, 0.9999999884321826, 0.9999999883509205, 0.9999999882696771, 0.9999999881884534, 0.9999999881072514, 0.9999999880260726, 0.9999999879449184, 0.9999999878637902, 0.9999999877826896, 0.9999999877016186, 0.9999999876205781, 0.9999999875395691, 0.9999999874585951, 0.9999999873776555, 0.9999999872967527, 0.9999999872158885, 0.9999999871350632, 0.9999999870542793, 0.9999999869735369, 0.999999986892839, 0.9999999868121856, 0.9999999867315785, 0.999999986651019, 0.9999999865705088, 0.9999999864900483, 0.9999999864096387, 0.9999999863292821, 0.9999999862489783, 0.9999999861687294, 0.9999999860885359, 0.999999986008399, 0.9999999859283195, 0.9999999858482977, 0.9999999857683359, 0.9999999856884338, 0.9999999856085928, 0.9999999855288135, 0.9999999854490964, 0.999999985369442, 0.999999985289851, 0.9999999852103245, 0.9999999851308621, 0.9999999850514646, 0.999999984972133, 0.9999999848928666, 0.9999999848136663, 0.9999999847344657, 0.9999999846553681, 0.9999999845762702, 0.9999999844971722, 0.9999999844182703, 0.9999999843393681, 0.9999999842604659, 0.9999999841823095, 0.999999984104077, 0.9999999840258444, 0.9999999839476121, 0.9999999838693797, 0.9999999837911473, 0.9999999837129152,  ...

# %% [markdown]
# ## Organização e gráfico da função objetivo
#
# Nessa etapa do trabalho se torna importante verificar como a função objetivo está se comportando durante o projeto. Além disso, nessa seção, organiza-se algumas informações relevantes acerca do trabalho.

# %%
ts = np.linspace(0, 20, 2000) # Tempo em x 

teste = np.zeros((2, 2000), dtype=np.complex_)
for i in range(0, 2000):
    teste[0][i] = (1/np.sqrt(2)*np.exp(-1*complex(0,1)*(1/2*np.pi)*i/100))

# Plotagem
plt.ylabel('Gráficos') 
plt.xlabel('Tempo') 
plt.plot(ts, abs(Resp[1]), color='g', marker='*', linewidth=1, markersize=1)
plt.plot(ts, abs(teste[0]), color='b', marker='o',  linewidth=1, markersize=1)
plt.savefig('abs2.png', format='png')
plt.show()

# %%
ts = np.linspace(0, 20, 2000) # Tempo em x 

teste = np.zeros((2, 2000), dtype=np.complex_)
for i in range(0, 2000):
    teste[0][i] = (1/np.sqrt(2)*np.exp(-1*complex(0,1)*(1/2*np.pi)*i/100))

# Plotagem
plt.ylabel('Gráficos') 
plt.xlabel('Tempo') 
plt.plot(ts, abs(Resp[0]), color='g', marker='*', linewidth=1, markersize=1)
plt.plot(ts, abs(teste[0]), color='b', marker='o',  linewidth=1, markersize=1)
plt.savefig('abs1.png', format='png')
plt.show()

# %%
ts = np.linspace(0, 20, 2000) # Tempo em x 

teste = np.zeros((2, 2000), dtype=np.complex_)
for i in range(0, 2000):
    teste[0][i] = (1/np.sqrt(2)*np.exp(-1*complex(0,1)*(3/2*np.pi)*i/100))
    
def zero_to_nan(values):
    return [float('nan') if x==0 else x for x in values]

# Plotagem
plt.ylabel('Gráficos') 
plt.xlabel('Tempo') 
plt.plot(ts, zero_to_nan(abs(Pico[0])), color='r', marker='o', linewidth=1, markersize=5)
plt.plot(ts, zero_to_nan(abs(Pico[1])), color='g', marker='o', linewidth=1, markersize=5)
plt.plot(ts, abs(teste[0]), color='b', marker='o',  linewidth=1, markersize=1)

plt.savefig('pico.png', format='png')
plt.show()

# %%
ts = np.linspace(0, 20, 2000) # Tempo em x 

# Plotagem
plt.ylabel('Gráficos') 
plt.xlabel('Tempo') 
plt.plot(ts, abs(Obj[0]), color='g', marker='o', linewidth=1, markersize=1)
plt.savefig('obj.png', format='png')
plt.show()
