# %% [markdown]
# ## Algoritmo Genético
#
# No jupyter anterior utilizamos o algoritmo Gradiente Decrescente para otimizar a função objetivo, afim de comparações, dessa vez utilizaremos um algoritmo genético.

# %%
from random import randint, uniform, random
from tqdm import tqdm
import numpy as np

# %%
# Manipulação das matrizes

def somar(A, B):
    C = []
    nLinhasA, nLinhasB = len(A), len(B)
    nColA, nColB = len(A[0]), len(B[0])
    
    for i in range (nLinhasA):
        linha = [0]*nColA
        C.append(linha)
        for j in range(nColA):
            C[i][j] = A[i][j] + B[i][j]

    return C

def sub(A, B):
    C = []
    nLinhasA, nLinhasB = len(A), len(B)
    nColA, nColB = len(A[0]), len(B[0])
    
    for i in range (nLinhasA):
        linha = [0]*nColA
        C.append(linha)
        for j in range(nColA):
            C[i][j] = A[i][j] - B[i][j]

    return C


#################################################################

## d (psi) / dt = -i * H * |psi>
def dpsidt(t, psi, H): # A derivada da onda em relação ao tempo não tem dependência temporal
    A = np.zeros((2,2), dtype=np.complex_)
    A = np.dot(complex(0,1),H) # i * H
    return -1*np.matmul(A,psi) # - i * H * |psi>

# Runge-Kutta de quarta ordem

def rungeKutta(onda, fatorRungeKutta, hamiltoniano, tempoFinal = 2, tempoInicial = 0):
    
    resultado = np.zeros((2,2), dtype=np.complex_)
    indice = 0

    for i in range(0, 2):
        
        resultado[0][indice] = onda[0][0]
        resultado[1][indice] = onda[1][0]
        
        k1 = dpsidt(tempoInicial, onda, hamiltoniano)
        k2 = dpsidt(tempoInicial + 0.5 * fatorRungeKutta, somar(onda, np.dot((0.5*fatorRungeKutta), k1)), hamiltoniano)
        k3 = dpsidt(tempoInicial + 0.5 * fatorRungeKutta, somar(onda, np.dot((0.5*fatorRungeKutta), k2)), hamiltoniano)
        k4 = dpsidt(tempoInicial + fatorRungeKutta, somar(onda, np.dot(fatorRungeKutta, k3)), hamiltoniano)
        
        ## y(i+1) = y(i) + h/6*(k1+2*k2+2*k3+k4)
        
        A = somar(np.dot(2,k3), k4)
        B = somar(np.dot(2,k2), k1)
        C = somar(A, B)
 
        onda = somar(onda,np.dot((fatorRungeKutta / 6.0),(C)))
    
        tempoInicial += fatorRungeKutta
        
        indice += 1
        
    runge = np.zeros((2,1), dtype=np.complex_)
    runge[0][0] = resultado[0][indice-1]
    runge[1][0] = resultado[1][indice-1]
    return runge

def funcaoObjetivo(x, iteracao, ondaDestino, hamiltoniano, onda, horizonteAnalisavel, fatorRungeKutta, tempoAnalise):
    
    avanco = np.zeros((2,1),dtype=np.complex_)
    
    y = 0
    
    horizonte = (horizonteAnalisavel+iteracao)/100
    
    tempo = iteracao/100
    
    tempoInicialAnalise = 0.00
    tempoFinalAnalise = 0.02
    
    controles = np.zeros((2,2), dtype=np.complex_)
    controles = [[0, x[0]], [x[0], 0]]
    
    matrizOrigem = np.zeros((2,1),dtype=np.complex_)
    matrizOrigem = [[onda[0][0]], [onda[1][0]]] 

    matrizDestino = np.zeros((2,1),dtype=np.complex_)
    
    ## Função-Objetivo (Return) = somatorio ||(Matriz_Origem - Matriz_Destino)||^2
    
    ## Avanço temporal
    
    matrizDestino[0][0] = ondaDestino[0][0]*np.exp(-1*complex(0,1)*(1/2*np.pi)*tempo)
    matrizDestino[1][0] = ondaDestino[1][0]*np.exp(-1*complex(0,1)*(3/2*np.pi)*tempo)

    y += (np.linalg.norm(matrizOrigem-matrizDestino))**2

    avanco = rungeKutta(matrizOrigem, fatorRungeKutta, somar(hamiltoniano, controles), tempoFinal = tempoFinalAnalise, tempoInicial = tempoInicialAnalise)

    matrizOrigem = avanco

    tempoInicialAnalise += 0.01
    tempoFinalAnalise += 0.01
    
    for indice in range((iteracao+1), (horizonteAnalisavel+iteracao)):
        tempo = indice/100
        
        matrizDestino[0][0] = ondaDestino[0][0]*np.exp(-1*complex(0,1)*(1/2*np.pi)*tempo)
        matrizDestino[1][0] = ondaDestino[1][0]*np.exp(-1*complex(0,1)*(3/2*np.pi)*tempo)
        
        y += (np.linalg.norm(matrizOrigem-matrizDestino))**2
        
        controles = [[0, x[int(tempoInicialAnalise*100)]], [x[int(tempoInicialAnalise*100)], 0]]

        avanco = rungeKutta(matrizOrigem, fatorRungeKutta, somar(hamiltoniano, controles), tempoFinal = tempoFinalAnalise, tempoInicial = tempoInicialAnalise)

        matrizOrigem = avanco

        tempoInicialAnalise += 0.01
        tempoFinalAnalise += 0.01
    
    return y

# %%
import matplotlib.pyplot as plt

# %%
import random
import numpy as np
from deap import algorithms, base, creator, tools

hamiltoniano = np.zeros((2,2), dtype=np.complex_) # Hamiltoniano
A = (1/2*np.pi)
B = (3/2*np.pi)
hamiltoniano = [[A, 0], [0, B]]
fatorRungeKutta = 0.01

iteracao = 0
fatorRungeKutta = 0.01
tempoAnalise = 2000
horizonte = 3

ondaOrigem = [[complex(1.0,0.0)],[complex(0.0,0.0)]]
ondaDestino = [[complex(1/np.sqrt(2),0)],[complex(1/np.sqrt(2),0)]]


def evaluate(individual, iteracao, ondaDestino, hamiltoniano, ondaOrigem, horizonteAnalisavel, fatorRungeKutta, tempoAnalise):
    teste = funcaoObjetivo(individual, iteracao, ondaDestino, hamiltoniano, ondaOrigem, horizonteAnalisavel, fatorRungeKutta, tempoAnalise)
    return teste.item(),

while iteracao < tempoAnalise:
    # Criando o objeto Fitness
    creator.create("FitnessMin", base.Fitness, weights=(-1.0,))

    # Criando o objeto Individual
    creator.create("Individual", list, fitness=creator.FitnessMin)

    # Criando o Toolbox
    toolbox = base.Toolbox()

    # Registrando o gerador de números aleatórios
    toolbox.register("attr_float", random.uniform, -5.0, 5.0)

    # Registrando o inicializador de indivíduos
    toolbox.register("individual", tools.initCycle, creator.Individual,
                     (toolbox.attr_float, toolbox.attr_float, toolbox.attr_float), n=1)

    # Registrando a população
    toolbox.register("population", tools.initRepeat, list, toolbox.individual)

    # Registrando a função objetivo
    toolbox.register("evaluate", evaluate, iteracao=iteracao, ondaDestino=ondaDestino , hamiltoniano=hamiltoniano , ondaOrigem=ondaOrigem , horizonteAnalisavel=horizonte, fatorRungeKutta=fatorRungeKutta, tempoAnalise=tempoAnalise)

    # Registrando os operadores genéticos
    toolbox.register("mate", tools.cxBlend, alpha=0.5)
    toolbox.register("mutate", tools.mutGaussian, mu=0.0, sigma=0.2, indpb=0.1)
    toolbox.register("select", tools.selTournament, tournsize=3)

    # Criando a população inicial
    pop = toolbox.population(n=50)

    # Avaliando a população inicial
    fitnesses = list(map(toolbox.evaluate, pop))
    for ind, fit in zip(pop, fitnesses):
        ind.fitness.values = fit

    # Executando o algoritmo genético
    for g in range(10):
        # Selecionando os indivíduos para cruzamento
        selected = toolbox.select(pop, len(pop))
        # Clonando os indivíduos selecionados
        offspring = [toolbox.clone(ind) for ind in selected]
        # Realizando o cruzamento e a mutação
        for child1, child2 in zip(offspring[::2], offspring[1::2]):
            if random.random() < 0.5:
                toolbox.mate(child1, child2)
            toolbox.mutate(child1)
            toolbox.mutate(child2)
            del child1.fitness.values, child2.fitness.values
        # Avaliando os novos indivíduos gerados
        invalid_ind = [ind for ind in offspring if not ind.fitness.valid]
        fitnesses = list(map(toolbox.evaluate, invalid_ind))
        for ind, fit in zip(invalid_ind, fitnesses):
            ind.fitness.values = fit
        # Substituindo a população antiga pela nova
        pop[:] = offspring

    # Exibindo o melhor indivíduo encontrado
    best_ind = tools.selBest(pop, 1)[0]
    print("Melhor solução encontrada: x1 = %.2f, x2 = %.2f, x3 = %.2f, f(x1,x2,x3) = %.2f" % (best_ind[0], best_ind[1], best_ind[2], best_ind.fitness.values[0]))
    
    controle = np.zeros((2,1), dtype=np.complex_)
    controle = [[0, sum(best_ind.fitness.values)],[sum(best_ind.fitness.values),0]]
    hamiltoniano = somar(hamiltoniano, controle)

    ondaAvancada = np.zeros((2,2), dtype=np.complex_)
    ondaAvancada = rungeKutta(ondaOrigem, fatorRungeKutta, hamiltoniano, tempoFinal = 0.02, tempoInicial = 0)

    ondaOrigem[0][0] = ondaAvancada[0][0]
    ondaOrigem[1][0] = ondaAvancada[1][0]

    A = (1/2*np.pi)
    B = (3/2*np.pi)
    hamiltoniano = [[A, 0], [0, B]]
    
    iteracao += 1
# Out:
# Melhor solução encontrada: x1 = -1.57, x2 = 6.30, x3 = 4.48, f(x1,x2,x3) = 1.76
# C:\Users\Gabriel\anaconda3\lib\site-packages\deap\creator.py:138: RuntimeWarning: A class named 'FitnessMin' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# C:\Users\Gabriel\anaconda3\lib\site-packages\deap\creator.py:138: RuntimeWarning: A class named 'Individual' has already been created and it will be overwritten. Consider deleting previous creation of that class or rename it.
#   warnings.warn("A class named '{0}' has already been created and it "
# Melhor solução encontrada: x1 = 0.13, x2 = 5.70, x3 = -10.94, f(x1,x2,x3) = 1.75
# Melhor solução encontrada: x1 = 1.40, x2 = 5.87, x3 = 3.40, f(x1,x2,x3) = 1.75
# Melhor solução encontrada: x1 = 2.56, x2 = 6.24, x3 = 6.60, f(x1,x2,x3) = 1.75
# Melhor solução encontrada: x1 = 3.83, x2 = 6.48, x3 = 1.35, f(x1,x2,x3) = 1.74
# Melhor solução encontrada: x1 = 5.34, x2 = 6.12, x3 = 1.52, f(x1,x2,x3) = 1.73
# Melhor solução encontrada: x1 = 4.55, x2 = 6.20, x3 = -0.32, f(x1,x2,x3) = 1.72
# Melhor solução encontrada: x1 = 7.52, x2 = 6.10, x3 = -8.22, f(x1,x2,x3) = 1.71
# Melhor solução encontrada: x1 = 5.88, x2 = 9.64, x3 = -2.67, f(x1,x2,x3) = 1.70
# Melhor solução encontrada: x1 = 7.93, x2 = 6.58, x3 = -6.99, f(x1,x2,x3) = 1.69
# Melhor solução encontrada: x1 = 12.94, x2 = 4.04, x3 = -0.81, f(x1,x2,x3) = 1.67
# Melhor solução encontrada: x1 = 6.01, x2 = 6.78, x3 = -3.32, f(x1,x2,x3) = 1.66
# Melhor solução encontrada: x1 = 6.46, x2 = 9.21, x3 = -7.53, f(x1,x2,x3) = 1.65
# Melhor solução encontrada: x1 = 8.16, x2 = 4.12, x3 = -1.27, f(x1,x2,x3) = 1.63
# Melhor solução encontrada: x1 = 7.37, x2 = 10.84, x3 = -2.93, f(x1,x2,x3) = 1.61
# Melhor solução encontrada: x1 = 5.23, x2 = 8.30, x3 = -12.57, f(x1,x2,x3) = 1.60
# Melhor solução encontrada: x1 = 9.69, x2 = 6.99, x3 = 1.28, f(x1,x2,x3) = 1.57
# Melhor solução encontrada: x1 = 5.16, x2 = 6.78, x3 = -3.28, f(x1,x2,x3) = 1.57
# Melhor solução encontrada: x1 = 7.06, x2 = 10.59, x3 = 2.10, f(x1,x2,x3) = 1.54
# Melhor solução encontrada: x1 = 5.86, x2 = 9.80, x3 = 0.37, f(x1,x2,x3) = 1.53
# Melhor solução encontrada: x1 = 5.81, x2 = 8.04, x3 = 2.72, f(x1,x2,x3) = 1.51
# Melhor solução encontrada: x1 = 6.17, x2 = 14.91, x3 = 0.49, f(x1,x2,x3) = 1.48
# Melhor solução encontrada: x1 = 11.01, x2 = 4.75, x3 = 0.50, f(x1,x2,x3) = 1.45
# Melhor solução encontrada: x1 = 8.96, x2 = 7.32, x3 = -2.77, f(x1,x2,x3) = 1.43
# Melhor solução encontrada: x1 = 9.56, x2 = 7.40, x3 = 1.93, f(x1,x2,x3) = 1.41
# Melhor solução encontrada: x1 = 7.84, x2 = 4.92, x3 = -1.63, f(x1,x2,x3) = 1.40
# Melhor solução encontrada: x1 = 5.86, x2 = 10.25, x3 = -9.77, f(x1,x2,x3) = 1.38
# Melhor solução encontrada: x1 = 7.30, x2 = 7.24, x3 = -4.04, f(x1,x2,x3) = 1.36
# Melhor solução encontrada: x1 = 5.02, x2 = 4.78, x3 = 3.10, f(x1,x2,x3) = 1.36
# Melhor solução encontrada: x1 = 17.87, x2 = 14.47, x3 = -1.49, f(x1,x2,x3) = 1.25
# Melhor solução encontrada: x1 = 5.32, x2 = 13.98, x3 = 2.62, f(x1,x2,x3) = 1.29
# Melhor solução encontrada: x1 = 7.62, x2 = 5.22, x3 = 15.59, f(x1,x2,x3) = 1.27
# Melhor solução encontrada: x1 = 6.09, x2 = 12.37, x3 = 2.61, f(x1,x2,x3) = 1.24
# Melhor solução encontrada: x1 = 7.85, x2 = 7.32, x3 = 0.34, f(x1,x2,x3) = 1.22
# Melhor solução encontrada: x1 = 6.00, x2 = 10.89, x3 = 0.67, f(x1,x2,x3) = 1.20
# Melhor solução encontrada: x1 = 5.25, x2 = 6.31, x3 = 2.80, f(x1,x2,x3) = 1.20
# Melhor solução encontrada: x1 = 5.94, x2 = 8.37, x3 = -2.66, f(x1,x2,x3) = 1.17
# Melhor solução encontrada: x1 = 7.16, x2 = 7.89, x3 = 0.16, f(x1,x2,x3) = 1.14
# Melhor solução encontrada: x1 = 8.28, x2 = 3.74, x3 = 5.69, f(x1,x2,x3) = 1.12
# Melhor solução encontrada: x1 = 9.46, x2 = 6.78, x3 = -1.73, f(x1,x2,x3) = 1.08
# Melhor solução encontrada: x1 = 9.49, x2 = 9.43, x3 = -3.31, f(x1,x2,x3) = 1.05
# Melhor solução encontrada: x1 = 10.65, x2 = 14.03, x3 = 3.41, f(x1,x2,x3) = 1.01
# Melhor solução encontrada: x1 = 7.07, x2 = 10.86, x3 = 5.21, f(x1,x2,x3) = 1.02
# Melhor solução encontrada: x1 = 5.59, x2 = 4.48, x3 = -1.02, f(x1,x2,x3) = 1.04
# Melhor solução encontrada: x1 = 7.70, x2 = 8.51, x3 = -0.66, f(x1,x2,x3) = 0.99
# Melhor solução encontrada: x1 = 7.29, x2 = 9.91, x3 = 1.15, f(x1,x2,x3) = 0.97
# Melhor solução encontrada: x1 = 8.80, x2 = 9.23, x3 = -3.43, f(x1,x2,x3) = 0.94
# Melhor solução encontrada: x1 = 7.15, x2 = 6.62, x3 = 0.89, f(x1,x2,x3) = 0.95
# Melhor solução encontrada: x1 = 4.91, x2 = 6.78, x3 = 0.44, f(x1,x2,x3) = 0.95
# Melhor solução encontrada: x1 = 8.56, x2 = 4.41, x3 = 1.19, f(x1,x2,x3) = 0.91
# Melhor solução encontrada: x1 = 10.76, x2 = 6.60, x3 = 4.82, f(x1,x2,x3) = 0.86
# Melhor solução encontrada: x1 = 6.37, x2 = 9.96, x3 = -8.15, f(x1,x2,x3) = 0.87
# Melhor solução encontrada: x1 = 6.79, x2 = 8.97, x3 = -0.87, f(x1,x2,x3) = 0.85
# Melhor solução encontrada: x1 = 5.33, x2 = 5.35, x3 = 2.53, f(x1,x2,x3) = 0.87
# Melhor solução encontrada: x1 = 7.96, x2 = 9.10, x3 = 3.09, f(x1,x2,x3) = 0.81
# Melhor solução encontrada: x1 = 8.12, x2 = 7.11, x3 = 6.22, f(x1,x2,x3) = 0.80
# Melhor solução encontrada: x1 = 6.89, x2 = 7.51, x3 = -2.22, f(x1,x2,x3) = 0.80
# Melhor solução encontrada: x1 = 7.40, x2 = 7.41, x3 = -1.05, f(x1,x2,x3) = 0.78
# Melhor solução encontrada: x1 = 6.88, x2 = 6.20, x3 = 0.51, f(x1,x2,x3) = 0.78
# Melhor solução encontrada: x1 = 7.17, x2 = 6.22, x3 = -0.16, f(x1,x2,x3) = 0.76
# Melhor solução encontrada: x1 = 5.73, x2 = 5.23, x3 = 3.31, f(x1,x2,x3) = 0.77
# Melhor solução encontrada: x1 = 6.63, x2 = 11.24, x3 = 1.33, f(x1,x2,x3) = 0.72
# Melhor solução encontrada: x1 = 8.74, x2 = 11.06, x3 = 1.59, f(x1,x2,x3) = 0.70
# Melhor solução encontrada: x1 = 8.66, x2 = 16.21, x3 = 0.65, f(x1,x2,x3) = 0.68
# Melhor solução encontrada: x1 = 5.28, x2 = 10.71, x3 = -4.12, f(x1,x2,x3) = 0.71
# Melhor solução encontrada: x1 = 6.84, x2 = 6.18, x3 = -14.16, f(x1,x2,x3) = 0.70
# Melhor solução encontrada: x1 = 5.76, x2 = 7.61, x3 = -2.01, f(x1,x2,x3) = 0.69
# Melhor solução encontrada: x1 = 5.47, x2 = 7.90, x3 = 0.13, f(x1,x2,x3) = 0.68
# Melhor solução encontrada: x1 = 7.83, x2 = 5.59, x3 = 1.82, f(x1,x2,x3) = 0.66
# Melhor solução encontrada: x1 = 9.70, x2 = 7.81, x3 = -2.62, f(x1,x2,x3) = 0.64
# Melhor solução encontrada: x1 = 6.39, x2 = 12.19, x3 = -2.29, f(x1,x2,x3) = 0.64
# Melhor solução encontrada: x1 = 7.20, x2 = 6.10, x3 = -3.75, f(x1,x2,x3) = 0.64
# Melhor solução encontrada: x1 = 7.72, x2 = 8.20, x3 = 3.71, f(x1,x2,x3) = 0.63
# Melhor solução encontrada: x1 = 7.60, x2 = 9.40, x3 = -0.65, f(x1,x2,x3) = 0.62
# Melhor solução encontrada: x1 = 8.09, x2 = 9.90, x3 = 5.10, f(x1,x2,x3) = 0.61
# Melhor solução encontrada: x1 = 6.76, x2 = 5.97, x3 = -2.32, f(x1,x2,x3) = 0.62
# Melhor solução encontrada: x1 = 7.18, x2 = 12.39, x3 = 5.80, f(x1,x2,x3) = 0.61
# Melhor solução encontrada: x1 = 5.91, x2 = 8.33, x3 = -1.62, f(x1,x2,x3) = 0.61
# Melhor solução encontrada: x1 = 6.17, x2 = 13.84, x3 = -14.05, f(x1,x2,x3) = 0.60
# Melhor solução encontrada: x1 = 18.39, x2 = -0.60, x3 = -1.44, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 8.03, x2 = 4.94, x3 = -4.41, f(x1,x2,x3) = 0.60
# Melhor solução encontrada: x1 = 8.20, x2 = 4.48, x3 = 6.41, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = 10.47, x2 = 3.25, x3 = 0.33, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = 11.78, x2 = 3.85, x3 = -1.37, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 8.13, x2 = 5.85, x3 = -0.87, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = 7.55, x2 = 6.09, x3 = -3.35, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = 9.27, x2 = 4.67, x3 = 0.23, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = 7.02, x2 = 4.61, x3 = 5.83, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = 4.98, x2 = 5.21, x3 = -1.93, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = 9.54, x2 = 0.99, x3 = -0.20, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = 7.37, x2 = 2.81, x3 = 2.59, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = 6.20, x2 = 2.85, x3 = -0.81, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = 5.92, x2 = 0.69, x3 = -0.60, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = 6.39, x2 = -0.38, x3 = 4.36, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = 5.14, x2 = -0.78, x3 = -0.42, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = 4.29, x2 = -1.38, x3 = 3.06, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = 3.08, x2 = -1.46, x3 = 0.82, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = 1.77, x2 = -1.39, x3 = 0.47, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = 0.49, x2 = -1.38, x3 = 0.03, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = -0.79, x2 = -1.36, x3 = -1.62, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = -2.06, x2 = -1.38, x3 = -2.75, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = -3.12, x2 = -1.63, x3 = 0.36, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = -4.66, x2 = -1.35, x3 = -2.76, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = -5.97, x2 = -1.31, x3 = 3.64, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = -6.64, x2 = -2.47, x3 = -3.14, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = -8.19, x2 = -1.94, x3 = 5.84, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -8.77, x2 = -2.06, x3 = 0.51, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -6.63, x2 = -5.30, x3 = -0.56, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -7.82, x2 = -6.21, x3 = 2.83, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -6.57, x2 = -4.03, x3 = 3.79, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -5.95, x2 = -6.35, x3 = -0.58, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -7.55, x2 = -8.44, x3 = 3.14, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -7.21, x2 = -7.90, x3 = 1.30, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -6.44, x2 = -7.24, x3 = 0.66, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = -5.49, x2 = -7.94, x3 = 1.47, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = -7.14, x2 = -7.21, x3 = 3.67, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = -13.14, x2 = -9.31, x3 = -7.25, f(x1,x2,x3) = 0.57
# Melhor solução encontrada: x1 = -6.11, x2 = -9.04, x3 = 3.40, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = -7.45, x2 = -6.44, x3 = -0.20, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = -9.07, x2 = -8.23, x3 = -2.04, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = -7.76, x2 = -4.25, x3 = -1.05, f(x1,x2,x3) = 0.61
# Melhor solução encontrada: x1 = -17.35, x2 = -5.06, x3 = -0.50, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = -6.22, x2 = -8.84, x3 = -1.06, f(x1,x2,x3) = 0.61
# Melhor solução encontrada: x1 = -5.52, x2 = -9.17, x3 = 1.82, f(x1,x2,x3) = 0.62
# Melhor solução encontrada: x1 = -5.19, x2 = -6.94, x3 = 3.95, f(x1,x2,x3) = 0.64
# Melhor solução encontrada: x1 = -4.09, x2 = -7.69, x3 = 0.61, f(x1,x2,x3) = 0.66
# Melhor solução encontrada: x1 = -5.85, x2 = -10.53, x3 = -0.70, f(x1,x2,x3) = 0.64
# Melhor solução encontrada: x1 = -5.98, x2 = -7.80, x3 = 1.03, f(x1,x2,x3) = 0.66
# Melhor solução encontrada: x1 = -9.19, x2 = -6.08, x3 = -3.72, f(x1,x2,x3) = 0.64
# Melhor solução encontrada: x1 = -7.89, x2 = -4.52, x3 = 2.69, f(x1,x2,x3) = 0.67
# Melhor solução encontrada: x1 = -9.38, x2 = -8.96, x3 = -0.49, f(x1,x2,x3) = 0.65
# Melhor solução encontrada: x1 = -9.47, x2 = -10.23, x3 = 6.14, f(x1,x2,x3) = 0.65
# Melhor solução encontrada: x1 = -7.05, x2 = -8.68, x3 = -2.23, f(x1,x2,x3) = 0.69
# Melhor solução encontrada: x1 = -6.85, x2 = -9.08, x3 = -6.39, f(x1,x2,x3) = 0.70
# Melhor solução encontrada: x1 = -7.23, x2 = -9.30, x3 = 0.33, f(x1,x2,x3) = 0.71
# Melhor solução encontrada: x1 = -10.55, x2 = -5.35, x3 = 5.18, f(x1,x2,x3) = 0.70
# Melhor solução encontrada: x1 = -6.13, x2 = -5.26, x3 = -2.63, f(x1,x2,x3) = 0.77
# Melhor solução encontrada: x1 = -8.19, x2 = -3.46, x3 = -0.13, f(x1,x2,x3) = 0.77
# Melhor solução encontrada: x1 = -6.10, x2 = -9.54, x3 = -3.55, f(x1,x2,x3) = 0.78
# Melhor solução encontrada: x1 = -10.51, x2 = -7.57, x3 = -1.56, f(x1,x2,x3) = 0.75
# Melhor solução encontrada: x1 = -6.36, x2 = -7.57, x3 = -4.36, f(x1,x2,x3) = 0.82
# Melhor solução encontrada: x1 = -7.03, x2 = -4.53, x3 = 0.51, f(x1,x2,x3) = 0.84
# Melhor solução encontrada: x1 = -9.59, x2 = -10.39, x3 = 2.63, f(x1,x2,x3) = 0.80
# Melhor solução encontrada: x1 = -13.38, x2 = -5.06, x3 = 10.43, f(x1,x2,x3) = 0.80
# Melhor solução encontrada: x1 = -5.45, x2 = -18.85, x3 = 7.52, f(x1,x2,x3) = 0.84
# Melhor solução encontrada: x1 = -6.82, x2 = -7.24, x3 = -1.30, f(x1,x2,x3) = 0.91
# Melhor solução encontrada: x1 = -4.27, x2 = -7.27, x3 = -9.14, f(x1,x2,x3) = 0.97
# Melhor solução encontrada: x1 = -9.06, x2 = -7.36, x3 = -2.61, f(x1,x2,x3) = 0.92
# Melhor solução encontrada: x1 = -13.84, x2 = -4.29, x3 = -2.29, f(x1,x2,x3) = 0.90
# Melhor solução encontrada: x1 = -9.33, x2 = -8.75, x3 = -2.96, f(x1,x2,x3) = 0.95
# Melhor solução encontrada: x1 = -9.14, x2 = -9.82, x3 = -0.98, f(x1,x2,x3) = 0.97
# Melhor solução encontrada: x1 = -9.33, x2 = -5.92, x3 = 1.69, f(x1,x2,x3) = 1.02
# Melhor solução encontrada: x1 = -4.61, x2 = -9.21, x3 = 0.12, f(x1,x2,x3) = 1.10
# Melhor solução encontrada: x1 = -9.35, x2 = -13.49, x3 = -3.62, f(x1,x2,x3) = 1.03
# Melhor solução encontrada: x1 = -6.89, x2 = -9.70, x3 = 0.45, f(x1,x2,x3) = 1.12
# Melhor solução encontrada: x1 = -7.05, x2 = -12.03, x3 = -4.34, f(x1,x2,x3) = 1.13
# Melhor solução encontrada: x1 = -7.07, x2 = -9.69, x3 = 7.15, f(x1,x2,x3) = 1.18
# Melhor solução encontrada: x1 = -10.54, x2 = -9.95, x3 = 6.02, f(x1,x2,x3) = 1.15
# Melhor solução encontrada: x1 = -6.61, x2 = -8.26, x3 = 0.62, f(x1,x2,x3) = 1.26
# Melhor solução encontrada: x1 = -6.42, x2 = -10.04, x3 = 3.12, f(x1,x2,x3) = 1.29
# Melhor solução encontrada: x1 = -9.17, x2 = -11.70, x3 = 4.12, f(x1,x2,x3) = 1.27
# Melhor solução encontrada: x1 = -5.63, x2 = -5.79, x3 = -1.48, f(x1,x2,x3) = 1.41
# Melhor solução encontrada: x1 = -9.40, x2 = -10.45, x3 = -4.75, f(x1,x2,x3) = 1.35
# Melhor solução encontrada: x1 = -11.27, x2 = -13.20, x3 = -0.98, f(x1,x2,x3) = 1.35
# Melhor solução encontrada: x1 = -5.22, x2 = -7.70, x3 = -0.04, f(x1,x2,x3) = 1.52
# Melhor solução encontrada: x1 = -5.30, x2 = -4.66, x3 = 2.09, f(x1,x2,x3) = 1.59
# Melhor solução encontrada: x1 = -8.38, x2 = -10.03, x3 = -0.09, f(x1,x2,x3) = 1.54
# Melhor solução encontrada: x1 = -6.60, x2 = -7.65, x3 = -0.37, f(x1,x2,x3) = 1.64
# Melhor solução encontrada: x1 = -7.17, x2 = -11.86, x3 = -2.01, f(x1,x2,x3) = 1.65
# Melhor solução encontrada: x1 = -7.74, x2 = -6.77, x3 = -0.67, f(x1,x2,x3) = 1.73
# Melhor solução encontrada: x1 = -4.63, x2 = -8.17, x3 = -0.17, f(x1,x2,x3) = 1.82
# Melhor solução encontrada: x1 = -8.28, x2 = -12.47, x3 = -3.51, f(x1,x2,x3) = 1.78
# Melhor solução encontrada: x1 = -8.61, x2 = -6.80, x3 = 6.16, f(x1,x2,x3) = 1.88
# Melhor solução encontrada: x1 = -6.99, x2 = -5.12, x3 = -0.62, f(x1,x2,x3) = 1.98
# Melhor solução encontrada: x1 = -5.39, x2 = -7.10, x3 = -2.64, f(x1,x2,x3) = 2.05
# Melhor solução encontrada: x1 = -6.45, x2 = -7.48, x3 = 0.07, f(x1,x2,x3) = 2.09
# Melhor solução encontrada: x1 = -5.70, x2 = -10.07, x3 = 4.70, f(x1,x2,x3) = 2.15
# Melhor solução encontrada: x1 = -6.34, x2 = -11.25, x3 = -2.00, f(x1,x2,x3) = 2.20
# Melhor solução encontrada: x1 = -6.40, x2 = -6.38, x3 = 1.05, f(x1,x2,x3) = 2.30
# Melhor solução encontrada: x1 = -6.26, x2 = -8.63, x3 = 0.40, f(x1,x2,x3) = 2.36
# Melhor solução encontrada: x1 = -4.64, x2 = -6.03, x3 = -0.24, f(x1,x2,x3) = 2.49
# Melhor solução encontrada: x1 = -8.07, x2 = -4.63, x3 = -1.63, f(x1,x2,x3) = 2.51
# Melhor solução encontrada: x1 = -7.90, x2 = -17.33, x3 = -1.81, f(x1,x2,x3) = 2.50
# Melhor solução encontrada: x1 = -9.84, x2 = -10.64, x3 = 2.90, f(x1,x2,x3) = 2.59
# Melhor solução encontrada: x1 = -7.77, x2 = -6.03, x3 = -5.39, f(x1,x2,x3) = 2.75
# Melhor solução encontrada: x1 = -10.14, x2 = -8.82, x3 = 12.91, f(x1,x2,x3) = 2.77
# Melhor solução encontrada: x1 = -6.31, x2 = -6.92, x3 = 3.94, f(x1,x2,x3) = 2.95
# Melhor solução encontrada: x1 = -6.43, x2 = -6.10, x3 = 4.14, f(x1,x2,x3) = 3.04
# Melhor solução encontrada: x1 = -11.04, x2 = -6.64, x3 = -2.72, f(x1,x2,x3) = 3.05
# Melhor solução encontrada: x1 = -5.98, x2 = -9.38, x3 = 0.51, f(x1,x2,x3) = 3.22
# Melhor solução encontrada: x1 = -7.14, x2 = -3.74, x3 = -0.11, f(x1,x2,x3) = 3.35
# Melhor solução encontrada: x1 = -7.64, x2 = -3.54, x3 = -0.86, f(x1,x2,x3) = 3.45
# Melhor solução encontrada: x1 = -6.65, x2 = -4.93, x3 = -3.64, f(x1,x2,x3) = 3.57
# Melhor solução encontrada: x1 = -5.29, x2 = -6.92, x3 = -0.36, f(x1,x2,x3) = 3.69
# Melhor solução encontrada: x1 = -7.97, x2 = -16.05, x3 = 0.91, f(x1,x2,x3) = 3.68
# Melhor solução encontrada: x1 = -7.91, x2 = -9.12, x3 = 1.11, f(x1,x2,x3) = 3.85
# Melhor solução encontrada: x1 = -6.30, x2 = -7.88, x3 = -1.82, f(x1,x2,x3) = 4.02
# Melhor solução encontrada: x1 = -6.55, x2 = -8.32, x3 = -5.94, f(x1,x2,x3) = 4.14
# Melhor solução encontrada: x1 = -6.23, x2 = -9.05, x3 = 2.52, f(x1,x2,x3) = 4.27
# Melhor solução encontrada: x1 = -5.55, x2 = -9.50, x3 = -4.17, f(x1,x2,x3) = 4.42
# Melhor solução encontrada: x1 = -9.23, x2 = -5.41, x3 = -1.78, f(x1,x2,x3) = 4.53
# Melhor solução encontrada: x1 = -7.81, x2 = -11.99, x3 = -3.85, f(x1,x2,x3) = 4.64
# Melhor solução encontrada: x1 = -5.51, x2 = -7.65, x3 = -2.49, f(x1,x2,x3) = 4.87
# Melhor solução encontrada: x1 = -6.94, x2 = -7.24, x3 = 2.80, f(x1,x2,x3) = 5.00
# Melhor solução encontrada: x1 = -6.63, x2 = -11.77, x3 = 3.09, f(x1,x2,x3) = 5.13
# Melhor solução encontrada: x1 = -8.07, x2 = -18.21, x3 = -1.06, f(x1,x2,x3) = 5.20
# Melhor solução encontrada: x1 = -9.78, x2 = -3.99, x3 = -3.82, f(x1,x2,x3) = 5.47
# Melhor solução encontrada: x1 = -16.34, x2 = -6.20, x3 = -1.43, f(x1,x2,x3) = 5.48
# Melhor solução encontrada: x1 = -6.65, x2 = -16.44, x3 = -9.34, f(x1,x2,x3) = 5.75
# Melhor solução encontrada: x1 = -7.66, x2 = -6.97, x3 = 0.95, f(x1,x2,x3) = 6.00
# Melhor solução encontrada: x1 = -6.10, x2 = -10.11, x3 = 2.21, f(x1,x2,x3) = 6.18
# Melhor solução encontrada: x1 = -6.21, x2 = -11.64, x3 = -1.23, f(x1,x2,x3) = 6.35
# Melhor solução encontrada: x1 = -6.16, x2 = -10.46, x3 = -6.09, f(x1,x2,x3) = 6.56
# Melhor solução encontrada: x1 = -7.38, x2 = -7.50, x3 = 6.26, f(x1,x2,x3) = 6.76
# Melhor solução encontrada: x1 = -10.58, x2 = -5.44, x3 = -0.48, f(x1,x2,x3) = 6.91
# Melhor solução encontrada: x1 = -9.92, x2 = -19.05, x3 = 1.42, f(x1,x2,x3) = 6.99
# Melhor solução encontrada: x1 = -4.89, x2 = -9.41, x3 = 0.42, f(x1,x2,x3) = 7.38
# Melhor solução encontrada: x1 = -8.51, x2 = -5.94, x3 = 2.03, f(x1,x2,x3) = 7.54
# Melhor solução encontrada: x1 = -8.67, x2 = -4.94, x3 = -1.08, f(x1,x2,x3) = 7.75
# Melhor solução encontrada: x1 = -5.74, x2 = -7.36, x3 = 4.42, f(x1,x2,x3) = 7.98
# Melhor solução encontrada: x1 = -10.88, x2 = -7.64, x3 = 0.05, f(x1,x2,x3) = 8.08
# Melhor solução encontrada: x1 = -7.16, x2 = -4.02, x3 = -3.66, f(x1,x2,x3) = 8.37
# Melhor solução encontrada: x1 = -6.53, x2 = -10.30, x3 = 7.26, f(x1,x2,x3) = 8.51
# Melhor solução encontrada: x1 = -6.58, x2 = -12.97, x3 = -1.28, f(x1,x2,x3) = 8.67
# Melhor solução encontrada: x1 = -6.49, x2 = -5.30, x3 = -7.87, f(x1,x2,x3) = 8.90
# Melhor solução encontrada: x1 = -10.21, x2 = -5.23, x3 = 1.85, f(x1,x2,x3) = 9.01
# Melhor solução encontrada: x1 = -7.34, x2 = -7.99, x3 = -2.60, f(x1,x2,x3) = 9.18
# Melhor solução encontrada: x1 = -5.86, x2 = -10.75, x3 = 0.86, f(x1,x2,x3) = 9.31
# Melhor solução encontrada: x1 = -6.23, x2 = -8.05, x3 = 2.73, f(x1,x2,x3) = 9.45
# Melhor solução encontrada: x1 = -9.53, x2 = -6.60, x3 = 3.65, f(x1,x2,x3) = 9.53
# Melhor solução encontrada: x1 = -7.12, x2 = -9.07, x3 = 5.61, f(x1,x2,x3) = 9.62
# Melhor solução encontrada: x1 = -7.03, x2 = -7.66, x3 = 4.51, f(x1,x2,x3) = 9.70
# Melhor solução encontrada: x1 = -6.04, x2 = -7.85, x3 = 2.16, f(x1,x2,x3) = 9.74
# Melhor solução encontrada: x1 = -18.29, x2 = -9.95, x3 = 0.22, f(x1,x2,x3) = 9.71
# Melhor solução encontrada: x1 = 6.88, x2 = 4.25, x3 = -7.23, f(x1,x2,x3) = 9.76
# Melhor solução encontrada: x1 = 5.81, x2 = 6.56, x3 = -6.75, f(x1,x2,x3) = 9.71
# Melhor solução encontrada: x1 = 7.32, x2 = 5.03, x3 = 2.74, f(x1,x2,x3) = 9.64
# Melhor solução encontrada: x1 = 6.53, x2 = 5.58, x3 = 4.74, f(x1,x2,x3) = 9.55
# Melhor solução encontrada: x1 = 5.30, x2 = 8.46, x3 = 2.46, f(x1,x2,x3) = 9.44
# Melhor solução encontrada: x1 = 6.02, x2 = 11.77, x3 = -2.22, f(x1,x2,x3) = 9.29
# Melhor solução encontrada: x1 = 5.77, x2 = 12.33, x3 = 2.66, f(x1,x2,x3) = 9.14
# Melhor solução encontrada: x1 = 7.94, x2 = 7.34, x3 = -0.72, f(x1,x2,x3) = 8.99
# Melhor solução encontrada: x1 = 5.91, x2 = 5.93, x3 = 5.40, f(x1,x2,x3) = 8.86
# Melhor solução encontrada: x1 = 12.56, x2 = 2.86, x3 = -2.65, f(x1,x2,x3) = 8.60
# Melhor solução encontrada: x1 = 6.54, x2 = 6.79, x3 = -0.18, f(x1,x2,x3) = 8.48
# Melhor solução encontrada: x1 = 6.88, x2 = 6.20, x3 = -2.73, f(x1,x2,x3) = 8.28
# Melhor solução encontrada: x1 = 7.32, x2 = 9.09, x3 = 6.50, f(x1,x2,x3) = 8.05
# Melhor solução encontrada: x1 = 8.84, x2 = 3.18, x3 = -1.05, f(x1,x2,x3) = 7.87
# Melhor solução encontrada: x1 = 6.33, x2 = 5.64, x3 = -1.92, f(x1,x2,x3) = 7.69
# Melhor solução encontrada: x1 = 8.36, x2 = 14.00, x3 = -10.30, f(x1,x2,x3) = 7.36
# Melhor solução encontrada: x1 = 6.49, x2 = 6.92, x3 = 1.84, f(x1,x2,x3) = 7.26
# Melhor solução encontrada: x1 = 5.54, x2 = 3.75, x3 = -8.00, f(x1,x2,x3) = 7.10
# Melhor solução encontrada: x1 = 10.84, x2 = 7.91, x3 = 0.45, f(x1,x2,x3) = 6.74
# Melhor solução encontrada: x1 = 7.40, x2 = 11.85, x3 = -0.13, f(x1,x2,x3) = 6.57
# Melhor solução encontrada: x1 = 9.31, x2 = 9.29, x3 = -1.65, f(x1,x2,x3) = 6.36
# Melhor solução encontrada: x1 = 6.33, x2 = 9.75, x3 = -1.41, f(x1,x2,x3) = 6.22
# Melhor solução encontrada: x1 = 8.40, x2 = 6.12, x3 = 1.28, f(x1,x2,x3) = 6.02
# Melhor solução encontrada: x1 = 8.88, x2 = 10.95, x3 = 2.43, f(x1,x2,x3) = 5.78
# Melhor solução encontrada: x1 = 8.88, x2 = 6.24, x3 = -3.22, f(x1,x2,x3) = 5.64
# Melhor solução encontrada: x1 = 5.91, x2 = 9.34, x3 = 4.10, f(x1,x2,x3) = 5.49
# Melhor solução encontrada: x1 = 3.60, x2 = 7.94, x3 = 2.88, f(x1,x2,x3) = 5.38
# Melhor solução encontrada: x1 = 7.90, x2 = 13.83, x3 = -4.08, f(x1,x2,x3) = 5.06
# Melhor solução encontrada: x1 = 8.51, x2 = 7.56, x3 = 8.72, f(x1,x2,x3) = 4.95
# Melhor solução encontrada: x1 = 5.90, x2 = 6.52, x3 = -0.03, f(x1,x2,x3) = 4.86
# Melhor solução encontrada: x1 = 7.40, x2 = 6.51, x3 = -6.05, f(x1,x2,x3) = 4.67
# Melhor solução encontrada: x1 = 5.10, x2 = 7.62, x3 = 1.71, f(x1,x2,x3) = 4.56
# Melhor solução encontrada: x1 = 6.14, x2 = 9.02, x3 = -2.28, f(x1,x2,x3) = 4.37
# Melhor solução encontrada: x1 = 10.21, x2 = 7.49, x3 = -0.81, f(x1,x2,x3) = 4.17
# Melhor solução encontrada: x1 = 7.43, x2 = 6.88, x3 = 3.73, f(x1,x2,x3) = 4.10
# Melhor solução encontrada: x1 = 6.24, x2 = 8.74, x3 = -3.17, f(x1,x2,x3) = 3.97
# Melhor solução encontrada: x1 = 13.90, x2 = 4.01, x3 = 4.44, f(x1,x2,x3) = 3.74
# Melhor solução encontrada: x1 = 6.59, x2 = 8.67, x3 = 1.30, f(x1,x2,x3) = 3.72
# Melhor solução encontrada: x1 = 6.05, x2 = 7.24, x3 = -3.93, f(x1,x2,x3) = 3.62
# Melhor solução encontrada: x1 = 7.60, x2 = 6.75, x3 = -2.32, f(x1,x2,x3) = 3.48
# Melhor solução encontrada: x1 = 7.18, x2 = 5.64, x3 = 2.76, f(x1,x2,x3) = 3.39
# Melhor solução encontrada: x1 = 6.39, x2 = 8.07, x3 = -4.77, f(x1,x2,x3) = 3.27
# Melhor solução encontrada: x1 = 5.91, x2 = 10.94, x3 = -2.72, f(x1,x2,x3) = 3.15
# Melhor solução encontrada: x1 = 6.59, x2 = 7.21, x3 = -3.69, f(x1,x2,x3) = 3.07
# Melhor solução encontrada: x1 = 6.86, x2 = 6.84, x3 = 0.95, f(x1,x2,x3) = 2.97
# Melhor solução encontrada: x1 = 10.07, x2 = 8.31, x3 = 1.36, f(x1,x2,x3) = 2.80
# Melhor solução encontrada: x1 = 9.70, x2 = 7.68, x3 = -0.04, f(x1,x2,x3) = 2.73
# Melhor solução encontrada: x1 = 7.22, x2 = 9.78, x3 = -4.31, f(x1,x2,x3) = 2.67
# Melhor solução encontrada: x1 = 9.95, x2 = 7.36, x3 = -1.75, f(x1,x2,x3) = 2.56
# Melhor solução encontrada: x1 = 7.16, x2 = 6.60, x3 = -1.16, f(x1,x2,x3) = 2.53
# Melhor solução encontrada: x1 = 12.99, x2 = 7.84, x3 = -2.64, f(x1,x2,x3) = 2.34
# Melhor solução encontrada: x1 = 4.79, x2 = 8.25, x3 = 5.24, f(x1,x2,x3) = 2.41
# Melhor solução encontrada: x1 = 5.87, x2 = 12.79, x3 = 2.61, f(x1,x2,x3) = 2.27
# Melhor solução encontrada: x1 = 6.73, x2 = 8.17, x3 = -2.88, f(x1,x2,x3) = 2.23
# Melhor solução encontrada: x1 = 10.72, x2 = 10.55, x3 = -0.84, f(x1,x2,x3) = 2.07
# Melhor solução encontrada: x1 = 8.12, x2 = 6.04, x3 = 5.56, f(x1,x2,x3) = 2.09
# Melhor solução encontrada: x1 = 7.96, x2 = 4.63, x3 = 0.70, f(x1,x2,x3) = 2.04
# Melhor solução encontrada: x1 = 9.01, x2 = 6.47, x3 = -0.65, f(x1,x2,x3) = 1.94
# Melhor solução encontrada: x1 = 6.56, x2 = 6.83, x3 = -6.47, f(x1,x2,x3) = 1.92
# Melhor solução encontrada: x1 = 20.10, x2 = 6.32, x3 = -0.30, f(x1,x2,x3) = 1.64
# Melhor solução encontrada: x1 = 5.39, x2 = 6.19, x3 = 0.63, f(x1,x2,x3) = 1.84
# Melhor solução encontrada: x1 = 6.96, x2 = 8.66, x3 = -4.44, f(x1,x2,x3) = 1.73
# Melhor solução encontrada: x1 = 5.14, x2 = 5.38, x3 = -3.90, f(x1,x2,x3) = 1.74
# Melhor solução encontrada: x1 = 6.27, x2 = 4.76, x3 = 4.10, f(x1,x2,x3) = 1.67
# Melhor solução encontrada: x1 = 7.76, x2 = 6.00, x3 = 2.92, f(x1,x2,x3) = 1.58
# Melhor solução encontrada: x1 = 6.04, x2 = 6.31, x3 = -7.43, f(x1,x2,x3) = 1.56
# Melhor solução encontrada: x1 = 7.14, x2 = 8.16, x3 = -3.75, f(x1,x2,x3) = 1.48
# Melhor solução encontrada: x1 = 6.29, x2 = 7.39, x3 = 5.36, f(x1,x2,x3) = 1.46
# Melhor solução encontrada: x1 = 8.80, x2 = 5.00, x3 = -5.27, f(x1,x2,x3) = 1.39
# Melhor solução encontrada: x1 = 6.62, x2 = 6.38, x3 = 1.83, f(x1,x2,x3) = 1.38
# Melhor solução encontrada: x1 = 7.58, x2 = 8.43, x3 = 4.80, f(x1,x2,x3) = 1.30
# Melhor solução encontrada: x1 = 6.30, x2 = 8.73, x3 = -1.76, f(x1,x2,x3) = 1.29
# Melhor solução encontrada: x1 = 4.89, x2 = 9.86, x3 = 1.31, f(x1,x2,x3) = 1.26
# Melhor solução encontrada: x1 = 8.45, x2 = 4.47, x3 = -3.15, f(x1,x2,x3) = 1.21
# Melhor solução encontrada: x1 = 3.94, x2 = 21.01, x3 = -1.15, f(x1,x2,x3) = 1.13
# Melhor solução encontrada: x1 = 9.10, x2 = 6.73, x3 = 4.34, f(x1,x2,x3) = 1.12
# Melhor solução encontrada: x1 = 5.57, x2 = 7.24, x3 = 0.59, f(x1,x2,x3) = 1.14
# Melhor solução encontrada: x1 = 6.14, x2 = 5.29, x3 = -0.17, f(x1,x2,x3) = 1.11
# Melhor solução encontrada: x1 = 12.99, x2 = 5.64, x3 = 0.52, f(x1,x2,x3) = 0.98
# Melhor solução encontrada: x1 = 4.61, x2 = 12.78, x3 = -3.28, f(x1,x2,x3) = 1.03
# Melhor solução encontrada: x1 = 7.03, x2 = 6.53, x3 = -8.69, f(x1,x2,x3) = 1.01
# Melhor solução encontrada: x1 = 6.70, x2 = 9.71, x3 = 2.00, f(x1,x2,x3) = 0.96
# Melhor solução encontrada: x1 = 6.97, x2 = 4.90, x3 = -4.71, f(x1,x2,x3) = 0.97
# Melhor solução encontrada: x1 = 5.82, x2 = 4.41, x3 = -15.00, f(x1,x2,x3) = 0.96
# Melhor solução encontrada: x1 = 7.31, x2 = 12.22, x3 = 2.84, f(x1,x2,x3) = 0.87
# Melhor solução encontrada: x1 = 7.81, x2 = 8.44, x3 = -7.67, f(x1,x2,x3) = 0.86
# Melhor solução encontrada: x1 = 5.43, x2 = 8.85, x3 = -3.21, f(x1,x2,x3) = 0.87
# Melhor solução encontrada: x1 = 5.84, x2 = 6.47, x3 = -2.82, f(x1,x2,x3) = 0.86
# Melhor solução encontrada: x1 = 4.51, x2 = 11.54, x3 = 4.17, f(x1,x2,x3) = 0.83
# Melhor solução encontrada: x1 = 4.85, x2 = 14.58, x3 = -6.28, f(x1,x2,x3) = 0.79
# Melhor solução encontrada: x1 = 6.82, x2 = 8.51, x3 = -11.22, f(x1,x2,x3) = 0.78
# Melhor solução encontrada: x1 = 8.48, x2 = 4.12, x3 = -7.92, f(x1,x2,x3) = 0.77
# Melhor solução encontrada: x1 = 6.21, x2 = 5.80, x3 = -1.29, f(x1,x2,x3) = 0.77
# Melhor solução encontrada: x1 = 5.27, x2 = 12.74, x3 = -1.21, f(x1,x2,x3) = 0.73
# Melhor solução encontrada: x1 = 8.01, x2 = 12.08, x3 = 14.29, f(x1,x2,x3) = 0.69
# Melhor solução encontrada: x1 = 5.50, x2 = 5.85, x3 = -8.87, f(x1,x2,x3) = 0.73
# Melhor solução encontrada: x1 = 9.27, x2 = 10.37, x3 = -0.25, f(x1,x2,x3) = 0.66
# Melhor solução encontrada: x1 = 4.84, x2 = 8.92, x3 = 0.09, f(x1,x2,x3) = 0.70
# Melhor solução encontrada: x1 = 11.28, x2 = 6.93, x3 = -0.78, f(x1,x2,x3) = 0.63
# Melhor solução encontrada: x1 = 8.39, x2 = 11.48, x3 = 2.47, f(x1,x2,x3) = 0.63
# Melhor solução encontrada: x1 = 6.47, x2 = 8.03, x3 = 3.32, f(x1,x2,x3) = 0.65
# Melhor solução encontrada: x1 = 6.35, x2 = 5.74, x3 = 0.72, f(x1,x2,x3) = 0.65
# Melhor solução encontrada: x1 = 7.98, x2 = 8.74, x3 = 5.27, f(x1,x2,x3) = 0.62
# Melhor solução encontrada: x1 = 4.81, x2 = 7.07, x3 = -0.66, f(x1,x2,x3) = 0.64
# Melhor solução encontrada: x1 = 6.59, x2 = 9.75, x3 = 1.94, f(x1,x2,x3) = 0.61
# Melhor solução encontrada: x1 = 6.51, x2 = 4.27, x3 = 8.71, f(x1,x2,x3) = 0.62
# Melhor solução encontrada: x1 = 7.51, x2 = 7.16, x3 = -4.60, f(x1,x2,x3) = 0.60
# Melhor solução encontrada: x1 = 9.47, x2 = 8.68, x3 = 0.70, f(x1,x2,x3) = 0.57
# Melhor solução encontrada: x1 = 5.60, x2 = 7.48, x3 = -2.70, f(x1,x2,x3) = 0.60
# Melhor solução encontrada: x1 = 9.47, x2 = 12.62, x3 = 11.82, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = 7.77, x2 = 3.78, x3 = 0.92, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 8.12, x2 = 10.87, x3 = -1.18, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = 6.79, x2 = 7.65, x3 = 2.97, f(x1,x2,x3) = 0.57
# Melhor solução encontrada: x1 = 5.94, x2 = 6.47, x3 = -1.32, f(x1,x2,x3) = 0.57
# Melhor solução encontrada: x1 = 6.45, x2 = 8.82, x3 = -1.76, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = 6.98, x2 = 11.24, x3 = -1.38, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = 5.30, x2 = 6.70, x3 = 4.48, f(x1,x2,x3) = 0.57
# Melhor solução encontrada: x1 = 9.84, x2 = 7.10, x3 = 0.78, f(x1,x2,x3) = 0.55
# Melhor solução encontrada: x1 = 8.49, x2 = 5.39, x3 = -2.90, f(x1,x2,x3) = 0.55
# Melhor solução encontrada: x1 = 6.77, x2 = 4.56, x3 = -8.38, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = 6.55, x2 = 4.05, x3 = -1.56, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = 7.47, x2 = 6.16, x3 = -1.30, f(x1,x2,x3) = 0.55
# Melhor solução encontrada: x1 = 7.10, x2 = 4.19, x3 = 4.25, f(x1,x2,x3) = 0.55
# Melhor solução encontrada: x1 = 5.33, x2 = 6.43, x3 = -4.96, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = 8.13, x2 = 2.65, x3 = 0.79, f(x1,x2,x3) = 0.55
# Melhor solução encontrada: x1 = 6.61, x2 = 4.22, x3 = 3.01, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = 6.23, x2 = 1.63, x3 = 1.14, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = 6.60, x2 = 0.81, x3 = 2.30, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = 6.19, x2 = 0.21, x3 = -0.94, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = 5.73, x2 = -1.31, x3 = 2.89, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = 4.29, x2 = -1.08, x3 = 3.69, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = 3.17, x2 = -1.36, x3 = 3.13, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = 1.96, x2 = -1.47, x3 = 0.02, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = 0.76, x2 = -1.65, x3 = 3.77, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = -0.64, x2 = -1.38, x3 = -5.04, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = -1.94, x2 = -1.37, x3 = -1.55, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = -3.13, x2 = -1.38, x3 = 1.11, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = -4.32, x2 = -1.42, x3 = 3.14, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = -5.49, x2 = -1.56, x3 = -1.55, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = -5.91, x2 = -2.73, x3 = 2.88, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = -7.91, x2 = -1.49, x3 = 1.26, f(x1,x2,x3) = 0.55
# Melhor solução encontrada: x1 = -6.72, x2 = -4.14, x3 = -2.54, f(x1,x2,x3) = 0.55
# Melhor solução encontrada: x1 = -6.10, x2 = -6.40, x3 = -0.76, f(x1,x2,x3) = 0.55
# Melhor solução encontrada: x1 = -5.74, x2 = -4.19, x3 = 5.16, f(x1,x2,x3) = 0.55
# Melhor solução encontrada: x1 = -6.27, x2 = -6.89, x3 = -3.34, f(x1,x2,x3) = 0.55
# Melhor solução encontrada: x1 = -10.49, x2 = -3.94, x3 = -2.81, f(x1,x2,x3) = 0.55
# Melhor solução encontrada: x1 = -6.78, x2 = -6.57, x3 = 0.94, f(x1,x2,x3) = 0.55
# Melhor solução encontrada: x1 = -6.94, x2 = -10.46, x3 = -0.48, f(x1,x2,x3) = 0.55
# Melhor solução encontrada: x1 = -7.89, x2 = -8.54, x3 = -2.03, f(x1,x2,x3) = 0.55
# Melhor solução encontrada: x1 = -8.90, x2 = -10.26, x3 = 1.42, f(x1,x2,x3) = 0.55
# Melhor solução encontrada: x1 = -7.10, x2 = -8.19, x3 = -0.47, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = -8.31, x2 = -7.05, x3 = 2.87, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = -6.68, x2 = -15.51, x3 = -3.12, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = -7.05, x2 = -5.34, x3 = -8.55, f(x1,x2,x3) = 0.57
# Melhor solução encontrada: x1 = -7.06, x2 = -10.52, x3 = -5.49, f(x1,x2,x3) = 0.56
# Melhor solução encontrada: x1 = -6.38, x2 = -7.10, x3 = 0.57, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -8.97, x2 = -7.83, x3 = 4.98, f(x1,x2,x3) = 0.57
# Melhor solução encontrada: x1 = -5.65, x2 = -6.22, x3 = 1.38, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = -9.44, x2 = -5.71, x3 = 0.78, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -7.98, x2 = -9.80, x3 = 7.57, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -5.18, x2 = -6.55, x3 = 0.21, f(x1,x2,x3) = 0.61
# Melhor solução encontrada: x1 = -6.92, x2 = -11.38, x3 = 3.00, f(x1,x2,x3) = 0.60
# Melhor solução encontrada: x1 = -6.96, x2 = -16.91, x3 = 4.31, f(x1,x2,x3) = 0.60
# Melhor solução encontrada: x1 = -12.24, x2 = -7.39, x3 = -0.72, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = -7.68, x2 = -13.15, x3 = 2.00, f(x1,x2,x3) = 0.61
# Melhor solução encontrada: x1 = -6.85, x2 = -4.96, x3 = 2.69, f(x1,x2,x3) = 0.64
# Melhor solução encontrada: x1 = -10.27, x2 = -15.36, x3 = 5.02, f(x1,x2,x3) = 0.61
# Melhor solução encontrada: x1 = -7.89, x2 = -11.44, x3 = 0.35, f(x1,x2,x3) = 0.63
# Melhor solução encontrada: x1 = -8.55, x2 = -8.51, x3 = 4.80, f(x1,x2,x3) = 0.65
# Melhor solução encontrada: x1 = -8.45, x2 = -10.45, x3 = 7.75, f(x1,x2,x3) = 0.65
# Melhor solução encontrada: x1 = -9.64, x2 = -7.01, x3 = 6.58, f(x1,x2,x3) = 0.66
# Melhor solução encontrada: x1 = -5.62, x2 = -19.31, x3 = 3.47, f(x1,x2,x3) = 0.67
# Melhor solução encontrada: x1 = -5.58, x2 = -7.91, x3 = 3.98, f(x1,x2,x3) = 0.71
# Melhor solução encontrada: x1 = -8.04, x2 = -7.75, x3 = -4.38, f(x1,x2,x3) = 0.71
# Melhor solução encontrada: x1 = -7.75, x2 = -4.14, x3 = -0.92, f(x1,x2,x3) = 0.73
# Melhor solução encontrada: x1 = -6.02, x2 = -5.18, x3 = -5.18, f(x1,x2,x3) = 0.76
# Melhor solução encontrada: x1 = -5.65, x2 = -12.69, x3 = -3.70, f(x1,x2,x3) = 0.75
# Melhor solução encontrada: x1 = -9.25, x2 = -6.64, x3 = -3.28, f(x1,x2,x3) = 0.75
# Melhor solução encontrada: x1 = -7.36, x2 = -10.11, x3 = -5.82, f(x1,x2,x3) = 0.77
# Melhor solução encontrada: x1 = -7.25, x2 = -5.93, x3 = 2.69, f(x1,x2,x3) = 0.80
# Melhor solução encontrada: x1 = -8.01, x2 = -12.60, x3 = 10.25, f(x1,x2,x3) = 0.79
# Melhor solução encontrada: x1 = -6.73, x2 = -12.18, x3 = -6.12, f(x1,x2,x3) = 0.81
# Melhor solução encontrada: x1 = -8.78, x2 = -7.40, x3 = 3.11, f(x1,x2,x3) = 0.82
# Melhor solução encontrada: x1 = -6.74, x2 = -10.74, x3 = 2.23, f(x1,x2,x3) = 0.85
# Melhor solução encontrada: x1 = -11.22, x2 = -11.46, x3 = 0.75, f(x1,x2,x3) = 0.83
# Melhor solução encontrada: x1 = -5.20, x2 = -7.27, x3 = -4.13, f(x1,x2,x3) = 0.90
# Melhor solução encontrada: x1 = -5.89, x2 = -7.22, x3 = -6.57, f(x1,x2,x3) = 0.92
# Melhor solução encontrada: x1 = -7.07, x2 = -6.09, x3 = -0.97, f(x1,x2,x3) = 0.93
# Melhor solução encontrada: x1 = -8.42, x2 = -6.75, x3 = 5.06, f(x1,x2,x3) = 0.93
# Melhor solução encontrada: x1 = -7.73, x2 = -9.76, x3 = 0.60, f(x1,x2,x3) = 0.95
# Melhor solução encontrada: x1 = -5.64, x2 = -7.28, x3 = -2.95, f(x1,x2,x3) = 0.99
# Melhor solução encontrada: x1 = -7.17, x2 = -9.54, x3 = -5.44, f(x1,x2,x3) = 0.99
# Melhor solução encontrada: x1 = -7.62, x2 = -6.39, x3 = 2.86, f(x1,x2,x3) = 1.01
# Melhor solução encontrada: x1 = -4.48, x2 = -7.25, x3 = 3.21, f(x1,x2,x3) = 1.06
# Melhor solução encontrada: x1 = -4.86, x2 = -9.33, x3 = 3.01, f(x1,x2,x3) = 1.07
# Melhor solução encontrada: x1 = -8.55, x2 = -6.56, x3 = 1.21, f(x1,x2,x3) = 1.07
# Melhor solução encontrada: x1 = -7.39, x2 = -3.88, x3 = -3.91, f(x1,x2,x3) = 1.10
# Melhor solução encontrada: x1 = -7.06, x2 = -8.05, x3 = 6.57, f(x1,x2,x3) = 1.11
# Melhor solução encontrada: x1 = -6.06, x2 = -4.25, x3 = 3.10, f(x1,x2,x3) = 1.15
# Melhor solução encontrada: x1 = -7.05, x2 = -10.87, x3 = 1.33, f(x1,x2,x3) = 1.15
# Melhor solução encontrada: x1 = -7.30, x2 = -4.59, x3 = -4.44, f(x1,x2,x3) = 1.18
# Melhor solução encontrada: x1 = -9.04, x2 = -9.80, x3 = 11.26, f(x1,x2,x3) = 1.18
# Melhor solução encontrada: x1 = -9.78, x2 = -7.86, x3 = 4.01, f(x1,x2,x3) = 1.20
# Melhor solução encontrada: x1 = -12.38, x2 = -7.26, x3 = 17.65, f(x1,x2,x3) = 1.21
# Melhor solução encontrada: x1 = -6.21, x2 = -8.10, x3 = -2.23, f(x1,x2,x3) = 1.26
# Melhor solução encontrada: x1 = -6.24, x2 = -9.93, x3 = -2.01, f(x1,x2,x3) = 1.28
# Melhor solução encontrada: x1 = -7.70, x2 = -7.45, x3 = -0.35, f(x1,x2,x3) = 1.30
# Melhor solução encontrada: x1 = -5.85, x2 = -6.36, x3 = -0.01, f(x1,x2,x3) = 1.33
# Melhor solução encontrada: x1 = -5.98, x2 = -9.66, x3 = -3.22, f(x1,x2,x3) = 1.35
# Melhor solução encontrada: x1 = -5.91, x2 = -6.21, x3 = 2.16, f(x1,x2,x3) = 1.37
# Melhor solução encontrada: x1 = -9.05, x2 = -8.64, x3 = 2.03, f(x1,x2,x3) = 1.37
# Melhor solução encontrada: x1 = -8.59, x2 = -6.98, x3 = 1.28, f(x1,x2,x3) = 1.40
# Melhor solução encontrada: x1 = -8.58, x2 = -7.28, x3 = 2.31, f(x1,x2,x3) = 1.42
# Melhor solução encontrada: x1 = -6.06, x2 = -6.41, x3 = -6.59, f(x1,x2,x3) = 1.45
# Melhor solução encontrada: x1 = -9.06, x2 = -4.93, x3 = 5.31, f(x1,x2,x3) = 1.46
# Melhor solução encontrada: x1 = -7.15, x2 = -5.47, x3 = -1.91, f(x1,x2,x3) = 1.48
# Melhor solução encontrada: x1 = -9.73, x2 = -5.51, x3 = 2.83, f(x1,x2,x3) = 1.49
# Melhor solução encontrada: x1 = -5.76, x2 = -8.28, x3 = -3.48, f(x1,x2,x3) = 1.52
# Melhor solução encontrada: x1 = -5.69, x2 = -6.76, x3 = -3.48, f(x1,x2,x3) = 1.53
# Melhor solução encontrada: x1 = -8.04, x2 = -5.81, x3 = 0.20, f(x1,x2,x3) = 1.54
# Melhor solução encontrada: x1 = -7.98, x2 = -3.77, x3 = -3.54, f(x1,x2,x3) = 1.56
# Melhor solução encontrada: x1 = -8.30, x2 = -2.73, x3 = 1.95, f(x1,x2,x3) = 1.57
# Melhor solução encontrada: x1 = -6.10, x2 = -4.00, x3 = -1.98, f(x1,x2,x3) = 1.59
# Melhor solução encontrada: x1 = -6.96, x2 = -1.90, x3 = -4.33, f(x1,x2,x3) = 1.60
# Melhor solução encontrada: x1 = -6.80, x2 = -1.09, x3 = -1.95, f(x1,x2,x3) = 1.61
# Melhor solução encontrada: x1 = -8.34, x2 = 2.22, x3 = -0.97, f(x1,x2,x3) = 1.62
# Melhor solução encontrada: x1 = -6.62, x2 = 0.38, x3 = 0.14, f(x1,x2,x3) = 1.63
# Melhor solução encontrada: x1 = -6.16, x2 = 2.51, x3 = 2.24, f(x1,x2,x3) = 1.64
# Melhor solução encontrada: x1 = -5.83, x2 = 4.39, x3 = -0.12, f(x1,x2,x3) = 1.64
# Melhor solução encontrada: x1 = -5.59, x2 = 5.23, x3 = -0.14, f(x1,x2,x3) = 1.65
# Melhor solução encontrada: x1 = -4.60, x2 = 5.29, x3 = -7.00, f(x1,x2,x3) = 1.65
# Melhor solução encontrada: x1 = -3.52, x2 = 5.92, x3 = 8.86, f(x1,x2,x3) = 1.65
# Melhor solução encontrada: x1 = -1.85, x2 = 5.46, x3 = 1.25, f(x1,x2,x3) = 1.66
# Melhor solução encontrada: x1 = -0.80, x2 = 5.67, x3 = -7.91, f(x1,x2,x3) = 1.65
# Melhor solução encontrada: x1 = 0.89, x2 = 5.25, x3 = -4.24, f(x1,x2,x3) = 1.65
# Melhor solução encontrada: x1 = 2.06, x2 = 5.57, x3 = -2.24, f(x1,x2,x3) = 1.65
# Melhor solução encontrada: x1 = 3.16, x2 = 5.91, x3 = 1.50, f(x1,x2,x3) = 1.64
# Melhor solução encontrada: x1 = 4.97, x2 = 5.11, x3 = -1.96, f(x1,x2,x3) = 1.64
# Melhor solução encontrada: x1 = 5.77, x2 = 5.83, x3 = 2.10, f(x1,x2,x3) = 1.63
# Melhor solução encontrada: x1 = 7.13, x2 = 5.72, x3 = -3.16, f(x1,x2,x3) = 1.62
# Melhor solução encontrada: x1 = 7.64, x2 = 7.05, x3 = 2.50, f(x1,x2,x3) = 1.61
# Melhor solução encontrada: x1 = 5.79, x2 = 7.02, x3 = -1.58, f(x1,x2,x3) = 1.60
# Melhor solução encontrada: x1 = 6.15, x2 = 10.50, x3 = -3.10, f(x1,x2,x3) = 1.59
# Melhor solução encontrada: x1 = 5.02, x2 = 8.41, x3 = -1.43, f(x1,x2,x3) = 1.58
# Melhor solução encontrada: x1 = 8.76, x2 = 6.34, x3 = -0.58, f(x1,x2,x3) = 1.56
# Melhor solução encontrada: x1 = 5.32, x2 = 6.48, x3 = -3.47, f(x1,x2,x3) = 1.55
# Melhor solução encontrada: x1 = 14.48, x2 = 4.55, x3 = -11.18, f(x1,x2,x3) = 1.52
# Melhor solução encontrada: x1 = 6.56, x2 = 7.99, x3 = -2.78, f(x1,x2,x3) = 1.52
# Melhor solução encontrada: x1 = 8.05, x2 = 7.61, x3 = -0.63, f(x1,x2,x3) = 1.50
# Melhor solução encontrada: x1 = 6.51, x2 = 4.96, x3 = 0.93, f(x1,x2,x3) = 1.49
# Melhor solução encontrada: x1 = 12.19, x2 = 8.18, x3 = 1.17, f(x1,x2,x3) = 1.45
# Melhor solução encontrada: x1 = 8.83, x2 = 13.18, x3 = -2.66, f(x1,x2,x3) = 1.43
# Melhor solução encontrada: x1 = 11.15, x2 = 5.14, x3 = 3.26, f(x1,x2,x3) = 1.41
# Melhor solução encontrada: x1 = 8.30, x2 = 3.57, x3 = 6.11, f(x1,x2,x3) = 1.41
# Melhor solução encontrada: x1 = 8.09, x2 = 6.14, x3 = 0.18, f(x1,x2,x3) = 1.39
# Melhor solução encontrada: x1 = 6.03, x2 = 9.11, x3 = -2.94, f(x1,x2,x3) = 1.37
# Melhor solução encontrada: x1 = 14.92, x2 = 4.72, x3 = -2.15, f(x1,x2,x3) = 1.32
# Melhor solução encontrada: x1 = 6.79, x2 = 6.26, x3 = -1.94, f(x1,x2,x3) = 1.33
# Melhor solução encontrada: x1 = 15.56, x2 = 6.81, x3 = 0.31, f(x1,x2,x3) = 1.27
# Melhor solução encontrada: x1 = 10.19, x2 = 8.25, x3 = 0.60, f(x1,x2,x3) = 1.27
# Melhor solução encontrada: x1 = 6.56, x2 = 8.51, x3 = 2.25, f(x1,x2,x3) = 1.27
# Melhor solução encontrada: x1 = 9.28, x2 = 11.00, x3 = 3.98, f(x1,x2,x3) = 1.22
# Melhor solução encontrada: x1 = 10.70, x2 = 8.94, x3 = 8.75, f(x1,x2,x3) = 1.20
# Melhor solução encontrada: x1 = 6.16, x2 = 10.55, x3 = 3.60, f(x1,x2,x3) = 1.20
# Melhor solução encontrada: x1 = 6.06, x2 = 11.48, x3 = 1.52, f(x1,x2,x3) = 1.17
# Melhor solução encontrada: x1 = 5.25, x2 = 8.55, x3 = 2.19, f(x1,x2,x3) = 1.17
# Melhor solução encontrada: x1 = 9.55, x2 = 15.06, x3 = -7.94, f(x1,x2,x3) = 1.10
# Melhor solução encontrada: x1 = 11.39, x2 = 13.12, x3 = -2.96, f(x1,x2,x3) = 1.07
# Melhor solução encontrada: x1 = 6.41, x2 = 7.30, x3 = 1.79, f(x1,x2,x3) = 1.10
# Melhor solução encontrada: x1 = 5.91, x2 = 4.72, x3 = -6.63, f(x1,x2,x3) = 1.10
# Melhor solução encontrada: x1 = 8.35, x2 = 7.86, x3 = 4.14, f(x1,x2,x3) = 1.04
# Melhor solução encontrada: x1 = 6.19, x2 = 5.92, x3 = 0.00, f(x1,x2,x3) = 1.05
# Melhor solução encontrada: x1 = 6.74, x2 = 4.17, x3 = 1.75, f(x1,x2,x3) = 1.03
# Melhor solução encontrada: x1 = 9.00, x2 = 6.24, x3 = -1.56, f(x1,x2,x3) = 0.98
# Melhor solução encontrada: x1 = 11.37, x2 = 4.83, x3 = 2.06, f(x1,x2,x3) = 0.95
# Melhor solução encontrada: x1 = 5.44, x2 = 12.76, x3 = -3.19, f(x1,x2,x3) = 0.95
# Melhor solução encontrada: x1 = 6.43, x2 = 10.94, x3 = 3.19, f(x1,x2,x3) = 0.93
# Melhor solução encontrada: x1 = 16.72, x2 = 8.48, x3 = 1.25, f(x1,x2,x3) = 0.84
# Melhor solução encontrada: x1 = 8.09, x2 = 11.60, x3 = -0.81, f(x1,x2,x3) = 0.87
# Melhor solução encontrada: x1 = 5.92, x2 = 5.98, x3 = -0.02, f(x1,x2,x3) = 0.90
# Melhor solução encontrada: x1 = 7.69, x2 = 8.11, x3 = 6.17, f(x1,x2,x3) = 0.85
# Melhor solução encontrada: x1 = 7.04, x2 = 5.88, x3 = 3.39, f(x1,x2,x3) = 0.85
# Melhor solução encontrada: x1 = 6.30, x2 = 10.53, x3 = -3.99, f(x1,x2,x3) = 0.82
# Melhor solução encontrada: x1 = 8.59, x2 = 9.24, x3 = -0.29, f(x1,x2,x3) = 0.79
# Melhor solução encontrada: x1 = 7.68, x2 = 10.00, x3 = 4.64, f(x1,x2,x3) = 0.78
# Melhor solução encontrada: x1 = 6.74, x2 = 10.84, x3 = 0.82, f(x1,x2,x3) = 0.77
# Melhor solução encontrada: x1 = 6.69, x2 = 5.47, x3 = -0.43, f(x1,x2,x3) = 0.78
# Melhor solução encontrada: x1 = 9.14, x2 = 10.31, x3 = 6.73, f(x1,x2,x3) = 0.72
# Melhor solução encontrada: x1 = 6.62, x2 = 5.38, x3 = 0.86, f(x1,x2,x3) = 0.75
# Melhor solução encontrada: x1 = 6.72, x2 = 4.54, x3 = 2.76, f(x1,x2,x3) = 0.74
# Melhor solução encontrada: x1 = 7.98, x2 = 10.16, x3 = -0.86, f(x1,x2,x3) = 0.69
# Melhor solução encontrada: x1 = 14.09, x2 = 8.86, x3 = -6.71, f(x1,x2,x3) = 0.63
# Melhor solução encontrada: x1 = 7.45, x2 = 12.11, x3 = 5.41, f(x1,x2,x3) = 0.66
# Melhor solução encontrada: x1 = 6.58, x2 = 7.94, x3 = 2.01, f(x1,x2,x3) = 0.67
# Melhor solução encontrada: x1 = 6.80, x2 = 7.24, x3 = -3.39, f(x1,x2,x3) = 0.66
# Melhor solução encontrada: x1 = 8.40, x2 = 11.54, x3 = 4.00, f(x1,x2,x3) = 0.62
# Melhor solução encontrada: x1 = 15.35, x2 = 6.25, x3 = 0.72, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 7.05, x2 = 3.80, x3 = 18.16, f(x1,x2,x3) = 0.64
# Melhor solução encontrada: x1 = 5.22, x2 = 17.69, x3 = -2.25, f(x1,x2,x3) = 0.60
# Melhor solução encontrada: x1 = 5.36, x2 = 8.55, x3 = 0.70, f(x1,x2,x3) = 0.62
# Melhor solução encontrada: x1 = 5.41, x2 = 4.70, x3 = -5.53, f(x1,x2,x3) = 0.62
# Melhor solução encontrada: x1 = 7.32, x2 = 7.77, x3 = 2.05, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 4.38, x2 = 14.41, x3 = -7.39, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 7.45, x2 = 6.56, x3 = 2.10, f(x1,x2,x3) = 0.57
# Melhor solução encontrada: x1 = 7.17, x2 = 5.80, x3 = 1.57, f(x1,x2,x3) = 0.57
# Melhor solução encontrada: x1 = 10.31, x2 = 3.33, x3 = 3.62, f(x1,x2,x3) = 0.55
# Melhor solução encontrada: x1 = 12.88, x2 = 4.08, x3 = -1.09, f(x1,x2,x3) = 0.52
# Melhor solução encontrada: x1 = 7.18, x2 = 8.72, x3 = -1.15, f(x1,x2,x3) = 0.54
# Melhor solução encontrada: x1 = 8.65, x2 = 9.88, x3 = -2.06, f(x1,x2,x3) = 0.53
# Melhor solução encontrada: x1 = 10.46, x2 = 5.02, x3 = -3.26, f(x1,x2,x3) = 0.52
# Melhor solução encontrada: x1 = 7.75, x2 = 12.16, x3 = -0.42, f(x1,x2,x3) = 0.52
# Melhor solução encontrada: x1 = 9.10, x2 = 6.72, x3 = -4.11, f(x1,x2,x3) = 0.52
# Melhor solução encontrada: x1 = 8.19, x2 = 10.43, x3 = -8.51, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = 5.75, x2 = 8.27, x3 = 3.23, f(x1,x2,x3) = 0.52
# Melhor solução encontrada: x1 = 8.48, x2 = 10.93, x3 = -9.90, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = 6.05, x2 = 7.43, x3 = -2.83, f(x1,x2,x3) = 0.52
# Melhor solução encontrada: x1 = 6.31, x2 = 8.60, x3 = 1.75, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = 5.76, x2 = 12.80, x3 = -0.67, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = 7.06, x2 = 8.35, x3 = -0.91, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = 6.30, x2 = 9.01, x3 = -2.89, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = 7.11, x2 = 6.86, x3 = -7.16, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = 7.37, x2 = 5.52, x3 = 0.44, f(x1,x2,x3) = 0.50
# Melhor solução encontrada: x1 = 7.20, x2 = 7.47, x3 = 4.03, f(x1,x2,x3) = 0.50
# Melhor solução encontrada: x1 = 7.17, x2 = 5.80, x3 = -2.46, f(x1,x2,x3) = 0.50
# Melhor solução encontrada: x1 = 6.31, x2 = 4.11, x3 = 0.23, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = 6.41, x2 = 3.66, x3 = 3.47, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = 5.72, x2 = 3.53, x3 = 4.67, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = 5.80, x2 = 3.33, x3 = -1.53, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = 5.87, x2 = 1.97, x3 = -1.15, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = 6.93, x2 = -0.25, x3 = 1.82, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = 6.37, x2 = -1.24, x3 = -3.17, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = 5.16, x2 = -1.52, x3 = -5.06, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = 3.84, x2 = -1.38, x3 = 2.78, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = 2.62, x2 = -1.51, x3 = 3.60, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = 1.32, x2 = -1.49, x3 = 2.91, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = 0.08, x2 = -1.55, x3 = 2.43, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = -1.21, x2 = -1.54, x3 = 8.84, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = -2.52, x2 = -1.54, x3 = -0.59, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = -3.80, x2 = -1.54, x3 = 2.23, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = -5.09, x2 = -1.57, x3 = -1.32, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = -6.39, x2 = -1.54, x3 = -0.31, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = -6.32, x2 = -3.56, x3 = -5.06, f(x1,x2,x3) = 0.51
# Melhor solução encontrada: x1 = -6.56, x2 = -4.73, x3 = -2.64, f(x1,x2,x3) = 0.50
# Melhor solução encontrada: x1 = -7.47, x2 = -4.43, x3 = 0.10, f(x1,x2,x3) = 0.50
# Melhor solução encontrada: x1 = -10.54, x2 = -2.48, x3 = 6.47, f(x1,x2,x3) = 0.50
# Melhor solução encontrada: x1 = -6.62, x2 = -7.17, x3 = 2.56, f(x1,x2,x3) = 0.50
# Melhor solução encontrada: x1 = -7.65, x2 = -8.22, x3 = -7.57, f(x1,x2,x3) = 0.50
# Melhor solução encontrada: x1 = -5.77, x2 = -8.29, x3 = -3.82, f(x1,x2,x3) = 0.50
# Melhor solução encontrada: x1 = -7.11, x2 = -10.00, x3 = 1.65, f(x1,x2,x3) = 0.50
# Melhor solução encontrada: x1 = -9.53, x2 = -6.56, x3 = 3.33, f(x1,x2,x3) = 0.49
# Melhor solução encontrada: x1 = -7.70, x2 = -8.92, x3 = 2.25, f(x1,x2,x3) = 0.49
# Melhor solução encontrada: x1 = -7.32, x2 = -8.09, x3 = 10.88, f(x1,x2,x3) = 0.50
# Melhor solução encontrada: x1 = -7.54, x2 = -9.38, x3 = -0.31, f(x1,x2,x3) = 0.50
# ...
# Melhor solução encontrada: x1 = -8.87, x2 = -5.31, x3 = 1.28, f(x1,x2,x3) = 0.67
# Melhor solução encontrada: x1 = -9.99, x2 = -7.15, x3 = -6.80, f(x1,x2,x3) = 0.67
# Melhor solução encontrada: x1 = -8.43, x2 = -13.27, x3 = -4.62, f(x1,x2,x3) = 0.67
# Melhor solução encontrada: x1 = -6.20, x2 = -7.72, x3 = 2.88, f(x1,x2,x3) = 0.72
# Melhor solução encontrada: x1 = -8.80, x2 = -12.08, x3 = 3.90, f(x1,x2,x3) = 0.70
# Melhor solução encontrada: x1 = -8.11, x2 = -6.55, x3 = 4.72, f(x1,x2,x3) = 0.73
# Melhor solução encontrada: x1 = -5.79, x2 = -6.00, x3 = -0.43, f(x1,x2,x3) = 0.77
# Melhor solução encontrada: x1 = -6.39, x2 = -8.10, x3 = -0.84, f(x1,x2,x3) = 0.77
# Melhor solução encontrada: x1 = -8.08, x2 = -8.72, x3 = -5.84, f(x1,x2,x3) = 0.77
# Melhor solução encontrada: x1 = -9.13, x2 = -14.11, x3 = -5.74, f(x1,x2,x3) = 0.76
# Melhor solução encontrada: x1 = -7.84, x2 = -4.86, x3 = 0.53, f(x1,x2,x3) = 0.81
# Melhor solução encontrada: x1 = -6.63, x2 = -6.87, x3 = -2.77, f(x1,x2,x3) = 0.83
# Melhor solução encontrada: x1 = -7.05, x2 = -6.88, x3 = 0.40, f(x1,x2,x3) = 0.84
# Melhor solução encontrada: x1 = -6.92, x2 = -5.97, x3 = -8.57, f(x1,x2,x3) = 0.87
# Melhor solução encontrada: x1 = -6.69, x2 = -7.11, x3 = -1.19, f(x1,x2,x3) = 0.88
# Melhor solução encontrada: x1 = -5.27, x2 = -7.07, x3 = 2.24, f(x1,x2,x3) = 0.91
# Melhor solução encontrada: x1 = -5.35, x2 = -6.84, x3 = 3.64, f(x1,x2,x3) = 0.93
# Melhor solução encontrada: x1 = -6.76, x2 = -3.59, x3 = -0.44, f(x1,x2,x3) = 0.95
# Melhor solução encontrada: x1 = -9.25, x2 = -14.03, x3 = -2.61, f(x1,x2,x3) = 0.91
# Melhor solução encontrada: x1 = -8.88, x2 = -10.32, x3 = 2.63, f(x1,x2,x3) = 0.94
# Melhor solução encontrada: x1 = -11.63, x2 = -14.25, x3 = 4.11, f(x1,x2,x3) = 0.93
# Melhor solução encontrada: x1 = -6.63, x2 = -5.66, x3 = 1.33, f(x1,x2,x3) = 1.02
# Melhor solução encontrada: x1 = -5.74, x2 = -9.32, x3 = -4.18, f(x1,x2,x3) = 1.03
# Melhor solução encontrada: x1 = -9.43, x2 = -4.72, x3 = 1.04, f(x1,x2,x3) = 1.04
# Melhor solução encontrada: x1 = -5.99, x2 = -6.19, x3 = 0.99, f(x1,x2,x3) = 1.08
# Melhor solução encontrada: x1 = -7.83, x2 = -4.78, x3 = 1.14, f(x1,x2,x3) = 1.09
# Melhor solução encontrada: x1 = -8.16, x2 = -6.86, x3 = -1.84, f(x1,x2,x3) = 1.10
# Melhor solução encontrada: x1 = -8.50, x2 = -10.46, x3 = 2.71, f(x1,x2,x3) = 1.11
# Melhor solução encontrada: x1 = -7.91, x2 = -7.61, x3 = 1.59, f(x1,x2,x3) = 1.14
# Melhor solução encontrada: x1 = -9.88, x2 = -9.39, x3 = 7.08, f(x1,x2,x3) = 1.15
# Melhor solução encontrada: x1 = -4.78, x2 = -9.78, x3 = -2.09, f(x1,x2,x3) = 1.21
# Melhor solução encontrada: x1 = -6.04, x2 = -6.27, x3 = 2.45, f(x1,x2,x3) = 1.23
# Melhor solução encontrada: x1 = -9.96, x2 = -11.06, x3 = -1.24, f(x1,x2,x3) = 1.21
# Melhor solução encontrada: x1 = -5.87, x2 = -6.86, x3 = -3.13, f(x1,x2,x3) = 1.27
# Melhor solução encontrada: x1 = -6.39, x2 = -6.97, x3 = -1.37, f(x1,x2,x3) = 1.29
# Melhor solução encontrada: x1 = -9.43, x2 = -12.59, x3 = 0.29, f(x1,x2,x3) = 1.28
# Melhor solução encontrada: x1 = -5.40, x2 = -11.10, x3 = 3.15, f(x1,x2,x3) = 1.33
# Melhor solução encontrada: x1 = -7.34, x2 = -8.68, x3 = 7.01, f(x1,x2,x3) = 1.34
# Melhor solução encontrada: x1 = -13.41, x2 = -2.52, x3 = 2.34, f(x1,x2,x3) = 1.35
# Melhor solução encontrada: x1 = -8.73, x2 = -6.04, x3 = -1.98, f(x1,x2,x3) = 1.39
# Melhor solução encontrada: x1 = -7.31, x2 = -9.61, x3 = -1.83, f(x1,x2,x3) = 1.41
# Melhor solução encontrada: x1 = -8.38, x2 = -5.64, x3 = 1.61, f(x1,x2,x3) = 1.43
# Melhor solução encontrada: x1 = -5.06, x2 = -7.63, x3 = 1.33, f(x1,x2,x3) = 1.46
# Melhor solução encontrada: x1 = -7.31, x2 = -14.07, x3 = -0.64, f(x1,x2,x3) = 1.47
# Melhor solução encontrada: x1 = -7.89, x2 = -7.00, x3 = -3.41, f(x1,x2,x3) = 1.49
# Melhor solução encontrada: x1 = -6.93, x2 = -7.66, x3 = -2.74, f(x1,x2,x3) = 1.51
# Melhor solução encontrada: x1 = -6.39, x2 = -4.08, x3 = 1.06, f(x1,x2,x3) = 1.54
# Melhor solução encontrada: x1 = -9.30, x2 = -8.73, x3 = 0.84, f(x1,x2,x3) = 1.55
# Melhor solução encontrada: x1 = -7.14, x2 = -7.51, x3 = 7.27, f(x1,x2,x3) = 1.57
# Melhor solução encontrada: x1 = -6.86, x2 = -7.01, x3 = 1.77, f(x1,x2,x3) = 1.59
# Melhor solução encontrada: x1 = -6.76, x2 = -5.58, x3 = 3.05, f(x1,x2,x3) = 1.60
# Melhor solução encontrada: x1 = -5.96, x2 = -5.22, x3 = -1.64, f(x1,x2,x3) = 1.62
# Melhor solução encontrada: x1 = -8.32, x2 = -2.23, x3 = 3.17, f(x1,x2,x3) = 1.63
# Melhor solução encontrada: x1 = -7.94, x2 = -1.25, x3 = 0.01, f(x1,x2,x3) = 1.65
# Melhor solução encontrada: x1 = -6.28, x2 = -2.49, x3 = 4.01, f(x1,x2,x3) = 1.66
# Melhor solução encontrada: x1 = -8.37, x2 = 1.92, x3 = -1.89, f(x1,x2,x3) = 1.67
# Melhor solução encontrada: x1 = -6.33, x2 = 0.38, x3 = -2.39, f(x1,x2,x3) = 1.68
# Melhor solução encontrada: x1 = -5.62, x2 = 0.74, x3 = 5.65, f(x1,x2,x3) = 1.69
# Melhor solução encontrada: x1 = -5.44, x2 = 1.41, x3 = -2.43, f(x1,x2,x3) = 1.70
# Melhor solução encontrada: x1 = -5.75, x2 = 4.08, x3 = 8.01, f(x1,x2,x3) = 1.71
# Melhor solução encontrada: x1 = -6.07, x2 = 5.83, x3 = -7.13, f(x1,x2,x3) = 1.71
# Melhor solução encontrada: x1 = -4.26, x2 = 5.22, x3 = 1.89, f(x1,x2,x3) = 1.72
# Melhor solução encontrada: x1 = -3.57, x2 = 5.99, x3 = -1.51, f(x1,x2,x3) = 1.72
# Melhor solução encontrada: x1 = -1.92, x2 = 5.59, x3 = -2.83, f(x1,x2,x3) = 1.72
# Melhor solução encontrada: x1 = -0.88, x2 = 5.95, x3 = 1.73, f(x1,x2,x3) = 1.72
# Melhor solução encontrada: x1 = 0.63, x2 = 5.65, x3 = -6.70, f(x1,x2,x3) = 1.72
# Melhor solução encontrada: x1 = 1.73, x2 = 6.07, x3 = 1.42, f(x1,x2,x3) = 1.71
# Melhor solução encontrada: x1 = 3.40, x2 = 5.36, x3 = 4.43, f(x1,x2,x3) = 1.71
# Melhor solução encontrada: x1 = 4.90, x2 = 5.69, x3 = 1.46, f(x1,x2,x3) = 1.70
# Melhor solução encontrada: x1 = 5.76, x2 = 6.09, x3 = -1.34, f(x1,x2,x3) = 1.69
# Melhor solução encontrada: x1 = 5.45, x2 = 8.14, x3 = 0.38, f(x1,x2,x3) = 1.69
# Melhor solução encontrada: x1 = 9.45, x2 = 4.62, x3 = 8.28, f(x1,x2,x3) = 1.67
# Melhor solução encontrada: x1 = 5.95, x2 = 8.00, x3 = 3.43, f(x1,x2,x3) = 1.66
# Melhor solução encontrada: x1 = 7.31, x2 = 6.33, x3 = 0.19, f(x1,x2,x3) = 1.65
# Melhor solução encontrada: x1 = 5.91, x2 = 5.11, x3 = 3.98, f(x1,x2,x3) = 1.64
# Melhor solução encontrada: x1 = 7.07, x2 = 7.50, x3 = -1.80, f(x1,x2,x3) = 1.62
# Melhor solução encontrada: x1 = 5.70, x2 = 7.64, x3 = -2.53, f(x1,x2,x3) = 1.61
# Melhor solução encontrada: x1 = 6.20, x2 = 10.37, x3 = -3.10, f(x1,x2,x3) = 1.59
# Melhor solução encontrada: x1 = 14.18, x2 = 8.90, x3 = 4.88, f(x1,x2,x3) = 1.56
# Melhor solução encontrada: x1 = 9.30, x2 = 11.62, x3 = 3.64, f(x1,x2,x3) = 1.55
# Melhor solução encontrada: x1 = 8.63, x2 = 5.37, x3 = 0.95, f(x1,x2,x3) = 1.54
# Melhor solução encontrada: x1 = 4.33, x2 = 5.27, x3 = -12.32, f(x1,x2,x3) = 1.54
# Melhor solução encontrada: x1 = 6.19, x2 = 12.53, x3 = -3.63, f(x1,x2,x3) = 1.50
# Melhor solução encontrada: x1 = 13.61, x2 = 7.67, x3 = -2.91, f(x1,x2,x3) = 1.46
# Melhor solução encontrada: x1 = 4.66, x2 = 10.04, x3 = 0.39, f(x1,x2,x3) = 1.47
# Melhor solução encontrada: x1 = 6.45, x2 = 5.95, x3 = 0.37, f(x1,x2,x3) = 1.45
# Melhor solução encontrada: x1 = 8.67, x2 = 4.61, x3 = -1.92, f(x1,x2,x3) = 1.43
# Melhor solução encontrada: x1 = 6.26, x2 = 9.91, x3 = -3.20, f(x1,x2,x3) = 1.40
# Melhor solução encontrada: x1 = 7.23, x2 = 12.77, x3 = 4.54, f(x1,x2,x3) = 1.37
# Melhor solução encontrada: x1 = 9.73, x2 = 9.39, x3 = -7.45, f(x1,x2,x3) = 1.35
# Melhor solução encontrada: x1 = 5.30, x2 = 7.49, x3 = 3.28, f(x1,x2,x3) = 1.35
# Melhor solução encontrada: x1 = 7.59, x2 = 4.48, x3 = -4.86, f(x1,x2,x3) = 1.33
# Melhor solução encontrada: x1 = 7.98, x2 = 8.00, x3 = 2.03, f(x1,x2,x3) = 1.29
# Melhor solução encontrada: x1 = 13.55, x2 = 5.22, x3 = -1.76, f(x1,x2,x3) = 1.25
# Melhor solução encontrada: x1 = 9.37, x2 = 4.47, x3 = -11.29, f(x1,x2,x3) = 1.25
# Melhor solução encontrada: x1 = 9.70, x2 = 6.70, x3 = -3.23, f(x1,x2,x3) = 1.22
# Melhor solução encontrada: x1 = 5.09, x2 = 7.27, x3 = 4.14, f(x1,x2,x3) = 1.23
# Melhor solução encontrada: x1 = 6.41, x2 = 10.59, x3 = -6.21, f(x1,x2,x3) = 1.19
# Melhor solução encontrada: x1 = 6.30, x2 = 8.64, x3 = 6.12, f(x1,x2,x3) = 1.17
# Melhor solução encontrada: x1 = 9.08, x2 = 6.89, x3 = 0.35, f(x1,x2,x3) = 1.14
# Melhor solução encontrada: x1 = 7.35, x2 = 10.77, x3 = 14.07, f(x1,x2,x3) = 1.12
# Melhor solução encontrada: x1 = 5.20, x2 = 10.45, x3 = 1.71, f(x1,x2,x3) = 1.11
# Melhor solução encontrada: x1 = 13.24, x2 = 5.85, x3 = 4.40, f(x1,x2,x3) = 1.05
# Melhor solução encontrada: x1 = 9.52, x2 = 6.54, x3 = -2.85, f(x1,x2,x3) = 1.05
# Melhor solução encontrada: x1 = 6.59, x2 = 17.35, x3 = 6.98, f(x1,x2,x3) = 1.02
# Melhor solução encontrada: x1 = 10.93, x2 = 7.54, x3 = 3.40, f(x1,x2,x3) = 1.00
# Melhor solução encontrada: x1 = 6.00, x2 = 5.42, x3 = 2.44, f(x1,x2,x3) = 1.03
# Melhor solução encontrada: x1 = 11.64, x2 = 13.89, x3 = -4.27, f(x1,x2,x3) = 0.94
# Melhor solução encontrada: x1 = 7.09, x2 = 4.82, x3 = -2.16, f(x1,x2,x3) = 0.98
# Melhor solução encontrada: x1 = 5.21, x2 = 6.37, x3 = 4.98, f(x1,x2,x3) = 0.98
# Melhor solução encontrada: x1 = 7.17, x2 = 11.31, x3 = 3.96, f(x1,x2,x3) = 0.92
# Melhor solução encontrada: x1 = 5.74, x2 = 6.40, x3 = -0.41, f(x1,x2,x3) = 0.94
# Melhor solução encontrada: x1 = 6.25, x2 = 9.23, x3 = 5.39, f(x1,x2,x3) = 0.90
# Melhor solução encontrada: x1 = 13.68, x2 = 8.81, x3 = 0.64, f(x1,x2,x3) = 0.83
# Melhor solução encontrada: x1 = 15.76, x2 = 3.06, x3 = 4.66, f(x1,x2,x3) = 0.82
# Melhor solução encontrada: x1 = 6.02, x2 = 6.25, x3 = 3.42, f(x1,x2,x3) = 0.87
# Melhor solução encontrada: x1 = 5.53, x2 = 8.73, x3 = -3.56, f(x1,x2,x3) = 0.85
# Melhor solução encontrada: x1 = 6.30, x2 = 8.27, x3 = 3.85, f(x1,x2,x3) = 0.83
# Melhor solução encontrada: x1 = 7.68, x2 = 19.35, x3 = 1.21, f(x1,x2,x3) = 0.77
# Melhor solução encontrada: x1 = 7.79, x2 = 6.08, x3 = 0.70, f(x1,x2,x3) = 0.79
# Melhor solução encontrada: x1 = 6.57, x2 = 13.32, x3 = 0.80, f(x1,x2,x3) = 0.76
# Melhor solução encontrada: x1 = 6.22, x2 = 11.62, x3 = -0.51, f(x1,x2,x3) = 0.76
# Melhor solução encontrada: x1 = 7.88, x2 = 10.44, x3 = 4.10, f(x1,x2,x3) = 0.74
# Melhor solução encontrada: x1 = 7.72, x2 = 8.51, x3 = -1.20, f(x1,x2,x3) = 0.73
# Melhor solução encontrada: x1 = 8.62, x2 = 13.77, x3 = 0.94, f(x1,x2,x3) = 0.70
# Melhor solução encontrada: x1 = 9.14, x2 = 6.98, x3 = 6.79, f(x1,x2,x3) = 0.70
# Melhor solução encontrada: x1 = 6.22, x2 = 7.44, x3 = 1.37, f(x1,x2,x3) = 0.71
# Melhor solução encontrada: x1 = 5.23, x2 = 5.23, x3 = -2.09, f(x1,x2,x3) = 0.72
# Melhor solução encontrada: x1 = 4.99, x2 = 9.20, x3 = 2.27, f(x1,x2,x3) = 0.70
# Melhor solução encontrada: x1 = 6.65, x2 = 10.24, x3 = 7.57, f(x1,x2,x3) = 0.67
# Melhor solução encontrada: x1 = 10.21, x2 = 3.74, x3 = -1.57, f(x1,x2,x3) = 0.66
# Melhor solução encontrada: x1 = 8.92, x2 = 8.24, x3 = -0.43, f(x1,x2,x3) = 0.64
# Melhor solução encontrada: x1 = 10.23, x2 = 8.78, x3 = 1.40, f(x1,x2,x3) = 0.63
# Melhor solução encontrada: x1 = 5.79, x2 = 9.72, x3 = 5.23, f(x1,x2,x3) = 0.65
# Melhor solução encontrada: x1 = 9.03, x2 = 13.05, x3 = -4.11, f(x1,x2,x3) = 0.62
# Melhor solução encontrada: x1 = 10.22, x2 = 7.76, x3 = 0.55, f(x1,x2,x3) = 0.61
# Melhor solução encontrada: x1 = 7.39, x2 = 7.76, x3 = 1.90, f(x1,x2,x3) = 0.62
# Melhor solução encontrada: x1 = 5.77, x2 = 5.27, x3 = -1.39, f(x1,x2,x3) = 0.63
# Melhor solução encontrada: x1 = 10.09, x2 = 7.40, x3 = 0.83, f(x1,x2,x3) = 0.60
# Melhor solução encontrada: x1 = 9.02, x2 = 8.64, x3 = -1.43, f(x1,x2,x3) = 0.60
# Melhor solução encontrada: x1 = 10.52, x2 = 4.49, x3 = 2.57, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = 8.02, x2 = 4.74, x3 = -3.51, f(x1,x2,x3) = 0.60
# Melhor solução encontrada: x1 = 5.41, x2 = 9.15, x3 = -7.20, f(x1,x2,x3) = 0.60
# Melhor solução encontrada: x1 = 8.24, x2 = 12.79, x3 = 0.39, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 10.25, x2 = 5.29, x3 = 0.43, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 10.89, x2 = 9.38, x3 = 0.40, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 7.27, x2 = 10.33, x3 = -4.69, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 5.90, x2 = 7.45, x3 = 4.60, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 8.00, x2 = 5.19, x3 = -2.46, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 7.22, x2 = 4.68, x3 = 6.45, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 6.00, x2 = 5.39, x3 = 3.72, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 7.30, x2 = 5.27, x3 = 1.32, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 8.72, x2 = 2.64, x3 = 1.09, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 9.74, x2 = 1.19, x3 = 2.89, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 7.89, x2 = 1.90, x3 = -4.51, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 8.14, x2 = -0.56, x3 = 0.59, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 5.85, x2 = 1.24, x3 = -0.95, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 5.89, x2 = -0.10, x3 = -5.13, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 5.29, x2 = -1.39, x3 = -2.29, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 3.92, x2 = -1.26, x3 = -0.62, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 2.81, x2 = -1.40, x3 = 5.15, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 1.57, x2 = -1.40, x3 = 0.01, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = 0.27, x2 = -1.37, x3 = 2.14, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -0.99, x2 = -1.40, x3 = -0.46, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -2.02, x2 = -1.69, x3 = -2.15, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -3.57, x2 = -1.36, x3 = -4.79, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -4.88, x2 = -1.33, x3 = 2.59, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -6.18, x2 = -1.33, x3 = 3.78, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -6.25, x2 = -3.43, x3 = 8.89, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -7.81, x2 = -2.25, x3 = -4.22, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -7.24, x2 = -4.16, x3 = -2.33, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -6.84, x2 = -4.83, x3 = -1.17, f(x1,x2,x3) = 0.57
# Melhor solução encontrada: x1 = -6.70, x2 = -7.77, x3 = 4.37, f(x1,x2,x3) = 0.57
# Melhor solução encontrada: x1 = -8.96, x2 = -4.56, x3 = 2.74, f(x1,x2,x3) = 0.57
# Melhor solução encontrada: x1 = -6.62, x2 = -6.80, x3 = -4.78, f(x1,x2,x3) = 0.57
# Melhor solução encontrada: x1 = -7.19, x2 = -7.12, x3 = -2.38, f(x1,x2,x3) = 0.57
# Melhor solução encontrada: x1 = -10.38, x2 = -3.08, x3 = -2.24, f(x1,x2,x3) = 0.57
# Melhor solução encontrada: x1 = -7.78, x2 = -7.54, x3 = 1.69, f(x1,x2,x3) = 0.57
# Melhor solução encontrada: x1 = -10.35, x2 = -5.22, x3 = 1.47, f(x1,x2,x3) = 0.57
# Melhor solução encontrada: x1 = -5.32, x2 = -4.98, x3 = -3.04, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = -8.00, x2 = -5.30, x3 = 2.63, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -5.67, x2 = -5.70, x3 = 0.57, f(x1,x2,x3) = 0.59
# Melhor solução encontrada: x1 = -9.49, x2 = -16.30, x3 = -0.25, f(x1,x2,x3) = 0.57
# Melhor solução encontrada: x1 = -7.23, x2 = -12.25, x3 = -0.75, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -10.33, x2 = -6.52, x3 = 1.91, f(x1,x2,x3) = 0.58
# Melhor solução encontrada: x1 = -5.65, x2 = -4.10, x3 = -1.82, f(x1,x2,x3) = 0.62
# Melhor solução encontrada: x1 = -6.83, x2 = -7.00, x3 = -0.36, f(x1,x2,x3) = 0.61
# Melhor solução encontrada: x1 = -7.14, x2 = -7.94, x3 = -2.71, f(x1,x2,x3) = 0.61
# Melhor solução encontrada: x1 = -5.01, x2 = -9.43, x3 = -5.35, f(x1,x2,x3) = 0.63
# Melhor solução encontrada: x1 = -13.67, x2 = -8.84, x3 = 1.72, f(x1,x2,x3) = 0.57
# Melhor solução encontrada: x1 = -15.05, x2 = -8.25, x3 = 2.47, f(x1,x2,x3) = 0.57
# Melhor solução encontrada: x1 = -5.57, x2 = -14.12, x3 = -2.63, f(x1,x2,x3) = 0.63
# Melhor solução encontrada: x1 = -6.99, x2 = -7.96, x3 = 2.00, f(x1,x2,x3) = 0.64
# Melhor solução encontrada: x1 = -4.95, x2 = -13.68, x3 = 2.95, f(x1,x2,x3) = 0.65
# Melhor solução encontrada: x1 = -8.41, x2 = -7.69, x3 = -1.80, f(x1,x2,x3) = 0.65
# Melhor solução encontrada: x1 = -7.50, x2 = -11.60, x3 = -2.66, f(x1,x2,x3) = 0.65
# Melhor solução encontrada: x1 = -9.09, x2 = -5.95, x3 = -1.02, f(x1,x2,x3) = 0.67
# Melhor solução encontrada: x1 = -8.94, x2 = -12.66, x3 = -1.48, f(x1,x2,x3) = 0.65
