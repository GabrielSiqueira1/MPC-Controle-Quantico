# %%
# Bilbiotecas para auxílio na programação matemática
import math, sys 
import numpy as np
import sympy as sp

from scipy import sparse # Produção das diagonais das matrizes
from scipy.sparse import diags 

# Plotagem 2D e 3D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm


from os import path # Suficiente para manipulação de arquivos
    
# Para solução exata
from scipy.special import hermite
from math import factorial

# %matplotlib inline
count = 0

# Para otimização dos sistemas
from scipy import optimize

from numba import jit

# %%
def N(n):
    return 1*1./np.sqrt(np.sqrt(np.pi)*2**n*factorial(n))

def psix(n, x):
    Hn=hermite(n)
    Px = N(n)*Hn(x)*np.exp(-0.5*x**2)
    return Px

def psixt(n, x, t):
    Hn=hermite(n)
    a = complex(0,1)
    Pxt = N(n)*Hn(x)*np.exp(-0.5*x**2)*np.exp(-a*(n+1/2)*t*np.pi)
    return Pxt

# %%
def CrankNicolson(M, O = 0, L = 1, T = 0.5):
    N = 200 #São os pontos no intervalo de tempo
    
    #Pensando no poço quadrado infinito, temos essas duas limitações, onde L varia
    x0, xL = O, L

    P = 3.141111111111111111111111111
    #Discretização espacial
    dx = (xL - x0)/(P*M-1) 

    #Discretização temporal
    t0, tF = 0, T
    dt = (tF - t0)/(P*N-1)

    #Retorno dos números em um intervalo
    xs = np.linspace(x0, xL, M)
    ts = np.linspace(t0, tF, N)

    #Suponha um oscilador harmônico simples
    hbar = 1
    m = 1
    w = np.pi
    V = 1/2*m*w**2*xs**2

    #A partir da demonstração
    a = hbar/(4*m*dx**2) 
    b = 1j*hbar/dt - 2*a - 1/2*V
    c = 1j*hbar/dt + 2*a + 1/2*V

    #Obtenção da matriz
    ##Diagonais principais
    diagPrincipalA = b*np.ones((1,M)) #Cria uma matriz de 1's
    diagPrincipalB = c*np.ones((1,M))

    ##Diagonais secundárias, tem um tamanho a menos
    diagSecundariaA = a*np.ones((1,M-1))
    diagSecundariaB = (-a)*np.ones((1,M-1))

    diagonaisA = [diagPrincipalA, diagSecundariaA, diagSecundariaA]
    matrizA = sparse.diags(diagonaisA, [0, -1, 1], shape=(M,M)).toarray()
    
    diagonaisB = [diagPrincipalB, diagSecundariaB, diagSecundariaB]         
    matrizB = sparse.diags(diagonaisB, [0, -1, 1], shape=(M,M)).toarray()
    
    #Obtenção da matriz psi (Ela acumulará para o psi futuro)
    ps = np.zeros((M, N))
    psi_c = np.zeros((M, N))

    #Condição inicial
    ps[:,0] = 1.0 * psix(0, xs) + 0.0 * psix(1, xs) #A primeira coluna da matriz terá a equação inicial, em todas as posições
    psi_c = ps.astype(complex)
    #For para o acúmulo de resultados
    for k in range(1,N):
        b = np.matmul(matrizB, np.array(psi_c[0:M, k-1])) #Multiplicação de arrays já que houve uma conversão anterior
        psi_c[0:M, k] = np.linalg.solve(matrizA, b) #Matlab: x = A\b
        #plt.plot(xs, np.absolute(psi_c[0:M, k])**2)
    return psi_c

# %%
def multMatrizes(M, us, O = -5, L = 5, T = 10):
    N = 200 #São os pontos no intervalo de tempo
    
    #Pensando no poço quadrado infinito, temos essas duas limitações, onde L varia
    x0, xL = O, L

    P = 3.141111111111111111111111111
    #Discretização espacial
    dx = (xL - x0)/(P*M-1) 

    #Discretização temporal
    t0, tF = 0, T
    dt = (tF - t0)/(P*N-1)

    #Retorno dos números em um intervalo
    xs = np.linspace(x0, xL, M)
    ts = np.linspace(t0, tF, N)
    
    #Suponha um oscilador harmônico simples
    hbar = 1
    m = 1
    w = np.pi
    #V = us #V(x,u(t))
    V = 1/2*m*w**2*xs**2

    #A partir da demonstração
    a = hbar/(4*m*dx**2) 
    b = 1j*hbar/dt - 2*a - 1/2*V
    c = 1j*hbar/dt + 2*a + 1/2*V

    #Obtenção da matriz
    ##Diagonais principais
    diagPrincipalA = b*np.ones((1,M)) #Cria uma matriz de 1's
    diagPrincipalB = c*np.ones((1,M))

    ##Diagonais secundárias, tem um tamanho a menos
    diagSecundariaA = a*np.ones((1,M-1))
    diagSecundariaB = (-a)*np.ones((1,M-1))

    diagonaisA = [diagPrincipalA, diagSecundariaA, diagSecundariaA]
    matrizA = sparse.diags(diagonaisA, [0, -1, 1], shape=(M,M)).toarray()
    
    diagonaisB = [diagPrincipalB, diagSecundariaB, diagSecundariaB]         
    matrizB = sparse.diags(diagonaisB, [0, -1, 1], shape=(M,M)).toarray()

    return np.matmul(np.linalg.inv(matrizA), matrizB)

# %%
# Gradiente e função objetivo

def ExactSolution(M, T = 5, L = 5):
    N = 1000

    xs = np.linspace(-5, L, M)
    ts = np.linspace(0, N/100, T)
    
    psiExato = np.zeros((M, N)).astype(complex)
    r=0
    for i in np.arange(-5, 5, 0.05):
        for j in np.arange(0, 10, 0.05):
            psiExato[r][int(j*20)] = 1/np.sqrt(2)*psixt(0,i,j)+1/np.sqrt(2)*psixt(1,i,j)
        r+=1
    return psiExato

def Objetivo(y, x, psi, psiExato):
    A = np.zeros((200,200))
    B = np.zeros((200,200))
    A = multMatrizes(M = 200, us = x[0])
    B = multMatrizes(M = 200, us = x[1])
    return ((np.linalg.norm(np.array(psiExato[0:200, y])-np.array(psi)))**2+
            (np.linalg.norm(np.array(psiExato[0:200, y+1])-np.array(np.matmul(A,psi))))**2+
            (np.linalg.norm(np.array(psiExato[0:200, y+2])-np.array(np.matmul(np.matmul(B,A),psi))))**2)


def ObjetivoS(y, x, psi, psiExato, alpha, d): #Função para a seção áurea
    z = x + alpha * d
    A = np.zeros((200,200))
    B = np.zeros((200,200))
    A = multMatrizes(M = 200, us = z[0])
    B = multMatrizes(M = 200, us = z[1])
    return ((np.linalg.norm(np.array(psiExato[0:200, y])-np.array(psi)))**2+
            (np.linalg.norm(np.array(psiExato[0:200, y+1])-np.array(np.matmul(A,psi))))**2+
            (np.linalg.norm(np.array(psiExato[0:200, y+2])-np.array(np.matmul(np.matmul(B,A),psi))))**2)


def SecaoAurea(y, x, psi, psiExato, d):
    eps = 0.001
    a = 0
    b = 1
    xa = b - 0.618*(b-a)
    xb = a + 0.618*(b-a)
    fxa = ObjetivoS(y, x, psi, psiExato, xa, d)
    fxb = ObjetivoS(y, x, psi, psiExato, xb, d)
    
    while(b - a > eps):
        if(fxa < fxb):
            b = xb
            xb = xa
            xa = b - 0.618*(b - a)
            fxb = fxa
            fxa = ObjetivoS(y, x, psi, psiExato, xa, d)
        else:
            a = xa
            xa = xb
            xb = a + 0.618*(b - a)
            fxa = fxb
            fxb = ObjetivoS(y, x, psi, psiExato, xb, d)
            
    xp = (a+b)/2
    return xp

#Avaliação do gradiente

def gradiente(x, tempo, psi, psiExato):
    h = 0.000000001
    grad = []
    
    for i in range(len(x)):
        xh = x.copy()
        xh[i] = xh[i] + h
        dx = (Objetivo(tempo, xh, psi, psiExato)-Objetivo(tempo, x, psi, psiExato))/h
        grad.append(dx)
    return grad


def hessiana(x, tempo, psi, psiExato):
    n = len(x)
    h = 0.001
    Hx = np.zeros((n,n))
    gradfx = gradiente(x, tempo, psi, psiExato)
    
    for i in range(len(x)):
        xh = x.copy()
        xh[i] = xh[i] + h
        gradfxh = gradiente(xh, tempo, psi, psiExato)
        
        for j in range(len(x)):
            Hx[i,j] = ((gradfxh[j] - gradfx[j])/h)
    
    return Hx

# %%
import random

psi = np.zeros((200, 200))
psi_f = np.zeros((200,200))
psi_g = psi_f.astype(complex)
psi = CrankNicolson(M = 200, O = -5, L = 5, T = 10)
psiExato = ExactSolution(M = 200)

# %%
def N(n):
    return 1*1./np.sqrt(np.sqrt(np.pi)*2**n*factorial(n))

def psii(n, x):
    Hn=hermite(n)
    Px = N(n)*Hn(x)*np.exp(-0.5*x**2)
    return Px

def psiii(n, x, t):
    Hn=hermite(n)
    a = complex(0,1)
    Pxt = N(n)*Hn(x.real)*np.exp(-0.5*x**2)*np.exp(-a*(n+1/2)*t*np.pi)
    return Pxt

# %%
def MetodoGradNewton(x, tempo, psi, psiExato):
    
    eps = 0.00000000001
    SequenciaPontos = [x]
    
    errox = eps + 1
    xant = x.copy()
    
    errof = eps + 1
    FuncF = Objetivo(tempo, x, psi, psiExato)
    
    k = 0
    kmax = 100
    normagrad = eps + 1
    
    CP = ''
    
    while(CP == ''):
        #print(x)
        d = -1*np.array(gradiente(x, tempo, psi, psiExato))
        #d = -1*(np.matmul(np.linalg.inv(hessiana(x, tempo, psi, psiExato)),gradiente(x, tempo, psi, psiExato)))
        alpha = SecaoAurea(tempo, x, psi, psiExato, d)
        x = x + alpha * d
        
        errox = np.linalg.norm(xant - x)
        xant = x.copy()
        if(errox <= eps):
            CP = CP + 'Erro x '
        normagrad = np.linalg.norm(d)
        if(normagrad <= eps):
            CP = CP + 'Norma Gradiente '
        FuncFx = Objetivo(tempo, x, psi, psiExato)
        errof = abs(FuncF - FuncFx)
        FuncF = FuncFx
        if(errof <= eps):
            CP = CP + 'Erro F '
        if(k >= kmax):
            CP = 'Numero de iteracoes '
            
        k += 1
        SequenciaPontos.append(x)
        
    xOtimo = x
    return SequenciaPontos, k, xOtimo, CP

x = []
x.append(random.uniform(-5, 5))
x.append(random.uniform(-5, 5))
tempo = 0
resultado = MetodoGradNewton(x, tempo, psi, psiExato)
print('iteracoes = ', resultado[1])
print('x = ', resultado[2])
print('Criterio de parada: ', resultado[3])
# Out:
# iteracoes =  1
# x =  [-2.65045848  2.61354576]
# Criterio de parada:  Erro x Norma Gradiente Erro F

# %%
u1 = []
u2 = []
vetor = []
u1.append(random.uniform(-5, 5))
u1.append(random.uniform(-5, 5))
tempo = 0
xs = np.linspace(-5,5,200)

while tempo < 199:
    print(u1)
    psi_g[0:200, tempo] = psi[0:200, tempo]
    plt.plot(xs, np.absolute(psi[0:200, tempo])**2)
    u2 = MetodoGradNewton(u1, tempo, psi, psiExato)
    print("Iteracao = ", (tempo+1))
    print("Otimo = ", u2[2])
    print("Iteracoes = ", u2[1])
    print("Criterio = ", u2[3])
    print("---------------")
    D = multMatrizes(M = 200, us = u2[2][0])
    psi = np.matmul(D, psi)
    tempo += 1
    u1 = []
    u1.append(u2[2][1])
    u1.append(random.uniform(-5, 5))
# Out:
# [2.021208586213449, 2.3764328307197404]
# Iteracao =  1
# Otimo =  [2.02120859 2.37643283]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.3764328307197404, -2.813637562646748]
# Iteracao =  2
# Otimo =  [ 2.37643283 -2.81363756]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.813637562646748, -0.034352524952222296]
# Iteracao =  3
# Otimo =  [-2.81363756 -0.03435252]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.034352524952222296, 2.6885156859664487]
# Iteracao =  4
# Otimo =  [-0.03435252  2.68851569]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.6885156859664487, 0.8281536710465023]
# Iteracao =  5
# Otimo =  [2.68851569 0.82815367]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.8281536710465023, -0.2455942237885731]
# Iteracao =  6
# Otimo =  [ 0.82815367 -0.24559422]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.2455942237885731, -0.25912372109607773]
# Iteracao =  7
# Otimo =  [-0.24559422 -0.25912372]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.25912372109607773, 2.0045187062428464]
# Iteracao =  8
# Otimo =  [-0.25912372  2.00451871]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.0045187062428464, 0.6316451268080296]
# Iteracao =  9
# Otimo =  [2.00451871 0.63164513]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.6316451268080296, -2.4453656649842137]
# Iteracao =  10
# Otimo =  [ 0.63164513 -2.44536566]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.4453656649842137, 1.3885308708605928]
# Iteracao =  11
# Otimo =  [-2.44536566  1.38853087]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.3885308708605928, 2.52440782251524]
# Iteracao =  12
# Otimo =  [1.38853087 2.52440782]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.52440782251524, 3.3481650289660934]
# Iteracao =  13
# Otimo =  [2.52440782 3.34816503]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.3481650289660934, 4.526474272991191]
# Iteracao =  14
# Otimo =  [3.34816503 4.52647427]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.526474272991191, 2.448250478961011]
# Iteracao =  15
# Otimo =  [4.52647427 2.44825048]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.448250478961011, 1.2039713310422515]
# Iteracao =  16
# Otimo =  [2.44825048 1.20397133]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.2039713310422515, 4.007137765885343]
# Iteracao =  17
# Otimo =  [1.20397133 4.00713777]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.007137765885343, -2.089500073962378]
# Iteracao =  18
# Otimo =  [ 4.00713777 -2.08950007]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.089500073962378, -0.150188590241628]
# Iteracao =  19
# Otimo =  [-2.08950007 -0.15018859]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.150188590241628, -4.775227006190779]
# Iteracao =  20
# Otimo =  [-0.15018859 -4.77522701]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.775227006190779, -0.01620200102682734]
# Iteracao =  21
# Otimo =  [-4.77522701 -0.016202  ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.01620200102682734, -1.869299397059799]
# Iteracao =  22
# Otimo =  [-0.016202  -1.8692994]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.869299397059799, -4.713774496482687]
# Iteracao =  23
# Otimo =  [-1.8692994 -4.7137745]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.713774496482687, -2.378077497494002]
# Iteracao =  24
# Otimo =  [-4.7137745 -2.3780775]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.378077497494002, 1.7512416086984341]
# Iteracao =  25
# Otimo =  [-2.3780775   1.75124161]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.7512416086984341, -2.5545074611260175]
# Iteracao =  26
# Otimo =  [ 1.75124161 -2.55450746]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.5545074611260175, 2.4299366512851925]
# Iteracao =  27
# Otimo =  [-2.55450746  2.42993665]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.4299366512851925, 2.8618849284186076]
# Iteracao =  28
# Otimo =  [2.42993665 2.86188493]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.8618849284186076, 2.1849183938602446]
# Iteracao =  29
# Otimo =  [2.86188493 2.18491839]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.1849183938602446, 4.7501491472776465]
# Iteracao =  30
# Otimo =  [2.18491839 4.75014915]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.7501491472776465, -1.8867672580629344]
# Iteracao =  31
# Otimo =  [ 4.75014915 -1.88676726]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.8867672580629344, 1.3066705235023202]
# Iteracao =  32
# Otimo =  [-1.88676726  1.30667052]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.3066705235023202, 1.5827392564509122]
# Iteracao =  33
# Otimo =  [1.30667052 1.58273926]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.5827392564509122, -4.417227278619215]
# Iteracao =  34
# Otimo =  [ 1.58273926 -4.41722728]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.417227278619215, 1.1295216443556457]
# Iteracao =  35
# Otimo =  [-4.41722728  1.12952164]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.1295216443556457, 2.5800654751221144]
# Iteracao =  36
# Otimo =  [1.12952164 2.58006548]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.5800654751221144, 1.217973730322596]
# Iteracao =  37
# Otimo =  [2.58006548 1.21797373]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.217973730322596, -1.6938547438095064]
# Iteracao =  38
# Otimo =  [ 1.21797373 -1.69385474]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.6938547438095064, 0.26638323504773176]
# Iteracao =  39
# Otimo =  [-1.69385474  0.26638324]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.26638323504773176, 0.5996032907718387]
# Iteracao =  40
# Otimo =  [0.26638324 0.59960329]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.5996032907718387, -2.2343917595456677]
# Iteracao =  41
# Otimo =  [ 0.59960329 -2.23439176]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.2343917595456677, -0.16115493333398057]
# Iteracao =  42
# Otimo =  [-2.23439176 -0.16115493]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.16115493333398057, -1.394612522557881]
# Iteracao =  43
# Otimo =  [-0.16115493 -1.39461252]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.394612522557881, 4.719642675316276]
# Iteracao =  44
# Otimo =  [-1.39461252  4.71964268]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.719642675316276, -3.750412851573678]
# Iteracao =  45
# Otimo =  [ 4.71964268 -3.75041285]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.750412851573678, 1.6871929423300545]
# Iteracao =  46
# Otimo =  [-3.75041285  1.68719294]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.6871929423300545, 1.2040621631501667]
# Iteracao =  47
# Otimo =  [1.68719294 1.20406216]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.2040621631501667, -3.2107697537744784]
# Iteracao =  48
# Otimo =  [ 1.20406216 -3.21076975]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.2107697537744784, -3.364974138316137]
# Iteracao =  49
# Otimo =  [-3.21076975 -3.36497414]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.364974138316137, 4.701199037964781]
# Iteracao =  50
# Otimo =  [-3.36497414  4.70119904]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.701199037964781, 1.038470225663768]
# Iteracao =  51
# Otimo =  [4.70119904 1.03847023]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.038470225663768, -2.3205308479794775]
# Iteracao =  52
# Otimo =  [ 1.03847023 -2.32053085]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.3205308479794775, 2.084203564391708]
# Iteracao =  53
# Otimo =  [-2.32053085  2.08420356]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.084203564391708, 2.399711310393852]
# Iteracao =  54
# Otimo =  [2.08420356 2.39971131]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.399711310393852, -4.5021619182003425]
# Iteracao =  55
# Otimo =  [ 2.39971131 -4.50216192]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.5021619182003425, -1.200251217112791]
# Iteracao =  56
# Otimo =  [-4.50216192 -1.20025122]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.200251217112791, 1.3763434096836562]
# Iteracao =  57
# Otimo =  [-1.20025122  1.37634341]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.3763434096836562, -4.0496737960064655]
# Iteracao =  58
# Otimo =  [ 1.37634341 -4.0496738 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.0496737960064655, -2.0137783509740483]
# Iteracao =  59
# Otimo =  [-4.0496738  -2.01377835]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.0137783509740483, 0.7425987851896174]
# Iteracao =  60
# Otimo =  [-2.01377835  0.74259879]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.7425987851896174, -0.4575346100355535]
# Iteracao =  61
# Otimo =  [ 0.74259879 -0.45753461]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.4575346100355535, -1.1252939735429166]
# Iteracao =  62
# Otimo =  [-0.45753461 -1.12529397]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.1252939735429166, 3.622646724578077]
# Iteracao =  63
# Otimo =  [-1.12529397  3.62264672]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.622646724578077, 1.9833704822247977]
# Iteracao =  64
# Otimo =  [3.62264672 1.98337048]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.9833704822247977, -2.933574556258516]
# Iteracao =  65
# Otimo =  [ 1.98337048 -2.93357456]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.933574556258516, -3.668508189419475]
# Iteracao =  66
# Otimo =  [-2.93357456 -3.66850819]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.668508189419475, -4.372899711668746]
# Iteracao =  67
# Otimo =  [-3.66850819 -4.37289971]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.372899711668746, -3.2426059907315774]
# Iteracao =  68
# Otimo =  [-4.37289971 -3.24260599]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.2426059907315774, -1.4772636563474761]
# Iteracao =  69
# Otimo =  [-3.24260599 -1.47726366]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.4772636563474761, -4.109487957857506]
# Iteracao =  70
# Otimo =  [-1.47726366 -4.10948796]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.109487957857506, -1.4984167122097514]
# Iteracao =  71
# Otimo =  [-4.10948796 -1.49841671]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.4984167122097514, 4.807393902428732]
# Iteracao =  72
# Otimo =  [-1.49841671  4.8073939 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.807393902428732, -4.495316839813359]
# Iteracao =  73
# Otimo =  [ 4.8073939  -4.49531684]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.495316839813359, -2.3828089124267793]
# Iteracao =  74
# Otimo =  [-4.49531684 -2.38280891]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.3828089124267793, 3.0696183651452085]
# Iteracao =  75
# Otimo =  [-2.38280891  3.06961837]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.0696183651452085, 3.4909084228831784]
# Iteracao =  76
# Otimo =  [3.06961837 3.49090842]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.4909084228831784, 0.4290694523682177]
# Iteracao =  77
# Otimo =  [3.49090842 0.42906945]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.4290694523682177, 4.331689970818706]
# Iteracao =  78
# Otimo =  [0.42906945 4.33168997]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.331689970818706, -4.6348354995588]
# Iteracao =  79
# Otimo =  [ 4.33168997 -4.6348355 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.6348354995588, -4.459622811901825]
# Iteracao =  80
# Otimo =  [-4.6348355  -4.45962281]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.459622811901825, -4.230308125764937]
# Iteracao =  81
# Otimo =  [-4.45962281 -4.23030813]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.230308125764937, -4.31095059579778]
# Iteracao =  82
# Otimo =  [-4.23030813 -4.3109506 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.31095059579778, 1.164968972001339]
# Iteracao =  83
# Otimo =  [-4.3109506   1.16496897]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.164968972001339, 0.35435627567326566]
# Iteracao =  84
# Otimo =  [1.16496897 0.35435628]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.35435627567326566, -0.6718472540625164]
# Iteracao =  85
# Otimo =  [ 0.35435628 -0.67184725]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.6718472540625164, 0.8647745542683065]
# Iteracao =  86
# Otimo =  [-0.67184725  0.86477455]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.8647745542683065, -4.876449921382972]
# Iteracao =  87
# Otimo =  [ 0.86477455 -4.87644992]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.876449921382972, 2.2895531844301953]
# Iteracao =  88
# Otimo =  [-4.87644992  2.28955318]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.2895531844301953, -0.4608139602834962]
# Iteracao =  89
# Otimo =  [ 2.28955318 -0.46081396]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.4608139602834962, -2.3926033041807173]
# Iteracao =  90
# Otimo =  [-0.46081396 -2.3926033 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.3926033041807173, -0.4561792520958372]
# Iteracao =  91
# Otimo =  [-2.3926033  -0.45617925]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.4561792520958372, -2.3227464542702227]
# Iteracao =  92
# Otimo =  [-0.45617925 -2.32274645]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.3227464542702227, 2.5258889761865078]
# Iteracao =  93
# Otimo =  [-2.32274645  2.52588898]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.5258889761865078, -3.0396523576848233]
# Iteracao =  94
# Otimo =  [ 2.52588898 -3.03965236]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.0396523576848233, -3.9448179238087135]
# Iteracao =  95
# Otimo =  [-3.03965236 -3.94481792]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.9448179238087135, 2.92373726120307]
# Iteracao =  96
# Otimo =  [-3.94481792  2.92373726]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.92373726120307, 4.6025782007096545]
# Iteracao =  97
# Otimo =  [2.92373726 4.6025782 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.6025782007096545, 3.044070363737376]
# Iteracao =  98
# Otimo =  [4.6025782  3.04407036]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.044070363737376, -2.9339271747266658]
# Iteracao =  99
# Otimo =  [ 3.04407036 -2.93392717]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.9339271747266658, -3.2185043594725293]
# Iteracao =  100
# Otimo =  [-2.93392717 -3.21850436]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.2185043594725293, -4.016824812903912]
# Iteracao =  101
# Otimo =  [-3.21850436 -4.01682481]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.016824812903912, -3.390913665515124]
# Iteracao =  102
# Otimo =  [-4.01682481 -3.39091367]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.390913665515124, 3.428385440278488]
# Iteracao =  103
# Otimo =  [-3.39091367  3.42838544]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.428385440278488, -2.6763043140981457]
# Iteracao =  104
# Otimo =  [ 3.42838544 -2.67630431]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.6763043140981457, -4.299364525434455]
# Iteracao =  105
# Otimo =  [-2.67630431 -4.29936453]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.299364525434455, 1.7320748082399646]
# Iteracao =  106
# Otimo =  [-4.29936453  1.73207481]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.7320748082399646, 3.170021630325566]
# Iteracao =  107
# Otimo =  [1.73207481 3.17002163]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.170021630325566, -0.5911214646727956]
# Iteracao =  108
# Otimo =  [ 3.17002163 -0.59112146]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.5911214646727956, 3.0196985904271614]
# Iteracao =  109
# Otimo =  [-0.59112146  3.01969859]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.0196985904271614, 0.04434979140889439]
# Iteracao =  110
# Otimo =  [3.01969859 0.04434979]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.04434979140889439, -0.33147745286913555]
# Iteracao =  111
# Otimo =  [ 0.04434979 -0.33147745]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.33147745286913555, -3.1182978902393907]
# Iteracao =  112
# Otimo =  [-0.33147745 -3.11829789]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.1182978902393907, -1.6410554604898273]
# Iteracao =  113
# Otimo =  [-3.11829789 -1.64105546]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.6410554604898273, 1.3496723083620328]
# Iteracao =  114
# Otimo =  [-1.64105546  1.34967231]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.3496723083620328, 1.2734410424289582]
# Iteracao =  115
# Otimo =  [1.34967231 1.27344104]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.2734410424289582, 3.6119727404954975]
# Iteracao =  116
# Otimo =  [1.27344104 3.61197274]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.6119727404954975, -3.1296039203045445]
# Iteracao =  117
# Otimo =  [ 3.61197274 -3.12960392]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.1296039203045445, 0.19133947235771132]
# Iteracao =  118
# Otimo =  [-3.12960392  0.19133947]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.19133947235771132, -3.954843885285846]
# Iteracao =  119
# Otimo =  [ 0.19133947 -3.95484389]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.954843885285846, 1.4336566622646272]
# Iteracao =  120
# Otimo =  [-3.95484389  1.43365666]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.4336566622646272, -2.5638285868075217]
# Iteracao =  121
# Otimo =  [ 1.43365666 -2.56382859]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.5638285868075217, 2.998384500375149]
# Iteracao =  122
# Otimo =  [-2.56382859  2.9983845 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.998384500375149, 0.9795074068310559]
# Iteracao =  123
# Otimo =  [2.9983845  0.97950741]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.9795074068310559, -4.299086433623392]
# Iteracao =  124
# Otimo =  [ 0.97950741 -4.29908643]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.299086433623392, 1.6027596151890036]
# Iteracao =  125
# Otimo =  [-4.29908643  1.60275962]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.6027596151890036, 0.09272930855072481]
# Iteracao =  126
# Otimo =  [1.60275962 0.09272931]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.09272930855072481, -2.174200243488679]
# Iteracao =  127
# Otimo =  [ 0.09272931 -2.17420024]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.174200243488679, 4.8316481096069825]
# Iteracao =  128
# Otimo =  [-2.17420024  4.83164811]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.8316481096069825, 2.911142648872368]
# Iteracao =  129
# Otimo =  [4.83164811 2.91114265]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.911142648872368, -4.359592256519795]
# Iteracao =  130
# Otimo =  [ 2.91114265 -4.35959226]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.359592256519795, -0.8630971944952393]
# Iteracao =  131
# Otimo =  [-4.35959226 -0.86309719]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.8630971944952393, 4.056222183561225]
# Iteracao =  132
# Otimo =  [-0.86309719  4.05622218]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.056222183561225, 4.7108702735636605]
# Iteracao =  133
# Otimo =  [4.05622218 4.71087027]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.7108702735636605, -4.911845657968844]
# Iteracao =  134
# Otimo =  [ 4.71087027 -4.91184566]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.911845657968844, 2.9341671450146825]
# Iteracao =  135
# Otimo =  [-4.91184566  2.93416715]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.9341671450146825, -3.5554399996908526]
# Iteracao =  136
# Otimo =  [ 2.93416715 -3.55544   ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.5554399996908526, 2.085036049305674]
# Iteracao =  137
# Otimo =  [-3.55544     2.08503605]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.085036049305674, -2.619410274166535]
# Iteracao =  138
# Otimo =  [ 2.08503605 -2.61941027]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.619410274166535, 0.8895772451927231]
# Iteracao =  139
# Otimo =  [-2.61941027  0.88957725]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.8895772451927231, 2.6813902273183583]
# Iteracao =  140
# Otimo =  [0.88957725 2.68139023]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.6813902273183583, 3.6851019387719433]
# Iteracao =  141
# Otimo =  [2.68139023 3.68510194]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.6851019387719433, 4.592961363905491]
# Iteracao =  142
# Otimo =  [3.68510194 4.59296136]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.592961363905491, 3.938846760557869]
# Iteracao =  143
# Otimo =  [4.59296136 3.93884676]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.938846760557869, 4.274973256978882]
# Iteracao =  144
# Otimo =  [3.93884676 4.27497326]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.274973256978882, -3.8311992495654765]
# Iteracao =  145
# Otimo =  [ 4.27497326 -3.83119925]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.8311992495654765, -1.5133241343757886]
# Iteracao =  146
# Otimo =  [-3.83119925 -1.51332413]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.5133241343757886, -1.084941716208192]
# Iteracao =  147
# Otimo =  [-1.51332413 -1.08494172]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.084941716208192, 4.423274504962901]
# Iteracao =  148
# Otimo =  [-1.08494172  4.4232745 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.423274504962901, -1.596344201363884]
# Iteracao =  149
# Otimo =  [ 4.4232745 -1.5963442]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.596344201363884, 2.902807817795983]
# Iteracao =  150
# Otimo =  [-1.5963442   2.90280782]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.902807817795983, 0.032089641730567386]
# Iteracao =  151
# Otimo =  [2.90280782 0.03208964]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.032089641730567386, 0.07791627261064349]
# Iteracao =  152
# Otimo =  [0.03208964 0.07791627]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.07791627261064349, 3.247588634552814]
# Iteracao =  153
# Otimo =  [0.07791627 3.24758863]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.247588634552814, 1.8384568451602812]
# Iteracao =  154
# Otimo =  [3.24758863 1.83845685]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.8384568451602812, -1.3650706992034003]
# Iteracao =  155
# Otimo =  [ 1.83845685 -1.3650707 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.3650706992034003, 3.75617812508362]
# Iteracao =  156
# Otimo =  [-1.3650707   3.75617813]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.75617812508362, -3.3323332889356094]
# Iteracao =  157
# Otimo =  [ 3.75617813 -3.33233329]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.3323332889356094, -1.79618275294807]
# Iteracao =  158
# Otimo =  [-3.33233329 -1.79618275]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.79618275294807, 1.6595716384424497]
# Iteracao =  159
# Otimo =  [-1.79618275  1.65957164]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.6595716384424497, -4.120871045947013]
# Iteracao =  160
# Otimo =  [ 1.65957164 -4.12087105]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.120871045947013, -2.391411770095393]
# Iteracao =  161
# Otimo =  [-4.12087105 -2.39141177]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.391411770095393, 3.876518953335422]
# Iteracao =  162
# Otimo =  [-2.39141177  3.87651895]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.876518953335422, -4.662842574339889]
# Iteracao =  163
# Otimo =  [ 3.87651895 -4.66284257]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.662842574339889, -1.2665328722241123]
# Iteracao =  164
# Otimo =  [-4.66284257 -1.26653287]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.2665328722241123, 3.683267628694484]
# Iteracao =  165
# Otimo =  [-1.26653287  3.68326763]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.683267628694484, -2.7680213306052917]
# Iteracao =  166
# Otimo =  [ 3.68326763 -2.76802133]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.7680213306052917, -0.5885771237750479]
# Iteracao =  167
# Otimo =  [-2.76802133 -0.58857712]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.5885771237750479, 2.2834251330082544]
# Iteracao =  168
# Otimo =  [-0.58857712  2.28342513]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.2834251330082544, -2.29721390428284]
# Iteracao =  169
# Otimo =  [ 2.28342513 -2.2972139 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.29721390428284, 1.1130258849687324]
# Iteracao =  170
# Otimo =  [-2.2972139   1.11302588]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.1130258849687324, -2.940370966063565]
# Iteracao =  171
# Otimo =  [ 1.11302588 -2.94037097]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.940370966063565, 0.04924548824698061]
# Iteracao =  172
# Otimo =  [-2.94037097  0.04924549]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.04924548824698061, -3.6905068299865276]
# Iteracao =  173
# Otimo =  [ 0.04924549 -3.69050683]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.6905068299865276, 3.7345914944670717]
# Iteracao =  174
# Otimo =  [-3.69050683  3.73459149]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.7345914944670717, 4.073089766332119]
# Iteracao =  175
# Otimo =  [3.73459149 4.07308977]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.073089766332119, 1.247599531281569]
# Iteracao =  176
# Otimo =  [4.07308977 1.24759953]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.247599531281569, -1.7006420303278427]
# Iteracao =  177
# Otimo =  [ 1.24759953 -1.70064203]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.7006420303278427, -1.6368277711550538]
# Iteracao =  178
# Otimo =  [-1.70064203 -1.63682777]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.6368277711550538, 1.4534738006304524]
# Iteracao =  179
# Otimo =  [-1.63682777  1.4534738 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.4534738006304524, 4.13055855224113]
# Iteracao =  180
# Otimo =  [1.4534738  4.13055855]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.13055855224113, -0.03869569790292271]
# Iteracao =  181
# Otimo =  [ 4.13055855 -0.0386957 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.03869569790292271, -0.6776897790956324]
# Iteracao =  182
# Otimo =  [-0.0386957  -0.67768978]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.6776897790956324, 4.0423911077082195]
# Iteracao =  183
# Otimo =  [-0.67768978  4.04239111]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.0423911077082195, 0.2913598820250227]
# Iteracao =  184
# Otimo =  [4.04239111 0.29135988]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.2913598820250227, 1.8197131455577242]
# Iteracao =  185
# Otimo =  [0.29135988 1.81971315]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.8197131455577242, -1.2255485975423475]
# Iteracao =  186
# Otimo =  [ 1.81971315 -1.2255486 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.2255485975423475, 2.2828343678638543]
# Iteracao =  187
# Otimo =  [-1.2255486   2.28283437]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.2828343678638543, 2.870657200790645]
# Iteracao =  188
# Otimo =  [2.28283437 2.8706572 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.870657200790645, 1.5340380450975557]
# Iteracao =  189
# Otimo =  [2.8706572  1.53403805]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.5340380450975557, 1.951735467828259]
# Iteracao =  190
# Otimo =  [1.53403805 1.95173547]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.951735467828259, -2.5458012688880647]
# Iteracao =  191
# Otimo =  [ 1.95173547 -2.54580127]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.5458012688880647, 4.498183311950964]
# Iteracao =  192
# Otimo =  [-2.54580127  4.49818331]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.498183311950964, 0.44429231082680243]
# Iteracao =  193
# Otimo =  [4.49818331 0.44429231]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.44429231082680243, 4.126675501994912]
# Iteracao =  194
# Otimo =  [0.44429231 4.1266755 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.126675501994912, -0.2887181958014162]
# Iteracao =  195
# Otimo =  [ 4.1266755 -0.2887182]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.2887181958014162, 3.7641956210311065]
# Iteracao =  196
# Otimo =  [-0.2887182   3.76419562]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.7641956210311065, -1.5372849458313196]
# Iteracao =  197
# Otimo =  [ 3.76419562 -1.53728495]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.5372849458313196, 1.4379267531230475]
# Iteracao =  198
# Otimo =  [-1.53728495  1.43792675]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.4379267531230475, 2.808165631856072]
# Iteracao =  199
# Otimo =  [1.43792675 2.80816563]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------

# %%
from matplotlib import animation
from matplotlib.animation import PillowWriter

def animate(i):
    xs = np.linspace(-5,5,200)
    ln1.set_data(xs, np.absolute(psi_g[0:200,i-1])**2)
    ln2.set_data(xs, np.absolute(psiExato[0:200,i-1])**2)
    time_text.set_text('$t=$'+'{:.1f}'.format(i/100))
    
fig, ax = plt.subplots(1, 1,figsize=(8,4))
ax.grid()
ln1, = plt.plot([], [], 'r-', lw=2, markersize=8, label='Curva')
ln2, = plt.plot([], [], 'b-', lw=2, markersize=8, label='Ideal')
time_text = ax.text(0.85, 1, '', fontsize=15,
           bbox=dict(facecolor='white', edgecolor='black'))
ax.set_ylim(0, 1)
ax.set_xlim(-5,5)
title = ax.set_title('Resposta analítica')
ax.set_ylabel('$|\psi(x)|^2$', fontsize=20)
ax.set_xlabel('$x$', fontsize=20)
ax.legend(loc='upper left')
ax.set_title('')
plt.tight_layout()
ani = animation.FuncAnimation(fig, animate, frames=200, interval=200)
ani.save('300x300.gif',writer='pillow',fps=10,dpi=100)

# %%
plt.plot(xs, np.absolute(psi_g[0:200,0:10])**2)
# Out:
# [<matplotlib.lines.Line2D at 0x7f030801d7c0>,
#  <matplotlib.lines.Line2D at 0x7f030801d790>,
#  <matplotlib.lines.Line2D at 0x7f030801d8b0>,
#  <matplotlib.lines.Line2D at 0x7f030801daf0>,
#  <matplotlib.lines.Line2D at 0x7f030801da60>,
#  <matplotlib.lines.Line2D at 0x7f030801dc40>,
#  <matplotlib.lines.Line2D at 0x7f030801dd60>,
#  <matplotlib.lines.Line2D at 0x7f030801df40>,
#  <matplotlib.lines.Line2D at 0x7f0308171af0>,
#  <matplotlib.lines.Line2D at 0x7f0308171d00>]
