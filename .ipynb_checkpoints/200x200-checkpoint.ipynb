# %%
# Bilbiotecas para auxílio na programação matemática
import math, sys 
import numpy as np
import sympy as sp

from scipy import sparse # Produção das diagonais das matrizes
from scipy.sparse import diags 

# Plotagem 2D e 3D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm


from os import path # Suficiente para manipulação de arquivos
    
# Para solução exata
from scipy.special import hermite
from math import factorial

# %matplotlib inline
count = 0

# Para otimização dos sistemas
from scipy import optimize

from numba import jit

# %%
def N(n):
    return 1*1./np.sqrt(np.sqrt(np.pi)*2**n*factorial(n))

def psix(n, x):
    Hn=hermite(n)
    Px = N(n)*Hn(x)*np.exp(-0.5*x**2)
    return Px

def psixt(n, x, t):
    Hn=hermite(n)
    a = complex(0,1)
    Pxt = N(n)*Hn(x)*np.exp(-0.5*x**2)*np.exp(-a*(n+1/2)*t*np.pi)
    return Pxt

# %%
def CrankNicolson(M, O = 0, L = 1, T = 0.5):
    N = 200 #São os pontos no intervalo de tempo
    
    #Pensando no poço quadrado infinito, temos essas duas limitações, onde L varia
    x0, xL = O, L

    P = 3.141111111111111111111111111
    #Discretização espacial
    dx = (xL - x0)/(P*M-1) 

    #Discretização temporal
    t0, tF = 0, T
    dt = (tF - t0)/(P*N-1)

    #Retorno dos números em um intervalo
    xs = np.linspace(x0, xL, M)
    ts = np.linspace(t0, tF, N)

    #Suponha um oscilador harmônico simples
    hbar = 1
    m = 1
    w = np.pi
    V = 1/2*m*w**2*xs**2

    #A partir da demonstração
    a = hbar/(4*m*dx**2) 
    b = 1j*hbar/dt - 2*a - 1/2*V
    c = 1j*hbar/dt + 2*a + 1/2*V

    #Obtenção da matriz
    ##Diagonais principais
    diagPrincipalA = b*np.ones((1,M)) #Cria uma matriz de 1's
    diagPrincipalB = c*np.ones((1,M))

    ##Diagonais secundárias, tem um tamanho a menos
    diagSecundariaA = a*np.ones((1,M-1))
    diagSecundariaB = (-a)*np.ones((1,M-1))

    diagonaisA = [diagPrincipalA, diagSecundariaA, diagSecundariaA]
    matrizA = sparse.diags(diagonaisA, [0, -1, 1], shape=(M,M)).toarray()
    
    diagonaisB = [diagPrincipalB, diagSecundariaB, diagSecundariaB]         
    matrizB = sparse.diags(diagonaisB, [0, -1, 1], shape=(M,M)).toarray()
    
    #Obtenção da matriz psi (Ela acumulará para o psi futuro)
    ps = np.zeros((M, N))
    psi_c = np.zeros((M, N))

    #Condição inicial
    ps[:,0] = 0.80 * psix(0, xs) + 0.60 * psix(1, xs) #A primeira coluna da matriz terá a equação inicial, em todas as posições
    psi_c = ps.astype(complex)
    #For para o acúmulo de resultados
    for k in range(1,N):
        b = np.matmul(matrizB, np.array(psi_c[0:M, k-1])) #Multiplicação de arrays já que houve uma conversão anterior
        psi_c[0:M, k] = np.linalg.solve(matrizA, b) #Matlab: x = A\b
        #plt.plot(xs, np.absolute(psi_c[0:M, k])**2)
    return psi_c

# %%
def multMatrizes(M, us, O = -5, L = 5, T = 10):
    N = 200 #São os pontos no intervalo de tempo
    
    #Pensando no poço quadrado infinito, temos essas duas limitações, onde L varia
    x0, xL = O, L

    P = 3.141111111111111111111111111
    #Discretização espacial
    dx = (xL - x0)/(P*M-1) 

    #Discretização temporal
    t0, tF = 0, T
    dt = (tF - t0)/(P*N-1)

    #Retorno dos números em um intervalo
    xs = np.linspace(x0, xL, M)
    ts = np.linspace(t0, tF, N)
    
    #Suponha um oscilador harmônico simples
    hbar = 1
    m = 1
    w = np.pi
    #V = us #V(x,u(t))
    V = 1/2*m*w**2*xs**2+us

    #A partir da demonstração
    a = hbar/(4*m*dx**2) 
    b = 1j*hbar/dt - 2*a - 1/2*V
    c = 1j*hbar/dt + 2*a + 1/2*V

    #Obtenção da matriz
    ##Diagonais principais
    diagPrincipalA = b*np.ones((1,M)) #Cria uma matriz de 1's
    diagPrincipalB = c*np.ones((1,M))

    ##Diagonais secundárias, tem um tamanho a menos
    diagSecundariaA = a*np.ones((1,M-1))
    diagSecundariaB = (-a)*np.ones((1,M-1))

    diagonaisA = [diagPrincipalA, diagSecundariaA, diagSecundariaA]
    matrizA = sparse.diags(diagonaisA, [0, -1, 1], shape=(M,M)).toarray()
    
    diagonaisB = [diagPrincipalB, diagSecundariaB, diagSecundariaB]         
    matrizB = sparse.diags(diagonaisB, [0, -1, 1], shape=(M,M)).toarray()

    return np.matmul(np.linalg.inv(matrizA), matrizB)

# %%
# Gradiente e função objetivo

def ExactSolution(M, T = 5, L = 5):
    N = 1000

    xs = np.linspace(-5, L, M)
    ts = np.linspace(0, N/100, T)
    
    psiExato = np.zeros((M, N)).astype(complex)
    r=0
    for i in np.arange(-5, 5, 0.05):
        for j in np.arange(0, 10, 0.05):
            psiExato[r][int(j*20)] = 1/np.sqrt(2)*psixt(0,i,j)+1/np.sqrt(2)*psixt(1,i,j)
        r+=1
    return psiExato

def Objetivo(y, x, psi, psiExato):
    A = np.zeros((200,200))
    B = np.zeros((200,200))
    A = multMatrizes(M = 200, us = x[0])
    B = multMatrizes(M = 200, us = x[1])
    return ((np.linalg.norm(np.array(psiExato[0:200, y])-np.array(psi)))**2+
            (np.linalg.norm(np.array(psiExato[0:200, y+1])-np.array(np.matmul(A,psi))))**2+
            (np.linalg.norm(np.array(psiExato[0:200, y+2])-np.array(np.matmul(np.matmul(B,A),psi))))**2)


def ObjetivoS(y, x, psi, psiExato, alpha, d): #Função para a seção áurea
    z = x + alpha * d
    A = np.zeros((200,200))
    B = np.zeros((200,200))
    A = multMatrizes(M = 200, us = z[0])
    B = multMatrizes(M = 200, us = z[1])
    return ((np.linalg.norm(np.array(psiExato[0:200, y])-np.array(psi)))**2+
            (np.linalg.norm(np.array(psiExato[0:200, y+1])-np.array(np.matmul(A,psi))))**2+
            (np.linalg.norm(np.array(psiExato[0:200, y+2])-np.array(np.matmul(np.matmul(B,A),psi))))**2)


def SecaoAurea(y, x, psi, psiExato, d):
    eps = 0.000000001
    a = 0
    b = 0.1
    xa = b - 0.618*(b-a)
    xb = a + 0.618*(b-a)
    fxa = ObjetivoS(y, x, psi, psiExato, xa, d)
    fxb = ObjetivoS(y, x, psi, psiExato, xb, d)
    
    while(b - a > eps):
        if(fxa < fxb):
            b = xb
            xb = xa
            xa = b - 0.618*(b - a)
            fxb = fxa
            fxa = ObjetivoS(y, x, psi, psiExato, xa, d)
        else:
            a = xa
            xa = xb
            xb = a + 0.618*(b - a)
            fxa = fxb
            fxb = ObjetivoS(y, x, psi, psiExato, xb, d)
            
    xp = (a+b)/2
    return xp

#Avaliação do gradiente

def gradiente(x, tempo, psi, psiExato):
    h = 0.000000001
    grad = []
    
    for i in range(len(x)):
        xh = x.copy()
        xh[i] = xh[i] + h
        dx = (Objetivo(tempo, xh, psi, psiExato)-Objetivo(tempo, x, psi, psiExato))/h
        grad.append(dx)
    return grad


def hessiana(x, tempo, psi, psiExato):
    n = len(x)
    h = 0.001
    Hx = np.zeros((n,n))
    gradfx = gradiente(x, tempo, psi, psiExato)
    
    for i in range(len(x)):
        xh = x.copy()
        xh[i] = xh[i] + h
        gradfxh = gradiente(xh, tempo, psi, psiExato)
        
        for j in range(len(x)):
            Hx[i,j] = ((gradfxh[j] - gradfx[j])/h)
    
    return Hx

# %%
import random

psi = np.zeros((200, 200))
psi_f = np.zeros((200,200))
psi_g = psi_f.astype(complex)
psi = CrankNicolson(M = 200, O = -5, L = 5, T = 10)
psiExato = ExactSolution(M = 200)

# %%
def N(n):
    return 1*1./np.sqrt(np.sqrt(np.pi)*2**n*factorial(n))

def psii(n, x):
    Hn=hermite(n)
    Px = N(n)*Hn(x)*np.exp(-0.5*x**2)
    return Px

def psiii(n, x, t):
    Hn=hermite(n)
    a = complex(0,1)
    Pxt = N(n)*Hn(x.real)*np.exp(-0.5*x**2)*np.exp(-a*(n+1/2)*t*np.pi)
    return Pxt

# %%
def MetodoGradNewton(x, tempo, psi, psiExato):
    
    eps = 0.00000000001
    SequenciaPontos = [x]
    
    errox = eps + 1
    xant = x.copy()
    
    errof = eps + 1
    FuncF = Objetivo(tempo, x, psi, psiExato)
    
    k = 0
    kmax = 100
    normagrad = eps + 1
    
    CP = ''
    
    while(CP == ''):
        #print(x)
        d = -1*np.array(gradiente(x, tempo, psi, psiExato))
        #d = -1*(np.matmul(np.linalg.inv(hessiana(x, tempo, psi, psiExato)),gradiente(x, tempo, psi, psiExato)))
        alpha = SecaoAurea(tempo, x, psi, psiExato, d)
        x = x + alpha * d
        
        errox = np.linalg.norm(xant - x)
        xant = x.copy()
        if(errox <= eps):
            CP = CP + 'Erro x '
        normagrad = np.linalg.norm(d)
        if(normagrad <= eps):
            CP = CP + 'Norma Gradiente '
        FuncFx = Objetivo(tempo, x, psi, psiExato)
        errof = abs(FuncF - FuncFx)
        FuncF = FuncFx
        if(errof <= eps):
            CP = CP + 'Erro F '
        if(k >= kmax):
            CP = 'Numero de iteracoes '
            
        k += 1
        SequenciaPontos.append(x)
        
    xOtimo = x
    return SequenciaPontos, k, xOtimo, CP

x = []
x.append(random.uniform(-5, 5))
x.append(random.uniform(-5, 5))
tempo = 0
resultado = MetodoGradNewton(x, tempo, psi, psiExato)
print('iteracoes = ', resultado[1])
print('x = ', resultado[2])
print('Criterio de parada: ', resultado[3])
# Out:
# iteracoes =  101
# x =  [-150.57104766  -53.40069207]
# Criterio de parada:  Numero de iteracoes

# %%
u1 = []
u2 = []
vetor = []
u1.append(random.uniform(-5, 5))
u1.append(random.uniform(-5, 5))
tempo = 0
xs = np.linspace(-5,5,200)

while tempo < 199:
    print(u1)
    psi_g[0:200, tempo] = psi[0:200, tempo]
    plt.plot(xs, np.absolute(psi[0:200, tempo])**2)
    u2 = MetodoGradNewton(u1, tempo, psi, psiExato)
    print("Iteracao = ", (tempo+1))
    print("Otimo = ", u2[2])
    print("Iteracoes = ", u2[1])
    print("Criterio = ", u2[3])
    print("---------------")
    D = multMatrizes(M = 200, us = u2[2][0])
    psi = np.matmul(D, psi)
    tempo += 1
    u1 = []
    u1.append(u2[2][1])
    u1.append(random.uniform(-5, 5))
# Out:
# [-1.679700651296736, 3.4872851460714553]
# Iteracao =  1
# Otimo =  [-152.966504    -51.97042739]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [-51.970427390723096, -0.14816735926068603]
# Iteracao =  2
# Otimo =  [-44.17060086   7.02847341]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.028473407394507, -0.15244890497400476]
# Iteracao =  3
# Otimo =  [8.11950325 5.83711938]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.837119381810953, -0.2591433589002978]
# Iteracao =  4
# Otimo =  [7.22864627 5.80172931]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.801729312251146, -2.6805248161968787]
# Iteracao =  5
# Otimo =  [7.3817035  5.30811282]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.308112818005671, -1.845411230443157]
# Iteracao =  6
# Otimo =  [6.88408523 5.44982765]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.449827645583245, -4.6609174377917215]
# Iteracao =  7
# Otimo =  [7.21643015 4.93607062]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [4.936070621330429, -0.006150466238706187]
# Iteracao =  8
# Otimo =  [6.34978918 5.74149223]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.741492230731379, 2.8641392289008074]
# Iteracao =  9
# Otimo =  [6.54694074 6.18561387]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.185613867873054, -2.975955986469181]
# Iteracao =  10
# Otimo =  [7.43744237 5.18330285]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.1833028531817495, 3.410674030200086]
# Iteracao =  11
# Otimo =  [6.12735835 6.3152363 ]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.315236299289095, 1.0998188087349359]
# Iteracao =  12
# Otimo =  [7.12032101 5.89321967]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.893219667984117, -1.7084541291443278]
# Iteracao =  13
# Otimo =  [7.19452468 5.44817775]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.448177754822726, 0.280477618850723]
# Iteracao =  14
# Otimo =  [6.73893263 5.8589543 ]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.858954301890113, -2.5325158979614546]
# Iteracao =  15
# Otimo =  [7.40109351 5.36517227]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.365172266385884, -0.053991701255229785]
# Iteracao =  16
# Otimo =  [6.89894413 5.92575404]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.925754042785361, -4.206152637125891]
# Iteracao =  17
# Otimo =  [7.89935754 5.12671816]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.12671816153672, -4.495470006477257]
# Iteracao =  18
# Otimo =  [7.61364047 5.17136725]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.171367245493698, -0.7793195207441777]
# Iteracao =  19
# Otimo =  [7.34724236 6.11756068]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.117560677316386, -3.920760525973488]
# Iteracao =  20
# Otimo =  [8.6703304  5.46449717]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.464497167325726, -2.834907868979082]
# Iteracao =  21
# Otimo =  [8.42362912 5.96536283]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.965362834211395, -3.0731420532772202]
# Iteracao =  22
# Otimo =  [9.20498295 6.12148555]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.12148555120547, -3.0726557533106047]
# Iteracao =  23
# Otimo =  [9.82640316 6.44502437]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.4450243680977986, -1.9151743340123364]
# Iteracao =  24
# Otimo =  [10.46026156  7.23907171]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.239071705854636, 4.485056584412364]
# Iteracao =  25
# Otimo =  [10.42375834 10.03333804]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [10.033338043459823, -2.1313074665573684]
# Iteracao =  26
# Otimo =  [14.5531629   8.12961172]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [8.129611722507844, -2.5924157100698233]
# Iteracao =  27
# Otimo =  [14.47824852  8.88831777]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [8.888317768693515, 0.4370980597699514]
# Iteracao =  28
# Otimo =  [15.31335212 10.79951686]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [10.799516857193584, 4.89850235413299]
# Iteracao =  29
# Otimo =  [16.27249216 13.03265914]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [13.032659140103885, -0.4410470432918059]
# Iteracao =  30
# Otimo =  [19.39875823 10.70462859]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [10.704628588524926, 1.1104836439623123]
# Iteracao =  31
# Otimo =  [17.16094955 11.21969912]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [11.219699117309029, -1.1553198109025264]
# Iteracao =  32
# Otimo =  [17.31658778  9.59054195]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.590541951430685, 0.7907935368559516]
# Iteracao =  33
# Otimo =  [14.70081076  9.63617518]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.63617517709462, 3.444453437460215]
# Iteracao =  34
# Otimo =  [13.11881228  9.74033954]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.74033953871753, -4.110683596720367]
# Iteracao =  35
# Otimo =  [13.92437895  6.50421093]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.504210929021337, 4.0895218842642596]
# Iteracao =  36
# Otimo =  [9.27416798 8.76577983]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [8.765779826339926, -0.6416701212953573]
# Iteracao =  37
# Otimo =  [11.1548405   6.74342683]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.743426830947999, 2.0601669380069705]
# Iteracao =  38
# Otimo =  [8.8250783  7.26247661]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.262476613725196, 0.4812314231318915]
# Iteracao =  39
# Otimo =  [9.08001082 6.5413765 ]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.5413764985244915, 3.3346715129741256]
# Iteracao =  40
# Otimo =  [7.87033015 7.0424995 ]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.042499500031478, -3.2190626475692463]
# Iteracao =  41
# Otimo =  [8.9120568  5.37238807]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.3723880728336635, 1.0899671146900802]
# Iteracao =  42
# Otimo =  [7.0138441  6.26753853]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.267538534607686, 0.25166162927061553]
# Iteracao =  43
# Otimo =  [7.57066254 5.9527382 ]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.952738197674831, -3.5277152192831385]
# Iteracao =  44
# Otimo =  [7.69132826 5.17651284]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.176512843740234, -1.5710128238191223]
# Iteracao =  45
# Otimo =  [6.84561751 5.53577875]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.535778750667277, -3.0253254584298785]
# Iteracao =  46
# Otimo =  [7.16341046 5.2332502 ]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.233250202302946, 3.0221667232326617]
# Iteracao =  47
# Otimo =  [6.25006528 6.27488356]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.274883562872297, 3.020222076033164]
# Iteracao =  48
# Otimo =  [6.89406755 6.20563631]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.205636308170029, 0.10427576966808516]
# Iteracao =  49
# Otimo =  [7.13623128 5.69985095]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.699850953040256, -0.43904950270087895]
# Iteracao =  50
# Otimo =  [6.86000239 5.62946292]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.629462923918403, 1.5362300434753093]
# Iteracao =  51
# Otimo =  [6.61280859 5.97711076]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.977110757565688, -0.06662038081095556]
# Iteracao =  52
# Otimo =  [7.02775903 5.70867095]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.708670954995118, 0.2270989571301607]
# Iteracao =  53
# Otimo =  [6.85754466 5.79866348]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.7986634804605535, 4.417390665114127]
# Iteracao =  54
# Otimo =  [6.50552276 6.59945035]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.599450345519308, -1.9428255016443527]
# Iteracao =  55
# Otimo =  [7.80980589 5.44336284]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.4433628442372655, 4.84461124620203]
# Iteracao =  56
# Otimo =  [6.35431273 6.89097432]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.890974316910873, -0.14814910916133073]
# Iteracao =  57
# Otimo =  [8.009289   5.91854433]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.918544328060846, -3.369273205203014]
# Iteracao =  58
# Otimo =  [7.97181956 5.37606402]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.376064018194918, -0.7906613400895965]
# Iteracao =  59
# Otimo =  [7.47663297 6.10148949]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.101489485538499, -1.6909479903594828]
# Iteracao =  60
# Otimo =  [8.33411707 6.0139273 ]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.013927297894803, 0.8568426915892928]
# Iteracao =  61
# Otimo =  [8.18761963 6.91516878]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.915168777584789, -3.01842583403661]
# Iteracao =  62
# Otimo =  [9.80263255 6.07215558]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.0721555769317135, -3.5855402590644303]
# Iteracao =  63
# Otimo =  [9.88985052 6.29229976]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.292299762970616, -4.1453504573558595]
# Iteracao =  64
# Otimo =  [10.7983003   6.51247222]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.512472218157507, -2.1171147937985344]
# Iteracao =  65
# Otimo =  [11.32588196  7.7483561 ]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.748356100336205, -4.97103958182567]
# Iteracao =  66
# Otimo =  [13.7011808   7.26748488]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.267484879771308, 3.5424168646769285]
# Iteracao =  67
# Otimo =  [12.50726574 11.41391158]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [11.413911581705959, -2.5293866804563736]
# Iteracao =  68
# Otimo =  [17.68578702  9.34133813]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.341338125046125, 1.5040859274953693]
# Iteracao =  69
# Otimo =  [16.12325819 11.74608763]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [11.746087626830692, -2.980249558503647]
# Iteracao =  70
# Otimo =  [19.20394415  9.78505423]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.785054232494732, 3.4447276940448877]
# Iteracao =  71
# Otimo =  [15.97762174 12.26355209]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [12.263552089085838, 4.574963279375849]
# Iteracao =  72
# Otimo =  [16.62839905 11.73086757]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [11.730867567584067, -1.6361857550626988]
# Iteracao =  73
# Otimo =  [16.73272461  8.55342905]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [8.55342904963602, 3.687273764389129]
# Iteracao =  74
# Otimo =  [12.31255254  9.9082175 ]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.908217502485744, -0.9814077794498219]
# Iteracao =  75
# Otimo =  [13.38248725  7.50890713]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.508907130474089, -2.930714576698239]
# Iteracao =  76
# Otimo =  [11.34442817  6.54767537]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.547675373732714, -2.00506718151668]
# Iteracao =  77
# Otimo =  [9.88515712 6.49434268]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.494342675392751, 3.1950935409367727]
# Iteracao =  78
# Otimo =  [8.46721858 7.57994938]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.579949381596333, -3.5151393694240527]
# Iteracao =  79
# Otimo =  [9.93226647 5.52996731]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.529967306616666, 1.8669361229828274]
# Iteracao =  80
# Otimo =  [7.40716436 6.75310544]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.753105441484331, -1.4317680662513155]
# Iteracao =  81
# Otimo =  [8.46841244 5.77797831]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.777978308111184, -3.0200064682204832]
# Iteracao =  82
# Otimo =  [7.82434138 5.38990911]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.389909110351418, 3.3579959342894465]
# Iteracao =  83
# Otimo =  [6.60244744 6.61034898]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.610348976311891, -1.928825211663725]
# Iteracao =  84
# Otimo =  [7.93675604 5.45045097]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.450450974508894, -1.0603610871040923]
# Iteracao =  85
# Otimo =  [6.96748813 5.61714899]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.617148989665698, 2.655371861073192]
# Iteracao =  86
# Otimo =  [6.58485135 6.2347792 ]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.234779196574455, -3.077778252494788]
# Iteracao =  87
# Otimo =  [7.56082247 5.18006981]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.180069812479196, 1.8966254803382911]
# Iteracao =  88
# Otimo =  [6.30638805 6.05701803]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.057018029395185, -2.1789421064542944]
# Iteracao =  89
# Otimo =  [7.27646852 5.31965978]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.3196597841683655, 1.037403652200327]
# Iteracao =  90
# Otimo =  [6.46089373 5.89446914]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.89446914028764, -4.326975674766329]
# Iteracao =  91
# Otimo =  [7.40168375 4.97024293]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [4.970242931713039, -3.990541514951932]
# Iteracao =  92
# Otimo =  [6.79614449 5.07166366]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.071663661421564, 0.5574323930540617]
# Iteracao =  93
# Otimo =  [6.41444163 5.88270575]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.882705752016537, 0.7287115987047885]
# Iteracao =  94
# Otimo =  [6.97118901 5.92229013]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.922290125316908, -4.235244085743219]
# Iteracao =  95
# Otimo =  [7.64050751 5.04160184]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.041601839488578, -1.4301661882288008]
# Iteracao =  96
# Otimo =  [6.85295148 5.66862183]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.6686218329103415, 1.6342337998846617]
# Iteracao =  97
# Otimo =  [7.00157726 6.34978191]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.349781912937786, 1.8100253002363695]
# Iteracao =  98
# Otimo =  [7.55722707 6.48810223]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.488102231709146, 1.0568724313054032]
# Iteracao =  99
# Otimo =  [7.93201602 6.47564185]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.4756418452790365, 4.839205472953616]
# Iteracao =  100
# Otimo =  [7.58668057 7.62626103]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.626261026937319, 0.2706659481907572]
# Iteracao =  101
# Otimo =  [9.31501078 6.65386354]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.653863540509077, 2.3006184061391473]
# Iteracao =  102
# Otimo =  [8.72169069 7.61570542]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.615705424477841, -1.8593462850681428]
# Iteracao =  103
# Otimo =  [10.56719762  6.71136796]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.711367956207776, 3.9813064966255176]
# Iteracao =  104
# Otimo =  [9.47368525 9.17597642]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.175976416875905, -1.3857132848771245]
# Iteracao =  105
# Otimo =  [12.9009029   7.78526746]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.7852674574432035, 2.186744050335321]
# Iteracao =  106
# Otimo =  [12.1355625   9.95528397]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.955283967488253, -1.3320581581670945]
# Iteracao =  107
# Otimo =  [15.38096554  9.21989933]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.219899334434803, 0.5121117174899652]
# Iteracao =  108
# Otimo =  [15.49795934 10.79667777]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [10.796677768717531, 2.8409169835472614]
# Iteracao =  109
# Otimo =  [16.7782425  12.16687562]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [12.166875622500871, -4.293636617902875]
# Iteracao =  110
# Otimo =  [19.79280677  9.19489736]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.194897357384159, 4.526484861133385]
# Iteracao =  111
# Otimo =  [15.30633793 12.75995847]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [12.759958468186177, -1.0678259952263969]
# Iteracao =  112
# Otimo =  [18.35444226  9.48631428]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.486314284652025, -3.850733038838304]
# Iteracao =  113
# Otimo =  [15.71271499  7.92722331]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.927223307411874, 2.025920692931546]
# Iteracao =  114
# Otimo =  [12.25932846  9.38155002]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.381550016941816, 3.3705512921721574]
# Iteracao =  115
# Otimo =  [12.10530474  8.97376623]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [8.973766231012164, -3.264214125761714]
# Iteracao =  116
# Otimo =  [12.42257013  6.34696205]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.346962050657851, -2.956528961439542]
# Iteracao =  117
# Otimo =  [9.91509165 6.23991763]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.2399176324402506, 4.5273016590602655]
# Iteracao =  118
# Otimo =  [8.06727438 7.95282249]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.952822491530857, 4.036152091535195]
# Iteracao =  119
# Otimo =  [8.9812791  7.38782195]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.387821954583786, 1.7741596380858713]
# Iteracao =  120
# Otimo =  [8.67020948 6.62940614]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.629406136836599, 3.6127451788080016]
# Iteracao =  121
# Otimo =  [7.68405619 6.89492965]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.894929646727941, 4.503638298567159]
# Iteracao =  122
# Otimo =  [7.57886966 6.90725089]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.9072508876268115, -0.5082503218964245]
# Iteracao =  123
# Otimo =  [8.08231804 5.77781324]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.77781323661653, -4.9207964354739]
# Iteracao =  124
# Otimo =  [7.7397752  4.92211899]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [4.922118990136749, -4.44520643078021]
# Iteracao =  125
# Otimo =  [7.00631704 5.02372477]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.023724774785799, -3.5107134652985126]
# Iteracao =  126
# Otimo =  [6.88127675 5.16877634]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.1687763419242385, 0.6593987622590749]
# Iteracao =  127
# Otimo =  [6.46426059 5.867893  ]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.867893001927453, -0.02075549227302531]
# Iteracao =  128
# Otimo =  [6.95601246 5.70287654]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.702876544655284, -1.2218697892059205]
# Iteracao =  129
# Otimo =  [6.9463377  5.49893224]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.498932235214954, -3.7844180717723255]
# Iteracao =  130
# Otimo =  [7.07890643 5.07442409]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.07442409000491, -4.337013781606923]
# Iteracao =  131
# Otimo =  [6.8734046  5.00022259]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.000222591608737, 2.9407158248772927]
# Iteracao =  132
# Otimo =  [6.07670052 6.26619224]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.26619224058346, -2.877627802405468]
# Iteracao =  133
# Otimo =  [7.55731091 5.22524237]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.225242365935229, -3.0077841040010256]
# Iteracao =  134
# Otimo =  [6.96674281 5.27261943]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.272619429497051, 0.25559556919688564]
# Iteracao =  135
# Otimo =  [6.70489168 5.91738197]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.917381966623649, -3.740648391769732]
# Iteracao =  136
# Otimo =  [7.69344321 5.17312725]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.1731272498000545, 1.431779343460315]
# Iteracao =  137
# Otimo =  [6.7079905  6.33250058]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.3325005771386556, 3.1938543104259836]
# Iteracao =  138
# Otimo =  [7.36350377 6.79399813]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.793998125092314, 2.946956159475307]
# Iteracao =  139
# Otimo =  [7.85592414 6.89670974]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.896709736347522, 4.186372381074152]
# Iteracao =  140
# Otimo =  [7.95972714 7.43545124]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.435451242181804, -4.185589949799865]
# Iteracao =  141
# Otimo =  [9.90964062 5.47979211]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.479792110653407, 4.718674217387571]
# Iteracao =  142
# Otimo =  [7.55198483 8.3937604 ]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [8.393760395188739, 0.663806117611764]
# Iteracao =  143
# Otimo =  [10.60747049  7.43190187]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.431901866357346, 1.5760163803349574]
# Iteracao =  144
# Otimo =  [10.40303915  8.31901008]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [8.319010075400502, 1.4515635347044924]
# Iteracao =  145
# Otimo =  [11.74853268  8.86358153]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [8.863581530024994, 0.8952998124827749]
# Iteracao =  146
# Otimo =  [13.12474609  9.37542838]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.375428381782905, 1.8464269722516393]
# Iteracao =  147
# Otimo =  [14.2615977  10.53573932]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [10.535739322218761, 2.269803957849879]
# Iteracao =  148
# Otimo =  [15.943231   11.39494617]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [11.394946167363177, -1.1141357999405708]
# Iteracao =  149
# Otimo =  [18.13248289 10.44772461]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [10.447724605933617, -4.009152465090294]
# Iteracao =  150
# Otimo =  [18.57460543  9.47501594]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.475015935643697, 0.2633354221530535]
# Iteracao =  151
# Otimo =  [16.57307636 11.00446781]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [11.004467812053795, -4.354477502557837]
# Iteracao =  152
# Otimo =  [17.96173846  8.36535155]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [8.36535155351293, -4.199177296571886]
# Iteracao =  153
# Otimo =  [15.04031505  7.89237282]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.89237282173907, 1.1759165969756271]
# Iteracao =  154
# Otimo =  [12.42856858  9.09070326]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.09070326165575, 4.016877529193643]
# Iteracao =  155
# Otimo =  [11.77262123  9.20645428]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.206454279132137, -1.2013349157276765]
# Iteracao =  156
# Otimo =  [12.17540877  6.95865152]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.958651519682102, 1.6642685191696014]
# Iteracao =  157
# Otimo =  [9.49432274 7.51850399]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.518503994809996, 2.4136863523754117]
# Iteracao =  158
# Otimo =  [9.29129106 7.31040581]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.3104058093801205, 3.275521020095754]
# Iteracao =  159
# Otimo =  [8.66555291 7.23618853]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.236188533291667, 3.7337988665562634]
# Iteracao =  160
# Otimo =  [8.28065225 7.09492747]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.094927474367865, 2.3138846185716746]
# Iteracao =  161
# Otimo =  [8.172133   6.58741831]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.587418308128455, 1.9181928030115056]
# Iteracao =  162
# Otimo =  [7.71446414 6.38199278]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.381992783505392, 2.183739858758753]
# Iteracao =  163
# Otimo =  [7.40390103 6.33067189]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.330671886277077, -1.507942038680099]
# Iteracao =  164
# Otimo =  [7.69927951 5.54282466]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.542824662375486, -2.4284991422834823]
# Iteracao =  165
# Otimo =  [7.1824617  5.36623422]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.366234222187755, 2.958320784302936]
# Iteracao =  166
# Otimo =  [6.38959766 6.29980431]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.2998043066958935, 4.515519021520104]
# Iteracao =  167
# Otimo =  [6.7814727  6.49057771]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.490577707650422, -2.8196073049227257]
# Iteracao =  168
# Otimo =  [7.65363953 5.20249973]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.202499734186541, -4.479187965787405]
# Iteracao =  169
# Otimo =  [6.96873844 4.96682397]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [4.96682397337509, -4.123870227709174]
# Iteracao =  170
# Otimo =  [6.77017006 5.03728797]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.037287971866791, -1.2762698706342102]
# Iteracao =  171
# Otimo =  [6.52776788 5.52129351]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.521293506344464, -1.2111869276559295]
# Iteracao =  172
# Otimo =  [6.85497653 5.52744119]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.527441192856566, 3.9548156778620793]
# Iteracao =  173
# Otimo =  [6.34052945 6.46538484]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.465384843193422, -3.372390320990574]
# Iteracao =  174
# Otimo =  [7.80343344 5.14884741]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.148847408684111, 2.7332281854126936]
# Iteracao =  175
# Otimo =  [6.33955787 6.39376245]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.3937624480449955, 2.32902670990838]
# Iteracao =  176
# Otimo =  [7.26796875 6.34681049]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.346810490170186, 2.4152735054607994]
# Iteracao =  177
# Otimo =  [7.33634072 6.47925962]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.479259616471169, -4.720998817701503]
# Iteracao =  178
# Otimo =  [8.50852419 5.04988463]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.049884627783819, 2.234334025300618]
# Iteracao =  179
# Otimo =  [6.84122539 6.83055643]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.830556433903697, -0.5472224344323031]
# Iteracao =  180
# Otimo =  [8.62517137 6.25907209]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.25907209165247, 4.608316963918323]
# Iteracao =  181
# Otimo =  [7.74154845 7.90432575]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.904325751471269, -3.750970273175186]
# Iteracao =  182
# Otimo =  [10.57060041  5.79581368]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.795813678586884, -3.750138313003694]
# Iteracao =  183
# Otimo =  [9.73647231 6.25830515]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [6.258305147743446, 4.07885550654615]
# Iteracao =  184
# Otimo =  [9.16395881 9.24260261]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.242602607045768, 1.3718695924274176]
# Iteracao =  185
# Otimo =  [12.36799019  8.75878553]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [8.75878553406788, 1.2444813137282775]
# Iteracao =  186
# Otimo =  [12.97229257  9.51870028]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.518700283276205, -0.8973826738595703]
# Iteracao =  187
# Otimo =  [14.989129   9.4352047]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.435204697451558, -0.18934846525797155]
# Iteracao =  188
# Otimo =  [15.80676076 10.48884689]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [10.488846891502961, -1.5965927565033944]
# Iteracao =  189
# Otimo =  [17.67749299 10.34179845]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [10.34179845457138, -2.721940061746123]
# Iteracao =  190
# Otimo =  [18.18237035 10.02481004]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [10.024810037401792, -2.7642544070165362]
# Iteracao =  191
# Otimo =  [17.70494707  9.7231078 ]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.723107804104307, -3.6780999123814038]
# Iteracao =  192
# Otimo =  [16.92048505  8.74632527]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [8.746325265599634, -1.9859779814615184]
# Iteracao =  193
# Otimo =  [14.78064069  8.68166724]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [8.681667236796207, 3.318179526882165]
# Iteracao =  194
# Otimo =  [12.4964518  9.7737729]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [9.773772897205234, -1.7571160607622325]
# Iteracao =  195
# Otimo =  [13.45431604  7.26397996]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.263979955236704, 2.6341023678584863]
# Iteracao =  196
# Otimo =  [10.08377732  8.26824013]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [8.26824012644927, 1.9108529658623663]
# Iteracao =  197
# Otimo =  [10.3480726   7.50169878]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [7.501698776802065, -3.6659871009132883]
# Iteracao =  198
# Otimo =  [10.31640297  5.69744272]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------
# [5.697442719620672, 1.862462266629933]
# Iteracao =  199
# Otimo =  [6.79174674 1.86137087]
# Iteracoes =  101
# Criterio =  Numero de iteracoes
# ---------------

# %%
from matplotlib import animation
from matplotlib.animation import PillowWriter

def animate(i):
    xs = np.linspace(-5,5,200)
    ln1.set_data(xs, np.absolute(psi_g[0:200,i-1])**2)
    ln2.set_data(xs, np.absolute(psiExato[0:200,i-1])**2)
    time_text.set_text('$t=$'+'{:.1f}'.format(i/100))
    
fig, ax = plt.subplots(1, 1,figsize=(8,4))
ax.grid()
ln1, = plt.plot([], [], 'r-', lw=2, markersize=8, label='Curva')
ln2, = plt.plot([], [], 'b-', lw=2, markersize=8, label='Ideal')
time_text = ax.text(0.85, 1, '', fontsize=15,
           bbox=dict(facecolor='white', edgecolor='black'))
ax.set_ylim(0, 1)
ax.set_xlim(-5,5)
title = ax.set_title('Resposta analítica')
ax.set_ylabel('$|\psi(x)|^2$', fontsize=20)
ax.set_xlabel('$x$', fontsize=20)
ax.legend(loc='upper left')
ax.set_title('')
plt.tight_layout()
ani = animation.FuncAnimation(fig, animate, frames=200, interval=200)
ani.save('200x200.gif',writer='pillow',fps=10,dpi=100)

# %%
plt.plot(xs, np.absolute(psi_g[0:200,0:10])**2)
# Out:
# [<matplotlib.lines.Line2D at 0x7f8ea3becfa0>,
#  <matplotlib.lines.Line2D at 0x7f8ea3bec4f0>,
#  <matplotlib.lines.Line2D at 0x7f8ea3bec310>,
#  <matplotlib.lines.Line2D at 0x7f8ea3bb4100>,
#  <matplotlib.lines.Line2D at 0x7f8ea3bb4220>,
#  <matplotlib.lines.Line2D at 0x7f8ea3bb4340>,
#  <matplotlib.lines.Line2D at 0x7f8ea3bb4460>,
#  <matplotlib.lines.Line2D at 0x7f8ea3bb4580>,
#  <matplotlib.lines.Line2D at 0x7f8ea3bb46a0>,
#  <matplotlib.lines.Line2D at 0x7f8ea3bb47c0>]
