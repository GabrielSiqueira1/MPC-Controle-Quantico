# %%
# Bilbiotecas para auxílio na programação matemática
import math, sys 
import numpy as np
import sympy as sp

from scipy import sparse # Produção das diagonais das matrizes
from scipy.sparse import diags 

# Plotagem 2D e 3D
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm


from os import path # Suficiente para manipulação de arquivos
    
# Para solução exata
from scipy.special import hermite
from math import factorial

# %matplotlib inline
count = 0

# Para otimização dos sistemas
from scipy import optimize

from numba import jit

# %%
def N(n):
    return 1*1./np.sqrt(np.sqrt(np.pi)*2**n*factorial(n))

def psix(n, x):
    Hn=hermite(n)
    Px = N(n)*Hn(x)*np.exp(-0.5*x**2)
    return Px

def psixt(n, x, t):
    Hn=hermite(n)
    a = complex(0,1)
    Pxt = N(n)*Hn(x)*np.exp(-0.5*x**2)*np.exp(-a*(n+1/2)*t*np.pi)
    return Pxt

# %%
def CrankNicolson(M, O = 0, L = 1, T = 0.5):
    N = 200 #São os pontos no intervalo de tempo
    
    #Pensando no poço quadrado infinito, temos essas duas limitações, onde L varia
    x0, xL = O, L

    P = 3.141111111111111111111111111
    #Discretização espacial
    dx = (xL - x0)/(P*M-1) 

    #Discretização temporal
    t0, tF = 0, T
    dt = (tF - t0)/(P*N-1)

    #Retorno dos números em um intervalo
    xs = np.linspace(x0, xL, M)
    ts = np.linspace(t0, tF, N)

    #Suponha um oscilador harmônico simples
    hbar = 1
    m = 1
    w = np.pi
    V = 1/2*m*w**2*xs**2

    #A partir da demonstração
    a = hbar/(4*m*dx**2) 
    b = 1j*hbar/dt - 2*a - 1/2*V
    c = 1j*hbar/dt + 2*a + 1/2*V

    #Obtenção da matriz
    ##Diagonais principais
    diagPrincipalA = b*np.ones((1,M)) #Cria uma matriz de 1's
    diagPrincipalB = c*np.ones((1,M))

    ##Diagonais secundárias, tem um tamanho a menos
    diagSecundariaA = a*np.ones((1,M-1))
    diagSecundariaB = (-a)*np.ones((1,M-1))

    diagonaisA = [diagPrincipalA, diagSecundariaA, diagSecundariaA]
    matrizA = sparse.diags(diagonaisA, [0, -1, 1], shape=(M,M)).toarray()
    
    diagonaisB = [diagPrincipalB, diagSecundariaB, diagSecundariaB]         
    matrizB = sparse.diags(diagonaisB, [0, -1, 1], shape=(M,M)).toarray()
    
    #Obtenção da matriz psi (Ela acumulará para o psi futuro)
    ps = np.zeros((M, N))
    psi_c = np.zeros((M, N))

    #Condição inicial
    ps[:,0] = 0.80 * psix(0, xs) + 0.60 * psix(1, xs) #A primeira coluna da matriz terá a equação inicial, em todas as posições
    psi_c = ps.astype(complex)
    #For para o acúmulo de resultados
    for k in range(1,N):
        b = np.matmul(matrizB, np.array(psi_c[0:M, k-1])) #Multiplicação de arrays já que houve uma conversão anterior
        psi_c[0:M, k] = np.linalg.solve(matrizA, b) #Matlab: x = A\b
        #plt.plot(xs, np.absolute(psi_c[0:M, k])**2)
    return psi_c

# %%
def multMatrizes(M, us, O = -5, L = 5, T = 10):
    N = 200 #São os pontos no intervalo de tempo
    
    #Pensando no poço quadrado infinito, temos essas duas limitações, onde L varia
    x0, xL = O, L

    P = 3.141111111111111111111111111
    #Discretização espacial
    dx = (xL - x0)/(P*M-1) 

    #Discretização temporal
    t0, tF = 0, T
    dt = (tF - t0)/(P*N-1)

    #Retorno dos números em um intervalo
    xs = np.linspace(x0, xL, M)
    ts = np.linspace(t0, tF, N)
    
    #Suponha um oscilador harmônico simples
    hbar = 1
    m = 1
    w = np.pi
    #V = us #V(x,u(t))
    V = 1/2*m*w**2*xs**2

    #A partir da demonstração
    a = hbar/(4*m*dx**2) 
    b = 1j*hbar/dt - 2*a - 1/2*V
    c = 1j*hbar/dt + 2*a + 1/2*V

    #Obtenção da matriz
    ##Diagonais principais
    diagPrincipalA = b*np.ones((1,M)) #Cria uma matriz de 1's
    diagPrincipalB = c*np.ones((1,M))

    ##Diagonais secundárias, tem um tamanho a menos
    diagSecundariaA = a*np.ones((1,M-1))
    diagSecundariaB = (-a)*np.ones((1,M-1))

    diagonaisA = [diagPrincipalA, diagSecundariaA, diagSecundariaA]
    matrizA = sparse.diags(diagonaisA, [0, -1, 1], shape=(M,M)).toarray()
    
    diagonaisB = [diagPrincipalB, diagSecundariaB, diagSecundariaB]         
    matrizB = sparse.diags(diagonaisB, [0, -1, 1], shape=(M,M)).toarray()

    return np.matmul(np.linalg.inv(matrizA), matrizB)

# %%
# Gradiente e função objetivo

def ExactSolution(M, T = 5, L = 5):
    N = 1000

    xs = np.linspace(-5, L, M)
    ts = np.linspace(0, N/100, T)
    
    psiExato = np.zeros((M, N)).astype(complex)
    r=0
    for i in np.arange(-5, 5, 0.05):
        for j in np.arange(0, 10, 0.05):
            psiExato[r][int(j*20)] = 1/np.sqrt(2)*psixt(0,i,j)+1/np.sqrt(2)*psixt(1,i,j)
        r+=1
    return psiExato

def Objetivo(y, x, psi, psiExato):
    A = np.zeros((200,200))
    B = np.zeros((200,200))
    A = multMatrizes(M = 200, us = x[0])
    B = multMatrizes(M = 200, us = x[1])
    return ((np.linalg.norm(np.array(psiExato[0:200, y])-np.array(psi)))**2+
            (np.linalg.norm(np.array(psiExato[0:200, y+1])-np.array(np.matmul(A,psi))))**2+
            (np.linalg.norm(np.array(psiExato[0:200, y+2])-np.array(np.matmul(np.matmul(B,A),psi))))**2)


def ObjetivoS(y, x, psi, psiExato, alpha, d): #Função para a seção áurea
    z = x + alpha * d
    A = np.zeros((200,200))
    B = np.zeros((200,200))
    A = multMatrizes(M = 200, us = z[0])
    B = multMatrizes(M = 200, us = z[1])
    return ((np.linalg.norm(np.array(psiExato[0:200, y])-np.array(psi)))**2+
            (np.linalg.norm(np.array(psiExato[0:200, y+1])-np.array(np.matmul(A,psi))))**2+
            (np.linalg.norm(np.array(psiExato[0:200, y+2])-np.array(np.matmul(np.matmul(B,A),psi))))**2)


def SecaoAurea(y, x, psi, psiExato, d):
    eps = 0.000000001
    a = 0
    b = 0.1
    xa = b - 0.618*(b-a)
    xb = a + 0.618*(b-a)
    fxa = ObjetivoS(y, x, psi, psiExato, xa, d)
    fxb = ObjetivoS(y, x, psi, psiExato, xb, d)
    
    while(b - a > eps):
        if(fxa < fxb):
            b = xb
            xb = xa
            xa = b - 0.618*(b - a)
            fxb = fxa
            fxa = ObjetivoS(y, x, psi, psiExato, xa, d)
        else:
            a = xa
            xa = xb
            xb = a + 0.618*(b - a)
            fxa = fxb
            fxb = ObjetivoS(y, x, psi, psiExato, xb, d)
            
    xp = (a+b)/2
    return xp

#Avaliação do gradiente

def gradiente(x, tempo, psi, psiExato):
    h = 0.000000001
    grad = []
    
    for i in range(len(x)):
        xh = x.copy()
        xh[i] = xh[i] + h
        dx = (Objetivo(tempo, xh, psi, psiExato)-Objetivo(tempo, x, psi, psiExato))/h
        grad.append(dx)
    return grad


def hessiana(x, tempo, psi, psiExato):
    n = len(x)
    h = 0.001
    Hx = np.zeros((n,n))
    gradfx = gradiente(x, tempo, psi, psiExato)
    
    for i in range(len(x)):
        xh = x.copy()
        xh[i] = xh[i] + h
        gradfxh = gradiente(xh, tempo, psi, psiExato)
        
        for j in range(len(x)):
            Hx[i,j] = ((gradfxh[j] - gradfx[j])/h)
    
    return Hx

# %%
import random

psi = np.zeros((200, 200))
psi_f = np.zeros((200,200))
psi_g = psi_f.astype(complex)
psi = CrankNicolson(M = 200, O = -5, L = 5, T = 10)
psiExato = ExactSolution(M = 200)

# %%
def N(n):
    return 1*1./np.sqrt(np.sqrt(np.pi)*2**n*factorial(n))

def psii(n, x):
    Hn=hermite(n)
    Px = N(n)*Hn(x)*np.exp(-0.5*x**2)
    return Px

def psiii(n, x, t):
    Hn=hermite(n)
    a = complex(0,1)
    Pxt = N(n)*Hn(x.real)*np.exp(-0.5*x**2)*np.exp(-a*(n+1/2)*t*np.pi)
    return Pxt

# %%
def MetodoGradNewton(x, tempo, psi, psiExato):
    
    eps = 0.00000000001
    SequenciaPontos = [x]
    
    errox = eps + 1
    xant = x.copy()
    
    errof = eps + 1
    FuncF = Objetivo(tempo, x, psi, psiExato)
    
    k = 0
    kmax = 100
    normagrad = eps + 1
    
    CP = ''
    
    while(CP == ''):
        #print(x)
        d = -1*np.array(gradiente(x, tempo, psi, psiExato))
        #d = -1*(np.matmul(np.linalg.inv(hessiana(x, tempo, psi, psiExato)),gradiente(x, tempo, psi, psiExato)))
        alpha = SecaoAurea(tempo, x, psi, psiExato, d)
        x = x + alpha * d
        
        errox = np.linalg.norm(xant - x)
        xant = x.copy()
        if(errox <= eps):
            CP = CP + 'Erro x '
        normagrad = np.linalg.norm(d)
        if(normagrad <= eps):
            CP = CP + 'Norma Gradiente '
        FuncFx = Objetivo(tempo, x, psi, psiExato)
        errof = abs(FuncF - FuncFx)
        FuncF = FuncFx
        if(errof <= eps):
            CP = CP + 'Erro F '
        if(k >= kmax):
            CP = 'Numero de iteracoes '
            
        k += 1
        SequenciaPontos.append(x)
        
    xOtimo = x
    return SequenciaPontos, k, xOtimo, CP

x = []
x.append(random.uniform(-5, 5))
x.append(random.uniform(-5, 5))
tempo = 0
resultado = MetodoGradNewton(x, tempo, psi, psiExato)
print('iteracoes = ', resultado[1])
print('x = ', resultado[2])
print('Criterio de parada: ', resultado[3])
# Out:
# iteracoes =  1
# x =  [ 4.7929387 -2.1653904]
# Criterio de parada:  Erro x Norma Gradiente Erro F

# %%
u1 = []
u2 = []
vetor = []
u1.append(random.uniform(-5, 5))
u1.append(random.uniform(-5, 5))
tempo = 0
xs = np.linspace(-5,5,200)

while tempo < 199:
    print(u1)
    psi_g[0:200, tempo] = psi[0:200, tempo]
    plt.plot(xs, np.absolute(psi[0:200, tempo])**2)
    u2 = MetodoGradNewton(u1, tempo, psi, psiExato)
    print("Iteracao = ", (tempo+1))
    print("Otimo = ", u2[2])
    print("Iteracoes = ", u2[1])
    print("Criterio = ", u2[3])
    print("---------------")
    D = multMatrizes(M = 200, us = u2[2][0])
    psi = np.matmul(D, psi)
    tempo += 1
    u1 = []
    u1.append(u2[2][1])
    u1.append(random.uniform(-5, 5))
# Out:
# [-1.096711823159997, -1.4038195566808351]
# Iteracao =  1
# Otimo =  [-1.09671182 -1.40381956]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.4038195566808351, -1.0801784421583815]
# Iteracao =  2
# Otimo =  [-1.40381956 -1.08017844]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.0801784421583815, -4.993160331000849]
# Iteracao =  3
# Otimo =  [-1.08017844 -4.99316033]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.993160331000849, 0.5646098193436107]
# Iteracao =  4
# Otimo =  [-4.99316033  0.56460982]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.5646098193436107, -4.490906504905547]
# Iteracao =  5
# Otimo =  [ 0.56460982 -4.4909065 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.490906504905547, 2.7611653072278886]
# Iteracao =  6
# Otimo =  [-4.4909065   2.76116531]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.7611653072278886, 0.43273751206729116]
# Iteracao =  7
# Otimo =  [2.76116531 0.43273751]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.43273751206729116, -0.049103853106631234]
# Iteracao =  8
# Otimo =  [ 0.43273751 -0.04910385]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.049103853106631234, 0.06544686794529131]
# Iteracao =  9
# Otimo =  [-0.04910385  0.06544687]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.06544686794529131, -4.1819543539331985]
# Iteracao =  10
# Otimo =  [ 0.06544687 -4.18195435]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.1819543539331985, -1.665689582024068]
# Iteracao =  11
# Otimo =  [-4.18195435 -1.66568958]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.665689582024068, -0.30659344015671497]
# Iteracao =  12
# Otimo =  [-1.66568958 -0.30659344]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.30659344015671497, 2.6731807588993775]
# Iteracao =  13
# Otimo =  [-0.30659344  2.67318076]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.6731807588993775, -4.003957744248265]
# Iteracao =  14
# Otimo =  [ 2.67318076 -4.00395774]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.003957744248265, 1.4035434842115766]
# Iteracao =  15
# Otimo =  [-4.00395774  1.40354348]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.4035434842115766, 1.1201067588314046]
# Iteracao =  16
# Otimo =  [1.40354348 1.12010676]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.1201067588314046, -0.8420005569359699]
# Iteracao =  17
# Otimo =  [ 1.12010676 -0.84200056]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.8420005569359699, 0.8784869982741483]
# Iteracao =  18
# Otimo =  [-0.84200056  0.878487  ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.8784869982741483, 2.00745305391811]
# Iteracao =  19
# Otimo =  [0.878487   2.00745305]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.00745305391811, -3.889443839153212]
# Iteracao =  20
# Otimo =  [ 2.00745305 -3.88944384]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.889443839153212, -2.920605742474003]
# Iteracao =  21
# Otimo =  [-3.88944384 -2.92060574]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.920605742474003, -0.017540934778271122]
# Iteracao =  22
# Otimo =  [-2.92060574 -0.01754093]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.017540934778271122, 2.0192045781096537]
# Iteracao =  23
# Otimo =  [-0.01754093  2.01920458]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.0192045781096537, -0.019743053812455003]
# Iteracao =  24
# Otimo =  [ 2.01920458 -0.01974305]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.019743053812455003, 2.655832174111012]
# Iteracao =  25
# Otimo =  [-0.01974305  2.65583217]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.655832174111012, -1.6169149568335484]
# Iteracao =  26
# Otimo =  [ 2.65583217 -1.61691496]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.6169149568335484, -2.030383202640391]
# Iteracao =  27
# Otimo =  [-1.61691496 -2.0303832 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.030383202640391, 0.14577027157854872]
# Iteracao =  28
# Otimo =  [-2.0303832   0.14577027]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.14577027157854872, -4.536674702463826]
# Iteracao =  29
# Otimo =  [ 0.14577027 -4.5366747 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.536674702463826, -1.3942216407237784]
# Iteracao =  30
# Otimo =  [-4.5366747  -1.39422164]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.3942216407237784, -4.847506206477801]
# Iteracao =  31
# Otimo =  [-1.39422164 -4.84750621]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.847506206477801, -3.3398013330269727]
# Iteracao =  32
# Otimo =  [-4.84750621 -3.33980133]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.3398013330269727, -2.509052232205937]
# Iteracao =  33
# Otimo =  [-3.33980133 -2.50905223]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.509052232205937, -3.7324657908850734]
# Iteracao =  34
# Otimo =  [-2.50905223 -3.73246579]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.7324657908850734, -2.6909095677885353]
# Iteracao =  35
# Otimo =  [-3.73246579 -2.69090957]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.6909095677885353, 2.6445430762793656]
# Iteracao =  36
# Otimo =  [-2.69090957  2.64454308]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.6445430762793656, -0.10497421055569589]
# Iteracao =  37
# Otimo =  [ 2.64454308 -0.10497421]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.10497421055569589, -2.1100265215939773]
# Iteracao =  38
# Otimo =  [-0.10497421 -2.11002652]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.1100265215939773, 2.073949095158695]
# Iteracao =  39
# Otimo =  [-2.11002652  2.0739491 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.073949095158695, -4.986819088311386]
# Iteracao =  40
# Otimo =  [ 2.0739491  -4.98681909]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.986819088311386, 0.19968737864194708]
# Iteracao =  41
# Otimo =  [-4.98681909  0.19968738]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.19968737864194708, 1.1658884670221035]
# Iteracao =  42
# Otimo =  [0.19968738 1.16588847]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.1658884670221035, 2.009733832636444]
# Iteracao =  43
# Otimo =  [1.16588847 2.00973383]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.009733832636444, -0.67550920513502]
# Iteracao =  44
# Otimo =  [ 2.00973383 -0.67550921]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.67550920513502, -2.2008200951405357]
# Iteracao =  45
# Otimo =  [-0.67550921 -2.2008201 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.2008200951405357, 3.1214431688739825]
# Iteracao =  46
# Otimo =  [-2.2008201   3.12144317]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.1214431688739825, -4.099046742057796]
# Iteracao =  47
# Otimo =  [ 3.12144317 -4.09904674]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.099046742057796, -1.5639270995279597]
# Iteracao =  48
# Otimo =  [-4.09904674 -1.5639271 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.5639270995279597, 4.563120038187545]
# Iteracao =  49
# Otimo =  [-1.5639271   4.56312004]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.563120038187545, 4.624751674717569]
# Iteracao =  50
# Otimo =  [4.56312004 4.62475167]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.624751674717569, -3.5966451237668897]
# Iteracao =  51
# Otimo =  [ 4.62475167 -3.59664512]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.5966451237668897, -2.720836472174292]
# Iteracao =  52
# Otimo =  [-3.59664512 -2.72083647]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.720836472174292, -4.893429755612693]
# Iteracao =  53
# Otimo =  [-2.72083647 -4.89342976]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.893429755612693, -4.180276934072151]
# Iteracao =  54
# Otimo =  [-4.89342976 -4.18027693]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.180276934072151, -2.68726205676845]
# Iteracao =  55
# Otimo =  [-4.18027693 -2.68726206]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.68726205676845, 4.626195538013791]
# Iteracao =  56
# Otimo =  [-2.68726206  4.62619554]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.626195538013791, -0.8572508675302668]
# Iteracao =  57
# Otimo =  [ 4.62619554 -0.85725087]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.8572508675302668, -0.1893661929314474]
# Iteracao =  58
# Otimo =  [-0.85725087 -0.18936619]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.1893661929314474, 1.4259813800182304]
# Iteracao =  59
# Otimo =  [-0.18936619  1.42598138]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.4259813800182304, 4.3690227497813545]
# Iteracao =  60
# Otimo =  [1.42598138 4.36902275]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.3690227497813545, 2.3164595139563895]
# Iteracao =  61
# Otimo =  [4.36902275 2.31645951]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.3164595139563895, 3.9599010682841076]
# Iteracao =  62
# Otimo =  [2.31645951 3.95990107]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.9599010682841076, 3.5625470152133882]
# Iteracao =  63
# Otimo =  [3.95990107 3.56254702]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.5625470152133882, 1.8869492045784275]
# Iteracao =  64
# Otimo =  [3.56254702 1.8869492 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.8869492045784275, 4.993376084490222]
# Iteracao =  65
# Otimo =  [1.8869492  4.99337608]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.993376084490222, 3.6401606073210537]
# Iteracao =  66
# Otimo =  [4.99337608 3.64016061]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.6401606073210537, -3.8563924987937326]
# Iteracao =  67
# Otimo =  [ 3.64016061 -3.8563925 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.8563924987937326, -0.05592808998791643]
# Iteracao =  68
# Otimo =  [-3.8563925  -0.05592809]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.05592808998791643, 3.7436993774144174]
# Iteracao =  69
# Otimo =  [-0.05592809  3.74369938]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.7436993774144174, 1.1433106127188708]
# Iteracao =  70
# Otimo =  [3.74369938 1.14331061]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.1433106127188708, 2.8778157074902317]
# Iteracao =  71
# Otimo =  [1.14331061 2.87781571]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.8778157074902317, -4.805474974906504]
# Iteracao =  72
# Otimo =  [ 2.87781571 -4.80547497]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.805474974906504, 2.142933567320192]
# Iteracao =  73
# Otimo =  [-4.80547497  2.14293357]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.142933567320192, -0.22244728702891425]
# Iteracao =  74
# Otimo =  [ 2.14293357 -0.22244729]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.22244728702891425, -0.6834033879100465]
# Iteracao =  75
# Otimo =  [-0.22244729 -0.68340339]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.6834033879100465, -1.1076418694843673]
# Iteracao =  76
# Otimo =  [-0.68340339 -1.10764187]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.1076418694843673, -1.456958675557103]
# Iteracao =  77
# Otimo =  [-1.10764187 -1.45695868]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.456958675557103, 1.51935604960941]
# Iteracao =  78
# Otimo =  [-1.45695868  1.51935605]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.51935604960941, -2.2694461958975563]
# Iteracao =  79
# Otimo =  [ 1.51935605 -2.2694462 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.2694461958975563, -3.457390945874627]
# Iteracao =  80
# Otimo =  [-2.2694462  -3.45739095]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.457390945874627, -4.658784638498786]
# Iteracao =  81
# Otimo =  [-3.45739095 -4.65878464]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.658784638498786, -1.5227877392243472]
# Iteracao =  82
# Otimo =  [-4.65878464 -1.52278774]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.5227877392243472, -0.7990898276288814]
# Iteracao =  83
# Otimo =  [-1.52278774 -0.79908983]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.7990898276288814, -3.3862790361174646]
# Iteracao =  84
# Otimo =  [-0.79908983 -3.38627904]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.3862790361174646, -4.665687946509264]
# Iteracao =  85
# Otimo =  [-3.38627904 -4.66568795]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.665687946509264, -0.6135881171325819]
# Iteracao =  86
# Otimo =  [-4.66568795 -0.61358812]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.6135881171325819, -1.0739433666823595]
# Iteracao =  87
# Otimo =  [-0.61358812 -1.07394337]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.0739433666823595, 0.803325705064796]
# Iteracao =  88
# Otimo =  [-1.07394337  0.80332571]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.803325705064796, -0.5565449790753725]
# Iteracao =  89
# Otimo =  [ 0.80332571 -0.55654498]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.5565449790753725, -4.2633025188903755]
# Iteracao =  90
# Otimo =  [-0.55654498 -4.26330252]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.2633025188903755, 0.4698733281131693]
# Iteracao =  91
# Otimo =  [-4.26330252  0.46987333]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.4698733281131693, 0.5949746344131865]
# Iteracao =  92
# Otimo =  [0.46987333 0.59497463]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.5949746344131865, 4.448651899241428]
# Iteracao =  93
# Otimo =  [0.59497463 4.4486519 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.448651899241428, 1.8670739506397709]
# Iteracao =  94
# Otimo =  [4.4486519  1.86707395]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.8670739506397709, 1.903307226904925]
# Iteracao =  95
# Otimo =  [1.86707395 1.90330723]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.903307226904925, -1.1161913503507446]
# Iteracao =  96
# Otimo =  [ 1.90330723 -1.11619135]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.1161913503507446, -1.2559747032686799]
# Iteracao =  97
# Otimo =  [-1.11619135 -1.2559747 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.2559747032686799, 4.9128363829613555]
# Iteracao =  98
# Otimo =  [-1.2559747   4.91283638]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.9128363829613555, 3.791484852098513]
# Iteracao =  99
# Otimo =  [4.91283638 3.79148485]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.791484852098513, 3.571513090952303]
# Iteracao =  100
# Otimo =  [3.79148485 3.57151309]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.571513090952303, -4.902466225922174]
# Iteracao =  101
# Otimo =  [ 3.57151309 -4.90246623]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.902466225922174, -1.7473598395672396]
# Iteracao =  102
# Otimo =  [-4.90246623 -1.74735984]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.7473598395672396, 3.418220280728283]
# Iteracao =  103
# Otimo =  [-1.74735984  3.41822028]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.418220280728283, -0.008361294804179131]
# Iteracao =  104
# Otimo =  [ 3.41822028 -0.00836129]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.008361294804179131, -3.285502570442398]
# Iteracao =  105
# Otimo =  [-0.00836129 -3.28550257]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.285502570442398, 0.7045997571546279]
# Iteracao =  106
# Otimo =  [-3.28550257  0.70459976]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.7045997571546279, -0.5102293593174867]
# Iteracao =  107
# Otimo =  [ 0.70459976 -0.51022936]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.5102293593174867, 3.671270842418876]
# Iteracao =  108
# Otimo =  [-0.51022936  3.67127084]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.671270842418876, 2.293608358091296]
# Iteracao =  109
# Otimo =  [3.67127084 2.29360836]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.293608358091296, -3.153063972093478]
# Iteracao =  110
# Otimo =  [ 2.29360836 -3.15306397]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.153063972093478, -4.393095757084393]
# Iteracao =  111
# Otimo =  [-3.15306397 -4.39309576]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.393095757084393, -0.3040396261134539]
# Iteracao =  112
# Otimo =  [-4.39309576 -0.30403963]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.3040396261134539, 2.985047999177697]
# Iteracao =  113
# Otimo =  [-0.30403963  2.985048  ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.985047999177697, 3.3075792244021684]
# Iteracao =  114
# Otimo =  [2.985048   3.30757922]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.3075792244021684, 4.697140906416834]
# Iteracao =  115
# Otimo =  [3.30757922 4.69714091]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.697140906416834, -0.5465615473493965]
# Iteracao =  116
# Otimo =  [ 4.69714091 -0.54656155]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.5465615473493965, 0.6233831701495411]
# Iteracao =  117
# Otimo =  [-0.54656155  0.62338317]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.6233831701495411, -1.1750393484538724]
# Iteracao =  118
# Otimo =  [ 0.62338317 -1.17503935]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.1750393484538724, -1.3778159883756658]
# Iteracao =  119
# Otimo =  [-1.17503935 -1.37781599]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.3778159883756658, 0.2910910087149521]
# Iteracao =  120
# Otimo =  [-1.37781599  0.29109101]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.2910910087149521, 0.092370391581996]
# Iteracao =  121
# Otimo =  [0.29109101 0.09237039]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.092370391581996, -0.7217207563014503]
# Iteracao =  122
# Otimo =  [ 0.09237039 -0.72172076]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.7217207563014503, -4.511294106747929]
# Iteracao =  123
# Otimo =  [-0.72172076 -4.51129411]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.511294106747929, -3.6834091430561666]
# Iteracao =  124
# Otimo =  [-4.51129411 -3.68340914]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.6834091430561666, 1.7221518369785391]
# Iteracao =  125
# Otimo =  [-3.68340914  1.72215184]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.7221518369785391, 4.819467182873918]
# Iteracao =  126
# Otimo =  [1.72215184 4.81946718]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.819467182873918, -2.3032658818770924]
# Iteracao =  127
# Otimo =  [ 4.81946718 -2.30326588]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.3032658818770924, 1.543286406055035]
# Iteracao =  128
# Otimo =  [-2.30326588  1.54328641]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.543286406055035, -2.875792154133392]
# Iteracao =  129
# Otimo =  [ 1.54328641 -2.87579215]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.875792154133392, 1.7590557971902454]
# Iteracao =  130
# Otimo =  [-2.87579215  1.7590558 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.7590557971902454, -2.016755633889237]
# Iteracao =  131
# Otimo =  [ 1.7590558  -2.01675563]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.016755633889237, 3.0007969882384096]
# Iteracao =  132
# Otimo =  [-2.01675563  3.00079699]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.0007969882384096, 4.422683076391088]
# Iteracao =  133
# Otimo =  [3.00079699 4.42268308]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.422683076391088, 4.982412958054846]
# Iteracao =  134
# Otimo =  [4.42268308 4.98241296]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.982412958054846, 0.2650935273392738]
# Iteracao =  135
# Otimo =  [4.98241296 0.26509353]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.2650935273392738, -2.355192942819718]
# Iteracao =  136
# Otimo =  [ 0.26509353 -2.35519294]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.355192942819718, 2.7095715508348928]
# Iteracao =  137
# Otimo =  [-2.35519294  2.70957155]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.7095715508348928, -1.5268358892404512]
# Iteracao =  138
# Otimo =  [ 2.70957155 -1.52683589]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.5268358892404512, -2.9396578782162655]
# Iteracao =  139
# Otimo =  [-1.52683589 -2.93965788]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.9396578782162655, 3.956288219163037]
# Iteracao =  140
# Otimo =  [-2.93965788  3.95628822]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.956288219163037, 1.6534248091982997]
# Iteracao =  141
# Otimo =  [3.95628822 1.65342481]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.6534248091982997, -3.4760913407513385]
# Iteracao =  142
# Otimo =  [ 1.65342481 -3.47609134]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.4760913407513385, -2.0014697944141755]
# Iteracao =  143
# Otimo =  [-3.47609134 -2.00146979]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.0014697944141755, 1.9337765439503016]
# Iteracao =  144
# Otimo =  [-2.00146979  1.93377654]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.9337765439503016, 4.3189882344675485]
# Iteracao =  145
# Otimo =  [1.93377654 4.31898823]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.3189882344675485, 2.4431894619777497]
# Iteracao =  146
# Otimo =  [4.31898823 2.44318946]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.4431894619777497, 0.531983130586406]
# Iteracao =  147
# Otimo =  [2.44318946 0.53198313]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.531983130586406, -4.724842610700071]
# Iteracao =  148
# Otimo =  [ 0.53198313 -4.72484261]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.724842610700071, -0.4507194235097467]
# Iteracao =  149
# Otimo =  [-4.72484261 -0.45071942]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.4507194235097467, 1.4753690093367755]
# Iteracao =  150
# Otimo =  [-0.45071942  1.47536901]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.4753690093367755, 3.2667818133628987]
# Iteracao =  151
# Otimo =  [1.47536901 3.26678181]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.2667818133628987, -2.155046951857295]
# Iteracao =  152
# Otimo =  [ 3.26678181 -2.15504695]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.155046951857295, -3.962851908858225]
# Iteracao =  153
# Otimo =  [-2.15504695 -3.96285191]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.962851908858225, 3.6561031772612687]
# Iteracao =  154
# Otimo =  [-3.96285191  3.65610318]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.6561031772612687, 4.407765870802871]
# Iteracao =  155
# Otimo =  [3.65610318 4.40776587]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.407765870802871, -2.0828668100006773]
# Iteracao =  156
# Otimo =  [ 4.40776587 -2.08286681]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.0828668100006773, 3.8726420308638847]
# Iteracao =  157
# Otimo =  [-2.08286681  3.87264203]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.8726420308638847, 3.1738435823835367]
# Iteracao =  158
# Otimo =  [3.87264203 3.17384358]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.1738435823835367, 0.647912789590209]
# Iteracao =  159
# Otimo =  [3.17384358 0.64791279]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.647912789590209, -3.8067698045277867]
# Iteracao =  160
# Otimo =  [ 0.64791279 -3.8067698 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.8067698045277867, 0.8727484563707035]
# Iteracao =  161
# Otimo =  [-3.8067698   0.87274846]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.8727484563707035, 1.2575008225350928]
# Iteracao =  162
# Otimo =  [0.87274846 1.25750082]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.2575008225350928, -0.6492174349978628]
# Iteracao =  163
# Otimo =  [ 1.25750082 -0.64921743]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.6492174349978628, -3.1383940228713314]
# Iteracao =  164
# Otimo =  [-0.64921743 -3.13839402]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.1383940228713314, -0.8162874329690215]
# Iteracao =  165
# Otimo =  [-3.13839402 -0.81628743]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.8162874329690215, -2.1569434475751526]
# Iteracao =  166
# Otimo =  [-0.81628743 -2.15694345]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.1569434475751526, -4.364868454505599]
# Iteracao =  167
# Otimo =  [-2.15694345 -4.36486845]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.364868454505599, 4.616674560033687]
# Iteracao =  168
# Otimo =  [-4.36486845  4.61667456]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.616674560033687, -1.4137976908041505]
# Iteracao =  169
# Otimo =  [ 4.61667456 -1.41379769]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.4137976908041505, 1.8690325455513843]
# Iteracao =  170
# Otimo =  [-1.41379769  1.86903255]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.8690325455513843, -3.951395881518829]
# Iteracao =  171
# Otimo =  [ 1.86903255 -3.95139588]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.951395881518829, -2.3238786727746605]
# Iteracao =  172
# Otimo =  [-3.95139588 -2.32387867]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.3238786727746605, -4.456908625318322]
# Iteracao =  173
# Otimo =  [-2.32387867 -4.45690863]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.456908625318322, 1.4332001179055265]
# Iteracao =  174
# Otimo =  [-4.45690863  1.43320012]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [1.4332001179055265, 4.843202143480841]
# Iteracao =  175
# Otimo =  [1.43320012 4.84320214]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.843202143480841, -2.3293937542594536]
# Iteracao =  176
# Otimo =  [ 4.84320214 -2.32939375]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.3293937542594536, -0.37322286804431837]
# Iteracao =  177
# Otimo =  [-2.32939375 -0.37322287]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.37322286804431837, -0.6325661161387437]
# Iteracao =  178
# Otimo =  [-0.37322287 -0.63256612]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.6325661161387437, -0.8823396260041063]
# Iteracao =  179
# Otimo =  [-0.63256612 -0.88233963]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.8823396260041063, -4.003299061980434]
# Iteracao =  180
# Otimo =  [-0.88233963 -4.00329906]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-4.003299061980434, -2.5781736385585274]
# Iteracao =  181
# Otimo =  [-4.00329906 -2.57817364]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.5781736385585274, 4.690315395030241]
# Iteracao =  182
# Otimo =  [-2.57817364  4.6903154 ]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.690315395030241, -3.410072510309022]
# Iteracao =  183
# Otimo =  [ 4.6903154  -3.41007251]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.410072510309022, 3.082327126110618]
# Iteracao =  184
# Otimo =  [-3.41007251  3.08232713]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.082327126110618, -0.4183044363479844]
# Iteracao =  185
# Otimo =  [ 3.08232713 -0.41830444]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.4183044363479844, -1.0653025552049753]
# Iteracao =  186
# Otimo =  [-0.41830444 -1.06530256]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-1.0653025552049753, 0.3998834755033842]
# Iteracao =  187
# Otimo =  [-1.06530256  0.39988348]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.3998834755033842, 3.2215373774239087]
# Iteracao =  188
# Otimo =  [0.39988348 3.22153738]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.2215373774239087, 3.8302417465285163]
# Iteracao =  189
# Otimo =  [3.22153738 3.83024175]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.8302417465285163, -0.9871209100172287]
# Iteracao =  190
# Otimo =  [ 3.83024175 -0.98712091]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-0.9871209100172287, 2.473463460691522]
# Iteracao =  191
# Otimo =  [-0.98712091  2.47346346]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [2.473463460691522, -2.868917632713476]
# Iteracao =  192
# Otimo =  [ 2.47346346 -2.86891763]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-2.868917632713476, 4.692913453453288]
# Iteracao =  193
# Otimo =  [-2.86891763  4.69291345]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [4.692913453453288, 0.32656185964569673]
# Iteracao =  194
# Otimo =  [4.69291345 0.32656186]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [0.32656185964569673, -3.712353961040027]
# Iteracao =  195
# Otimo =  [ 0.32656186 -3.71235396]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [-3.712353961040027, 3.0232583865666136]
# Iteracao =  196
# Otimo =  [-3.71235396  3.02325839]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.0232583865666136, 3.3637949620121272]
# Iteracao =  197
# Otimo =  [3.02325839 3.36379496]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.3637949620121272, 3.8079479913980716]
# Iteracao =  198
# Otimo =  [3.36379496 3.80794799]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------
# [3.8079479913980716, 3.813352121375498]
# Iteracao =  199
# Otimo =  [3.80794799 3.81335212]
# Iteracoes =  1
# Criterio =  Erro x Norma Gradiente Erro F
# ---------------

# %%
from matplotlib import animation
from matplotlib.animation import PillowWriter

def animate(i):
    xs = np.linspace(-5,5,200)
    ln1.set_data(xs, np.absolute(psi_g[0:200,i-1])**2)
    ln2.set_data(xs, np.absolute(psiExato[0:200,i-1])**2)
    time_text.set_text('$t=$'+'{:.1f}'.format(i/100))
    
fig, ax = plt.subplots(1, 1,figsize=(8,4))
ax.grid()
ln1, = plt.plot([], [], 'r-', lw=2, markersize=8, label='Curva')
ln2, = plt.plot([], [], 'b-', lw=2, markersize=8, label='Ideal')
time_text = ax.text(0.85, 1, '', fontsize=15,
           bbox=dict(facecolor='white', edgecolor='black'))
ax.set_ylim(0, 1)
ax.set_xlim(-5,5)
title = ax.set_title('Resposta analítica')
ax.set_ylabel('$|\psi(x)|^2$', fontsize=20)
ax.set_xlabel('$x$', fontsize=20)
ax.legend(loc='upper left')
ax.set_title('')
plt.tight_layout()
ani = animation.FuncAnimation(fig, animate, frames=200, interval=200)
ani.save('200x200.gif',writer='pillow',fps=10,dpi=100)

# %%
plt.plot(xs, np.absolute(psi_g[0:200,0:10])**2)
# Out:
# [<matplotlib.lines.Line2D at 0x7f1882439460>,
#  <matplotlib.lines.Line2D at 0x7f18824394c0>,
#  <matplotlib.lines.Line2D at 0x7f18824395e0>,
#  <matplotlib.lines.Line2D at 0x7f1882439700>,
#  <matplotlib.lines.Line2D at 0x7f1882439820>,
#  <matplotlib.lines.Line2D at 0x7f1882439940>,
#  <matplotlib.lines.Line2D at 0x7f1882439a60>,
#  <matplotlib.lines.Line2D at 0x7f1882439b80>,
#  <matplotlib.lines.Line2D at 0x7f1882439ca0>,
#  <matplotlib.lines.Line2D at 0x7f1882439dc0>]
